# %%
from __future__ import print_function
import mackinac
import cobra
from cobra import Model, Reaction, Metabolite
from cobra.core.model import copy
import os
from os.path import join
from cobra.flux_analysis.parsimonious import add_pfba
import sys
from cobra.util.solver import linear_reaction_coefficients
from optlang.interface import OPTIMAL
from itertools import chain
from optlang.symbolics import Zero
from cobra.util import solver as sutil
from cobra.core.solution import get_solution

# %%
# Create a profile on PATRIC https://www.patricbrc.org/
# I highly suggest you use PATRIC rather than ModelSEED directly, it allows for gathering more 
# information about your microbe of interest. You'll probably want to start with an array of
# different strains all from the same species you are interested in. We can talk more about this
# idea during a call. 
username = 'tjmoutinho'
mackinac.get_token(username) # Use your PATRIC database username here
# Out:
# patric password: ········
# u'tjmoutinho@patricbrc.org'

# %%
genome_id = '405948.11'

# %%
## Only run this once to limit any confusion later on.
## Check to make sure it completes on your PATRIC profile: www.patricbrc.org/job/
## If it failes to complete, just run it again until it completes. 

mackinac.create_patric_model(genome_id,genome_id)
# Out:
# {'fba_count': 0,
#  'gapfilled_reactions': 110,
#  'gene_associated_reactions': 1351,
#  'genome_ref': u'/tjmoutinho@patricbrc.org/home/models/.405948.11/genome',
#  'id': u'405948.11',
#  'integrated_gapfills': 1,
#  'name': u'Saccharopolyspora erythraea NRRL 2338',
#  'num_biomass_compounds': 85,
#  'num_biomasses': 1,
#  'num_compartments': 2,
#  'num_compounds': 1598,
#  'num_genes': 1165,
#  'num_reactions': 1461,
#  'ref': u'/tjmoutinho@patricbrc.org/home/models/.405948.11',
#  'rundate': u'2019-02-05T17:11:43Z',
#  'source': u'PATRIC',
#  'source_id': u'.405948.11',
#  'template_ref': u'/chenry/public/modelsupport/templates/GramNegative.modeltemplate',
#  'type': u'GenomeScale',
#  'unintegrated_gapfills': 0}

# %%
model = mackinac.create_cobra_model_from_patric_model(genome_id)

# %%
# I wouldn't suggest you worry about the charge imbalanced reactions for right now.
# The code you sent had a useless 'validation' section that didn't remove the exchange reactions
# before checking for imbalances. All EX_ (exchange), SK_ (sink), and DM_ (demand) reactions are
# by nature imbalanced, this is how it should be. 

imbalanced_reactions = []
for rxn in model.reactions:
    if not rxn.id.startswith('EX') | rxn.id.startswith('bio1') | rxn.id.startswith('SK'):
        rxn_mass_dict = rxn.check_mass_balance()
        if bool(rxn_mass_dict) == True:
            imbalanced_reactions.append([rxn,rxn_mass_dict])
imbalanced_reactions
# Out:
# [[<Reaction rxn05404_c at 0x7f9bc982edd0>, {'charge': 1.0}],
#  [<Reaction rxn05444_c at 0x7f9bc9841610>, {'charge': -1.0}],
#  [<Reaction rxn05459_c at 0x7f9bc98062d0>, {'charge': -1.0}],
#  [<Reaction rxn05453_c at 0x7f9bc9806310>, {'charge': -1.0}],
#  [<Reaction rxn05350_c at 0x7f9bc975eb50>, {'charge': -1.0}],
#  [<Reaction rxn05358_c at 0x7f9bc9772590>, {'charge': 1.0}],
#  [<Reaction rxn05437_c at 0x7f9bc9772a50>, {'charge': -1.0}],
#  [<Reaction rxn05408_c at 0x7f9bc9772f50>, {'charge': 1.0}],
#  [<Reaction rxn05324_c at 0x7f9bc978bb90>, {'charge': -1.0}],
#  [<Reaction rxn05458_c at 0x7f9bc9660890>, {'charge': -1.0}],
#  [<Reaction rxn05450_c at 0x7f9bc9675750>, {'charge': -1.0}],
#  [<Reaction rxn05443_c at 0x7f9bc9675f50>, {'charge': -1.0}],
#  [<Reaction rxn05359_c at 0x7f9bc95f4b10>, {'charge': 1.0}],
#  [<Reaction rxn05327_c at 0x7f9bc95b3150>, {'charge': -1.0}],
#  [<Reaction rxn00082_c at 0x7f9bc954ea50>, {'charge': 4.0}],
#  [<Reaction rxn07578_c at 0x7f9bc954ec50>,
#   {'C': 11.0, 'H': 21.0, 'N': 2.0, 'O': 7.0, 'P': 1.0, 'charge': -2.0}],
#  [<Reaction rxn05322_c at 0x7f9bc93f4350>, {'charge': -2.0}],
#  [<Reaction rxn05429_c at 0x7f9bc93312d0>, {'charge': 1.0}],
#  [<Reaction rxn05452_c at 0x7f9bc9260750>, {'charge': -1.0}],
#  [<Reaction rxn05409_c at 0x7f9bc920a710>, {'charge': 1.0}],
#  [<Reaction rxn06723_c at 0x7f9bc920a890>, {'charge': -2.0}],
#  [<Reaction rxn04750_c at 0x7f9bc915df10>, {'charge': -4.0}],
#  [<Reaction rxn07295_c at 0x7f9bc9189550>, {'charge': 2.0}],
#  [<Reaction rxn05451_c at 0x7f9bc90dc750>, {'charge': -1.0}],
#  [<Reaction rxn05460_c at 0x7f9bc910a790>, {'charge': 1.0}],
#  [<Reaction rxn05455_c at 0x7f9bc7cdca50>, {'charge': -1.0}],
#  [<Reaction rxn05379_c at 0x7f9bc7a90d50>, {'charge': 1.0}],
#  [<Reaction rxn05454_c at 0x7f9bc7aba850>, {'charge': -1.0}],
#  [<Reaction rxn05449_c at 0x7f9bc7acb550>, {'charge': -1.0}],
#  [<Reaction rxn08808_c at 0x7f9bc7a225d0>, {'charge': -2.0}],
#  [<Reaction rxn05323_c at 0x7f9bc7a3a750>, {'charge': 1.0}],
#  [<Reaction rxn05438_c at 0x7f9bc7a4ee90>, {'charge': -1.0}],
#  [<Reaction rxn05384_c at 0x7f9bc79bd910>, {'charge': 1.0}],
#  [<Reaction rxn05326_c at 0x7f9bc7912490>, {'charge': -1.0}],
#  [<Reaction rxn05464_c at 0x7f9bc78e8190>, {'charge': -1.0}],
#  [<Reaction rxn05456_c at 0x7f9bc78a4610>, {'charge': -1.0}],
#  [<Reaction rxn05383_c at 0x7f9bc7851910>, {'charge': 1.0}],
#  [<Reaction rxn06023_c at 0x7f9bc786d150>, {'charge': -2.0}],
#  [<Reaction rxn06729_c at 0x7f9bc786d590>, {'charge': -2.0}],
#  [<Reaction rxn08708_c at 0x7f9bc786d990>, {'charge': 2.0}],
#  [<Reaction rxn05335_c at 0x7f9bc786db50>, {'charge': 1.0}],
#  [<Reaction rxn08710_c at 0x7f9bc788a450>, {'charge': -2.0}]]

# %%
model.reactions.get_by_id('rxn07578_c')
# Out:
# <Reaction rxn07578_c at 0x7f9bc954ec50>

# %%
# List of Genomic Features from PATRIC
feature_list = mackinac.get_genome_features(genome_id, annotation='PATRIC')

# %%
feature_list
# Out:
# [{u'aa_length': 304,
#   u'aa_sequence_md5': u'cd77eb5fff7b05f349d932b183b23e0d',
#   u'accession': u'NC_009142',
#   u'alt_locus_tag': u'VBISacEry28377_6275',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2014-10-21T03:28:32.203Z',
#   u'date_modified': u'2014-10-27T11:56:20.149Z',
#   u'end': 7048535,
#   u'feature_id': u'PATRIC.405948.11.NC_009142.CDS.7047621.7048535.rev',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00000582',
#   u'gene': u'thrB',
#   u'gene_id': 4946027,
#   u'genome_id': u'405948.11',
#   u'genome_name': u'Saccharopolyspora erythraea NRRL 2338',
#   u'go': [u'GO:0004413|homoserine kinase activity'],
#   u'location': u'complement(7047621..7048535)',
#   u'na_length': 915,
#   u'na_sequence_md5': u'f90eecbd19e91981aaea5c6f3274eebf',
#   u'owner': u'PATRIC',
#   u'p2_feature_id': 23419976,
#   u'patric_id': u'fig|405948.11.peg.6275',
#   u'pgfam_id': u'PGF_00012356',
#   u'plfam_id': u'PLF_1835_00000662',
#   u'product': u'Homoserine kinase (EC 2.7.1.39)',
#   u'property': [u'EC number', u'Pathway', u'Subsystem'],
#   u'protein_id': u'YP_001108393.1',
#   u'public': True,
#   u'refseq_locus_tag': u'SACE_6296',
#   u'segments': [u'7047621..7048535'],
#   u'sequence_id': u'NC_009142',
#   u'start': 7047621,
#   u'strand': u'-',
#   u'taxon_id': 405948},
#  {u'aa_length': 391,
#   u'aa_sequence_md5': u'6e07f72ff42b84a5e94614d20837c9d6',
#   u'accession': u'NC_009142',
#   u'alt_locus_tag': u'VBISacEry28377_0941',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2014-10-21T02:16:15.797Z',
#   u'date_modified': u'2014-10-27T11:56:20.149Z',
#   u'end': 1049567,
#   u'feature_id': u'PATRIC.405948.11.NC_009142.CDS.1048392.1049567.rev',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00000323',
#   u'gene': u'xseA',
#   u'gene_id': 4940795,
#   u'genome_id': u'405948.11',
#   u'genome_name': u'Saccharopolyspora erythraea NRRL 2338',
#   u'go': [u'GO:0008855|exodeoxyribonuclease VII activity'],
#   u'location': u'complement(1048392..1049567)',
#   u'na_length': 1176,
#   u'na_sequence_md5': u'ce468bbca6a29c87ce8233a56fb8ac5e',
#   u'owner': u'PATRIC',
#   u'p2_feature_id': 23409250,
#   u'patric_id': u'fig|405948.11.peg.941',
#   u'pgfam_id': u'PGF_00425024',
#   u'plfam_id': u'PLF_1835_00001008',
#   u'product': u'Exodeoxyribonuclease VII large subunit (EC 3.1.11.6)',
#   u'property': [u'EC number', u'Subsystem'],
#   u'protein_id': u'YP_001103196.1',
#   u'public': True,
#   u'refseq_locus_tag': u'SACE_0937',
#   u'segments': [u'1048392..1049567'],
#   u'sequence_id': u'NC_009142',
#   u'start': 1048392,
#   u'strand': u'-',
#   u'taxon_id': 405948},
#  {u'aa_length': 260,
#   u'aa_sequence_md5': u'6fd5e5790846205e4e81f89cf6841a15',
#   u'accession': u'NC_009142',
#   u'alt_locus_tag': u'VBISacEry28377_6576',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2014-10-21T03:15:55.938Z',
#   u'date_modified': u'2014-10-27T11:56:20.149Z',
#   u'end': 7382472,
#   u'feature_id': u'PATRIC.405948.11.NC_009142.CDS.7381690.7382472.fwd',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00026006',
#   u'gene': u'sdhB',
#   u'gene_id': 4946316,
#   u'genome_id': u'405948.11',
#   u'genome_name': u'Saccharopolyspora erythraea NRRL 2338',
#   u'go': [u'GO:0008177|succinate dehydrogenase (ubiquinone) activity'],
#   u'location': u'7381690..7382472',
#   u'na_length': 783,
#   u'na_sequence_md5': u'acad6f5c78fd773d6808b92d8b6ab06a',
#   u'owner': u'PATRIC',
#   u'p2_feature_id': 23420586,
#   u'patric_id': u'fig|405948.11.peg.6576',
#   u'pgfam_id': u'PGF_00054480',
#   u'plfam_id': u'PLF_1835_00002299',
#   u'product': u'Succinate dehydrogenase iron-sulfur protein (EC 1.3.5.1)',
#   u'property': [u'EC number', u'Pathway', u'Subsystem'],
#   u'protein_id': u'YP_001108677.1',
#   u'public': True,
#   u'refseq_locus_tag': u'SACE_6585',
#   u'segments': [u'7381690..7382472'],
#   u'sequence_id': u'NC_009142',
#   u'start': 7381690,
#   u'strand': u'+',
#   u'taxon_id': 405948},
#  {u'aa_length': 461,
#   u'aa_sequence_md5': u'e6929365a47787d2892842e83e8e7a7d',
#   u'accession': u'NC_009142',
#   u'alt_locus_tag': u'VBISacEry28377_7314',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2014-10-21T05:06:26.097Z',
#   u'date_modified': u'2014-10-27T11:56:20.149Z',
#   u'end': 8103991,
#   u'feature_id': u'PATRIC.405948.11.NC_009142.CDS.8102606.8103991.fwd',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00136675',
#   u'gene': u'bkdC1',
#   u'gene_id': 4947028,
#   u'genome_id': u'405948.11',
#   u'genome_name': u'Saccharopolyspora erythraea NRRL 2338',
#   u'go': [u'GO:0043754|dihydrolipoyllysine-residue (2-methylpropanoyl)transferase activity'],
#   u'location': u'8102606..8103991',
#   u'na_length': 1386,
#   u'na_sequence_md5': u'e32fa9567d4022744c7d412c34787214',
#   u'owner': u'PATRIC',
#   u'p2_feature_id': 23422082,
#   u'patric_id': u'fig|405948.11.peg.7314',
#   u'pgfam_id': u'PGF_01797166',
#   u'plfam_id': u'PLF_1835_00000309',
#   u'product': u'Dihydrolipoamide acyltransferase component of branched-chain alpha-keto acid dehydrogenase complex (EC 2.3.1.168)',
#   u'property': [u'EC number', u'Pathway', u'Subsystem'],
#   u'protein_id': u'YP_001109379.1',
#   u'public': True,
#   u'refseq_locus_tag': u'SACE_7296',
#   u'segments': [u'8102606..8103991'],
#   u'sequence_id': u'NC_009142',
#   u'start': 8102606,
#   u'strand': u'+',
#   u'taxon_id': 405948},
#  {u'aa_length': 122,
#   u'aa_sequence_md5': u'21734e5ab880825bc0a50893643b5a7f',
#   u'accession': u'NC_009142',
#   u'alt_locus_tag': u'VBISacEry28377_6831',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2014-10-21T05:16:59.513Z',
#   u'date_modified': u'2014-10-27T11:56:20.149Z',
#   u'end': 7626737,
#   u'feature_id': u'PATRIC.405948.11.NC_009142.CDS.7626369.7626737.rev',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00090781',
#   u'gene': u'rplN',
#   u'gene_id': 4946555,
#   u'genome_id': u'405948.11',
#   u'genome_name': u'Saccharopolyspora erythraea NRRL 2338',
#   u'go': [u'GO:0003735|structural constituent of ribosome',
#    u'GO:0005622|intracellular',
#    u'GO:0005840|ribosome',
#    u'GO:0006412|translation'],
#   u'location': u'complement(7626369..7626737)',
#   u'na_length': 369,
#   u'na_sequence_md5': u'a5753519ba2365828aee88f447d9ab41',
#   u'owner': u'PATRIC',
#   u'p2_feature_id': 23421098,
#   u'patric_id': u'fig|405948.11.peg.6831',
#   u'pgfam_id': u'PGF_00016340',
#   u'plfam_id': u'PLF_1835_00000736',
#   u'product': u'LSU ribosomal protein L14p (L23e)',
#   u'property': [u'Subsystem'],
#   u'protein_id': u'YP_001108915.1',
#   u'public': True,
#   u'refseq_locus_tag': u'SACE_6826',
#   u'segments': [u'7626369..7626737'],
#   u'sequence_id': u'NC_009142',
#   u'start': 7626369,
#   u'strand': u'-',
#   u'taxon_id': 405948},
#  {u'aa_length': 620,
#   u'aa_sequence_md5': u'df466ebf0c92126435f88b7fe5bf0414',
#   u'accession': u'NC_009142',
#   u'alt_locus_tag': u'VBISacEry28377_5903',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2014-10-21T05:06:15.902Z',
#   u'date_modified': u'2014-10-27T11:56:20.149Z',
#   u'end': 6664733,
#   u'feature_id': u'PATRIC.405948.11.NC_009142.CDS.6662871.6664733.rev',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00000069',
#   u'gene': u'proS,pro',
#   u'gene_id': 4945675,
#   u'genome_id': u'405948.11',
#   u'genome_name': u'Saccharopolyspora erythraea NRRL 2338',
#   u'go': [u'GO:0004827|proline-tRNA ligase activity'],
#   u'location': u'complement(6662871..6664733)',
#   u'na_length': 1863,
#   u'na_sequence_md5': u'cf2367aa1443bf1df1463e2ab600df10',
#   u'owner': u'PATRIC',
#   u'p2_feature_id': 23419226,
#   u'patric_id': u'fig|405948.11.peg.5903',
#   u'pgfam_id': u'PGF_00037588',
#   u'plfam_id': u'PLF_1835_00001316',
#   u'product': u'Prolyl-tRNA synthetase (EC 6.1.1.15), bacterial type',
#   u'property': [u'EC number', u'Pathway', u'Subsystem'],
#   u'protein_id': u'YP_001108044.1',
#   u'public': True,
#   u'refseq_locus_tag': u'SACE_5936',
#   u'segments': [u'6662871..6664733'],
#   u'sequence_id': u'NC_009142',
#   u'start': 6662871,
#   u'strand': u'-',
#   u'taxon_id': 405948},
#  {u'aa_length': 305,
#   u'aa_sequence_md5': u'9323ccc06253f892f88fbfa48af1e445',
#   u'accession': u'NC_009142',
#   u'alt_locus_tag': u'VBISacEry28377_2018',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2014-10-21T05:27:05.023Z',
#   u'date_modified': u'2014-10-27T11:56:20.149Z',
#   u'end': 2196893,
#   u'feature_id': u'PATRIC.405948.11.NC_009142.CDS.2195976.2196893.fwd',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00021445',
#   u'gene': u'pdx1',
#   u'gene_id': 4941867,
#   u'genome_id': u'405948.11',
#   u'genome_name': u'Saccharopolyspora erythraea NRRL 2338',
#   u'go': [u"GO:0036381|pyridoxal 5'-phosphate synthase (glutamine hydrolysing) activity"],
#   u'location': u'2195976..2196893',
#   u'na_length': 918,
#   u'na_sequence_md5': u'4c0ad313ba1d94fd59caee26e8d3f26f',
#   u'owner': u'PATRIC',
#   u'p2_feature_id': 23411446,
#   u'patric_id': u'fig|405948.11.peg.2018',
#   u'pgfam_id': u'PGF_00045788',
#   u'plfam_id': u'PLF_1835_00001393',
#   u'product': u"Pyridoxal 5'-phosphate synthase (glutamine hydrolyzing), synthase subunit (EC 4.3.3.6)",
#   u'property': [u'EC number', u'Subsystem'],
#   u'protein_id': u'YP_001104244.1',
#   u'public': True,
#   u'refseq_locus_tag': u'SACE_2009',
#   u'segments': [u'2195976..2196893'],
#   u'sequence_id': u'NC_009142',
#   u'start': 2195976,
#   u'strand': u'+',
#   u'taxon_id': 405948},
#  {u'aa_length': 395,
#   u'aa_sequence_md5': u'60c3addb9b9866735745b6831aa5bbf0',
#   u'accession': u'NC_009142',
#   u'alt_locus_tag': u'VBISacEry28377_0164',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2014-10-21T05:45:52.722Z',
#   u'date_modified': u'2014-10-27T11:56:20.149Z',
#   u'end': 193185,
#   u'feature_id': u'PATRIC.405948.11.NC_009142.CDS.191998.193185.fwd',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00003472',
#   u'gene': u'glf',
#   u'gene_id': 4940029,
#   u'genome_id': u'405948.11',
#   u'genome_name': u'Saccharopolyspora erythraea NRRL 2338',
#   u'go': [u'GO:0008767|UDP-galactopyranose mutase activity'],
#   u'location': u'191998..193185',
#   u'na_length': 1188,
#   u'na_sequence_md5': u'a109d4d7c861202442ca6321fe54aa50',
#   u'owner': u'PATRIC',
#   u'p2_feature_id': 23407672,
#   u'patric_id': u'fig|405948.11.peg.164',
#   u'pgfam_id': u'PGF_00064046',
#   u'plfam_id': u'PLF_1835_00000423',
#   u'product': u'UDP-galactopyranose mutase (EC 5.4.99.9)',
#   u'property': [u'EC number', u'Subsystem'],
#   u'protein_id': u'YP_001102443.1',
#   u'public': True,
#   u'refseq_locus_tag': u'SACE_0165',
#   u'segments': [u'191998..193185'],
#   u'sequence_id': u'NC_009142',
#   u'start': 191998,
#   u'strand': u'+',
#   u'taxon_id': 405948},
#  {u'aa_length': 281,
#   u'aa_sequence_md5': u'bf37560c576666137d725436e2f488a2',
#   u'accession': u'NC_009142',
#   u'alt_locus_tag': u'VBISacEry28377_2410',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2014-10-20T20:32:15.756Z',
#   u'date_modified': u'2014-10-27T11:56:20.149Z',
#   u'end': 2617431,
#   u'feature_id': u'PATRIC.405948.11.NC_009142.CDS.2616586.2617431.fwd',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00002587',
#   u'gene_id': 4942259,
#   u'genome_id': u'405948.11',
#   u'genome_name': u'Saccharopolyspora erythraea NRRL 2338',
#   u'location': u'2616586..2617431',
#   u'na_length': 846,
#   u'na_sequence_md5': u'9d7b58f58fcc85524ca75cc05d4edfa6',
#   u'owner': u'PATRIC',
#   u'p2_feature_id': 23412232,
#   u'patric_id': u'fig|405948.11.peg.2410',
#   u'pgfam_id': u'PGF_00004652',
#   u'plfam_id': u'PLF_1835_00002107',
#   u'product': u'Ferrous iron transport permease EfeU',
#   u'property': [u'Subsystem'],
#   u'protein_id': u'YP_001104635.1',
#   u'public': True,
#   u'refseq_locus_tag': u'SACE_2412',
#   u'segments': [u'2616586..2617431'],
#   u'sequence_id': u'NC_009142',
#   u'start': 2616586,
#   u'strand': u'+',
#   u'taxon_id': 405948},
#  {u'aa_length': 66,
#   u'aa_sequence_md5': u'bf7d3dff3062a6a38e1fef5757e78352',
#   u'accession': u'NC_009142',
#   u'alt_locus_tag': u'VBISacEry28377_6099',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2014-10-21T02:50:08.634Z',
#   u'date_modified': u'2014-10-27T11:56:20.149Z',
#   u'end': 6870110,
#   u'feature_id': u'PATRIC.405948.11.NC_009142.CDS.6869910.6870110.fwd',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00000266',
#   u'gene': u'rpmB',
#   u'gene_id': 4945852,
#   u'genome_id': u'405948.11',
#   u'genome_name': u'Saccharopolyspora erythraea NRRL 2338',
#   u'location': u'6869910..6870110',
#   u'na_length': 201,
#   u'na_sequence_md5': u'02c195d9249a246d63347b97a3c34aa1',
#   u'owner': u'PATRIC',
#   u'p2_feature_id': 23419618,
#   u'patric_id': u'fig|405948.11.peg.6099',
#   u'pgfam_id': u'PGF_00016387',
#   u'plfam_id': u'PLF_1835_00000911',
#   u'product': u'LSU ribosomal protein L28p @ LSU ribosomal protein L28p, zinc-dependent',
#   u'property': [u'Subsystem'],
#   u'protein_id': u'YP_001108221.1',
#   u'public': True,
#   u'refseq_locus_tag': u'SACE_6123',
#   u'segments': [u'6869910..6870110'],
#   u'sequence_id': u'NC_009142',
#   u'start': 6869910,
#   u'strand': u'+',
#   u'taxon_id': 405948},
#  {u'aa_length': 119,
#   u'aa_sequence_md5': u'd06cba8a8e60898036490ff4996cf1fc',
#   u'accession': u'NC_009142',
#   u'alt_locus_tag': u'VBISacEry28377_6021',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2014-10-21T02:33:02.734Z',
#   u'date_modified': u'2014-10-27T11:56:20.149Z',
#   u'end': 6786354,
#   u'feature_id': u'PATRIC.405948.11.NC_009142.CDS.6785995.6786354.rev',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00000214',
#   u'gene': u'rplS',
#   u'gene_id': 4945778,
#   u'genome_id': u'405948.11',
#   u'genome_name': u'Saccharopolyspora erythraea NRRL 2338',
#   u'go': [u'GO:0003735|structural constituent of ribosome',
#    u'GO:0005622|intracellular',
#    u'GO:0005840|ribosome',
#    u'GO:0006412|translation'],
#   u'location': u'complement(6785995..6786354)',
#   u'na_length': 360,
#   u'na_sequence_md5': u'a87803ce70bde585f49125b9144cacd0',
#   u'owner': u'PATRIC',
#   u'p2_feature_id': 23419462,
#   u'patric_id': u'fig|405948.11.peg.6021',
#   u'pgfam_id': u'PGF_04845029',
#   u'plfam_id': u'PLF_1835_00000902',
#   u'product': u'LSU ribosomal protein L19p',
#   u'property': [u'Subsystem'],
#   u'protein_id': u'YP_001108147.1',
#   u'public': True,
#   u'refseq_locus_tag': u'SACE_6049',
#   u'segments': [u'6785995..6786354'],
#   u'sequence_id': u'NC_009142',
#   u'start': 6785995,
#   u'strand': u'-',
#   u'taxon_id': 405948},
#  {u'aa_length': 295,
#   u'aa_sequence_md5': u'409a10d87645d20e29f03de65d2e6e2c',
#   u'accession': u'NC_009142',
#   u'alt_locus_tag': u'VBISacEry28377_5972',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2014-10-21T05:28:33.218Z',
#   u'date_modified': u'2014-10-27T11:56:20.149Z',
#   u'end': 6732742,
#   u'feature_id': u'PATRIC.405948.11.NC_009142.CDS.6731855.6732742.fwd',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG01849403',
#   u'gene': u'hur',
#   u'gene_id': 4945733,
#   u'genome_id': u'405948.11',
#   u'genome_name': u'Saccharopolyspora erythraea NRRL 2338',
#   u'go': [u'GO:0050300|aminoglycoside 6-kinase activity'],
#   u'location': u'6731855..6732742',
#   u'na_length': 888,
#   u'na_sequence_md5': u'5657b444d7224a765f97633465ea79ce',
#   u'owner': u'PATRIC',
#   u'p2_feature_id': 23419364,
#   u'patric_id': u'fig|405948.11.peg.5972',
#   u'pgfam_id': u'PGF_05600488',
#   u'plfam_id': u'PLF_1835_00003803',
#   u'product': u'Aminoglycoside 6-phosphotransferase (EC 2.7.1.72) => APH(6)-Ia/APH(6)-Ib',
#   u'property': [u'EC number', u'Pathway', u'Subsystem'],
#   u'protein_id': u'YP_001108102.1',
#   u'public': True,
#   u'refseq_locus_tag': u'SACE_5997',
#   u'segments': [u'6731855..6732742'],
#   u'sequence_id': u'NC_009142',
#   u'start': 6731855,
#   u'strand': u'+',
#   u'taxon_id': 405948},
#  {u'aa_length': 261,
#   u'aa_sequence_md5': u'bde3652abbacee006787bd47448284d5',
#   u'accession': u'NC_009142',
#   u'alt_locus_tag': u'VBISacEry28377_0368',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2014-10-21T04:22:24.895Z',
#   u'date_modified': u'2014-10-27T11:56:20.149Z',
#   u'end': 403222,
#   u'feature_id': u'PATRIC.405948.11.NC_009142.CDS.402437.403222.rev',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00000149',
#   u'gene_id': 4940231,
#   u'genome_id': u'405948.11',
#   u'genome_name': u'Saccharopolyspora erythraea NRRL 2338',
#   u'go': [u'GO:0004647|phosphoserine phosphatase activity'],
#   u'location': u'complement(402437..403222)',
#   u'na_length': 786,
#   u'na_sequence_md5': u'0b73eb7d69f7e5871c9fdd623f791567',
#   u'owner': u'PATRIC',
#   u'p2_feature_id': 23408092,
#   u'patric_id': u'fig|405948.11.peg.368',
#   u'pgfam_id': u'PGF_03116802',
#   u'plfam_id': u'PLF_1835_00002220',
#   u'product': u'Phosphoserine phosphatase (EC 3.1.3.3)',
#   u'property': [u'EC number', u'Pathway', u'Subsystem'],
#   u'protein_id': u'YP_001102639.1',
#   u'public': True,
#   u'refseq_locus_tag': u'SACE_0365',
#   u'segments': [u'402437..403222'],
#   u'sequence_id': u'NC_009142',
#   u'start': 402437,
#   u'strand': u'-',
#   u'taxon_id': 405948},
#  {u'aa_length': 1110,
#   u'aa_sequence_md5': u'f3ef3ccfc57fd73b283d14263f06d1be',
#   u'accession': u'NC_009142',
#   u'alt_locus_tag': u'VBISacEry28377_2090',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2014-10-21T04:57:04.853Z',
#   u'date_modified': u'2014-10-27T11:56:20.149Z',
#   u'end': 2271871,
#   u'feature_id': u'PATRIC.405948.11.NC_009142.CDS.2268539.2271871.fwd',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00000111',
#   u'gene': u'carB',
#   u'gene_id': 4941938,
#   u'genome_id': u'405948.11',
#   u'genome_name': u'Saccharopolyspora erythraea NRRL 2338',
#   u'go': [u'GO:0004088|carbamoyl-phosphate synthase (glutamine-hydrolyzing) activity'],
#   u'location': u'2268539..2271871',
#   u'na_length': 3333,
#   u'na_sequence_md5': u'c1b7171bfdc14140a7111544c60e0668',
#   u'owner': u'PATRIC',
#   u'p2_feature_id': 23411590,
#   u'patric_id': u'fig|405948.11.peg.2090',
#   u'pgfam_id': u'PGF_00416410',
#   u'plfam_id': u'PLF_1835_00000365',
#   u'product': u'Carbamoyl-phosphate synthase large chain (EC 6.3.5.5)',
#   u'property': [u'EC number', u'Pathway', u'Subsystem'],
#   u'protein_id': u'YP_001104315.1',
#   u'public': True,
#   u'refseq_locus_tag': u'SACE_2083',
#   u'segments': [u'2268539..2271871'],
#   u'sequence_id': u'NC_009142',
#   u'start': 2268539,
#   u'strand': u'+',
#   u'taxon_id': 405948},
#  {u'aa_length': 226,
#   u'aa_sequence_md5': u'660628561b5e647e3923ad6ed1409b85',
#   u'accession': u'NC_009142',
#   u'alt_locus_tag': u'VBISacEry28377_4136',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2014-10-21T05:50:56.776Z',
#   u'date_modified': u'2014-10-27T11:56:20.149Z',
#   u'end': 4541425,
#   u'feature_id': u'PATRIC.405948.11.NC_009142.CDS.4540745.4541425.fwd',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00057597',
#   u'gene_id': 4943939,
#   u'genome_id': u'405948.11',
#   u'genome_name': u'Saccharopolyspora erythraea NRRL 2338',
#   u'location': u'4540745..4541425',
#   u'na_length': 681,
#   u'na_sequence_md5': u'333ad638d362245e7b516678b645bd1f',
#   u'owner': u'PATRIC',
#   u'p2_feature_id': 23415684,
#   u'patric_id': u'fig|405948.11.peg.4136',
#   u'pgfam_id': u'PGF_00771971',
#   u'plfam_id': u'PLF_1835_00016285',
#   u'product': u'Domain of unknown function / TesB-like acyl-CoA thioesterase 5',
#   u'property': [u'Subsystem'],
#   u'protein_id': u'YP_001106314.1',
#   u'public': True,
#   u'refseq_locus_tag': u'SACE_4119',
#   u'segments': [u'4540745..4541425'],
#   u'sequence_id': u'NC_009142',
#   u'start': 4540745,
#   u'strand': u'+',
#   u'taxon_id': 405948},
#  {u'aa_length': 360,
#   u'aa_sequence_md5': u'c5fe09d747843db214fa08bbae135c4f',
#   u'accession': u'NC_009142',
#   u'alt_locus_tag': u'VBISacEry28377_4515',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2014-10-21T05:04:14.684Z',
#   u'date_modified': u'2014-10-27T11:56:20.149Z',
#   u'end': 5019308,
#   u'feature_id': u'PATRIC.405948.11.NC_009142.CDS.5018226.5019308.rev',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00013253',
#   u'gene_id': 4944309,
#   u'genome_id': u'405948.11',
#   u'genome_name': u'Saccharopolyspora erythraea NRRL 2338',
#   u'location': u'complement(5018226..5019308)',
#   u'na_length': 1083,
#   u'na_sequence_md5': u'0ecf4296de77b813a44dc059b71f658b',
#   u'owner': u'PATRIC',
#   u'p2_feature_id': 23416442,
#   u'patric_id': u'fig|405948.11.peg.4515',
#   u'pgfam_id': u'PGF_01368025',
#   u'plfam_id': u'PLF_1835_00000101',
#   u'product': u'Formaldehyde dehydrogenase MscR, NAD/mycothiol-dependent (EC 1.2.1.66) / S-nitrosomycothiol reductase MscR',
#   u'property': [u'EC number', u'Subsystem'],
#   u'protein_id': u'YP_001106684.1',
#   u'public': True,
#   u'refseq_locus_tag': u'SACE_4490',
#   u'segments': [u'5018226..5019308'],
#   u'sequence_id': u'NC_009142',
#   u'start': 5018226,
#   u'strand': u'-',
#   u'taxon_id': 405948},
#  {u'aa_length': 45,
#   u'aa_sequence_md5': u'cb9b8218006df64490323afbd69a42eb',
#   u'accession': u'NC_009142',
#   u'alt_locus_tag': u'VBISacEry28377_4449',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2014-10-21T02:45:13.627Z',
#   u'date_modified': u'2014-10-27T11:56:20.149Z',
#   u'end': 4951009,
#   u'feature_id': u'PATRIC.405948.11.NC_009142.CDS.4950872.4951009.fwd',
#   u'feature_type': u'CDS',
#   u'gene_id': 4944242,
#   u'genome_id': u'405948.11',
#   u'genome_name': u'Saccharopolyspora erythraea NRRL 2338',
#   u'location': u'4950872..4951009',
#   u'na_length': 138,
#   u'na_sequence_md5': u'e32fd5d831c35c8d58218f87f2df4f06',
#   u'owner': u'PATRIC',
#   u'p2_feature_id': 23416310,
#   u'patric_id': u'fig|405948.11.peg.4449',
#   u'pgfam_id': u'PGF_03277009',
#   u'plfam_id': u'PLF_1835_00002171',
#   u'product': u'Coenzyme PQQ synthesis protein A',
#   u'property': [u'Subsystem'],
#   u'protein_id': u'YP_001106617.1',
#   u'public': True,
#   u'refseq_locus_tag': u'SACE_4423',
#   u'segments': [u'4950872..4951009'],
#   u'sequence_id': u'NC_009142',
#   u'start': 4950872,
#   u'strand': u'+',
#   u'taxon_id': 405948},
#  {u'aa_length': 169,
#   u'aa_sequence_md5': u'ae26d4f1bfa8086678743e46bca48da7',
#   u'accession': u'NC_009142',
#   u'alt_locus_tag': u'VBISacEry28377_6750',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2014-10-21T00:48:04.371Z',
#   u'date_modified': u'2014-10-27T11:56:20.149Z',
#   u'end': 7554661,
#   u'feature_id': u'PATRIC.405948.11.NC_009142.CDS.7554152.7554661.fwd',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00638284',
#   u'gene_id': 4946477,
#   u'genome_id': u'405948.11',
#   u'genome_name': u'Saccharopolyspora erythraea NRRL 2338',
#   u'go': [u'GO:0008127|quercetin 2,3-dioxygenase activity'],
#   u'location': u'7554152..7554661',
#   u'na_length': 510,
#   u'na_sequence_md5': u'90a215348f070770ad2792618f4f3a7c',
#   u'owner': u'PATRIC',
#   u'p2_feature_id': 23420936,
#   u'patric_id': u'fig|405948.11.peg.6750',
#   u'pgfam_id': u'PGF_00230517',
#   u'plfam_id': u'PLF_1835_00005758',
#   u'product': u'Quercetin 2,3-dioxygenase (EC 1.13.11.24)',
#   u'property': [u'EC number', u'Subsystem'],
#   u'protein_id': u'YP_001108837.1',
#   u'public': True,
#   u'refseq_locus_tag': u'SACE_6746',
#   u'segments': [u'7554152..7554661'],
#   u'sequence_id': u'NC_009142',
#   u'start': 7554152,
#   u'strand': u'+',
#   u'taxon_id': 405948},
#  {u'aa_length': 232,
#   u'aa_sequence_md5': u'a4e991b916cfbf066ffe0207aaf11604',
#   u'accession': u'NC_009142',
#   u'alt_locus_tag': u'VBISacEry28377_2520',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2014-10-21T05:52:22.234Z',
#   u'date_modified': u'2014-10-27T11:56:20.149Z',
#   u'end': 2733786,
#   u'feature_id': u'PATRIC.405948.11.NC_009142.CDS.2733088.2733786.rev',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00001001',
#   u'gene': u'ureG',
#   u'gene_id': 4942365,
#   u'genome_id': u'405948.11',
#   u'genome_name': u'Saccharopolyspora erythraea NRRL 2338',
#   u'location': u'complement(2733088..2733786)',
#   u'na_length': 699,
#   u'na_sequence_md5': u'844e96d7d39ccab9935bf76f213b4ca3',
#   u'owner': u'PATRIC',
#   u'p2_feature_id': 23412452,
#   u'patric_id': u'fig|405948.11.peg.2520',
#   u'pgfam_id': u'PGF_00066214',
#   u'plfam_id': u'PLF_1835_00004781',
#   u'product': u'Urease accessory protein UreG',
#   u'property': [u'Subsystem'],
#   u'protein_id': u'YP_001104741.1',
#   u'public': True,
#   u'refseq_locus_tag': u'SACE_2524',
#   u'segments': [u'2733088..2733786'],
#   u'sequence_id': u'NC_009142',
#   u'start': 2733088,
#   u'strand': u'-',
#   u'taxon_id': 405948},
#  {u'aa_length': 135,
#   u'aa_sequence_md5': u'24e4c288245c97a51cd6c7f6ba9779ee',
#   u'accession': u'NC_009142',
#   u'alt_locus_tag': u'VBISacEry28377_1947',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2014-10-21T04:27:02.529Z',
#   u'date_modified': u'2014-10-27T11:56:20.149Z',
#   u'end': 2117955,
#   u'feature_id': u'PATRIC.405948.11.NC_009142.CDS.2117548.2117955.fwd',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00001524',
#   u'gene_id': 4941794,
#   u'genome_id': u'405948.11',
#   u'genome_name': u'Saccharopolyspora erythraea NRRL 2338',
#   u'go': [u'GO:0004061|arylformamidase activity'],
#   u'location': u'2117548..2117955',
#   u'na_length': 408,
#   u'na_sequence_md5': u'b91ab77e471268408f78c12ec16cf086',
#   u'owner': u'PATRIC',
#   u'p2_feature_id': 23411296,
#   u'patric_id': u'fig|405948.11.peg.1947',
#   u'pgfam_id': u'PGF_00015949',
#   u'plfam_id': u'PLF_1835_00004539',
#   u'product': u'Kynurenine formamidase, bacterial (EC 3.5.1.9)',
#   u'property': [u'EC number', u'Pathway', u'Subsystem'],
#   u'protein_id': u'YP_001104175.1',
#   u'public': True,
#   u'refseq_locus_tag': u'SACE_1939',
#   u'segments': [u'2117548..2117955'],
#   u'sequence_id': u'NC_009142',
#   u'start': 2117548,
#   u'strand': u'+',
#   u'taxon_id': 405948},
#  {u'aa_length': 383,
#   u'aa_sequence_md5': u'6348013d7569e579a0860ed9ce6af95f',
#   u'accession': u'NC_009142',
#   u'alt_locus_tag': u'VBISacEry28377_6867',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2014-10-20T20:30:07.139Z',
#   u'date_modified': u'2014-10-27T11:56:20.149Z',
#   u'end': 7676181,
#   u'feature_id': u'PATRIC.405948.11.NC_009142.CDS.7675030.7676181.rev',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00820669',
#   u'gene': u'mce4D',
#   u'gene_id': 4946589,
#   u'genome_id': u'405948.11',
#   u'genome_name': u'Saccharopolyspora erythraea NRRL 2338',
#   u'location': u'complement(7675030..7676181)',
#   u'na_length': 1152,
#   u'na_sequence_md5': u'7f7f75aa2b0d87cd629815e0cf5a440b',
#   u'owner': u'PATRIC',
#   u'p2_feature_id': 23421170,
#   u'patric_id': u'fig|405948.11.peg.6867',
#   u'pgfam_id': u'PGF_03064922',
#   u'plfam_id': u'PLF_1835_00000942',
#   u'product': u'MCE-family protein MceD',
#   u'property': [u'Subsystem'],
#   u'protein_id': u'YP_001108949.1',
#   u'public': True,
#   u'refseq_locus_tag': u'SACE_6860',
#   u'segments': [u'7675030..7676181'],
#   u'sequence_id': u'NC_009142',
#   u'start': 7675030,
#   u'strand': u'-',
#   u'taxon_id': 405948},
#  {u'aa_length': 115,
#   u'aa_sequence_md5': u'71c777f6e536cbc5c9362a667169913d',
#   u'accession': u'NC_009142',
#   u'alt_locus_tag': u'VBISacEry28377_5269',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2014-10-21T02:39:26.463Z',
#   u'date_modified': u'2014-10-27T11:56:20.149Z',
#   u'end': 5904864,
#   u'feature_id': u'PATRIC.405948.11.NC_009142.CDS.5904517.5904864.rev',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00000216',
#   u'gene': u'rplT',
#   u'gene_id': 4945073,
#   u'genome_id': u'405948.11',
#   u'genome_name': u'Saccharopolyspora erythraea NRRL 2338',
#   u'go': [u'GO:0003723|RNA binding',
#    u'GO:0003735|structural constituent of ribosome',
#    u'GO:0005622|intracellular',
#    u'GO:0005840|ribosome',
#    u'GO:0006412|translation'],
#   u'location': u'complement(5904517..5904864)',
#   u'na_length': 348,
#   u'na_sequence_md5': u'605ae3a14d28f4910026058b52e2a2a1',
#   u'owner': u'PATRIC',
#   u'p2_feature_id': 23417958,
#   u'patric_id': u'fig|405948.11.peg.5269',
#   u'pgfam_id': u'PGF_00016358',
#   u'plfam_id': u'PLF_1835_00000904',
#   u'product': u'LSU ribosomal protein L20p',
#   u'property': [u'Subsystem'],
#   u'protein_id': u'YP_001107443.1',
#   u'public': True,
#   u'refseq_locus_tag': u'SACE_5279',
#   u'segments': [u'5904517..5904864'],
#   u'sequence_id': u'NC_009142',
#   u'start': 5904517,
#   u'strand': u'-',
#   u'taxon_id': 405948},
#  {u'aa_length': 299,
#   u'aa_sequence_md5': u'0acff8c39f48c78c962b8ccf300d6803',
#   u'accession': u'NC_009142',
#   u'alt_locus_tag': u'VBISacEry28377_4525',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2014-10-21T03:07:22.777Z',
#   u'date_modified': u'2014-10-27T11:56:20.149Z',
#   u'end': 5031302,
#   u'feature_id': u'PATRIC.405948.11.NC_009142.CDS.5030403.5031302.fwd',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00000307',
#   u'gene': u'folP',
#   u'gene_id': 4944318,
#   u'genome_id': u'405948.11',
#   u'genome_name': u'Saccharopolyspora erythraea NRRL 2338',
#   u'go': [u'GO:0004156|dihydropteroate synthase activity'],
#   u'location': u'5030403..5031302',
#   u'na_length': 900,
#   u'na_sequence_md5': u'c37f7393a422a6c70ff239d9106d0f94',
#   u'owner': u'PATRIC',
#   u'p2_feature_id': 23416462,
#   u'patric_id': u'fig|405948.11.peg.4525',
#   u'pgfam_id': u'PGF_01853493',
#   u'plfam_id': u'PLF_1835_00003543',
#   u'product': u'Dihydropteroate synthase (EC 2.5.1.15)',
#   u'property': [u'EC number', u'Pathway', u'Subsystem'],
#   u'protein_id': u'YP_001106693.1',
#   u'public': True,
#   u'refseq_locus_tag': u'SACE_4499',
#   u'segments': [u'5030403..5031302'],
#   u'sequence_id': u'NC_009142',
#   u'start': 5030403,
#   u'strand': u'+',
#   u'taxon_id': 405948},
#  {u'aa_length': 104,
#   u'aa_sequence_md5': u'885f670e9cc84325e1ffec0eace9367c',
#   u'accession': u'NC_009142',
#   u'alt_locus_tag': u'VBISacEry28377_6830',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2014-10-21T04:44:58.875Z',
#   u'date_modified': u'2014-10-27T11:56:20.149Z',
#   u'end': 7626369,
#   u'feature_id': u'PATRIC.405948.11.NC_009142.CDS.7626055.7626369.rev',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00000198',
#   u'gene': u'rplX',
#   u'gene_id': 4946554,
#   u'genome_id': u'405948.11',
#   u'genome_name': u'Saccharopolyspora erythraea NRRL 2338',
#   u'location': u'complement(7626055..7626369)',
#   u'na_length': 315,
#   u'na_sequence_md5': u'928ceca4ed5246d58d27a556f5b7e270',
#   u'owner': u'PATRIC',
#   u'p2_feature_id': 23421096,
#   u'patric_id': u'fig|405948.11.peg.6830',
#   u'pgfam_id': u'PGF_00016377',
#   u'plfam_id': u'PLF_1835_00000908',
#   u'product': u'LSU ribosomal protein L24p (L26e)',
#   u'property': [u'Subsystem'],
#   u'protein_id': u'YP_001108914.1',
#   u'public': True,
#   u'refseq_locus_tag': u'SACE_6825',
#   u'segments': [u'7626055..7626369'],
#   u'sequence_id': u'NC_009142',
#   u'start': 7626055,
#   u'strand': u'-',
#   u'taxon_id': 405948},
#  {u'aa_length': 215,
#   u'aa_sequence_md5': u'a288e59178c38f24ca04adf02e4677c7',
#   u'accession': u'NC_009142',
#   u'alt_locus_tag': u'VBISacEry28377_6225',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2014-10-21T05:16:20.933Z',
#   u'date_modified': u'2014-10-27T11:56:20.149Z',
#   u'end': 6999911,
#   u'feature_id': u'PATRIC.405948.11.NC_009142.CDS.6999264.6999911.rev',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00059413',
#   u'gene': u'dak2',
#   u'gene_id': 4945979,
#   u'genome_id': u'405948.11',
#   u'genome_name': u'Saccharopolyspora erythraea NRRL 2338',
#   u'location': u'complement(6999264..6999911)',
#   u'na_length': 648,
#   u'na_sequence_md5': u'0ed5889d1107d88f1d8592415cdc7827',
#   u'owner': u'PATRIC',
#   u'p2_feature_id': 23419876,
#   u'patric_id': u'fig|405948.11.peg.6225',
#   u'pgfam_id': u'PGF_00719345',
#   u'plfam_id': u'PLF_1835_00002861',
#   u'product': u'Phosphoenolpyruvate-dihydroxyacetone phosphotransferase (EC 2.7.1.121), ADP-binding subunit DhaL',
#   u'property': [u'EC number', u'Subsystem'],
#   u'protein_id': u'YP_001108345.1',
#   u'public': True,
#   u'refseq_locus_tag': u'SACE_6247',
#   u'segments': [u'6999264..6999911'],
#   u'sequence_id': u'NC_009142',
#   u'start': 6999264,
#   u'strand': u'-',
#   u'taxon_id': 405948},
#  {u'aa_length': 252,
#   u'aa_sequence_md5': u'f0d16028269792434e678312447f17a7',
#   u'accession': u'NC_009142',
#   u'alt_locus_tag': u'VBISacEry28377_1466',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2014-10-21T06:07:22.110Z',
#   u'date_modified': u'2014-10-27T11:56:20.149Z',
#   u'end': 1613446,
#   u'feature_id': u'PATRIC.405948.11.NC_009142.CDS.1612688.1613446.rev',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00138403',
#   u'gene': u'echA21',
#   u'gene_id': 4941323,
#   u'genome_id': u'405948.11',
#   u'genome_name': u'Saccharopolyspora erythraea NRRL 2338',
#   u'go': [u'GO:0004490|methylglutaconyl-CoA hydratase activity'],
#   u'location': u'complement(1612688..1613446)',
#   u'na_length': 759,
#   u'na_sequence_md5': u'541598db939d2d1b3c941469bf0b7446',
#   u'owner': u'PATRIC',
#   u'p2_feature_id': 23410324,
#   u'patric_id': u'fig|405948.11.peg.1466',
#   u'pgfam_id': u'PGF_00943546',
#   u'plfam_id': u'PLF_1835_00000346',
#   u'product': u'Methylglutaconyl-CoA hydratase (EC 4.2.1.18)',
#   u'property': [u'EC number', u'Pathway', u'Subsystem'],
#   u'protein_id': u'YP_001103711.1',
#   u'public': True,
#   u'refseq_locus_tag': u'SACE_1464',
#   u'segments': [u'1612688..1613446'],
#   u'sequence_id': u'NC_009142',
#   u'start': 1612688,
#   u'strand': u'-',
#   u'taxon_id': 405948},
#  {u'aa_length': 307,
#   u'aa_sequence_md5': u'fe8147c83d5daad055b7a78b812c8ba7',
#   u'accession': u'NC_009142',
#   u'alt_locus_tag': u'VBISacEry28377_1373',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2014-10-21T06:07:54.440Z',
#   u'date_modified': u'2014-10-27T11:56:20.149Z',
#   u'end': 1520986,
#   u'feature_id': u'PATRIC.405948.11.NC_009142.CDS.1520063.1520986.fwd',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00000747',
#   u'gene': u'penA,blaA',
#   u'gene_id': 4941233,
#   u'genome_id': u'405948.11',
#   u'genome_name': u'Saccharopolyspora erythraea NRRL 2338',
#   u'go': [u'GO:0008800|beta-lactamase activity'],
#   u'location': u'1520063..1520986',
#   u'na_length': 924,
#   u'na_sequence_md5': u'ecf5f8dbdee300ddd4fbac33c502697f',
#   u'owner': u'PATRIC',
#   u'p2_feature_id': 23410138,
#   u'patric_id': u'fig|405948.11.peg.1373',
#   u'pgfam_id': u'PGF_00095687',
#   u'plfam_id': u'PLF_1835_00002578',
#   u'product': u'Class A beta-lactamase (EC 3.5.2.6)',
#   u'property': [u'EC number', u'Pathway', u'Subsystem'],
#   u'protein_id': u'YP_001103621.1',
#   u'public': True,
#   u'refseq_locus_tag': u'SACE_1374',
#   u'segments': [u'1520063..1520986'],
#   u'sequence_id': u'NC_009142',
#   u'start': 1520063,
#   u'strand': u'+',
#   u'taxon_id': 405948},
#  {u'aa_length': 61,
#   u'aa_sequence_md5': u'eacdda809cfcb73fc0d82f7972093a11',
#   u'accession': u'NC_009142',
#   u'alt_locus_tag': u'VBISacEry28377_6828',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2014-10-20T23:14:28.075Z',
#   u'date_modified': u'2014-10-27T11:56:20.149Z',
#   u'end': 7625484,
#   u'feature_id': u'PATRIC.405948.11.NC_009142.CDS.7625299.7625484.rev',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG01955777',
#   u'gene': u'rpsN',
#   u'gene_id': 4946552,
#   u'genome_id': u'405948.11',
#   u'genome_name': u'Saccharopolyspora erythraea NRRL 2338',
#   u'location': u'complement(7625299..7625484)',
#   u'na_length': 186,
#   u'na_sequence_md5': u'3de69de091581442fb189cd1d63d1528',
#   u'owner': u'PATRIC',
#   u'p2_feature_id': 23421092,
#   u'patric_id': u'fig|405948.11.peg.6828',
#   u'pgfam_id': u'PGF_00049842',
#   u'plfam_id': u'PLF_1835_00001467',
#   u'product': u'SSU ribosomal protein S14p (S29e) @ SSU ribosomal protein S14p (S29e), zinc-dependent',
#   u'property': [u'Subsystem'],
#   u'protein_id': u'YP_001108912.1',
#   u'public': True,
#   u'refseq_locus_tag': u'SACE_6823',
#   u'segments': [u'7625299..7625484'],
#   u'sequence_id': u'NC_009142',
#   u'start': 7625299,
#   u'strand': u'-',
#   u'taxon_id': 405948},
#  {u'aa_length': 663,
#   u'aa_sequence_md5': u'f4353df7e550c5abb7bcc6bbc965408b',
#   u'accession': u'NC_009142',
#   u'alt_locus_tag': u'VBISacEry28377_6898',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2014-10-21T03:33:25.343Z',
#   u'date_modified': u'2014-10-27T11:56:20.149Z',
#   u'end': 7708607,
#   u'feature_id': u'PATRIC.405948.11.NC_009142.CDS.7706616.7708607.rev',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00068727',
#   u'gene': u'nuoL',
#   u'gene_id': 4946624,
#   u'genome_id': u'405948.11',
#   u'genome_name': u'Saccharopolyspora erythraea NRRL 2338',
#   u'go': [u'GO:0008137|NADH dehydrogenase (ubiquinone) activity'],
#   u'location': u'complement(7706616..7708607)',
#   u'na_length': 1992,
#   u'na_sequence_md5': u'48b920d0baec744bb3e9660d93594e06',
#   u'owner': u'PATRIC',
#   u'p2_feature_id': 23421240,
#   u'patric_id': u'fig|405948.11.peg.6898',
#   u'pgfam_id': u'PGF_04757308',
#   u'plfam_id': u'PLF_1835_00001177',
#   u'product': u'NADH-ubiquinone oxidoreductase chain L (EC 1.6.5.3)',
#   u'property': [u'EC number', u'Pathway', u'Subsystem'],
#   u'protein_id': u'YP_001108980.1',
#   u'public': True,
#   u'refseq_locus_tag': u'SACE_6891',
#   u'segments': [u'7706616..7708607'],
#   u'sequence_id': u'NC_009142',
#   u'start': 7706616,
#   u'strand': u'-',
#   u'taxon_id': 405948},
#  {u'aa_length': 653,
#   u'aa_sequence_md5': u'870f138c98fe359c7327a03f63a7a46f',
#   u'accession': u'NC_009142',
#   u'alt_locus_tag': u'VBISacEry28377_0165',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2014-10-21T03:17:06.732Z',
#   u'date_modified': u'2014-10-27T11:56:20.149Z',
#   u'end': 195150,
#   u'feature_id': u'PATRIC.405948.11.NC_009142.CDS.193189.195150.fwd',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00511876',
#   u'gene_id': 4940030,
#   u'genome_id': u'405948.11',
#   u'genome_name': u'Saccharopolyspora erythraea NRRL 2338',
#   u'location': u'193189..195150',
#   u'na_length': 1962,
#   u'na_sequence_md5': u'0cc91c3d2ea437686b8cadf987719e1a',
#   u'owner': u'PATRIC',
#   u'p2_feature_id': 23407674,
#   u'patric_id': u'fig|405948.11.peg.165',
#   u'pgfam_id': u'PGF_03144461',
#   u'plfam_id': u'PLF_1835_00000131',
#   u'product': u'Bifunctional beta-1,5/1,6-galactofuranosyltransferase GlfT2 in cell wall galactan polymerization (EC 2.4.1.288)',
#   u'property': [u'EC number', u'Subsystem'],
#   u'protein_id': u'YP_001102444.1',
#   u'public': True,
#   u'refseq_locus_tag': u'SACE_0166',
#   u'segments': [u'193189..195150'],
#   u'sequence_id': u'NC_009142',
#   u'start': 193189,
#   u'strand': u'+',
#   u'taxon_id': 405948},
#  {u'aa_length': 363,
#   u'aa_sequence_md5': u'f14ebbd0350649c4d4f3a6f598580c39',
#   u'accession': u'NC_009142',
#   u'alt_locus_tag': u'VBISacEry28377_4451',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2014-10-21T05:51:37.759Z',
#   u'date_modified': u'2014-10-27T11:56:20.149Z',
#   u'end': 4952481,
#   u'feature_id': u'PATRIC.405948.11.NC_009142.CDS.4951390.4952481.fwd',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00133580',
#   u'gene': u'pqqE',
#   u'gene_id': 4944244,
#   u'genome_id': u'405948.11',
#   u'genome_name': u'Saccharopolyspora erythraea NRRL 2338',
#   u'location': u'4951390..4952481',
#   u'na_length': 1092,
#   u'na_sequence_md5': u'c05606ec070bdfdd05457e1838f535e4',
#   u'owner': u'PATRIC',
#   u'p2_feature_id': 23416314,
#   u'patric_id': u'fig|405948.11.peg.4451',
#   u'pgfam_id': u'PGF_00418486',
#   u'plfam_id': u'PLF_1835_00002648',
#   u'product': u'Coenzyme PQQ synthesis protein E',
#   u'property': [u'Subsystem'],
#   u'protein_id': u'YP_001106619.1',
#   u'public': True,
#   u'refseq_locus_tag': u'SACE_4425',
#   u'segments': [u'4951390..4952481'],
#   u'sequence_id': u'NC_009142',
#   u'start': 4951390,
#   u'strand': u'+',
#   u'taxon_id': 405948},
#  {u'aa_length': 218,
#   u'aa_sequence_md5': u'e3256ca9a5dd2aab613b54712fe5dc9f',
#   u'accession': u'NC_009142',
#   u'alt_locus_tag': u'VBISacEry28377_1604',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2014-10-20T22:20:29.583Z',
#   u'date_modified': u'2014-10-27T11:56:20.149Z',
#   u'end': 1756388,
#   u'feature_id': u'PATRIC.405948.11.NC_009142.CDS.1755732.1756388.fwd',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00815260',
#   u'gene_id': 4941461,
#   u'genome_id': u'405948.11',
#   u'genome_name': u'Saccharopolyspora erythraea NRRL 2338',
#   u'location': u'1755732..1756388',
#   u'na_length': 657,
#   u'na_sequence_md5': u'a8b6e45013cf64077fb1d17f443b9d97',
#   u'owner': u'PATRIC',
#   u'p2_feature_id': 23410606,
#   u'patric_id': u'fig|405948.11.peg.1604',
#   u'pgfam_id': u'PGF_02278171',
#   u'plfam_id': u'PLF_1835_00000073',
#   u'product': u'NADPH-dependent F420 reductase',
#   u'property': [u'Subsystem'],
#   u'protein_id': u'YP_001103846.1',
#   u'public': True,
#   u'refseq_locus_tag': u'SACE_1601',
#   u'segments': [u'1755732..1756388'],
#   u'sequence_id': u'NC_009142',
#   u'start': 1755732,
#   u'strand': u'+',
#   u'taxon_id': 405948},
#  {u'aa_length': 166,
#   u'aa_sequence_md5': u'76174c42304ffe73deedcff67e806b2c',
#   u'accession': u'NC_009142',
#   u'alt_locus_tag': u'VBISacEry28377_0778',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2014-10-21T06:03:59.825Z',
#   u'date_modified': u'2014-10-27T11:56:20.149Z',
#   u'end': 859494,
#   u'feature_id': u'PATRIC.405948.11.NC_009142.CDS.858994.859494.fwd',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00032229',
#   u'gene': u'moaB',
#   u'gene_id': 4940628,
#   u'genome_id': u'405948.11',
#   u'genome_name': u'Saccharopolyspora erythraea NRRL 2338',
#   u'go': [u'GO:0061598|molybdopterin adenylyltransferase activity'],
#   u'location': u'858994..859494',
#   u'na_length': 501,
#   u'na_sequence_md5': u'3ed7ce329a3ea9487d60994e796f1fc3',
#   u'owner': u'PATRIC',
#   u'p2_feature_id': 23408918,
#   u'patric_id': u'fig|405948.11.peg.778',
#   u'pgfam_id': u'PGF_00022507',
#   u'plfam_id': u'PLF_1835_00000986',
#   u'product': u'Molybdopterin adenylyltransferase (EC 2.7.7.75)',
#   u'property': [u'EC number', u'Subsystem'],
#   u'protein_id': u'YP_001103033.1',
#   u'public': True,
#   u'refseq_locus_tag': u'SACE_0766',
#   u'segments': [u'858994..859494'],
#   u'sequence_id': u'NC_009142',
#   u'start': 858994,
#   u'strand': u'+',
#   u'taxon_id': 405948},
#  {u'aa_length': 281,
#   u'aa_sequence_md5': u'7020023ed7bc04292ef12ee58fd5a2bd',
#   u'accession': u'NC_009142',
#   u'alt_locus_tag': u'VBISacEry28377_4072',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2014-10-21T05:28:34.001Z',
#   u'date_modified': u'2014-10-27T11:56:20.149Z',
#   u'end': 4460048,
#   u'feature_id': u'PATRIC.405948.11.NC_009142.CDS.4459203.4460048.fwd',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00001622',
#   u'gene_id': 4943876,
#   u'genome_id': u'405948.11',
#   u'genome_name': u'Saccharopolyspora erythraea NRRL 2338',
#   u'go': [u'GO:0004833|tryptophan 2,3-dioxygenase activity'],
#   u'location': u'4459203..4460048',
#   u'na_length': 846,
#   u'na_sequence_md5': u'52eb4c153391bef7009af68b024a8536',
#   u'owner': u'PATRIC',
#   u'p2_feature_id': 23415556,
#   u'patric_id': u'fig|405948.11.peg.4072',
#   u'pgfam_id': u'PGF_00062002',
#   u'plfam_id': u'PLF_1835_00003879',
#   u'product': u'Tryptophan 2,3-dioxygenase (EC 1.13.11.11)',
#   u'property': [u'EC number', u'Pathway', u'Subsystem'],
#   u'protein_id': u'YP_001106251.1',
#   u'public': True,
#   u'refseq_locus_tag': u'SACE_4055',
#   u'segments': [u'4459203..4460048'],
#   u'sequence_id': u'NC_009142',
#   u'start': 4459203,
#   u'strand': u'+',
#   u'taxon_id': 405948},
#  {u'aa_length': 608,
#   u'aa_sequence_md5': u'89ff96733e6151c577542510f9e510d4',
#   u'accession': u'NC_009142',
#   u'alt_locus_tag': u'VBISacEry28377_2522',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2014-10-21T04:02:43.644Z',
#   u'date_modified': u'2014-10-27T11:56:20.149Z',
#   u'end': 2736325,
#   u'feature_id': u'PATRIC.405948.11.NC_009142.CDS.2734499.2736325.rev',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00002050',
#   u'gene': u'ureC',
#   u'gene_id': 4942367,
#   u'genome_id': u'405948.11',
#   u'genome_name': u'Saccharopolyspora erythraea NRRL 2338',
#   u'go': [u'GO:0009039|urease activity'],
#   u'location': u'complement(2734499..2736325)',
#   u'na_length': 1827,
#   u'na_sequence_md5': u'b36bffa4f166fb6c7152ce869c5885f0',
#   u'owner': u'PATRIC',
#   u'p2_feature_id': 23412456,
#   u'patric_id': u'fig|405948.11.peg.2522',
#   u'pgfam_id': u'PGF_00066215',
#   u'plfam_id': u'PLF_1835_00000162',
#   u'product': u'Urease alpha subunit (EC 3.5.1.5)',
#   u'property': [u'EC number', u'Pathway', u'Subsystem'],
#   u'protein_id': u'YP_001104743.1',
#   u'public': True,
#   u'refseq_locus_tag': u'SACE_2526',
#   u'segments': [u'2734499..2736325'],
#   u'sequence_id': u'NC_009142',
#   u'start': 2734499,
#   u'strand': u'-',
#   u'taxon_id': 405948},
#  {u'aa_length': 339,
#   u'aa_sequence_md5': u'daab7cad9c0b81045c53b03a7ab80a45',
#   u'accession': u'NC_009142',
#   u'alt_locus_tag': u'VBISacEry28377_2358',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2014-10-20T20:36:49.605Z',
#   u'date_modified': u'2014-10-27T11:56:20.149Z',
#   u'end': 2561344,
#   u'feature_id': u'PATRIC.405948.11.NC_009142.CDS.2560325.2561344.fwd',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00763551',
#   u'gene_id': 4942208,
#   u'genome_id': u'405948.11',
#   u'genome_name': u'Saccharopolyspora erythraea NRRL 2338',
#   u'location': u'2560325..2561344',
#   u'na_length': 1020,
#   u'na_sequence_md5': u'fa2ef57a2cb6e31fb12b9796b36bc53d',
#   u'owner': u'PATRIC',
#   u'p2_feature_id': 23412128,
#   u'patric_id': u'fig|405948.11.peg.2358',
#   u'pgfam_id': u'PGF_00018208',
#   u'plfam_id': u'PLF_1835_00003573',
#   u'product': u'MCE-family protein MceB',
#   u'property': [u'Subsystem'],
#   u'protein_id': u'YP_001104584.1',
#   u'public': True,
#   u'refseq_locus_tag': u'SACE_2359',
#   u'segments': [u'2560325..2561344'],
#   u'sequence_id': u'NC_009142',
#   u'start': 2560325,
#   u'strand': u'+',
#   u'taxon_id': 405948},
#  {u'aa_length': 78,
#   u'aa_sequence_md5': u'b06d046593492fbe75e3d59ff46f3b86',
#   u'accession': u'NC_009142',
#   u'alt_locus_tag': u'VBISacEry28377_0766',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2014-10-21T05:36:20.491Z',
#   u'date_modified': u'2014-10-27T11:56:20.149Z',
#   u'end': 847294,
#   u'feature_id': u'PATRIC.405948.11.NC_009142.CDS.847058.847294.rev',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00000266',
#   u'gene': u'rpmB',
#   u'gene_id': 4940616,
#   u'genome_id': u'405948.11',
#   u'genome_name': u'Saccharopolyspora erythraea NRRL 2338',
#   u'location': u'complement(847058..847294)',
#   u'na_length': 237,
#   u'na_sequence_md5': u'7ce8c2da47b26f7b1e583f77fd1457eb',
#   u'owner': u'PATRIC',
#   u'p2_feature_id': 23408894,
#   u'patric_id': u'fig|405948.11.peg.766',
#   u'pgfam_id': u'PGF_03278866',
#   u'plfam_id': u'PLF_1835_00002726',
#   u'product': u'LSU ribosomal protein L28p @ LSU ribosomal protein L28p, zinc-independent',
#   u'property': [u'Subsystem'],
#   u'protein_id': u'YP_001103021.1',
#   u'public': True,
#   u'refseq_locus_tag': u'SACE_0754',
#   u'segments': [u'847058..847294'],
#   u'sequence_id': u'NC_009142',
#   u'start': 847058,
#   u'strand': u'-',
#   u'taxon_id': 405948},
#  {u'aa_length': 256,
#   u'aa_sequence_md5': u'4fd7073edd8857eb29afb09a98262c4e',
#   u'accession': u'NC_009142',
#   u'alt_locus_tag': u'VBISacEry28377_7369',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2014-10-21T05:46:43.125Z',
#   u'date_modified': u'2014-10-27T11:56:20.149Z',
#   u'end': 8160194,
#   u'feature_id': u'PATRIC.405948.11.NC_009142.CDS.8159424.8160194.fwd',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00000899',
#   u'gene': u'end',
#   u'gene_id': 4947083,
#   u'genome_id': u'405948.11',
#   u'genome_name': u'Saccharopolyspora erythraea NRRL 2338',
#   u'go': [u'GO:0008833|deoxyribonuclease IV (phage-T4-induced) activity'],
#   u'location': u'8159424..8160194',
#   u'na_length': 771,
#   u'na_sequence_md5': u'7875f2b80f9cbd5716d8bacb68695c73',
#   u'owner': u'PATRIC',
#   u'p2_feature_id': 23422192,
#   u'patric_id': u'fig|405948.11.peg.7369',
#   u'pgfam_id': u'PGF_00424337',
#   u'plfam_id': u'PLF_1835_00000993',
#   u'product': u'Endonuclease IV (EC 3.1.21.2)',
#   u'property': [u'EC number', u'Subsystem'],
#   u'protein_id': u'YP_001109434.1',
#   u'public': True,
#   u'refseq_locus_tag': u'SACE_7353',
#   u'segments': [u'8159424..8160194'],
#   u'sequence_id': u'NC_009142',
#   u'start': 8159424,
#   u'strand': u'+',
#   u'taxon_id': 405948},
#  {u'aa_length': 379,
#   u'aa_sequence_md5': u'2445742755ee729f220dc202310d4e04',
#   u'accession': u'NC_009142',
#   u'alt_locus_tag': u'VBISacEry28377_1044',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2014-10-20T20:31:39.978Z',
#   u'date_modified': u'2014-10-27T11:56:20.149Z',
#   u'end': 1155313,
#   u'feature_id': u'PATRIC.405948.11.NC_009142.CDS.1154174.1155313.rev',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00448421',
#   u'gene_id': 4940895,
#   u'genome_id': u'405948.11',
#   u'genome_name': u'Saccharopolyspora erythraea NRRL 2338',
#   u'location': u'complement(1154174..1155313)',
#   u'na_length': 1140,
#   u'na_sequence_md5': u'79c57a22161b582efda488d33b6bfcec',
#   u'owner': u'PATRIC',
#   u'p2_feature_id': 23409456,
#   u'patric_id': u'fig|405948.11.peg.1044',
#   u'pgfam_id': u'PGF_00022722',
#   u'plfam_id': u'PLF_1835_00000352',
#   u'product': u'Mrp protein homolog',
#   u'property': [u'Subsystem'],
#   u'protein_id': u'YP_001103296.1',
#   u'public': True,
#   u'refseq_locus_tag': u'SACE_1039',
#   u'segments': [u'1154174..1155313'],
#   u'sequence_id': u'NC_009142',
#   u'start': 1154174,
#   u'strand': u'-',
#   u'taxon_id': 405948},
#  {u'aa_length': 321,
#   u'aa_sequence_md5': u'7ef49fd73e863b6aec0481be87d1d42b',
#   u'accession': u'NC_009142',
#   u'alt_locus_tag': u'VBISacEry28377_3551',
#   u'annotation': u'PATRIC',
# ...
#   u'owner': u'PATRIC',
#   u'p2_feature_id': 23412104,
#   u'patric_id': u'fig|405948.11.peg.2346',
#   u'pgfam_id': u'PGF_04239526',
#   u'plfam_id': u'PLF_1835_00015786',
#   u'product': u'Transcriptional regulator, AfsR family',
#   u'protein_id': u'YP_001104572.1',
#   u'public': True,
#   u'refseq_locus_tag': u'SACE_2347',
#   u'segments': [u'2544386..2546227'],
#   u'sequence_id': u'NC_009142',
#   u'start': 2544386,
#   u'strand': u'-',
#   u'taxon_id': 405948},
#  {u'aa_length': 89,
#   u'aa_sequence_md5': u'41a42398c2bd01d7ec7c820b7151c898',
#   u'accession': u'NC_009142',
#   u'alt_locus_tag': u'VBISacEry28377_2646',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2014-10-21T02:38:32.115Z',
#   u'date_modified': u'2014-10-27T11:56:20.149Z',
#   u'end': 2903460,
#   u'feature_id': u'PATRIC.405948.11.NC_009142.CDS.2903191.2903460.rev',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG01306568',
#   u'gene_id': 0,
#   u'genome_id': u'405948.11',
#   u'genome_name': u'Saccharopolyspora erythraea NRRL 2338',
#   u'location': u'complement(2903191..2903460)',
#   u'na_length': 270,
#   u'na_sequence_md5': u'a13ce8087a935cab561ca6ce0b549f27',
#   u'owner': u'PATRIC',
#   u'p2_feature_id': 23412702,
#   u'patric_id': u'fig|405948.11.peg.2646',
#   u'pgfam_id': u'PGF_01000105',
#   u'plfam_id': u'PLF_1835_00000027',
#   u'product': u'Mobile element protein',
#   u'public': True,
#   u'segments': [u'2903191..2903460'],
#   u'sequence_id': u'NC_009142',
#   u'start': 2903191,
#   u'strand': u'-',
#   u'taxon_id': 405948},
#  {u'aa_length': 78,
#   u'aa_sequence_md5': u'4028421da0be94828b2d02483cd519eb',
#   u'accession': u'NC_009142',
#   u'alt_locus_tag': u'VBISacEry28377_2684',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2014-10-20T23:45:55.321Z',
#   u'date_modified': u'2014-10-27T11:56:20.149Z',
#   u'end': 2944301,
#   u'feature_id': u'PATRIC.405948.11.NC_009142.CDS.2944065.2944301.fwd',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG01039820',
#   u'gene_id': 4942523,
#   u'genome_id': u'405948.11',
#   u'genome_name': u'Saccharopolyspora erythraea NRRL 2338',
#   u'location': u'2944065..2944301',
#   u'na_length': 237,
#   u'na_sequence_md5': u'5e32c5a9cbc20dc761c47ef91ec53651',
#   u'owner': u'PATRIC',
#   u'p2_feature_id': 23412778,
#   u'patric_id': u'fig|405948.11.peg.2684',
#   u'pgfam_id': u'PGF_08214619',
#   u'plfam_id': u'PLF_1835_00000075',
#   u'product': u'MbtH-like NRPS chaperone',
#   u'protein_id': u'YP_001104899.1',
#   u'public': True,
#   u'refseq_locus_tag': u'SACE_2692',
#   u'segments': [u'2944065..2944301'],
#   u'sequence_id': u'NC_009142',
#   u'start': 2944065,
#   u'strand': u'+',
#   u'taxon_id': 405948},
#  {u'aa_length': 80,
#   u'aa_sequence_md5': u'80120967a8b8423b798ad964846e010f',
#   u'accession': u'NC_009142',
#   u'alt_locus_tag': u'VBISacEry28377_2832',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2014-10-20T22:14:46.891Z',
#   u'date_modified': u'2014-10-27T11:56:20.149Z',
#   u'end': 3099304,
#   u'feature_id': u'PATRIC.405948.11.NC_009142.CDS.3099062.3099304.fwd',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG01306568',
#   u'gene_id': 4942669,
#   u'genome_id': u'405948.11',
#   u'genome_name': u'Saccharopolyspora erythraea NRRL 2338',
#   u'location': u'3099062..3099304',
#   u'na_length': 243,
#   u'na_sequence_md5': u'd93a93549e9eb7ea5f6ace2a3c284d65',
#   u'owner': u'PATRIC',
#   u'p2_feature_id': 23413074,
#   u'patric_id': u'fig|405948.11.peg.2832',
#   u'pgfam_id': u'PGF_01000105',
#   u'plfam_id': u'PLF_1835_00000028',
#   u'product': u'Mobile element protein',
#   u'protein_id': u'YP_001105045.1',
#   u'public': True,
#   u'refseq_locus_tag': u'SACE_2841',
#   u'segments': [u'3099062..3099304'],
#   u'sequence_id': u'NC_009142',
#   u'start': 3099062,
#   u'strand': u'+',
#   u'taxon_id': 405948},
#  {u'aa_length': 449,
#   u'aa_sequence_md5': u'f8f88fb1cf228b3eb823fc2611e436ff',
#   u'accession': u'NC_009142',
#   u'alt_locus_tag': u'VBISacEry28377_3215',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2014-10-20T22:16:20.169Z',
#   u'date_modified': u'2014-10-27T11:56:20.149Z',
#   u'end': 3551995,
#   u'feature_id': u'PATRIC.405948.11.NC_009142.CDS.3550646.3551995.fwd',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG01393078',
#   u'gene_id': 4943037,
#   u'genome_id': u'405948.11',
#   u'genome_name': u'Saccharopolyspora erythraea NRRL 2338',
#   u'location': u'3550646..3551995',
#   u'na_length': 1350,
#   u'na_sequence_md5': u'062cfbfb8628ab44c4be3b1c637a2da1',
#   u'owner': u'PATRIC',
#   u'p2_feature_id': 23413840,
#   u'patric_id': u'fig|405948.11.peg.3215',
#   u'pgfam_id': u'PGF_12720951',
#   u'plfam_id': u'PLF_1835_00002867',
#   u'product': u'Pleiotropic regulatory protein',
#   u'protein_id': u'YP_001105413.1',
#   u'public': True,
#   u'refseq_locus_tag': u'SACE_3213',
#   u'segments': [u'3550646..3551995'],
#   u'sequence_id': u'NC_009142',
#   u'start': 3550646,
#   u'strand': u'+',
#   u'taxon_id': 405948},
#  {u'aa_length': 266,
#   u'aa_sequence_md5': u'0887a46cceccff584c9f31ad82ba4e2f',
#   u'accession': u'NC_009142',
#   u'alt_locus_tag': u'VBISacEry28377_2222',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2014-10-21T05:51:26.921Z',
#   u'date_modified': u'2014-10-27T11:56:20.149Z',
#   u'end': 2404930,
#   u'feature_id': u'PATRIC.405948.11.NC_009142.CDS.2404130.2404930.rev',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG01306568',
#   u'gene_id': 4942068,
#   u'genome_id': u'405948.11',
#   u'genome_name': u'Saccharopolyspora erythraea NRRL 2338',
#   u'location': u'complement(2404130..2404930)',
#   u'na_length': 801,
#   u'na_sequence_md5': u'3b1e6376d41710615c7b05f84ee1cfc9',
#   u'owner': u'PATRIC',
#   u'p2_feature_id': 23411854,
#   u'patric_id': u'fig|405948.11.peg.2222',
#   u'pgfam_id': u'PGF_01000105',
#   u'plfam_id': u'PLF_1835_00000010',
#   u'product': u'Mobile element protein',
#   u'protein_id': u'YP_001104445.1',
#   u'public': True,
#   u'refseq_locus_tag': u'SACE_2214',
#   u'segments': [u'2404130..2404930'],
#   u'sequence_id': u'NC_009142',
#   u'start': 2404130,
#   u'strand': u'-',
#   u'taxon_id': 405948},
#  {u'aa_length': 2117,
#   u'aa_sequence_md5': u'9568b37bdda8efff08b39e44ce272027',
#   u'accession': u'NC_009142',
#   u'alt_locus_tag': u'VBISacEry28377_2619',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2014-10-21T05:58:44.019Z',
#   u'date_modified': u'2014-10-27T11:56:20.149Z',
#   u'end': 2862484,
#   u'feature_id': u'PATRIC.405948.11.NC_009142.CDS.2856131.2862484.rev',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00000319',
#   u'gene_id': 4942462,
#   u'genome_id': u'405948.11',
#   u'genome_name': u'Saccharopolyspora erythraea NRRL 2338',
#   u'location': u'complement(2856131..2862484)',
#   u'na_length': 6354,
#   u'na_sequence_md5': u'f6e150494ae18b31b159b7bfebbfc170',
#   u'owner': u'PATRIC',
#   u'p2_feature_id': 23412648,
#   u'patric_id': u'fig|405948.11.peg.2619',
#   u'pgfam_id': u'PGF_10503453',
#   u'plfam_id': u'PLF_1835_00006380',
#   u'product': u'Polyketide synthase modules and related proteins',
#   u'protein_id': u'YP_001104838.1',
#   u'public': True,
#   u'refseq_locus_tag': u'SACE_2629',
#   u'segments': [u'2856131..2862484'],
#   u'sequence_id': u'NC_009142',
#   u'start': 2856131,
#   u'strand': u'-',
#   u'taxon_id': 405948},
#  {u'aa_length': 4576,
#   u'aa_sequence_md5': u'0c052d5b706c1eef9fbe352d9f52dbb0',
#   u'accession': u'NC_009142',
#   u'alt_locus_tag': u'VBISacEry28377_2620',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2014-10-21T03:31:49.207Z',
#   u'date_modified': u'2014-10-27T11:56:20.149Z',
#   u'end': 2876250,
#   u'feature_id': u'PATRIC.405948.11.NC_009142.CDS.2862520.2876250.rev',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00000319',
#   u'gene_id': 4942463,
#   u'genome_id': u'405948.11',
#   u'genome_name': u'Saccharopolyspora erythraea NRRL 2338',
#   u'location': u'complement(2862520..2876250)',
#   u'na_length': 13731,
#   u'na_sequence_md5': u'd36499755a15f1782bdc20bcf17584da',
#   u'owner': u'PATRIC',
#   u'p2_feature_id': 23412650,
#   u'patric_id': u'fig|405948.11.peg.2620',
#   u'pgfam_id': u'PGF_10503453',
#   u'plfam_id': u'PLF_1835_00006380',
#   u'product': u'Polyketide synthase modules and related proteins',
#   u'protein_id': u'YP_001104839.1',
#   u'public': True,
#   u'refseq_locus_tag': u'SACE_2630',
#   u'segments': [u'2862520..2876250'],
#   u'sequence_id': u'NC_009142',
#   u'start': 2862520,
#   u'strand': u'-',
#   u'taxon_id': 405948},
#  {u'aa_length': 512,
#   u'aa_sequence_md5': u'37b9c55695fd168f8c3bc3c9161b5715',
#   u'accession': u'NC_009142',
#   u'alt_locus_tag': u'VBISacEry28377_2936',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2014-10-21T05:24:15.501Z',
#   u'date_modified': u'2014-10-27T11:56:20.149Z',
#   u'end': 3225879,
#   u'feature_id': u'PATRIC.405948.11.NC_009142.CDS.3224341.3225879.fwd',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG01332075',
#   u'gene_id': 4942768,
#   u'genome_id': u'405948.11',
#   u'genome_name': u'Saccharopolyspora erythraea NRRL 2338',
#   u'location': u'3224341..3225879',
#   u'na_length': 1539,
#   u'na_sequence_md5': u'59b792f09173ef451952c6e68d91038e',
#   u'owner': u'PATRIC',
#   u'p2_feature_id': 23413282,
#   u'patric_id': u'fig|405948.11.peg.2936',
#   u'pgfam_id': u'PGF_03015381',
#   u'plfam_id': u'PLF_1835_00002260',
#   u'product': u'Putative regulatory protein',
#   u'protein_id': u'YP_001105144.1',
#   u'public': True,
#   u'refseq_locus_tag': u'SACE_2941',
#   u'segments': [u'3224341..3225879'],
#   u'sequence_id': u'NC_009142',
#   u'start': 3224341,
#   u'strand': u'+',
#   u'taxon_id': 405948},
#  {u'aa_length': 272,
#   u'aa_sequence_md5': u'7d4df2015b750993bd20654b9cf60ac0',
#   u'accession': u'NC_009142',
#   u'alt_locus_tag': u'VBISacEry28377_3083',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2014-10-20T21:56:49.570Z',
#   u'date_modified': u'2014-10-27T11:56:20.149Z',
#   u'end': 3391127,
#   u'feature_id': u'PATRIC.405948.11.NC_009142.CDS.3390309.3391127.rev',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG01321859',
#   u'gene_id': 4942910,
#   u'genome_id': u'405948.11',
#   u'genome_name': u'Saccharopolyspora erythraea NRRL 2338',
#   u'location': u'complement(3390309..3391127)',
#   u'na_length': 819,
#   u'na_sequence_md5': u'0f13e4c21a0a4dc79069b251a9df0458',
#   u'owner': u'PATRIC',
#   u'p2_feature_id': 23413576,
#   u'patric_id': u'fig|405948.11.peg.3083',
#   u'pgfam_id': u'PGF_04150638',
#   u'plfam_id': u'PLF_1835_00002202',
#   u'product': u'Oxidoreductase',
#   u'protein_id': u'YP_001105286.1',
#   u'public': True,
#   u'refseq_locus_tag': u'SACE_3083',
#   u'segments': [u'3390309..3391127'],
#   u'sequence_id': u'NC_009142',
#   u'start': 3390309,
#   u'strand': u'-',
#   u'taxon_id': 405948},
#  {u'aa_length': 956,
#   u'aa_sequence_md5': u'703fd425ae6cf9cd7a5ce8e30c93fab8',
#   u'accession': u'NC_009142',
#   u'alt_locus_tag': u'VBISacEry28377_3090',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2014-10-21T05:59:38.732Z',
#   u'date_modified': u'2014-10-27T11:56:20.149Z',
#   u'end': 3400287,
#   u'feature_id': u'PATRIC.405948.11.NC_009142.CDS.3397417.3400287.rev',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG01313191',
#   u'gene': u'helZ2',
#   u'gene_id': 4942917,
#   u'genome_id': u'405948.11',
#   u'genome_name': u'Saccharopolyspora erythraea NRRL 2338',
#   u'location': u'complement(3397417..3400287)',
#   u'na_length': 2871,
#   u'na_sequence_md5': u'acc1c75690348f1d2b176f251e8b4ceb',
#   u'owner': u'PATRIC',
#   u'p2_feature_id': 23413590,
#   u'patric_id': u'fig|405948.11.peg.3090',
#   u'pgfam_id': u'PGF_10429292',
#   u'plfam_id': u'PLF_1835_00007201',
#   u'product': u'Helicase, SNF2/RAD54 family',
#   u'protein_id': u'YP_001105293.1',
#   u'public': True,
#   u'refseq_locus_tag': u'SACE_3090',
#   u'segments': [u'3397417..3400287'],
#   u'sequence_id': u'NC_009142',
#   u'start': 3397417,
#   u'strand': u'-',
#   u'taxon_id': 405948},
#  {u'aa_length': 110,
#   u'aa_sequence_md5': u'9072516d86ea9b63156897456e91adcc',
#   u'accession': u'NC_009142',
#   u'alt_locus_tag': u'VBISacEry28377_3126',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2014-10-20T22:21:30.384Z',
#   u'date_modified': u'2014-10-27T11:56:20.149Z',
#   u'end': 3440663,
#   u'feature_id': u'PATRIC.405948.11.NC_009142.CDS.3440331.3440663.rev',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00638284',
#   u'gene_id': 4942950,
#   u'genome_id': u'405948.11',
#   u'genome_name': u'Saccharopolyspora erythraea NRRL 2338',
#   u'location': u'complement(3440331..3440663)',
#   u'na_length': 333,
#   u'na_sequence_md5': u'437d3114b6652cb1f3f577305ab188d0',
#   u'owner': u'PATRIC',
#   u'p2_feature_id': 23413662,
#   u'patric_id': u'fig|405948.11.peg.3126',
#   u'pgfam_id': u'PGF_08225224',
#   u'plfam_id': u'PLF_1835_00001834',
#   u'product': u'hypothetical protein',
#   u'protein_id': u'YP_001105326.1',
#   u'public': True,
#   u'refseq_locus_tag': u'SACE_3123',
#   u'segments': [u'3440331..3440663'],
#   u'sequence_id': u'NC_009142',
#   u'start': 3440331,
#   u'strand': u'-',
#   u'taxon_id': 405948},
#  {u'aa_length': 242,
#   u'aa_sequence_md5': u'5734bcde55843e65deb5a9520ca906c7',
#   u'accession': u'NC_009142',
#   u'alt_locus_tag': u'VBISacEry28377_3393',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2014-10-20T23:09:20.419Z',
#   u'date_modified': u'2014-10-27T11:56:20.149Z',
#   u'end': 3742138,
#   u'feature_id': u'PATRIC.405948.11.NC_009142.CDS.3741410.3742138.rev',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00001609',
#   u'gene_id': 4943212,
#   u'genome_id': u'405948.11',
#   u'genome_name': u'Saccharopolyspora erythraea NRRL 2338',
#   u'go': [u'GO:0036348|hydantoin racemase activity'],
#   u'location': u'complement(3741410..3742138)',
#   u'na_length': 729,
#   u'na_sequence_md5': u'657539151d3541a6b1307e2214943af6',
#   u'owner': u'PATRIC',
#   u'p2_feature_id': 23414196,
#   u'patric_id': u'fig|405948.11.peg.3393',
#   u'pgfam_id': u'PGF_07226974',
#   u'plfam_id': u'PLF_1835_00016218',
#   u'product': u'Hydantoin racemase (EC 5.1.99.5)',
#   u'property': [u'EC number'],
#   u'protein_id': u'YP_001105588.1',
#   u'public': True,
#   u'refseq_locus_tag': u'SACE_3388',
#   u'segments': [u'3741410..3742138'],
#   u'sequence_id': u'NC_009142',
#   u'start': 3741410,
#   u'strand': u'-',
#   u'taxon_id': 405948},
#  {u'aa_length': 385,
#   u'aa_sequence_md5': u'de41cee6aff8fcbcf460209d9329a55f',
#   u'accession': u'NC_009142',
#   u'alt_locus_tag': u'VBISacEry28377_0790',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2014-10-21T05:34:26.134Z',
#   u'date_modified': u'2014-10-27T11:56:20.149Z',
#   u'end': 870324,
#   u'feature_id': u'PATRIC.405948.11.NC_009142.CDS.869167.870324.fwd',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG01306568',
#   u'gene': u'tnp',
#   u'gene_id': 4940642,
#   u'genome_id': u'405948.11',
#   u'genome_name': u'Saccharopolyspora erythraea NRRL 2338',
#   u'location': u'869167..870324',
#   u'na_length': 1158,
#   u'na_sequence_md5': u'48bb88adc613e885896b0f6c6e471774',
#   u'owner': u'PATRIC',
#   u'p2_feature_id': 23408944,
#   u'patric_id': u'fig|405948.11.peg.790',
#   u'pgfam_id': u'PGF_01000105',
#   u'plfam_id': u'PLF_1835_00000126',
#   u'product': u'Mobile element protein',
#   u'protein_id': u'YP_001103046.1',
#   u'public': True,
#   u'refseq_locus_tag': u'SACE_0779',
#   u'segments': [u'869167..870324'],
#   u'sequence_id': u'NC_009142',
#   u'start': 869167,
#   u'strand': u'+',
#   u'taxon_id': 405948},
#  {u'aa_length': 178,
#   u'aa_sequence_md5': u'2ec416a666c1d53509481924fb8fc09f',
#   u'accession': u'NC_009142',
#   u'alt_locus_tag': u'VBISacEry28377_4098',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2014-10-21T05:51:28.655Z',
#   u'date_modified': u'2014-10-27T11:56:20.149Z',
#   u'end': 4490413,
#   u'feature_id': u'PATRIC.405948.11.NC_009142.CDS.4489877.4490413.rev',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00554610',
#   u'gene_id': 4943901,
#   u'genome_id': u'405948.11',
#   u'genome_name': u'Saccharopolyspora erythraea NRRL 2338',
#   u'location': u'complement(4489877..4490413)',
#   u'na_length': 537,
#   u'na_sequence_md5': u'5b79033e8dc38e137264f79808927c4c',
#   u'owner': u'PATRIC',
#   u'p2_feature_id': 23415608,
#   u'patric_id': u'fig|405948.11.peg.4098',
#   u'pgfam_id': u'PGF_10423881',
#   u'plfam_id': u'PLF_1835_00003033',
#   u'product': u'Transcriptional regulator, MarR family',
#   u'protein_id': u'YP_001106276.1',
#   u'public': True,
#   u'refseq_locus_tag': u'SACE_4080',
#   u'segments': [u'4489877..4490413'],
#   u'sequence_id': u'NC_009142',
#   u'start': 4489877,
#   u'strand': u'-',
#   u'taxon_id': 405948},
#  ...]

# %%
file_name = "test_for_martin_%s.faa" % (genome_id)
feats = mackinac.features_to_protein_fasta_file(feature_list, file_name)

# %%
feats
# Out:
# 0

# %%
feature_list_2 = mackinac.get_genome_features(genome_id, annotation='PATRIC')
feature_list_2
# Out:
# [{u'aa_length': 552,
#   u'aa_sequence_md5': u'c8141f44119381d979a1acf3eba7a7b9',
#   u'accession': u'FNEA01000020',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2016-11-19T18:47:57.167Z',
#   u'date_modified': u'2016-11-19T18:47:57.167Z',
#   u'end': 33752,
#   u'feature_id': u'PATRIC.266.10.FNEA01000020.CDS.32094.33752.rev',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00094176',
#   u'genome_id': u'266.10',
#   u'genome_name': u'Paracoccus denitrificans strain DSM 413',
#   u'go': [u'GO:0016153|urocanate hydratase activity'],
#   u'location': u'complement(32094..33752)',
#   u'na_length': 1659,
#   u'na_sequence_md5': u'204df824ca7c3aaa88baa15636008d1f',
#   u'owner': u'PATRIC@patricbrc.org',
#   u'patric_id': u'fig|266.10.peg.418',
#   u'pgfam_id': u'PGF_00066260',
#   u'plfam_id': u'PLF_265_00007981',
#   u'product': u'Urocanate hydratase (EC 4.2.1.49)',
#   u'property': [u'EC number', u'Pathway', u'Subsystem'],
#   u'public': True,
#   u'refseq_locus_tag': u'SAMN04244581_03492',
#   u'segments': [u'32094..33752'],
#   u'sequence_id': u'266.10.con.0037',
#   u'start': 32094,
#   u'strand': u'-',
#   u'taxon_id': 266},
#  {u'aa_length': 266,
#   u'aa_sequence_md5': u'3f9a9e1573cf57664235425ab95a82ab',
#   u'accession': u'FNEA01000021',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2016-11-19T18:47:57.167Z',
#   u'date_modified': u'2016-11-19T18:47:57.167Z',
#   u'end': 7701,
#   u'feature_id': u'PATRIC.266.10.FNEA01000021.CDS.6901.7701.rev',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00025360',
#   u'genome_id': u'266.10',
#   u'genome_name': u'Paracoccus denitrificans strain DSM 413',
#   u'location': u'complement(6901..7701)',
#   u'na_length': 801,
#   u'na_sequence_md5': u'452595688a8c0f7bb462e92b3ca1d114',
#   u'owner': u'PATRIC@patricbrc.org',
#   u'patric_id': u'fig|266.10.peg.1067',
#   u'pgfam_id': u'PGF_01899924',
#   u'plfam_id': u'PLF_265_00000904',
#   u'product': u'Flagellar motor rotation protein MotB',
#   u'property': [u'Subsystem'],
#   u'public': True,
#   u'refseq_locus_tag': u'SAMN04244581_03556',
#   u'segments': [u'6901..7701'],
#   u'sequence_id': u'266.10.con.0045',
#   u'start': 6901,
#   u'strand': u'-',
#   u'taxon_id': 266},
#  {u'aa_length': 529,
#   u'aa_sequence_md5': u'923f35f7c5e016b4cff78371ccb77a84',
#   u'accession': u'FNEA01000008',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2016-11-19T18:47:57.167Z',
#   u'date_modified': u'2016-11-19T18:47:57.167Z',
#   u'end': 15723,
#   u'feature_id': u'PATRIC.266.10.FNEA01000008.CDS.14134.15723.rev',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00000275',
#   u'genome_id': u'266.10',
#   u'genome_name': u'Paracoccus denitrificans strain DSM 413',
#   u'go': [u'GO:0003937|IMP cyclohydrolase activity',
#    u'GO:0004643|phosphoribosylaminoimidazolecarboxamide formyltransferase activity'],
#   u'location': u'complement(14134..15723)',
#   u'na_length': 1590,
#   u'na_sequence_md5': u'64ee19aa77ba058a8e0702c2e58fbb51',
#   u'owner': u'PATRIC@patricbrc.org',
#   u'patric_id': u'fig|266.10.peg.2479',
#   u'pgfam_id': u'PGF_00013509',
#   u'plfam_id': u'PLF_265_00000942',
#   u'product': u'IMP cyclohydrolase (EC 3.5.4.10) / Phosphoribosylaminoimidazolecarboxamide formyltransferase (EC 2.1.2.3)',
#   u'property': [u'EC number', u'Pathway', u'Subsystem'],
#   u'public': True,
#   u'refseq_locus_tag': u'SAMN04244581_01659',
#   u'segments': [u'14134..15723'],
#   u'sequence_id': u'266.10.con.0058',
#   u'start': 14134,
#   u'strand': u'-',
#   u'taxon_id': 266},
#  {u'aa_length': 555,
#   u'aa_sequence_md5': u'd980bf5aad5c64107237cea3d11f1af0',
#   u'accession': u'FNEA01000002',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2016-11-19T18:47:57.167Z',
#   u'date_modified': u'2016-11-19T18:47:57.167Z',
#   u'end': 122859,
#   u'feature_id': u'PATRIC.266.10.FNEA01000002.CDS.121192.122859.rev',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00000145',
#   u'genome_id': u'266.10',
#   u'genome_name': u'Paracoccus denitrificans strain DSM 413',
#   u'location': u'complement(121192..122859)',
#   u'na_length': 1668,
#   u'na_sequence_md5': u'977ced0399f658ae96b786ca037eedd7',
#   u'owner': u'PATRIC@patricbrc.org',
#   u'patric_id': u'fig|266.10.peg.3645',
#   u'pgfam_id': u'PGF_03520151',
#   u'plfam_id': u'PLF_265_00000060',
#   u'product': u'Cell division protein FtsZ',
#   u'property': [u'Subsystem'],
#   u'public': True,
#   u'refseq_locus_tag': u'SAMN04244581_00361',
#   u'segments': [u'121192..122859'],
#   u'sequence_id': u'266.10.con.0070',
#   u'start': 121192,
#   u'strand': u'-',
#   u'taxon_id': 266},
#  {u'aa_length': 184,
#   u'aa_sequence_md5': u'ff6c1ea8e87550c36520aaf186cfc08f',
#   u'accession': u'FNEA01000032',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2016-11-19T18:47:57.167Z',
#   u'date_modified': u'2016-11-19T18:47:57.167Z',
#   u'end': 22520,
#   u'feature_id': u'PATRIC.266.10.FNEA01000032.CDS.21966.22520.fwd',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00000979',
#   u'genome_id': u'266.10',
#   u'genome_name': u'Paracoccus denitrificans strain DSM 413',
#   u'go': [u'GO:0043755|alpha-ribazole phosphatase activity'],
#   u'location': u'21966..22520',
#   u'na_length': 555,
#   u'na_sequence_md5': u'1d17454ab247f7662b12a60af6b57dac',
#   u'owner': u'PATRIC@patricbrc.org',
#   u'patric_id': u'fig|266.10.peg.3207',
#   u'pgfam_id': u'PGF_00368502',
#   u'plfam_id': u'PLF_265_00001829',
#   u'product': u"Alpha-ribazole-5'-phosphate phosphatase (EC 3.1.3.73)",
#   u'property': [u'EC number', u'Pathway', u'Subsystem'],
#   u'public': True,
#   u'refseq_locus_tag': u'SAMN04244581_04274',
#   u'segments': [u'21966..22520'],
#   u'sequence_id': u'266.10.con.0063',
#   u'start': 21966,
#   u'strand': u'+',
#   u'taxon_id': 266},
#  {u'aa_length': 693,
#   u'aa_sequence_md5': u'0a402950a1c272a9e939fbc410d6462d',
#   u'accession': u'FNEA01000027',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2016-11-19T18:47:57.167Z',
#   u'date_modified': u'2016-11-19T18:47:57.167Z',
#   u'end': 13217,
#   u'feature_id': u'PATRIC.266.10.FNEA01000027.CDS.11136.13217.fwd',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG01304711',
#   u'genome_id': u'266.10',
#   u'genome_name': u'Paracoccus denitrificans strain DSM 413',
#   u'go': [u'GO:0003863|3-methyl-2-oxobutanoate dehydrogenase (2-methylpropanoyl-transferring) activity'],
#   u'location': u'11136..13217',
#   u'na_length': 2082,
#   u'na_sequence_md5': u'bfea94ddd2df11a27a3aa8d33572a2ff',
#   u'owner': u'PATRIC@patricbrc.org',
#   u'patric_id': u'fig|266.10.peg.3868',
#   u'pgfam_id': u'PGF_00412160',
#   u'plfam_id': u'PLF_265_00005793',
#   u'product': u'Branched-chain alpha-keto acid dehydrogenase, E1 component, alpha subunit (EC 1.2.4.4) / Branched-chain alpha-keto acid dehydrogenase, E1 component, beta subunit (EC 1.2.4.4)',
#   u'property': [u'EC number', u'Pathway', u'Subsystem'],
#   u'public': True,
#   u'refseq_locus_tag': u'SAMN04244581_03995',
#   u'segments': [u'11136..13217'],
#   u'sequence_id': u'266.10.con.0072',
#   u'start': 11136,
#   u'strand': u'+',
#   u'taxon_id': 266},
#  {u'aa_length': 205,
#   u'aa_sequence_md5': u'649e331e3ca3b7452cbf6bdb8be8bee0',
#   u'accession': u'FNEA01000017',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2016-11-19T18:47:57.167Z',
#   u'date_modified': u'2016-11-19T18:47:57.167Z',
#   u'end': 48632,
#   u'feature_id': u'PATRIC.266.10.FNEA01000017.CDS.48015.48632.fwd',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00001056',
#   u'genome_id': u'266.10',
#   u'genome_name': u'Paracoccus denitrificans strain DSM 413',
#   u'go': [u'GO:0008827|cytochrome o ubiquinol oxidase activity',
#    u'GO:0008827|cytochrome bo3 ubiquinol oxidase activity'],
#   u'location': u'48015..48632',
#   u'na_length': 618,
#   u'na_sequence_md5': u'7416ea23f5f0214913e10311815b2696',
#   u'owner': u'PATRIC@patricbrc.org',
#   u'patric_id': u'fig|266.10.peg.641',
#   u'pgfam_id': u'PGF_00420155',
#   u'plfam_id': u'PLF_265_00001662',
#   u'product': u'Cytochrome O ubiquinol oxidase subunit III (EC 1.10.3.-)',
#   u'property': [u'EC number', u'Pathway', u'Subsystem'],
#   u'public': True,
#   u'refseq_locus_tag': u'SAMN04244581_03154',
#   u'segments': [u'48015..48632'],
#   u'sequence_id': u'266.10.con.0041',
#   u'start': 48015,
#   u'strand': u'+',
#   u'taxon_id': 266},
#  {u'aa_length': 216,
#   u'aa_sequence_md5': u'd71eacca8fe6d82bf5b77f3c5a41d69c',
#   u'accession': u'FNEA01000001',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2016-11-19T18:47:57.167Z',
#   u'date_modified': u'2016-11-19T18:47:57.167Z',
#   u'end': 20786,
#   u'feature_id': u'PATRIC.266.10.FNEA01000001.CDS.20136.20786.rev',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00005559',
#   u'genome_id': u'266.10',
#   u'genome_name': u'Paracoccus denitrificans strain DSM 413',
#   u'location': u'complement(20136..20786)',
#   u'na_length': 651,
#   u'na_sequence_md5': u'babb5451ee8d02cfcf2f2dd87bfe2464',
#   u'owner': u'PATRIC@patricbrc.org',
#   u'patric_id': u'fig|266.10.peg.4634',
#   u'pgfam_id': u'PGF_00037131',
#   u'plfam_id': u'PLF_265_00004977',
#   u'product': u'Osmoprotectant ABC transporter, permease protein OsmW',
#   u'property': [u'Subsystem'],
#   u'public': True,
#   u'refseq_locus_tag': u'SAMN04244581_00020',
#   u'segments': [u'20136..20786'],
#   u'sequence_id': u'266.10.con.0090',
#   u'start': 20136,
#   u'strand': u'-',
#   u'taxon_id': 266},
#  {u'aa_length': 241,
#   u'aa_sequence_md5': u'832b0ff07b6f8f9a2d88a25f6ec89a4c',
#   u'accession': u'FNEA01000003',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2016-11-19T18:47:57.167Z',
#   u'date_modified': u'2016-11-19T18:47:57.167Z',
#   u'end': 163799,
#   u'feature_id': u'PATRIC.266.10.FNEA01000003.CDS.163074.163799.fwd',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00000815',
#   u'genome_id': u'266.10',
#   u'genome_name': u'Paracoccus denitrificans strain DSM 413',
#   u'location': u'163074..163799',
#   u'na_length': 726,
#   u'na_sequence_md5': u'758035975a6299f516b61801c546da90',
#   u'owner': u'PATRIC@patricbrc.org',
#   u'patric_id': u'fig|266.10.peg.1828',
#   u'pgfam_id': u'PGF_00420482',
#   u'plfam_id': u'PLF_265_00000431',
#   u'product': u'Cytochrome c-type biogenesis protein CcmC, putative heme lyase for CcmE',
#   u'property': [u'Subsystem'],
#   u'public': True,
#   u'refseq_locus_tag': u'SAMN04244581_00647',
#   u'segments': [u'163074..163799'],
#   u'sequence_id': u'266.10.con.0054',
#   u'start': 163074,
#   u'strand': u'+',
#   u'taxon_id': 266},
#  {u'aa_length': 149,
#   u'aa_sequence_md5': u'dd6283a4200177315f57902bbfc254d8',
#   u'accession': u'FNEA01000004',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2016-11-19T18:47:57.167Z',
#   u'date_modified': u'2016-11-19T18:47:57.167Z',
#   u'end': 243759,
#   u'feature_id': u'PATRIC.266.10.FNEA01000004.CDS.243310.243759.rev',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00000473',
#   u'genome_id': u'266.10',
#   u'genome_name': u'Paracoccus denitrificans strain DSM 413',
#   u'location': u'complement(243310..243759)',
#   u'na_length': 450,
#   u'na_sequence_md5': u'822fc86704c815070341f8bbf0040331',
#   u'owner': u'PATRIC@patricbrc.org',
#   u'patric_id': u'fig|266.10.peg.1607',
#   u'pgfam_id': u'PGF_00421071',
#   u'plfam_id': u'PLF_265_00000438',
#   u'product': u'D-aminoacyl-tRNA deacylase (EC 3.1.1.96)',
#   u'property': [u'EC number', u'Subsystem'],
#   u'public': True,
#   u'refseq_locus_tag': u'SAMN04244581_00972',
#   u'segments': [u'243310..243759'],
#   u'sequence_id': u'266.10.con.0050',
#   u'start': 243310,
#   u'strand': u'-',
#   u'taxon_id': 266},
#  {u'aa_length': 271,
#   u'aa_sequence_md5': u'319cc525e5642a15df99c6e77e2eb0da',
#   u'accession': u'FNEA01000054',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2016-11-19T18:47:57.167Z',
#   u'date_modified': u'2016-11-19T18:47:57.167Z',
#   u'end': 814,
#   u'feature_id': u'PATRIC.266.10.FNEA01000054.CDS.2.814.rev',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00008889',
#   u'genome_id': u'266.10',
#   u'genome_name': u'Paracoccus denitrificans strain DSM 413',
#   u'location': u'complement(2..814)',
#   u'na_length': 813,
#   u'na_sequence_md5': u'336b2005bdf1186e4bbdf9e7d6b300db',
#   u'owner': u'PATRIC@patricbrc.org',
#   u'patric_id': u'fig|266.10.peg.871',
#   u'pgfam_id': u'PGF_00065238',
#   u'plfam_id': u'PLF_265_00001139',
#   u'product': u'Arsenical-resistance protein ACR3',
#   u'property': [u'Subsystem'],
#   u'public': True,
#   u'segments': [u'2..814'],
#   u'sequence_id': u'266.10.con.0043',
#   u'start': 2,
#   u'strand': u'-',
#   u'taxon_id': 266},
#  {u'aa_length': 366,
#   u'aa_sequence_md5': u'1895261eeb68754c321a24849a0c6fe9',
#   u'accession': u'FNEA01000021',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2016-11-19T18:47:57.167Z',
#   u'date_modified': u'2016-11-19T18:47:57.167Z',
#   u'end': 2944,
#   u'feature_id': u'PATRIC.266.10.FNEA01000021.CDS.1844.2944.rev',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00000751',
#   u'genome_id': u'266.10',
#   u'genome_name': u'Paracoccus denitrificans strain DSM 413',
#   u'location': u'complement(1844..2944)',
#   u'na_length': 1101,
#   u'na_sequence_md5': u'3b3b16fb7fade4ad57cdb57c172e121a',
#   u'owner': u'PATRIC@patricbrc.org',
#   u'patric_id': u'fig|266.10.peg.1063',
#   u'pgfam_id': u'PGF_00005288',
#   u'plfam_id': u'PLF_265_00001163',
#   u'product': u'Flagellar P-ring protein FlgI',
#   u'property': [u'Subsystem'],
#   u'public': True,
#   u'refseq_locus_tag': u'SAMN04244581_03552',
#   u'segments': [u'1844..2944'],
#   u'sequence_id': u'266.10.con.0045',
#   u'start': 1844,
#   u'strand': u'-',
#   u'taxon_id': 266},
#  {u'aa_length': 1031,
#   u'aa_sequence_md5': u'4bd8ac8da0311c70ded3bb185d1a3096',
#   u'accession': u'FNEA01000021',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2016-11-19T18:47:57.167Z',
#   u'date_modified': u'2016-11-19T18:47:57.167Z',
#   u'end': 56521,
#   u'feature_id': u'PATRIC.266.10.FNEA01000021.CDS.53426.56521.rev',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00956700',
#   u'genome_id': u'266.10',
#   u'genome_name': u'Paracoccus denitrificans strain DSM 413',
#   u'location': u'complement(53426..56521)',
#   u'na_length': 3096,
#   u'na_sequence_md5': u'bf1648484d0ab37bf37abf1d0d6fa50f',
#   u'owner': u'PATRIC@patricbrc.org',
#   u'patric_id': u'fig|266.10.peg.1108',
#   u'pgfam_id': u'PGF_02964292',
#   u'plfam_id': u'PLF_265_00000127',
#   u'product': u'Multidrug efflux system, inner membrane proton/drug antiporter (RND type) => TriC of TriABC-OpmH system',
#   u'property': [u'Subsystem'],
#   u'public': True,
#   u'refseq_locus_tag': u'SAMN04244581_03597',
#   u'segments': [u'53426..56521'],
#   u'sequence_id': u'266.10.con.0045',
#   u'start': 53426,
#   u'strand': u'-',
#   u'taxon_id': 266},
#  {u'aa_length': 106,
#   u'aa_sequence_md5': u'574325a00916cd142391e296c4d8ba57',
#   u'accession': u'FNEA01000025',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2016-11-19T18:47:57.167Z',
#   u'date_modified': u'2016-11-19T18:47:57.167Z',
#   u'end': 18172,
#   u'feature_id': u'PATRIC.266.10.FNEA01000025.CDS.17852.18172.fwd',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG01716613',
#   u'genome_id': u'266.10',
#   u'genome_name': u'Paracoccus denitrificans strain DSM 413',
#   u'location': u'17852..18172',
#   u'na_length': 321,
#   u'na_sequence_md5': u'ca8fe2f663c058fb493c7be7cdeb2853',
#   u'owner': u'PATRIC@patricbrc.org',
#   u'patric_id': u'fig|266.10.peg.3490',
#   u'pgfam_id': u'PGF_00402906',
#   u'plfam_id': u'PLF_265_00014109',
#   u'product': u'Aldehyde dehydrogenase',
#   u'property': [u'Subsystem'],
#   u'public': True,
#   u'refseq_locus_tag': u'SAMN04244581_03872',
#   u'segments': [u'17852..18172'],
#   u'sequence_id': u'266.10.con.0068',
#   u'start': 17852,
#   u'strand': u'+',
#   u'taxon_id': 266},
#  {u'aa_length': 368,
#   u'aa_sequence_md5': u'29d7c11329f289102bc925c4675593aa',
#   u'accession': u'FNEA01000049',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2016-11-19T18:47:57.167Z',
#   u'date_modified': u'2016-11-19T18:47:57.167Z',
#   u'end': 17162,
#   u'feature_id': u'PATRIC.266.10.FNEA01000049.CDS.16056.17162.fwd',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG01304805',
#   u'genome_id': u'266.10',
#   u'genome_name': u'Paracoccus denitrificans strain DSM 413',
#   u'location': u'16056..17162',
#   u'na_length': 1107,
#   u'na_sequence_md5': u'57dfb1d53ee5403bd1f8a6df392fa714',
#   u'owner': u'PATRIC@patricbrc.org',
#   u'patric_id': u'fig|266.10.peg.266',
#   u'pgfam_id': u'PGF_00416622',
#   u'plfam_id': u'PLF_265_00000411',
#   u'product': u'Carboxynorspermidine decarboxylase (EC 4.1.1.96)',
#   u'property': [u'EC number', u'Subsystem'],
#   u'public': True,
#   u'refseq_locus_tag': u'SAMN04244581_04849',
#   u'segments': [u'16056..17162'],
#   u'sequence_id': u'266.10.con.0034',
#   u'start': 16056,
#   u'strand': u'+',
#   u'taxon_id': 266},
#  {u'aa_length': 229,
#   u'aa_sequence_md5': u'c03f80456453bbe534a6efa0468c1820',
#   u'accession': u'FNEA01000011',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2016-11-19T18:47:57.167Z',
#   u'date_modified': u'2016-11-19T18:47:57.167Z',
#   u'end': 142874,
#   u'feature_id': u'PATRIC.266.10.FNEA01000011.CDS.142185.142874.fwd',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00000208',
#   u'genome_id': u'266.10',
#   u'genome_name': u'Paracoccus denitrificans strain DSM 413',
#   u'go': [u'GO:0004525|ribonuclease III activity'],
#   u'location': u'142185..142874',
#   u'na_length': 690,
#   u'na_sequence_md5': u'b75b88753c1881a07731694fa19d77e8',
#   u'owner': u'PATRIC@patricbrc.org',
#   u'patric_id': u'fig|266.10.peg.1327',
#   u'pgfam_id': u'PGF_03790040',
#   u'plfam_id': u'PLF_265_00000676',
#   u'product': u'Ribonuclease III (EC 3.1.26.3)',
#   u'property': [u'EC number', u'Subsystem'],
#   u'public': True,
#   u'refseq_locus_tag': u'SAMN04244581_02355',
#   u'segments': [u'142185..142874'],
#   u'sequence_id': u'266.10.con.0049',
#   u'start': 142185,
#   u'strand': u'+',
#   u'taxon_id': 266},
#  {u'aa_length': 186,
#   u'aa_sequence_md5': u'916547711961b3d7d581cf87dc2adc97',
#   u'accession': u'FNEA01000014',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2016-11-19T18:47:57.167Z',
#   u'date_modified': u'2016-11-19T18:47:57.167Z',
#   u'end': 8121,
#   u'feature_id': u'PATRIC.266.10.FNEA01000014.CDS.7561.8121.fwd',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00000174',
#   u'genome_id': u'266.10',
#   u'genome_name': u'Paracoccus denitrificans strain DSM 413',
#   u'location': u'7561..8121',
#   u'na_length': 561,
#   u'na_sequence_md5': u'35cfe53ecbf01a421615bb2ad7e3d4f3',
#   u'owner': u'PATRIC@patricbrc.org',
#   u'patric_id': u'fig|266.10.peg.724',
#   u'pgfam_id': u'PGF_00016443',
#   u'plfam_id': u'PLF_265_00000251',
#   u'product': u'LSU ribosomal protein L5p (L11e)',
#   u'property': [u'Subsystem'],
#   u'public': True,
#   u'refseq_locus_tag': u'SAMN04244581_02722',
#   u'segments': [u'7561..8121'],
#   u'sequence_id': u'266.10.con.0042',
#   u'start': 7561,
#   u'strand': u'+',
#   u'taxon_id': 266},
#  {u'aa_length': 425,
#   u'aa_sequence_md5': u'fb5bd0072ee67162b5b1cce3a4880ff3',
#   u'accession': u'FNEA01000023',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2016-11-19T18:47:57.167Z',
#   u'date_modified': u'2016-11-19T18:47:57.167Z',
#   u'end': 20308,
#   u'feature_id': u'PATRIC.266.10.FNEA01000023.CDS.19031.20308.rev',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00117785',
#   u'genome_id': u'266.10',
#   u'genome_name': u'Paracoccus denitrificans strain DSM 413',
#   u'go': [u'GO:0008892|guanine deaminase activity'],
#   u'location': u'complement(19031..20308)',
#   u'na_length': 1278,
#   u'na_sequence_md5': u'3a9991447396bad3a205a2b6ee62e648',
#   u'owner': u'PATRIC@patricbrc.org',
#   u'patric_id': u'fig|266.10.peg.3423',
#   u'pgfam_id': u'PGF_00010332',
#   u'plfam_id': u'PLF_265_00000237',
#   u'product': u'Guanine deaminase (EC 3.5.4.3)',
#   u'property': [u'EC number', u'Pathway', u'Subsystem'],
#   u'public': True,
#   u'refseq_locus_tag': u'SAMN04244581_03742',
#   u'segments': [u'19031..20308'],
#   u'sequence_id': u'266.10.con.0067',
#   u'start': 19031,
#   u'strand': u'-',
#   u'taxon_id': 266},
#  {u'aa_length': 347,
#   u'aa_sequence_md5': u'3c241a02405f8311ffcb8f13d20d1959',
#   u'accession': u'FNEA01000005',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2016-11-19T18:47:57.167Z',
#   u'date_modified': u'2016-11-19T18:47:57.167Z',
#   u'end': 56326,
#   u'feature_id': u'PATRIC.266.10.FNEA01000005.CDS.55283.56326.rev',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00000375',
#   u'genome_id': u'266.10',
#   u'genome_name': u'Paracoccus denitrificans strain DSM 413',
#   u'go': [u'GO:0034028|5-(carboxyamino)imidazole ribonucleotide synthase activity'],
#   u'location': u'complement(55283..56326)',
#   u'na_length': 1044,
#   u'na_sequence_md5': u'5a64c426df1711dde44c67c66ffa0503',
#   u'owner': u'PATRIC@patricbrc.org',
#   u'patric_id': u'fig|266.10.peg.4975',
#   u'pgfam_id': u'PGF_00024274',
#   u'plfam_id': u'PLF_265_00001193',
#   u'product': u'N5-carboxyaminoimidazole ribonucleotide synthase (EC 6.3.4.18)',
#   u'property': [u'EC number', u'Pathway', u'Subsystem'],
#   u'public': True,
#   u'refseq_locus_tag': u'SAMN04244581_01030',
#   u'segments': [u'55283..56326'],
#   u'sequence_id': u'266.10.con.0093',
#   u'start': 55283,
#   u'strand': u'-',
#   u'taxon_id': 266},
#  {u'aa_length': 221,
#   u'aa_sequence_md5': u'76341ed01b1da62cb75e459b75364717',
#   u'accession': u'FNEA01000065',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2016-11-19T18:47:57.167Z',
#   u'date_modified': u'2016-11-19T18:47:57.167Z',
#   u'end': 6448,
#   u'feature_id': u'PATRIC.266.10.FNEA01000065.CDS.5783.6448.fwd',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00000646',
#   u'genome_id': u'266.10',
#   u'genome_name': u'Paracoccus denitrificans strain DSM 413',
#   u'location': u'5783..6448',
#   u'na_length': 666,
#   u'na_sequence_md5': u'bc54cd7217a80a28f29db419d507424a',
#   u'owner': u'PATRIC@patricbrc.org',
#   u'patric_id': u'fig|266.10.peg.63',
#   u'pgfam_id': u'PGF_01602421',
#   u'plfam_id': u'PLF_265_00001260',
#   u'product': u'Flagellar basal-body rod modification protein FlgD',
#   u'property': [u'Subsystem'],
#   u'public': True,
#   u'refseq_locus_tag': u'SAMN04244581_05078',
#   u'segments': [u'5783..6448'],
#   u'sequence_id': u'266.10.con.0015',
#   u'start': 5783,
#   u'strand': u'+',
#   u'taxon_id': 266},
#  {u'aa_length': 132,
#   u'aa_sequence_md5': u'667e15a2fa389c9cd9b32ca3a18b5b81',
#   u'accession': u'FNEA01000003',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2016-11-19T18:47:57.167Z',
#   u'date_modified': u'2016-11-19T18:47:57.167Z',
#   u'end': 130606,
#   u'feature_id': u'PATRIC.266.10.FNEA01000003.CDS.130208.130606.rev',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00598409',
#   u'genome_id': u'266.10',
#   u'genome_name': u'Paracoccus denitrificans strain DSM 413',
#   u'go': [u'GO:0004476|mannose-6-phosphate isomerase activity'],
#   u'location': u'complement(130208..130606)',
#   u'na_length': 399,
#   u'na_sequence_md5': u'975a009e94b1105f09981335ec56bda3',
#   u'owner': u'PATRIC@patricbrc.org',
#   u'patric_id': u'fig|266.10.peg.1797',
#   u'pgfam_id': u'PGF_05126853',
#   u'plfam_id': u'PLF_265_00020962',
#   u'product': u'Mannose-6-phosphate isomerase (EC 5.3.1.8)',
#   u'property': [u'EC number', u'Pathway', u'Subsystem'],
#   u'public': True,
#   u'refseq_locus_tag': u'SAMN04244581_00616',
#   u'segments': [u'130208..130606'],
#   u'sequence_id': u'266.10.con.0054',
#   u'start': 130208,
#   u'strand': u'-',
#   u'taxon_id': 266},
#  {u'aa_length': 340,
#   u'aa_sequence_md5': u'5851b5e50f7518fa20d7f4291236b9a4',
#   u'accession': u'FNEA01000004',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2016-11-19T18:47:57.167Z',
#   u'date_modified': u'2016-11-19T18:47:57.167Z',
#   u'end': 228250,
#   u'feature_id': u'PATRIC.266.10.FNEA01000004.CDS.227228.228250.rev',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00000244',
#   u'genome_id': u'266.10',
#   u'genome_name': u'Paracoccus denitrificans strain DSM 413',
#   u'go': [u'GO:0004455|ketol-acid reductoisomerase activity'],
#   u'location': u'complement(227228..228250)',
#   u'na_length': 1023,
#   u'na_sequence_md5': u'903d69329e2d3a56407f370c14df65aa',
#   u'owner': u'PATRIC@patricbrc.org',
#   u'patric_id': u'fig|266.10.peg.1589',
#   u'pgfam_id': u'PGF_00015855',
#   u'plfam_id': u'PLF_265_00000944',
#   u'product': u'Ketol-acid reductoisomerase (NADP(+)) (EC 1.1.1.86)',
#   u'property': [u'EC number', u'Pathway', u'Subsystem'],
#   u'public': True,
#   u'refseq_locus_tag': u'SAMN04244581_00954',
#   u'segments': [u'227228..228250'],
#   u'sequence_id': u'266.10.con.0050',
#   u'start': 227228,
#   u'strand': u'-',
#   u'taxon_id': 266},
#  {u'aa_length': 348,
#   u'aa_sequence_md5': u'599bff6e35d156612c6bf111aff421f4',
#   u'accession': u'FNEA01000029',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2016-11-19T18:47:57.167Z',
#   u'date_modified': u'2016-11-19T18:47:57.167Z',
#   u'end': 3772,
#   u'feature_id': u'PATRIC.266.10.FNEA01000029.CDS.2726.3772.rev',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00030415',
#   u'genome_id': u'266.10',
#   u'genome_name': u'Paracoccus denitrificans strain DSM 413',
#   u'location': u'complement(2726..3772)',
#   u'na_length': 1047,
#   u'na_sequence_md5': u'21a23a384abe4a7bdf0a34b4415c10c2',
#   u'owner': u'PATRIC@patricbrc.org',
#   u'patric_id': u'fig|266.10.peg.3965',
#   u'pgfam_id': u'PGF_01014588',
#   u'plfam_id': u'PLF_265_00004868',
#   u'product': u'Microsomal dipeptidase (EC 3.4.13.19)',
#   u'property': [u'EC number', u'Subsystem'],
#   u'public': True,
#   u'refseq_locus_tag': u'SAMN04244581_04102',
#   u'segments': [u'2726..3772'],
#   u'sequence_id': u'266.10.con.0075',
#   u'start': 2726,
#   u'strand': u'-',
#   u'taxon_id': 266},
#  {u'aa_length': 423,
#   u'aa_sequence_md5': u'79987e6f8ba1430489f6da3274124e9e',
#   u'accession': u'FNEA01000007',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2016-11-19T18:47:57.167Z',
#   u'date_modified': u'2016-11-19T18:47:57.167Z',
#   u'end': 61068,
#   u'feature_id': u'PATRIC.266.10.FNEA01000007.CDS.59797.61068.fwd',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00000032',
#   u'genome_id': u'266.10',
#   u'genome_name': u'Paracoccus denitrificans strain DSM 413',
#   u'go': [u'GO:0004151|dihydroorotase activity'],
#   u'location': u'59797..61068',
#   u'na_length': 1272,
#   u'na_sequence_md5': u'b201ade9be1cb6e7c0d0257e5f3d811e',
#   u'owner': u'PATRIC@patricbrc.org',
#   u'patric_id': u'fig|266.10.peg.2327',
#   u'pgfam_id': u'PGF_00423378',
#   u'plfam_id': u'PLF_265_00000888',
#   u'product': u'Dihydroorotase (EC 3.5.2.3)',
#   u'property': [u'EC number', u'Pathway', u'Subsystem'],
#   u'public': True,
#   u'refseq_locus_tag': u'SAMN04244581_01511',
#   u'segments': [u'59797..61068'],
#   u'sequence_id': u'266.10.con.0057',
#   u'start': 59797,
#   u'strand': u'+',
#   u'taxon_id': 266},
#  {u'aa_length': 235,
#   u'aa_sequence_md5': u'220a71ff3afc1218dd432f1093a527f4',
#   u'accession': u'FNEA01000019',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2016-11-19T18:47:57.167Z',
#   u'date_modified': u'2016-11-19T18:47:57.167Z',
#   u'end': 37018,
#   u'feature_id': u'PATRIC.266.10.FNEA01000019.CDS.36311.37018.rev',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00000151',
#   u'genome_id': u'266.10',
#   u'genome_name': u'Paracoccus denitrificans strain DSM 413',
#   u'go': [u'GO:0004045|aminoacyl-tRNA hydrolase activity'],
#   u'location': u'complement(36311..37018)',
#   u'na_length': 708,
#   u'na_sequence_md5': u'4a9bd8888cc805cf72120b84134db911',
#   u'owner': u'PATRIC@patricbrc.org',
#   u'patric_id': u'fig|266.10.peg.3116',
#   u'pgfam_id': u'PGF_04788810',
#   u'plfam_id': u'PLF_265_00000986',
#   u'product': u'Peptidyl-tRNA hydrolase (EC 3.1.1.29)',
#   u'property': [u'EC number', u'Subsystem'],
#   u'public': True,
#   u'refseq_locus_tag': u'SAMN04244581_03396',
#   u'segments': [u'36311..37018'],
#   u'sequence_id': u'266.10.con.0062',
#   u'start': 36311,
#   u'strand': u'-',
#   u'taxon_id': 266},
#  {u'aa_length': 131,
#   u'aa_sequence_md5': u'8e04af35863d47876871b636866ea9a9',
#   u'accession': u'FNEA01000001',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2016-11-19T18:47:57.167Z',
#   u'date_modified': u'2016-11-19T18:47:57.167Z',
#   u'end': 211494,
#   u'feature_id': u'PATRIC.266.10.FNEA01000001.CDS.211099.211494.rev',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00004743',
#   u'genome_id': u'266.10',
#   u'genome_name': u'Paracoccus denitrificans strain DSM 413',
#   u'go': [u'GO:0004462|lactoylglutathione lyase activity'],
#   u'location': u'complement(211099..211494)',
#   u'na_length': 396,
#   u'na_sequence_md5': u'cfc269493d1f930c27a6164a2c2efae4',
#   u'owner': u'PATRIC@patricbrc.org',
#   u'patric_id': u'fig|266.10.peg.4812',
#   u'pgfam_id': u'PGF_00016546',
#   u'plfam_id': u'PLF_265_00001524',
#   u'product': u'Lactoylglutathione lyase (EC 4.4.1.5)',
#   u'property': [u'EC number', u'Pathway', u'Subsystem'],
#   u'public': True,
#   u'refseq_locus_tag': u'SAMN04244581_00196',
#   u'segments': [u'211099..211494'],
#   u'sequence_id': u'266.10.con.0090',
#   u'start': 211099,
#   u'strand': u'-',
#   u'taxon_id': 266},
#  {u'aa_length': 154,
#   u'aa_sequence_md5': u'b7e9ada0a2d70031b4f43472b2b463b2',
#   u'accession': u'FNEA01000040',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2016-11-19T18:47:57.167Z',
#   u'date_modified': u'2016-11-19T18:47:57.167Z',
#   u'end': 4219,
#   u'feature_id': u'PATRIC.266.10.FNEA01000040.CDS.3755.4219.fwd',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00002724',
#   u'genome_id': u'266.10',
#   u'genome_name': u'Paracoccus denitrificans strain DSM 413',
#   u'location': u'3755..4219',
#   u'na_length': 465,
#   u'na_sequence_md5': u'f0e8faf8893054ccbe7e9200db50ecd5',
#   u'owner': u'PATRIC@patricbrc.org',
#   u'patric_id': u'fig|266.10.peg.4396',
#   u'pgfam_id': u'PGF_01077980',
#   u'plfam_id': u'PLF_265_00000291',
#   u'product': u'PutR, transcriptional activator of PutA and PutP',
#   u'property': [u'Subsystem'],
#   u'public': True,
#   u'refseq_locus_tag': u'SAMN04244581_04580',
#   u'segments': [u'3755..4219'],
#   u'sequence_id': u'266.10.con.0084',
#   u'start': 3755,
#   u'strand': u'+',
#   u'taxon_id': 266},
#  {u'aa_length': 540,
#   u'aa_sequence_md5': u'757a6e4913e4610dd2272da4a05b0b8b',
#   u'accession': u'FNEA01000003',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2016-11-19T18:47:57.167Z',
#   u'date_modified': u'2016-11-19T18:47:57.167Z',
#   u'end': 213959,
#   u'feature_id': u'PATRIC.266.10.FNEA01000003.CDS.212337.213959.fwd',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00001217',
#   u'genome_id': u'266.10',
#   u'genome_name': u'Paracoccus denitrificans strain DSM 413',
#   u'go': [u'GO:0004474|malate synthase activity'],
#   u'location': u'212337..213959',
#   u'na_length': 1623,
#   u'na_sequence_md5': u'cdd797394ad666c3ae405b590526fd38',
#   u'owner': u'PATRIC@patricbrc.org',
#   u'patric_id': u'fig|266.10.peg.1876',
#   u'pgfam_id': u'PGF_00018964',
#   u'plfam_id': u'PLF_265_00004004',
#   u'product': u'Malate synthase (EC 2.3.3.9)',
#   u'property': [u'EC number', u'Pathway', u'Subsystem'],
#   u'public': True,
#   u'refseq_locus_tag': u'SAMN04244581_00695',
#   u'segments': [u'212337..213959'],
#   u'sequence_id': u'266.10.con.0054',
#   u'start': 212337,
#   u'strand': u'+',
#   u'taxon_id': 266},
#  {u'aa_length': 434,
#   u'aa_sequence_md5': u'415838719c622e623e71e5f808a4c888',
#   u'accession': u'FNEA01000008',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2016-11-19T18:47:57.167Z',
#   u'date_modified': u'2016-11-19T18:47:57.167Z',
#   u'end': 134472,
#   u'feature_id': u'PATRIC.266.10.FNEA01000008.CDS.133168.134472.fwd',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00000392',
#   u'genome_id': u'266.10',
#   u'genome_name': u'Paracoccus denitrificans strain DSM 413',
#   u'location': u'133168..134472',
#   u'na_length': 1305,
#   u'na_sequence_md5': u'79fe3ac465425d3ca678691a20214f8e',
#   u'owner': u'PATRIC@patricbrc.org',
#   u'patric_id': u'fig|266.10.peg.2598',
#   u'pgfam_id': u'PGF_00057483',
#   u'plfam_id': u'PLF_265_00000732',
#   u'product': u'Transcription termination factor Rho',
#   u'property': [u'Subsystem'],
#   u'public': True,
#   u'refseq_locus_tag': u'SAMN04244581_01778',
#   u'segments': [u'133168..134472'],
#   u'sequence_id': u'266.10.con.0058',
#   u'start': 133168,
#   u'strand': u'+',
#   u'taxon_id': 266},
#  {u'aa_length': 1144,
#   u'aa_sequence_md5': u'67e6f85b12fd82e3ee9e4096e8ea0721',
#   u'accession': u'FNEA01000012',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2016-11-19T18:47:57.167Z',
#   u'date_modified': u'2016-11-19T18:47:57.167Z',
#   u'end': 75708,
#   u'feature_id': u'PATRIC.266.10.FNEA01000012.CDS.72274.75708.rev',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00001308',
#   u'genome_id': u'266.10',
#   u'genome_name': u'Paracoccus denitrificans strain DSM 413',
#   u'go': [u'GO:0004736|pyruvate carboxylase activity'],
#   u'location': u'complement(72274..75708)',
#   u'na_length': 3435,
#   u'na_sequence_md5': u'7c15c60a036a8f1ada7783dee815bef6',
#   u'owner': u'PATRIC@patricbrc.org',
#   u'patric_id': u'fig|266.10.peg.968',
#   u'pgfam_id': u'PGF_00045963',
#   u'plfam_id': u'PLF_265_00000052',
#   u'product': u'Pyruvate carboxylase (EC 6.4.1.1)',
#   u'property': [u'EC number', u'Pathway', u'Subsystem'],
#   u'public': True,
#   u'refseq_locus_tag': u'SAMN04244581_02472',
#   u'segments': [u'72274..75708'],
#   u'sequence_id': u'266.10.con.0044',
#   u'start': 72274,
#   u'strand': u'-',
#   u'taxon_id': 266},
#  {u'aa_length': 184,
#   u'aa_sequence_md5': u'765446d38b3b34e06150c6dfb0de59aa',
#   u'accession': u'FNEA01000024',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2016-11-19T18:47:57.167Z',
#   u'date_modified': u'2016-11-19T18:47:57.167Z',
#   u'end': 35609,
#   u'feature_id': u'PATRIC.266.10.FNEA01000024.CDS.35055.35609.rev',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00060678',
#   u'genome_id': u'266.10',
#   u'genome_name': u'Paracoccus denitrificans strain DSM 413',
#   u'location': u'complement(35055..35609)',
#   u'na_length': 555,
#   u'na_sequence_md5': u'2cf8abb2af6acdcb32017c1dfd1d3217',
#   u'owner': u'PATRIC@patricbrc.org',
#   u'patric_id': u'fig|266.10.peg.2701',
#   u'pgfam_id': u'PGF_00056712',
#   u'plfam_id': u'PLF_265_00001587',
#   u'product': u'Thiol:disulfide oxidoreductase TlpA',
#   u'property': [u'Subsystem'],
#   u'public': True,
#   u'refseq_locus_tag': u'SAMN04244581_03824',
#   u'segments': [u'35055..35609'],
#   u'sequence_id': u'266.10.con.0059',
#   u'start': 35055,
#   u'strand': u'-',
#   u'taxon_id': 266},
#  {u'aa_length': 152,
#   u'aa_sequence_md5': u'51b20305344494d3f4b0ac2c3e7206aa',
#   u'accession': u'FNEA01000028',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2016-11-19T18:47:57.167Z',
#   u'date_modified': u'2016-11-19T18:47:57.167Z',
#   u'end': 43889,
#   u'feature_id': u'PATRIC.266.10.FNEA01000028.CDS.43431.43889.rev',
#   u'feature_type': u'CDS',
#   u'genome_id': u'266.10',
#   u'genome_name': u'Paracoccus denitrificans strain DSM 413',
#   u'go': [u'GO:0046353|aminoglycoside 3-N-acetyltransferase activity'],
#   u'location': u'complement(43431..43889)',
#   u'na_length': 459,
#   u'na_sequence_md5': u'e2070113d7c1bbc973c5de7b9c7befed',
#   u'owner': u'PATRIC@patricbrc.org',
#   u'patric_id': u'fig|266.10.peg.4520',
#   u'pgfam_id': u'PGF_04399682',
#   u'plfam_id': u'PLF_265_00005828',
#   u'product': u'Aminoglycoside N(3)-acetyltransferase (EC 2.3.1.81) => AAC(3)-I',
#   u'property': [u'EC number', u'Subsystem'],
#   u'public': True,
#   u'refseq_locus_tag': u'SAMN04244581_04083',
#   u'segments': [u'43431..43889'],
#   u'sequence_id': u'266.10.con.0086',
#   u'start': 43431,
#   u'strand': u'-',
#   u'taxon_id': 266},
#  {u'aa_length': 167,
#   u'aa_sequence_md5': u'a5e018d224d4acab899e0e93a4803fc6',
#   u'accession': u'FNEA01000014',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2016-11-19T18:47:57.167Z',
#   u'date_modified': u'2016-11-19T18:47:57.167Z',
#   u'end': 149088,
#   u'feature_id': u'PATRIC.266.10.FNEA01000014.CDS.148585.149088.fwd',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00000670',
#   u'genome_id': u'266.10',
#   u'genome_name': u'Paracoccus denitrificans strain DSM 413',
#   u'location': u'148585..149088',
#   u'na_length': 504,
#   u'na_sequence_md5': u'd6d513b6bafd7e8ab36a9750bf03a228',
#   u'owner': u'PATRIC@patricbrc.org',
#   u'patric_id': u'fig|266.10.peg.863',
#   u'pgfam_id': u'PGF_00709443',
#   u'plfam_id': u'PLF_265_00001073',
#   u'product': u'Twin-arginine translocation protein TatB',
#   u'property': [u'Subsystem'],
#   u'public': True,
#   u'refseq_locus_tag': u'SAMN04244581_02861',
#   u'segments': [u'148585..149088'],
#   u'sequence_id': u'266.10.con.0042',
#   u'start': 148585,
#   u'strand': u'+',
#   u'taxon_id': 266},
#  {u'aa_length': 142,
#   u'aa_sequence_md5': u'ff54ded0b0c082761462754058eb12b6',
#   u'accession': u'FNEA01000040',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2016-11-19T18:47:57.167Z',
#   u'date_modified': u'2016-11-19T18:47:57.167Z',
#   u'end': 10755,
#   u'feature_id': u'PATRIC.266.10.FNEA01000040.CDS.10327.10755.rev',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00004743',
#   u'genome_id': u'266.10',
#   u'genome_name': u'Paracoccus denitrificans strain DSM 413',
#   u'go': [u'GO:0004462|lactoylglutathione lyase activity'],
#   u'location': u'complement(10327..10755)',
#   u'na_length': 429,
#   u'na_sequence_md5': u'3d2179dd6bd3e00070b038c8ac29f980',
#   u'owner': u'PATRIC@patricbrc.org',
#   u'patric_id': u'fig|266.10.peg.4403',
#   u'pgfam_id': u'PGF_00016546',
#   u'plfam_id': u'PLF_265_00000547',
#   u'product': u'Lactoylglutathione lyase (EC 4.4.1.5)',
#   u'property': [u'EC number', u'Pathway', u'Subsystem'],
#   u'public': True,
#   u'refseq_locus_tag': u'SAMN04244581_04587',
#   u'segments': [u'10327..10755'],
#   u'sequence_id': u'266.10.con.0084',
#   u'start': 10327,
#   u'strand': u'-',
#   u'taxon_id': 266},
#  {u'aa_length': 217,
#   u'aa_sequence_md5': u'15242870ab52a58e18b7ced004f4908e',
#   u'accession': u'FNEA01000036',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2016-11-19T18:47:57.167Z',
#   u'date_modified': u'2016-11-19T18:47:57.167Z',
#   u'end': 36624,
#   u'feature_id': u'PATRIC.266.10.FNEA01000036.CDS.35971.36624.rev',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00002546',
#   u'genome_id': u'266.10',
#   u'genome_name': u'Paracoccus denitrificans strain DSM 413',
#   u'location': u'complement(35971..36624)',
#   u'na_length': 654,
#   u'na_sequence_md5': u'671f856f13fcb903d72acdfc5b85179f',
#   u'owner': u'PATRIC@patricbrc.org',
#   u'patric_id': u'fig|266.10.peg.3272',
#   u'pgfam_id': u'PGF_00418926',
#   u'plfam_id': u'PLF_265_00001481',
#   u'product': u'Conjugative transfer protein TrbJ',
#   u'property': [u'Subsystem'],
#   u'public': True,
#   u'refseq_locus_tag': u'SAMN04244581_04475',
#   u'segments': [u'35971..36624'],
#   u'sequence_id': u'266.10.con.0064',
#   u'start': 35971,
#   u'strand': u'-',
#   u'taxon_id': 266},
#  {u'aa_length': 156,
#   u'aa_sequence_md5': u'57df4095e361e1e9e8a3a7f7d58fa309',
#   u'accession': u'FNEA01000046',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2016-11-19T18:47:57.167Z',
#   u'date_modified': u'2016-11-19T18:47:57.167Z',
#   u'end': 2794,
#   u'feature_id': u'PATRIC.266.10.FNEA01000046.CDS.2324.2794.rev',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00000209',
#   u'genome_id': u'266.10',
#   u'genome_name': u'Paracoccus denitrificans strain DSM 413',
#   u'location': u'complement(2324..2794)',
#   u'na_length': 471,
#   u'na_sequence_md5': u'4b18c46bb96cbcbd5c059e0cead47fe2',
#   u'owner': u'PATRIC@patricbrc.org',
#   u'patric_id': u'fig|266.10.peg.5329',
#   u'pgfam_id': u'PGF_00049904',
#   u'plfam_id': u'PLF_265_00000704',
#   u'product': u'SSU ribosomal protein S7p (S5e)',
#   u'property': [u'Subsystem'],
#   u'public': True,
#   u'refseq_locus_tag': u'SAMN04244581_04770',
#   u'segments': [u'2324..2794'],
#   u'sequence_id': u'266.10.con.0095',
#   u'start': 2324,
#   u'strand': u'-',
#   u'taxon_id': 266},
#  {u'aa_length': 338,
#   u'aa_sequence_md5': u'09c27ab8e796a5e00831a8e05a66b6df',
#   u'accession': u'FNEA01000005',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2016-11-19T18:47:57.167Z',
#   u'date_modified': u'2016-11-19T18:47:57.167Z',
#   u'end': 60633,
#   u'feature_id': u'PATRIC.266.10.FNEA01000005.CDS.59617.60633.rev',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00018396',
#   u'genome_id': u'266.10',
#   u'genome_name': u'Paracoccus denitrificans strain DSM 413',
#   u'go': [u'GO:0004791|thioredoxin-disulfide reductase activity'],
#   u'location': u'complement(59617..60633)',
#   u'na_length': 1017,
#   u'na_sequence_md5': u'e878e27de1cc363d31f6721b88aff203',
#   u'owner': u'PATRIC@patricbrc.org',
#   u'patric_id': u'fig|266.10.peg.4983',
#   u'pgfam_id': u'PGF_01625234',
#   u'plfam_id': u'PLF_265_00000722',
#   u'product': u'Thioredoxin reductase (EC 1.8.1.9)',
#   u'property': [u'EC number', u'Pathway', u'Subsystem'],
#   u'public': True,
#   u'refseq_locus_tag': u'SAMN04244581_01037',
#   u'segments': [u'59617..60633'],
#   u'sequence_id': u'266.10.con.0093',
#   u'start': 59617,
#   u'strand': u'-',
#   u'taxon_id': 266},
#  {u'aa_length': 453,
#   u'aa_sequence_md5': u'de7d234d3746e5e573cba3dd7e692dc1',
#   u'accession': u'FNEA01000014',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2016-11-19T18:47:57.167Z',
#   u'date_modified': u'2016-11-19T18:47:57.167Z',
#   u'end': 154417,
#   u'feature_id': u'PATRIC.266.10.FNEA01000014.CDS.153056.154417.rev',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00001172',
#   u'genome_id': u'266.10',
#   u'genome_name': u'Paracoccus denitrificans strain DSM 413',
#   u'go': [u'GO:0004411|homogentisate 1,2-dioxygenase activity'],
#   u'location': u'complement(153056..154417)',
#   u'na_length': 1362,
#   u'na_sequence_md5': u'7c792a6e760eac4f459777025454fbd4',
#   u'owner': u'PATRIC@patricbrc.org',
#   u'patric_id': u'fig|266.10.peg.869',
#   u'pgfam_id': u'PGF_00012291',
#   u'plfam_id': u'PLF_265_00000032',
#   u'product': u'Homogentisate 1,2-dioxygenase (EC 1.13.11.5)',
#   u'property': [u'EC number', u'Pathway', u'Subsystem'],
#   u'public': True,
#   u'refseq_locus_tag': u'SAMN04244581_02867',
#   u'segments': [u'153056..154417'],
#   u'sequence_id': u'266.10.con.0042',
#   u'start': 153056,
#   u'strand': u'-',
#   u'taxon_id': 266},
#  {u'aa_length': 385,
#   u'aa_sequence_md5': u'1b7a741e89e3273ca6bfd44236a71e03',
#   u'accession': u'FNEA01000017',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2016-11-19T18:47:57.167Z',
#   u'date_modified': u'2016-11-19T18:47:57.167Z',
#   u'end': 93711,
#   u'feature_id': u'PATRIC.266.10.FNEA01000017.CDS.92554.93711.fwd',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00121995',
#   u'genome_id': u'266.10',
#   u'genome_name': u'Paracoccus denitrificans strain DSM 413',
#   u'location': u'92554..93711',
#   u'na_length': 1158,
#   u'na_sequence_md5': u'a8764cf6afe395fba8dd5475e16ccf40',
#   u'owner': u'PATRIC@patricbrc.org',
#   u'patric_id': u'fig|266.10.peg.685',
#   u'pgfam_id': u'PGF_00016130',
#   u'plfam_id': u'PLF_265_00002598',
#   u'product': u'L-lactate dehydrogenase',
#   u'property': [u'Subsystem'],
#   u'public': True,
#   u'refseq_locus_tag': u'SAMN04244581_03198',
#   u'segments': [u'92554..93711'],
#   u'sequence_id': u'266.10.con.0041',
#   u'start': 92554,
#   u'strand': u'+',
#   u'taxon_id': 266},
#  {u'aa_length': 321,
#   u'aa_sequence_md5': u'3b39a5090e65e136a886991954b3082a',
#   u'accession': u'FNEA01000015',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2016-11-19T18:47:57.167Z',
#   u'date_modified': u'2016-11-19T18:47:57.167Z',
#   u'end': 141424,
#   u'feature_id': u'PATRIC.266.10.FNEA01000015.CDS.140459.141424.fwd',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00002746',
#   u'genome_id': u'266.10',
#   u'genome_name': u'Paracoccus denitrificans strain DSM 413',
#   u'location': u'140459..141424',
#   u'na_length': 966,
#   u'na_sequence_md5': u'84cab1978addc246e4c0da5c90285e2f',
#   u'owner': u'PATRIC@patricbrc.org',
#   u'patric_id': u'fig|266.10.peg.3406',
#   u'pgfam_id': u'PGF_08193089',
#   u'plfam_id': u'PLF_265_00003064',
#   u'product': u'Chromosome (plasmid) partitioning protein ParB',
#   u'property': [u'Subsystem'],
#   u'public': True,
#   u'refseq_locus_tag': u'SAMN04244581_02996',
#   u'segments': [u'140459..141424'],
#   u'sequence_id': u'266.10.con.0066',
#   u'start': 140459,
#   u'strand': u'+',
#   u'taxon_id': 266},
#  {u'aa_length': 532,
#   u'aa_sequence_md5': u'40a6548aa5ae240d3d7f971e04e93af9',
#   u'accession': u'FNEA01000002',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2016-11-19T18:47:57.167Z',
#   u'date_modified': u'2016-11-19T18:47:57.167Z',
#   u'end': 168382,
#   u'feature_id': u'PATRIC.266.10.FNEA01000002.CDS.166784.168382.fwd',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00000834',
#   u'genome_id': u'266.10',
#   u'genome_name': u'Paracoccus denitrificans strain DSM 413',
#   u'go': [u'GO:0004612|phosphoenolpyruvate carboxykinase (ATP) activity'],
#   u'location': u'166784..168382',
#   u'na_length': 1599,
#   u'na_sequence_md5': u'fd5f10480aeebc902e4270dca826589f',
#   u'owner': u'PATRIC@patricbrc.org',
#   u'patric_id': u'fig|266.10.peg.3693',
#   u'pgfam_id': u'PGF_02947204',
#   u'plfam_id': u'PLF_265_00000627',
#   u'product': u'Phosphoenolpyruvate carboxykinase [ATP] (EC 4.1.1.49)',
#   u'property': [u'EC number', u'Pathway', u'Subsystem'],
#   u'public': True,
#   u'refseq_locus_tag': u'SAMN04244581_00409',
#   u'segments': [u'166784..168382'],
#   u'sequence_id': u'266.10.con.0070',
#   u'start': 166784,
#   u'strand': u'+',
#   u'taxon_id': 266},
#  {u'aa_length': 289,
#   u'aa_sequence_md5': u'7d1b1ef666f265cacc02d3f8bb2f07bf',
#   u'accession': u'FNEA01000028',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2016-11-19T18:47:57.167Z',
#   u'date_modified': u'2016-11-19T18:47:57.167Z',
#   u'end': 35706,
#   u'feature_id': u'PATRIC.266.10.FNEA01000028.CDS.34837.35706.rev',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG01577562',
#   u'genome_id': u'266.10',
#   u'genome_name': u'Paracoccus denitrificans strain DSM 413',
#   u'location': u'complement(34837..35706)',
#   u'na_length': 870,
#   u'na_sequence_md5': u'516c6b716901e79ea2ece0b1ee26d052',
#   u'owner': u'PATRIC@patricbrc.org',
#   u'patric_id': u'fig|266.10.peg.4504',
#   u'pgfam_id': u'PGF_05286155',
#   u'plfam_id': u'PLF_265_00004955',
#   u'product': u'Plasmid replication protein RepA',
#   u'property': [u'Subsystem'],
#   u'public': True,
#   u'refseq_locus_tag': u'SAMN04244581_04068',
#   u'segments': [u'34837..35706'],
#   u'sequence_id': u'266.10.con.0086',
#   u'start': 34837,
#   u'strand': u'-',
#   u'taxon_id': 266},
#  {u'aa_length': 68,
#   u'aa_sequence_md5': u'6eb4bdf3880d9ca0435f8a2a7828b2c0',
#   u'accession': u'FNEA01000014',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2016-11-19T18:47:57.167Z',
#   u'date_modified': u'2016-11-19T18:47:57.167Z',
#   u'end': 6563,
#   u'feature_id': u'PATRIC.266.10.FNEA01000014.CDS.6357.6563.fwd',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00015729',
#   u'genome_id': u'266.10',
#   u'genome_name': u'Paracoccus denitrificans strain DSM 413',
#   u'location': u'6357..6563',
#   u'na_length': 207,
#   u'na_sequence_md5': u'4362e2e6c180bae584d67c1d84674462',
#   u'owner': u'PATRIC@patricbrc.org',
#   u'patric_id': u'fig|266.10.peg.720',
#   u'pgfam_id': u'PGF_02899131',
#   u'plfam_id': u'PLF_265_00000537',
#   u'product': u'LSU ribosomal protein L29p (L35e)',
#   u'property': [u'Subsystem'],
#   u'public': True,
#   u'refseq_locus_tag': u'SAMN04244581_02718',
#   u'segments': [u'6357..6563'],
#   u'sequence_id': u'266.10.con.0042',
#   u'start': 6357,
#   u'strand': u'+',
#   u'taxon_id': 266},
#  {u'aa_length': 260,
#   u'aa_sequence_md5': u'495ad14a9214b6a5600998435676c4e6',
#   u'accession': u'FNEA01000003',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2016-11-19T18:47:57.167Z',
#   u'date_modified': u'2016-11-19T18:47:57.167Z',
#   u'end': 103266,
#   u'feature_id': u'PATRIC.266.10.FNEA01000003.CDS.102484.103266.fwd',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00002546',
#   u'genome_id': u'266.10',
#   u'genome_name': u'Paracoccus denitrificans strain DSM 413',
#   u'location': u'102484..103266',
#   u'na_length': 783,
#   u'na_sequence_md5': u'88072f1c538b6e1107108c8a64651a08',
#   u'owner': u'PATRIC@patricbrc.org',
#   u'patric_id': u'fig|266.10.peg.1765',
#   u'pgfam_id': u'PGF_00418926',
#   u'plfam_id': u'PLF_265_00001481',
#   u'product': u'Conjugative transfer protein TrbJ',
#   u'property': [u'Subsystem'],
#   u'public': True,
#   u'refseq_locus_tag': u'SAMN04244581_00584',
#   u'segments': [u'102484..103266'],
#   u'sequence_id': u'266.10.con.0054',
#   u'start': 102484,
#   u'strand': u'+',
#   u'taxon_id': 266},
#  {u'aa_length': 70,
#   u'aa_sequence_md5': u'6d64cd3919b733c2195e92517aaa44e3',
#   u'accession': u'FNEA01000002',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2016-11-19T18:47:57.167Z',
#   u'date_modified': u'2016-11-19T18:47:57.167Z',
#   u'end': 206980,
#   u'feature_id': u'PATRIC.266.10.FNEA01000002.CDS.206768.206980.rev',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00451255',
#   u'genome_id': u'266.10',
#   u'genome_name': u'Paracoccus denitrificans strain DSM 413',
#   u'location': u'complement(206768..206980)',
#   u'na_length': 213,
#   u'na_sequence_md5': u'13d282d856b8797a75ff1128d2cbd103',
#   u'owner': u'PATRIC@patricbrc.org',
#   u'patric_id': u'fig|266.10.peg.3733',
#   u'pgfam_id': u'PGF_00007263',
#   u'plfam_id': u'PLF_265_00002826',
#   u'product': u'Gene Transfer Agent (GTA) ORFG10b',
#   u'property': [u'Subsystem'],
#   u'public': True,
#   u'refseq_locus_tag': u'SAMN04244581_00449',
# ...
#   u'figfam_id': u'FIG00885043',
#   u'genome_id': u'266.10',
#   u'genome_name': u'Paracoccus denitrificans strain DSM 413',
#   u'location': u'complement(140475..142175)',
#   u'na_length': 1701,
#   u'na_sequence_md5': u'ad49b741cf40cae68e5456385c863cc6',
#   u'owner': u'PATRIC@patricbrc.org',
#   u'patric_id': u'fig|266.10.peg.5072',
#   u'pgfam_id': u'PGF_00419639',
#   u'plfam_id': u'PLF_265_00001150',
#   u'product': u'Core-2/I-branching enzyme family protein',
#   u'public': True,
#   u'refseq_locus_tag': u'SAMN04244581_01123',
#   u'segments': [u'140475..142175'],
#   u'sequence_id': u'266.10.con.0093',
#   u'start': 140475,
#   u'strand': u'-',
#   u'taxon_id': 266},
#  {u'aa_length': 370,
#   u'aa_sequence_md5': u'475e6dbc0761e612dd11ba3059732974',
#   u'accession': u'FNEA01000005',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2016-11-19T18:47:57.167Z',
#   u'date_modified': u'2016-11-19T18:47:57.167Z',
#   u'end': 170597,
#   u'feature_id': u'PATRIC.266.10.FNEA01000005.CDS.169485.170597.rev',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG01030755',
#   u'genome_id': u'266.10',
#   u'genome_name': u'Paracoccus denitrificans strain DSM 413',
#   u'location': u'complement(169485..170597)',
#   u'na_length': 1113,
#   u'na_sequence_md5': u'3302e0433953dc2d951092ac6c1d333f',
#   u'owner': u'PATRIC@patricbrc.org',
#   u'patric_id': u'fig|266.10.peg.5100',
#   u'pgfam_id': u'PGF_00402639',
#   u'plfam_id': u'PLF_265_00001625',
#   u'product': u'peptidoglycan binding domain protein',
#   u'public': True,
#   u'refseq_locus_tag': u'SAMN04244581_01149',
#   u'segments': [u'169485..170597'],
#   u'sequence_id': u'266.10.con.0093',
#   u'start': 169485,
#   u'strand': u'-',
#   u'taxon_id': 266},
#  {u'accession': u'FNEA01000005',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2016-11-19T18:47:57.167Z',
#   u'date_modified': u'2016-11-19T18:47:57.167Z',
#   u'end': 192617,
#   u'feature_id': u'PATRIC.266.10.FNEA01000005.tRNA.192542.192617.rev',
#   u'feature_type': u'tRNA',
#   u'genome_id': u'266.10',
#   u'genome_name': u'Paracoccus denitrificans strain DSM 413',
#   u'location': u'complement(192542..192617)',
#   u'na_length': 76,
#   u'na_sequence_md5': u'6061dce4f3d83588aa00fbf482033979',
#   u'owner': u'PATRIC@patricbrc.org',
#   u'patric_id': u'fig|266.10.rna.62',
#   u'product': u'tRNA-Ala',
#   u'public': True,
#   u'refseq_locus_tag': u'SAMN04244581_01175',
#   u'segments': [u'192542..192617'],
#   u'sequence_id': u'266.10.con.0093',
#   u'start': 192542,
#   u'strand': u'-',
#   u'taxon_id': 266},
#  {u'aa_length': 393,
#   u'aa_sequence_md5': u'e7e6864fa78d9f5ee2a6893817a42aab',
#   u'accession': u'FNEA01000005',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2016-11-19T18:47:57.167Z',
#   u'date_modified': u'2016-11-19T18:47:57.167Z',
#   u'end': 201853,
#   u'feature_id': u'PATRIC.266.10.FNEA01000005.CDS.200672.201853.rev',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG01395536',
#   u'genome_id': u'266.10',
#   u'genome_name': u'Paracoccus denitrificans strain DSM 413',
#   u'location': u'complement(200672..201853)',
#   u'na_length': 1182,
#   u'na_sequence_md5': u'c261e5d6e1378f7630691d3e95d23148',
#   u'owner': u'PATRIC@patricbrc.org',
#   u'patric_id': u'fig|266.10.peg.5132',
#   u'pgfam_id': u'PGF_00007576',
#   u'plfam_id': u'PLF_265_00002085',
#   u'product': u'GfdT',
#   u'public': True,
#   u'refseq_locus_tag': u'SAMN04244581_01185',
#   u'segments': [u'200672..201853'],
#   u'sequence_id': u'266.10.con.0093',
#   u'start': 200672,
#   u'strand': u'-',
#   u'taxon_id': 266},
#  {u'aa_length': 218,
#   u'aa_sequence_md5': u'36984d13cfd19cb6f5e60e68523792b8',
#   u'accession': u'FNEA01000005',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2016-11-19T18:47:57.167Z',
#   u'date_modified': u'2016-11-19T18:47:57.167Z',
#   u'end': 232553,
#   u'feature_id': u'PATRIC.266.10.FNEA01000005.CDS.231897.232553.fwd',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00132823',
#   u'genome_id': u'266.10',
#   u'genome_name': u'Paracoccus denitrificans strain DSM 413',
#   u'go': [u'GO:0008908|isochorismatase activity'],
#   u'location': u'231897..232553',
#   u'na_length': 657,
#   u'na_sequence_md5': u'92f2de82d71a1a47090b04bea468ddf3',
#   u'owner': u'PATRIC@patricbrc.org',
#   u'patric_id': u'fig|266.10.peg.5162',
#   u'pgfam_id': u'PGF_00015660',
#   u'plfam_id': u'PLF_265_00002361',
#   u'product': u'Isochorismatase (EC 3.3.2.1) of siderophore biosynthesis',
#   u'property': [u'EC number', u'Pathway'],
#   u'public': True,
#   u'refseq_locus_tag': u'SAMN04244581_01214',
#   u'segments': [u'231897..232553'],
#   u'sequence_id': u'266.10.con.0093',
#   u'start': 231897,
#   u'strand': u'+',
#   u'taxon_id': 266},
#  {u'aa_length': 80,
#   u'aa_sequence_md5': u'1c44d01e4d6df675d34f871f18de1bc2',
#   u'accession': u'FNEA01000005',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2016-11-19T18:47:57.167Z',
#   u'date_modified': u'2016-11-19T18:47:57.167Z',
#   u'end': 233596,
#   u'feature_id': u'PATRIC.266.10.FNEA01000005.CDS.233354.233596.rev',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00009017',
#   u'genome_id': u'266.10',
#   u'genome_name': u'Paracoccus denitrificans strain DSM 413',
#   u'go': [u'GO:0008908|isochorismatase activity'],
#   u'location': u'complement(233354..233596)',
#   u'na_length': 243,
#   u'na_sequence_md5': u'bc8d1ed619d32326b4a6db72e2711327',
#   u'owner': u'PATRIC@patricbrc.org',
#   u'patric_id': u'fig|266.10.peg.5164',
#   u'pgfam_id': u'PGF_00015659',
#   u'plfam_id': u'PLF_265_00002106',
#   u'product': u'Isochorismatase (EC 3.3.2.1) of siderophore biosynthesis',
#   u'property': [u'EC number', u'Pathway'],
#   u'public': True,
#   u'refseq_locus_tag': u'SAMN04244581_01216',
#   u'segments': [u'233354..233596'],
#   u'sequence_id': u'266.10.con.0093',
#   u'start': 233354,
#   u'strand': u'-',
#   u'taxon_id': 266},
#  {u'aa_length': 475,
#   u'aa_sequence_md5': u'20beb662255d35b612a60297e64b975f',
#   u'accession': u'FNEA01000013',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2016-11-19T18:47:57.167Z',
#   u'date_modified': u'2016-11-19T18:47:57.167Z',
#   u'end': 5978,
#   u'feature_id': u'PATRIC.266.10.FNEA01000013.CDS.4551.5978.rev',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG01668751',
#   u'genome_id': u'266.10',
#   u'genome_name': u'Paracoccus denitrificans strain DSM 413',
#   u'go': [u'GO:0000155|phosphorelay sensor kinase activity',
#    u'GO:0000155|histone arginine kinase activity'],
#   u'location': u'complement(4551..5978)',
#   u'na_length': 1428,
#   u'na_sequence_md5': u'15cf5901400084471141cc7eb2ad20b0',
#   u'owner': u'PATRIC@patricbrc.org',
#   u'patric_id': u'fig|266.10.peg.5178',
#   u'pgfam_id': u'PGF_02742817',
#   u'plfam_id': u'PLF_265_00003486',
#   u'product': u'Methanol utilization control sensor protein MoxY (EC 2.7.3.-)',
#   u'property': [u'EC number'],
#   u'public': True,
#   u'refseq_locus_tag': u'SAMN04244581_02568',
#   u'segments': [u'4551..5978'],
#   u'sequence_id': u'266.10.con.0094',
#   u'start': 4551,
#   u'strand': u'-',
#   u'taxon_id': 266},
#  {u'aa_length': 339,
#   u'aa_sequence_md5': u'4cac7f282c9ff1dc4b932298c2185844',
#   u'accession': u'FNEA01000013',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2016-11-19T18:47:57.167Z',
#   u'date_modified': u'2016-11-19T18:47:57.167Z',
#   u'end': 11581,
#   u'feature_id': u'PATRIC.266.10.FNEA01000013.CDS.10562.11581.fwd',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00799111',
#   u'genome_id': u'266.10',
#   u'genome_name': u'Paracoccus denitrificans strain DSM 413',
#   u'location': u'10562..11581',
#   u'na_length': 1020,
#   u'na_sequence_md5': u'4ee02d4f31ed207d608c8aeab3c910d0',
#   u'owner': u'PATRIC@patricbrc.org',
#   u'patric_id': u'fig|266.10.peg.5185',
#   u'pgfam_id': u'PGF_00020638',
#   u'plfam_id': u'PLF_265_00003483',
#   u'product': u'Methanol dehydrogenase regulatory protein MoxR',
#   u'public': True,
#   u'refseq_locus_tag': u'SAMN04244581_02574',
#   u'segments': [u'10562..11581'],
#   u'sequence_id': u'266.10.con.0094',
#   u'start': 10562,
#   u'strand': u'+',
#   u'taxon_id': 266},
#  {u'aa_length': 284,
#   u'aa_sequence_md5': u'c6b36177878ae7e6b2eaad53d7cad48d',
#   u'accession': u'FNEA01000013',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2016-11-19T18:47:57.167Z',
#   u'date_modified': u'2016-11-19T18:47:57.167Z',
#   u'end': 12432,
#   u'feature_id': u'PATRIC.266.10.FNEA01000013.CDS.11578.12432.fwd',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00809021',
#   u'genome_id': u'266.10',
#   u'genome_name': u'Paracoccus denitrificans strain DSM 413',
#   u'location': u'11578..12432',
#   u'na_length': 855,
#   u'na_sequence_md5': u'718880c218769d4c3e822a82b7dc0473',
#   u'owner': u'PATRIC@patricbrc.org',
#   u'patric_id': u'fig|266.10.peg.5186',
#   u'pgfam_id': u'PGF_02742818',
#   u'plfam_id': u'PLF_265_00003499',
#   u'product': u'MxaS, protein involved in methanol oxidation',
#   u'public': True,
#   u'refseq_locus_tag': u'SAMN04244581_02575',
#   u'segments': [u'11578..12432'],
#   u'sequence_id': u'266.10.con.0094',
#   u'start': 11578,
#   u'strand': u'+',
#   u'taxon_id': 266},
#  {u'aa_length': 38,
#   u'aa_sequence_md5': u'b1483895ca1243e86adb4de439deac0b',
#   u'accession': u'FNEA01000013',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2016-11-19T18:47:57.167Z',
#   u'date_modified': u'2016-11-19T18:47:57.167Z',
#   u'end': 54719,
#   u'feature_id': u'PATRIC.266.10.FNEA01000013.CDS.54603.54719.fwd',
#   u'feature_type': u'CDS',
#   u'genome_id': u'266.10',
#   u'genome_name': u'Paracoccus denitrificans strain DSM 413',
#   u'location': u'54603..54719',
#   u'na_length': 117,
#   u'na_sequence_md5': u'2bab9f33bcbb001f1cbab649c0db1ade',
#   u'owner': u'PATRIC@patricbrc.org',
#   u'patric_id': u'fig|266.10.peg.5225',
#   u'pgfam_id': u'PGF_02743754',
#   u'plfam_id': u'PLF_265_00006933',
#   u'product': u'hypothetical protein',
#   u'public': True,
#   u'segments': [u'54603..54719'],
#   u'sequence_id': u'266.10.con.0094',
#   u'start': 54603,
#   u'strand': u'+',
#   u'taxon_id': 266},
#  {u'aa_length': 660,
#   u'aa_sequence_md5': u'da8f4db0b109180a99d69b72ecf966bf',
#   u'accession': u'FNEA01000013',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2016-11-19T18:47:57.167Z',
#   u'date_modified': u'2016-11-19T18:47:57.167Z',
#   u'end': 85726,
#   u'feature_id': u'PATRIC.266.10.FNEA01000013.CDS.83744.85726.fwd',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00638284',
#   u'genome_id': u'266.10',
#   u'genome_name': u'Paracoccus denitrificans strain DSM 413',
#   u'location': u'83744..85726',
#   u'na_length': 1983,
#   u'na_sequence_md5': u'851c628af94f7f04b1f300b7b8fb5d80',
#   u'owner': u'PATRIC@patricbrc.org',
#   u'patric_id': u'fig|266.10.peg.5257',
#   u'pgfam_id': u'PGF_00402036',
#   u'plfam_id': u'PLF_265_00006632',
#   u'product': u'outer membrane autotransporter barrel domain',
#   u'public': True,
#   u'refseq_locus_tag': u'SAMN04244581_02640',
#   u'segments': [u'83744..85726'],
#   u'sequence_id': u'266.10.con.0094',
#   u'start': 83744,
#   u'strand': u'+',
#   u'taxon_id': 266},
#  {u'aa_length': 1164,
#   u'aa_sequence_md5': u'7317a18ebc1acbec026ce9752eaaf93a',
#   u'accession': u'FNEA01000013',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2016-11-19T18:47:57.167Z',
#   u'date_modified': u'2016-11-19T18:47:57.167Z',
#   u'end': 106979,
#   u'feature_id': u'PATRIC.266.10.FNEA01000013.CDS.103485.106979.rev',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG00638284',
#   u'genome_id': u'266.10',
#   u'genome_name': u'Paracoccus denitrificans strain DSM 413',
#   u'location': u'complement(103485..106979)',
#   u'na_length': 3495,
#   u'na_sequence_md5': u'fe868a132ca055f173f81c7de557f0ca',
#   u'owner': u'PATRIC@patricbrc.org',
#   u'patric_id': u'fig|266.10.peg.5275',
#   u'pgfam_id': u'PGF_02743755',
#   u'plfam_id': u'PLF_265_00006938',
#   u'product': u'putative autotransporter protein',
#   u'public': True,
#   u'refseq_locus_tag': u'SAMN04244581_02656',
#   u'segments': [u'103485..106979'],
#   u'sequence_id': u'266.10.con.0094',
#   u'start': 103485,
#   u'strand': u'-',
#   u'taxon_id': 266},
#  {u'aa_length': 38,
#   u'aa_sequence_md5': u'b2813d0433c46bd107c7ef012dd64fc6',
#   u'accession': u'FNEA01000013',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2016-11-19T18:47:57.167Z',
#   u'date_modified': u'2016-11-19T18:47:57.167Z',
#   u'end': 107119,
#   u'feature_id': u'PATRIC.266.10.FNEA01000013.CDS.107003.107119.rev',
#   u'feature_type': u'CDS',
#   u'genome_id': u'266.10',
#   u'genome_name': u'Paracoccus denitrificans strain DSM 413',
#   u'location': u'complement(107003..107119)',
#   u'na_length': 117,
#   u'na_sequence_md5': u'fc6fc0c799e8aca99647b67fcf3f8efc',
#   u'owner': u'PATRIC@patricbrc.org',
#   u'patric_id': u'fig|266.10.peg.5276',
#   u'pgfam_id': u'PGF_02742456',
#   u'plfam_id': u'PLF_265_00018626',
#   u'product': u'hypothetical protein',
#   u'public': True,
#   u'segments': [u'107003..107119'],
#   u'sequence_id': u'266.10.con.0094',
#   u'start': 107003,
#   u'strand': u'-',
#   u'taxon_id': 266},
#  {u'aa_length': 261,
#   u'aa_sequence_md5': u'9fc1d03af78f52705c12472e26461830',
#   u'accession': u'FNEA01000013',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2016-11-19T18:47:57.167Z',
#   u'date_modified': u'2016-11-19T18:47:57.167Z',
#   u'end': 142372,
#   u'feature_id': u'PATRIC.266.10.FNEA01000013.CDS.141587.142372.fwd',
#   u'feature_type': u'CDS',
#   u'figfam_id': u'FIG01323940',
#   u'genome_id': u'266.10',
#   u'genome_name': u'Paracoccus denitrificans strain DSM 413',
#   u'location': u'141587..142372',
#   u'na_length': 786,
#   u'na_sequence_md5': u'1095b88b7e84c82347366902b8eaa166',
#   u'owner': u'PATRIC@patricbrc.org',
#   u'patric_id': u'fig|266.10.peg.5310',
#   u'pgfam_id': u'PGF_00422774',
#   u'plfam_id': u'PLF_265_00007316',
#   u'product': u'Dehydrogenase',
#   u'public': True,
#   u'refseq_locus_tag': u'SAMN04244581_02690',
#   u'segments': [u'141587..142372'],
#   u'sequence_id': u'266.10.con.0094',
#   u'start': 141587,
#   u'strand': u'+',
#   u'taxon_id': 266},
#  {u'accession': u'FNEA01000013',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2016-11-19T18:47:57.167Z',
#   u'date_modified': u'2016-11-19T18:47:57.167Z',
#   u'end': 157529,
#   u'feature_id': u'PATRIC.266.10.FNEA01000013.repeat_region.157130.157529.fwd',
#   u'feature_type': u'repeat_region',
#   u'genome_id': u'266.10',
#   u'genome_name': u'Paracoccus denitrificans strain DSM 413',
#   u'location': u'157130..157529',
#   u'na_length': 400,
#   u'na_sequence_md5': u'a50a3e24c975b5d4b4e27f22d25f6652',
#   u'owner': u'PATRIC@patricbrc.org',
#   u'patric_id': u'fig|266.10.repeat.183',
#   u'product': u'repeat region',
#   u'public': True,
#   u'segments': [u'157130..157529'],
#   u'sequence_id': u'266.10.con.0094',
#   u'start': 157130,
#   u'strand': u'+',
#   u'taxon_id': 266},
#  {u'aa_length': 91,
#   u'aa_sequence_md5': u'14742ea6bf8a460b32f6024e96233970',
#   u'accession': u'FNEA01000046',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2016-11-19T18:47:57.167Z',
#   u'date_modified': u'2016-11-19T18:47:57.167Z',
#   u'end': 5687,
#   u'feature_id': u'PATRIC.266.10.FNEA01000046.CDS.5412.5687.rev',
#   u'feature_type': u'CDS',
#   u'genome_id': u'266.10',
#   u'genome_name': u'Paracoccus denitrificans strain DSM 413',
#   u'location': u'complement(5412..5687)',
#   u'na_length': 276,
#   u'na_sequence_md5': u'70510c2b5eeb1b24da722d17d7e553f9',
#   u'owner': u'PATRIC@patricbrc.org',
#   u'patric_id': u'fig|266.10.peg.5333',
#   u'pgfam_id': u'PGF_02743527',
#   u'plfam_id': u'PLF_265_00006572',
#   u'product': u'hypothetical protein',
#   u'public': True,
#   u'refseq_locus_tag': u'SAMN04244581_04774',
#   u'segments': [u'5412..5687'],
#   u'sequence_id': u'266.10.con.0095',
#   u'start': 5412,
#   u'strand': u'-',
#   u'taxon_id': 266},
#  {u'accession': u'FNEA01000046',
#   u'annotation': u'PATRIC',
#   u'date_inserted': u'2016-11-19T18:47:57.167Z',
#   u'date_modified': u'2016-11-19T18:47:57.167Z',
#   u'end': 19526,
#   u'feature_id': u'PATRIC.266.10.FNEA01000046.tRNA.19451.19526.rev',
#   u'feature_type': u'tRNA',
#   u'genome_id': u'266.10',
#   u'genome_name': u'Paracoccus denitrificans strain DSM 413',
#   u'location': u'complement(19451..19526)',
#   u'na_length': 76,
#   u'na_sequence_md5': u'6c3beea3b7b811577db3881026eb4654',
#   u'owner': u'PATRIC@patricbrc.org',
#   u'patric_id': u'fig|266.10.rna.64',
#   u'product': u'tRNA-Trp',
#   u'public': True,
#   u'refseq_locus_tag': u'SAMN04244581_04785',
#   u'segments': [u'19451..19526'],
#   u'sequence_id': u'266.10.con.0095',
#   u'start': 19451,
#   u'strand': u'-',
#   u'taxon_id': 266},
#  ...]

# %%
file_name = "test_for_martin_%s.faa" % (genome_id)
feats2 = mackinac.features_to_protein_fasta_file(feature_list_2, file_name)

# %%
feats2
# Out:
# 0

# %%
# You can use the GPR ID to link reactions to their annotated genes in the feature file.
model.reactions[150].gene_reaction_rule
# Out:
# u'266.10.peg.366'

# %%
# It's a bit clumsy, but it works... 
for i in range(0,len(model.reactions)):
    if feature_list[i]['patric_id'] == u'fig|266.10.peg.366':
        print(i)
feature_list[i]['patric_id']
# Out:
# 522
# u'fig|266.10.peg.4145'

# %%
# This function allows us to identify which reactions were gapfilled to allow for 'growth'. 
gf_solutions = mackinac.get_patric_gapfill_solutions(genome_id)
# Out:
# 1

# %%
# PATRIC has a built in ModelSEED that is more up-to-date than the ModelSEED website
# There is a built in gapfill step to ensure that the model can grow on complete media.
# Complete media refers to having all exchange reactions open. 
# When the model is generate using PATRIC it is given exchange reactions for all of the 
# transporters it has evidence of along with other important transporters such as water. 

# There were 100 reactions gapfilled to allow for 'growth' on complete media
# The rxn IDs are the keys in this list(dict).
len(gf_solutions[0]['reactions'].keys())
# Out:
# 100

# %%
# Model Stats: this are well within the range I would expect based on the reported numbers.
print(len(model.metabolites))
print(len(model.reactions))
print(len(model.genes))
MODEL
# Out:
# 1490
# 1434
# 966
# <Model 266.10 at 0x7f0921b657d0>

# %%
# Here is the list of exchange reactions that are open, therefore the model has access to these
# metabolites for the next optimization step. 
model.medium

# %%
# Optimize using FBA: again very similar to the reported value!
opt = model.slim_optimize()
print('Objective value: %3.15f\n' % opt)
# Out:
# Objective value: 205.727409809327952

# %%
# Save the model. This is considered a draft reconstruction.
cobra.io.save_json_model(model, "initMODEL.json")

# %%
# Here is a universal model. This model is a bit of a long story but it essentially contains all of 
# decent quality ModelSEED reactions and metabolites. Ideally you wouldn't have any imbalances when
# gapfilling with this reaction bag. 

univ_master = cobra.io.load_json_model("../Data/Near_complete_ModelSEED_universal.json")

# %%
univ_master
# Out:
# <Model MicrobialNegative at 0x7f9bbfa84f50>

# %%
univ_master = cobra.io.load_json_model("../Data/Near_complete_ModelSEED_universal.json")

# Probably all ModelSEED Erythromycin related reactions
Eryth_rxns = ['rxn03808_c',
 'rxn03809_c',
 'rxn03810_c',
 'rxn03811_c',
 'rxn03820_c',
 'rxn03821_c',
 'rxn04367_c',
 'rxn18756_c',
 'rxn18757_c',
 'rxn18758_c',
 'rxn18784_c']

for rxn_id in Eryth_rxns:
    try: 
        univ_master.reactions.get_by_id(rxn_id)
        print('Yes: '+rxn_id)
    except:
        print('No: '+rxn_id)

# %%
# Out:
# Yes: rxn03808_c
# Yes: rxn03809_c
# No: rxn03810_c
# No: rxn03811_c
# Yes: rxn03820_c
# Yes: rxn03821_c
# Yes: rxn04367_c
# Yes: rxn18756_c
# Yes: rxn18757_c
# Yes: rxn18758_c
# Yes: rxn18784_c

# %%
# You might consider removing the previous gapfilled reactions if you have some decent experimental
# data to work with. The best/cheapest data to work with is growth/no-growth data in defined media 
# conditions. You will want to use this to gapfill in the future. Here's an example: 

slim_model = model.copy() # It's best to deep.copy your model or universal before altering it. If 
# don't you will likely run into solver issues. Cobrapy has it's own deep.copy function. 

for rxn in gf_solutions[0]['reactions'].keys():
    slim_model.reactions.get_by_id(rxn).remove_from_model(remove_orphans=True)

# %%
slim_model
# Out:
# <Model 266.10 at 0x7f091cc252d0>

# %%
# This is just a simple example media you could gapfill on. It has no biological significance. 
medium = [
    'cpd00067',
    'cpd00001',
    'cpd00011',
    'cpd00007',
    'cpd00528',
    'cpd00205',
    'cpd00971',
    'cpd00254',
    'cpd00030',
    'cpd10515', 
    'cpd00063',
    'cpd03422',
    'cpd00644',
    'cpd01415',
    'cpd00029',
    'cpd00137',
    'cpd00443',
    'cpd00013',
    'cpd00009',
    'cpd00048',
    'cpd00182',
    'cpd00307',
    'cpd00311',
    'cpd00184',
    'cpd00249',
    'cpd00027', 
    # Metals and ions
    'cpd00030',
    'cpd00034',
    'cpd00048', # Sulfate
    'cpd00058',
    'cpd00063',
    'cpd00099',
    'cpd00149',
    'cpd00205',
    'cpd00254',
    'cpd00971',
    'cpd10515',
    'cpd10516',
    'cpd00028',# Heme
    'cpd00268' # H2S2O3
]

# %%
sys.stdout.write('Load models...')

# NOTE THE NAME CHANGES HERE (Copying takes some time, most of the time it's worth it)
universal = univ_master.copy()
model = slim_model.copy()

sys.stdout.write('Set-up...')

# Ensure free diffusion of water (The ModelSEED water transporter is no good)
universal.reactions.get_by_id('rxn05319_c').name = "Water transport"
universal.reactions.get_by_id('rxn05319_c').bounds = (-1000., 1000.)
model.reactions.get_by_id('rxn05319_c').name = "Water transport"
model.reactions.get_by_id('rxn05319_c').bounds = (-1000., 1000.)

# Ensure the objective is biomass production ('growth')
# This biomass function is super generic, you will want to update this in the future. However,
# this is one of the more challanging/unknown aspects of modeling, in regards to it's importance and
# utility. It largely depends on your applications. 
model.objective = model.reactions.get_by_id('bio1')
# Out:
# Load models...Set-up...

# %%
model
# Out:
# <Model 266.10 at 0x7f091f305c90>

# %%
universal
# Out:
# <Model MicrobialNegative at 0x7f091f305bd0>

# %%
# pFBA-based gapfilling code that's way faster than the subpar Cobrapy gapfill function.
# In this gapfilling code you will see some more complex techniques I use to quickly gapfill a 
# model by minimizing the sum of fluxes through reactions from the universal while allowing 
# free flow (with no minimization) through the original model network. This will be far easier
# to explain during a skype call. 

# Establish from base values. 
lower_bound=0.05
penalties=None
demand_reactions=False
exchange_reactions=False
flux_cutoff=1E-10
exchange_prefix='EX_'

# Deep.copy the models
gapfiller = universal.copy()
model_to_gapfill = model.copy()

'''
General steps:
Add EXs to Universal (Create new objects)
Add Media metabolites to model if not present (Copy from Universal)
Add EXs to model (Copy from universal)
Add Transporters to Model (Copy from Universal)
'''

sys.stdout.write('Add EXs...')
# Add Exchanges to Gapfiller, just in case we have new-to-the-model metabolites in the media
for met in gapfiller.metabolites:
    base_met_id = met.id.split('_')[0]
    if 'EX_' + base_met_id + '_e' not in set([reaction.id for reaction in gapfiller.reactions])\
    and base_met_id + '_e' in set([metabolite.id for metabolite in gapfiller.metabolites]):
        # Create exchange reaction and add to model
        new_exchange = cobra.Reaction('EX_' + base_met_id + '_e')
        new_exchange.name = base_met_id + ' exchange'
        met_obj = gapfiller.metabolites.get_by_id(base_met_id + '_e')
        new_exchange.add_metabolites({met_obj:-1})
        new_exchange.lower_bound = -1000.
        new_exchange.upper_bound = 1000.
        gapfiller.add_reaction(new_exchange)
        gapfiller.repair()
    elif 'EX_' + base_met_id + '_e' in set([reaction.id for reaction in gapfiller.reactions]):
        gapfiller.reactions.get_by_id('EX_'+base_met_id+'_e').upper_bound = 1.0*1000

sys.stdout.write('Add Mets...')
# Add media metabolites to model_to_gapfill from gapfiller
for base_met_id in medium:
    if base_met_id + '_e' not in set([metabolite.id for metabolite in model_to_gapfill.metabolites])\
    and base_met_id + '_e' in set([metabolite.id for metabolite in gapfiller.metabolites]):
        # Add metabolite from gapfiller
        MET = gapfiller.metabolites.get_by_id(base_met_id + '_e').copy()
        model_to_gapfill.add_metabolites([MET])
        model_to_gapfill.repair()
    if base_met_id + '_c' not in set([metabolite.id for metabolite in model_to_gapfill.metabolites])\
    and base_met_id + '_c' in set([metabolite.id for metabolite in gapfiller.metabolites]):
        # Add metabolite from gapfiller
        MET = gapfiller.metabolites.get_by_id(base_met_id + '_c').copy()
        model_to_gapfill.add_metabolites([MET])
        model_to_gapfill.repair()

sys.stdout.write('Copy EXs...')
# Add missing Exchanges to model_to_gapfill from gapfiller
for met in model_to_gapfill.metabolites:
    base_met_id = met.id.split('_')[0]
    if 'EX_' + base_met_id + '_e' not in set([reaction.id for reaction in model_to_gapfill.reactions])\
    and 'EX_' + base_met_id + '_e' in set([reaction.id for reaction in gapfiller.reactions]):
        # Add Exchange from gapfiller
        EX = gapfiller.reactions.get_by_id('EX_' + base_met_id + '_e').copy()
        model_to_gapfill.add_reactions([EX])
        model_to_gapfill.repair()

sys.stdout.write('Transporters...')
# Identify transporters for each biolog component in the universal model
# and pick one that will enable transport in the gapfilling problem.
pick_transporter = {}
transporters_in_universal = [rxn for rxn in gapfiller.reactions if len(rxn.compartments)>1]
for base_met_id in medium:
    metabolite = model_to_gapfill.metabolites.get_by_id(base_met_id+'_c')
    rxns_with_metabolite = metabolite.reactions
    transport = False
    for rxn in rxns_with_metabolite:
        metabolites = [met_in_rxn.id for met_in_rxn in rxn.metabolites]
        if (base_met_id+'_e' in metabolites and base_met_id+'_c' in metabolites):
            transport = True

    if not transport:
        print("missing transporter for " + metabolite.name)
        for rxn in transporters_in_universal:
            metabolites = [met_in_rxn.id for met_in_rxn in rxn.metabolites]
            if (base_met_id+'_e' in metabolites and base_met_id+'_c' in metabolites):
                pick_transporter[base_met_id] = rxn.id

# Add the transporters to the model
transporters_to_add = list(pick_transporter.values())
transporter_list = []
for rxn in transporters_to_add:
    transporter_list.append(gapfiller.reactions.get_by_id(rxn).copy())
model_to_gapfill.add_reactions(transporter_list)

# Grab the linear reaction coefficients from the model 
original_objective = linear_reaction_coefficients(model_to_gapfill)
# convert to IDs to avoid issues with model membership when these reactions are added to gapfiller
original_objective = {rxn.id:original_objective[rxn] for rxn in original_objective.keys()}

# get the reactions in the original model, which need to be removed from
# the universal if present. This cannot catch identical reactions that do
# not share IDs, so make sure your model and universal are in the same
# namespace.
rxns_to_remove = [rxn for rxn in gapfiller.reactions if rxn.id in \
                    [rxn.id for rxn in model_to_gapfill.reactions]]
gapfiller.remove_reactions(rxns_to_remove)

# get the list of reactions currently in the gapfiller, which are the ones
# we will need to check for flux after solving the problem (e.g. these are
# the reactions we are considering adding to the model)
get_fluxes = [rxn.id for rxn in gapfiller.reactions]

# add the reactions from the model to the gapfiller, which are not
# included in the pFBA formulation, and thus flux is not penalized
# through them.
original_model_reactions = [rxn.copy() for rxn
                            in model_to_gapfill.reactions]
gapfiller.add_reactions(original_model_reactions)
original_reaction_ids = [reaction.id for reaction
                            in original_model_reactions]

# Add the pFBA constraints and objective (minimizes sum of fluxes)
add_pfba(gapfiller)

# set the linear coefficients for reactions in the original model to 0
coefficients = (gapfiller.objective
                .get_linear_coefficients(gapfiller.variables))
reaction_variables = (((gapfiller.reactions.get_by_id(reaction)
                        .forward_variable),
                       (gapfiller.reactions.get_by_id(reaction)
                        .reverse_variable))
                        for reaction in original_reaction_ids)
variables = chain(*reaction_variables)
for variable in variables:
    coefficients[variable] = 0.0 # might need to be 0.001
gapfiller.objective.set_linear_coefficients(coefficients)

# set a constraint on flux through the original objective
for reaction in original_objective.keys():
    print("Constraining lower bound for " + reaction)
    gapfiller.reactions.get_by_id(reaction).lower_bound = lower_bound

# Close import for all exchanges
exchange_reactions = [rxn for rxn in gapfiller.reactions if rxn.id.startswith(exchange_prefix)]
for rxn in exchange_reactions:
    rxn.lower_bound = 0

# Set the medium for this condition.
# set_media(gapfiller, medium, universal)
for ex_rxn in medium:
    gapfiller.reactions.get_by_id('EX_'+ex_rxn+'_e').lower_bound = -1.0*1000
    gapfiller.reactions.get_by_id('EX_'+ex_rxn+'_e').upper_bound = 1.0*1000

# gapfill and get the solution
iteration_solution = gapfiller.optimize()

filtered_solution = {rxn:iteration_solution.x_dict[rxn] for rxn in\
   get_fluxes if abs(iteration_solution.x_dict[rxn]) > flux_cutoff}

add_rxns = [gapfiller.reactions.get_by_id(rxn).copy() for \
                                rxn in filtered_solution.keys()]

def validate(original_model, reactions, lower_bound):
        with original_model as model:
            model.add_reactions(reactions)
            mets = [x.metabolites for x in reactions]
            all_keys = set().union(*(d.keys() for d in mets))
            model.add_metabolites(all_keys)
            model.slim_optimize()
            return (model.solver.status == OPTIMAL and
                    model.solver.objective.value >= lower_bound)

# validate that the proposed solution restores flux through the
# objective in the original model
# set the bounds on the original model to represent media
# and validate the gapfill solution
for ex_rxn in [rxn for rxn in model_to_gapfill.reactions if rxn.id.startswith(exchange_prefix)]:
    ex_rxn.lower_bound = 0

for ex_rxn in medium:
    model_to_gapfill.reactions.get_by_id('EX_'+ex_rxn+'_e').lower_bound = -1.0*1000
    model_to_gapfill.reactions.get_by_id('EX_'+ex_rxn+'_e').upper_bound = 1.0*1000
# set_media(model_to_gapfill, medium, universal)

print(len(add_rxns))

if not validate(model_to_gapfill, [gapfiller.reactions.get_by_id(rxn.id).copy() for rxn in add_rxns], lower_bound):
    raise RuntimeError('Failed to validate gapfilled model, '
                        'try lowering the flux_cutoff through '
                        'inclusion_threshold')

new_model = model_to_gapfill.copy()
reactions = [gapfiller.reactions.get_by_id(rxn.id).copy() for rxn in add_rxns]
new_model.add_reactions(reactions)
mets = [x.metabolites for x in reactions]
all_keys = set().union(*(d.keys() for d in mets))
new_model.add_metabolites(all_keys)
new_model.slim_optimize()
# Out:
# Add EXs...Add Mets...Copy EXs...Transporters...missing transporter for N2
# missing transporter for Fe2+
# missing transporter for Ca2+
# missing transporter for Cobinamide
# missing transporter for Thioglycolate
# missing transporter for Acetate
# missing transporter for ABEE
# missing transporter for Adenosine
# missing transporter for Guanosine
# missing transporter for Thymidine
# missing transporter for Uridine
# missing transporter for D-Glucose
# missing transporter for Ca2+
# missing transporter for Co2+
# missing transporter for Fe2+
# missing transporter for Heme
# Constraining lower bound for bio1
# 488
# 185.65780881952182

# %%
# This media condition is much more minimal than complete media which is why so many reactions 
# were added to the model. You'll notice if you re-run this a few times you'll get different solutions,
# this is to be expected. Additional growth conditions will help to narrow the solution space. 
new_model
# Out:
# <Model 266.10 at 0x7f0908b2da10>

# %%
# There are some other packages that help to better link genes/annotations to reactions, what is
# currently annoying about this field is that there are not many great tools out there for generating
# a solid link between the genes and reactions. Probannopy is the best place to start and I can help
# you work with that package as well! I'm currently developing some code that uses Probannopy reaction
# likelihoods to preferentially gapfill. The inputs for Probannopy are a fasta file, PATRIC genome ID, 
# and a unique template model. The downside is that the template model only contains 6500 reactions. 
# So it's limited by that template model, which I'm also trying to figure out how to expand to account
# for all of the reactions in the universal model file I sent you. I think your best bet would be to 
# use a variety of methods to automatically generate models with a strong connections to the annotations
# I'm happy to be your point person for questions and help. As I said before a lot of this is stuff 
# I'm building projects around currently, so it won't be a bother at all!

# %%
# Add demand for pyruvate
# Open all exchanges
# run pFBA
# Get list of reactions with flux
# remove rest of reactions to make slim model
new_model
