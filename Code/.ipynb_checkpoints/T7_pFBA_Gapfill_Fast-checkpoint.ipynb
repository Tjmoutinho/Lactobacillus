# %%
from __future__ import print_function
from __future__ import absolute_import

import cobra
import cobra.test
import numpy as np
import csv
import glob
import pickle
import pandas as pd
import math
import copy
import time
import random
import time
import sys

from copy import deepcopy
from collections import defaultdict
from cobra.flux_analysis import sample
from cobra.core.solution import get_solution
from cobra.flux_analysis.sampling import OptGPSampler
from cobra.manipulation.delete import *
from cobra.medium import find_boundary_types
from cobra.flux_analysis import pfba

from warnings import warn
from itertools import chain
from optlang.symbolics import Zero
from cobra.util import solver as sutil
from cobra.core.solution import get_solution

import logging
LOGGER = logging.getLogger(__name__)

# Set default logger to python logger to avoid warnings given when adding reactions and/or metaboites 
# because "cobra.core.model" doesn't innately have a logger.
# import logging
# logging.basicConfig()
# logger = logging.getLogger('logger')

# %%
def set_media(model, media, universal, verbose=False):

    # Find and close all exchange reactions in the model
    model_rxns = [rxn.id for rxn in model.reactions]
    for rxn in model_rxns:
        if rxn.startswith('EX_') and rxn.endswith('_e'):
            model.reactions.get_by_id(rxn).lower_bound = 0.0

    # Check for existence of exchange reactions for the media metabolites in the model
    for metabolite in media:
        met = metabolite[1]+'_e'
        if 'EX_'+met in model_rxns:
            model.reactions.get_by_id('EX_'+met).lower_bound = -1000.
        else:
            # Create exchange reaction and add to model
            if verbose:
                print("added exchange rxn for " + met)
            new_exchange = cobra.Reaction('EX_'+met)
            new_exchange.name = met + ' exchange'
            met_obj = universal.metabolites.get_by_id(met)
            new_exchange.add_metabolites({met_obj:-1})
            new_exchange.lower_bound = -1000.
            new_exchange.upper_bound = 1000.
            model.add_reaction(new_exchange)
            model.repair()

# %%
# Basal Synthetic Media
bsm = [
    ['H+','cpd00067'],
    ['H2O','cpd00001'],
    ['CO2','cpd00011'],
    ['O2','cpd00007'],
    ['N2','cpd00528'], 
#     ['H2','cpd11640'], # Only with no O2
    
    ['K+','cpd00205'],
    ['Na+','cpd00971'],
    ['Mg','cpd00254'],
    ['Mn2+','cpd00030'],
    ['Fe2+','cpd10515'], # Iron ion in heme
    ['Ca2+','cpd00063'], # Calcium pantothenate;cpd19112
    
    ['Vitamin B12r','cpd00423'], # C62H91CoN13O14P : cobalamin;cpd03424;cpd00730 : not present in any exchange reactions
    ['Cobinamide','cpd03422'], #EXs : related to cobalamin (B12) Added to ensure cells have access to B12
    ['BIOT','cpd00104'], # C10H15N2O3S : biotin B7
    ['PAN','cpd00644'], # C9H16NO5 : Pantothenate B5
    ['Folate','cpd00393'], # C19H17N7O6 : B9
    ['Niacin','cpd00218'], # C6H4NO2 : B3
    ['Pyridoxal','cpd00215'], # C8H9NO3 : B6
    ['Riboflavin','cpd00220'], # C17H19N4O6 : B2
    ['thiamin','cpd00305'], # C12H17N4OS : B1
    
#     ['Phosphate','cpd00009'], # HO4P : In M9 Defaults
    
    ['Thioglycolate','cpd01415'], # C2H3O2S : not present in any exchange reactions
#     ['Sulfate','cpd00048'], # O4S : In M9 Defaults
    
    ['Acetate','cpd00029'], # C2H3O2 : not present in any exchange reactions
    ['Citrate','cpd00137'], # C6H5O7 : Consider removing. 
#     ['Polysorbate 60','cpd24450'], # C35H68O10 : Almost tween 80 : not present in any reactions
#     ['Ethyl acetate','cpd00633'], # C4H8O2 : not present in any exchange reactions, only present in one reaction at all
    
    ['ABEE','cpd00443'] # C7H6NO2 : aminobenzoate : not present in any exchange reactions
]

# Potentially add to BSM (from M9 media)
M9_ions = [
    ['Cl-','cpd00099'],
    ['Co2+','cpd00149'],
    ['Cu2+','cpd00058'],
    ['Fe3','cpd10516'],
#     ['Sodium molybdate','cpd11145'], # This doesn't connect to anything
    ['Ni2+','cpd00244'],
    ['Selenate','cpd03396'],
    ['Selenite','cpd03387'],
    ['Zn2+','cpd00034']
]

# M9 default carbon, nitrogen, phosphorous, and sulfur sources
M9_sources = [
#     ['D-Glucose','cpd00027'],
#     ['NH3','cpd00013'], # this is actually NH4 : ammonium
    ['Phosphate','cpd00009'],
    ['Sulfate','cpd00048']
]

# Vitamins
vit_k = [
#     ['BIOT','cpd00104'], #EXs : Biotin
#     ['Cobinamide','cpd03422'], #EXs : related to cobalamin (B12)
#     ['Folate','cpd00393'], #EXs : 
    ['Menaquinone 7','cpd11606'], #EXs : Vitamine K2 : Add when there is no O2
#     ['Niacin','cpd00218'], #EXs : 
#     ['PAN','cpd00644'], #EXs : Pantothenate
#     ['Pyridoxal','cpd00215'], #EXs : 
#     ['Riboflavin','cpd00220'], #EXs : 
#     ['Thiamin','cpd00305'] #EXs : 
]

# For aerobic simulations, O2 was added with a lower bound of −20 and to 0 for anaerobic simulations.

# DNA/RNA related metabolites
rna_bases = [
#     ['35ccmp','cpd00696'], #EXs : 
#     ['AMP','cpd00018'], #EXs : 
    ['Adenosine','cpd00182'], #EXs : In BSM (as adenine)
#     ['Adenosine 3-5-bisphosphate','cpd00045'], #EXs : 
    ['Cytosine','cpd00307'], #EXs : 
#     ['Deoxyadenosine','cpd00438'], #EXs : 
#     ['Deoxycytidine','cpd00654'], #EXs : 
#     ['Deoxyguanosine','cpd00277'], #EXs : In BSM
#     ['Deoxyinosine','cpd03279'], #EXs : 
#     ['Deoxyuridine','cpd00412'], #EXs : 
#     ['GMP','cpd00126'], #EXs : 
#     ['GTP','cpd00038'], #EXs : 
    ['Guanosine','cpd00311'], #EXs : In BSM (as Guanine)
#     ['Inosine','cpd00246'], #EXs : 
#     ['HYXN','cpd00226'], #EXs : Hypoxanthine
#     ['Nicotinamide ribonucleotide','cpd00355'], #EXs : 
#     ['TTP','cpd00357'], #EXs : Deoxythymidine triphosphate
    ['Thymidine','cpd00184'], #EXs : In BSM
#     ['Thyminose','cpd01242'], #EXs : deoxyribose
#     ['Uracil','cpd00092'], #EXs : 
    ['Uridine','cpd00249'], #EXs : In BSM (as uracil)
#     ['XAN','cpd00309'], #EXs : Xanthine
#     ['Xanthosine','cpd01217'], #EXs : 
#     ['dATP','cpd00115'], #EXs : 
#     ['dGTP','cpd00241'], #EXs : 
#     ['dTMP','cpd00298'] #EXs : 
]

# Check to see if these metabolites are used in pathways? Should I add some of these to media? 
# Yes for ATP, and GTP. (TTP, CTP as well?)

# %%
# Amino Acid related metabolites
products = [
    ['D-Alanine','cpd00117'], #EXs : 
    ['D-Glutamate','cpd00186'], #EXs : 
    ['D-Methionine','cpd00637'], #EXs : 
    ['D-Serine','cpd00550'], #EXs : 
    ['Glycine','cpd00033'], #EXs : 1
    ['L-Alanine','cpd00035'], #EXs : 2
    ['L-Arginine','cpd00051'], #EXs : 3
    ['L-Asparagine','cpd00132'], #EXs : 4
    ['L-Aspartate','cpd00041'], #EXs : 5
    ['L-Cysteine','cpd00084'], #EXs : 7
    ['L-Glutamate','cpd00023'], #EXs : 8
    ['L-Glutamine','cpd00053'], #EXs : 9
    ['L-Histidine','cpd00119'], #EXs : 10
    ['L-Isoleucine','cpd00322'], #EXs : 11
    ['L-Leucine','cpd00107'], #EXs : 12
    ['L-Lysine','cpd00039'], #EXs : 13
    ['L-Methionine','cpd00060'], #EXs : 14
    ['L-Phenylalanine','cpd00066'], #EXs : 15
    ['L-Proline','cpd00129'], #EXs : 16
    ['L-Serine','cpd00054'], #EXs : 17
    ['L-Threonine','cpd00161'], #EXs : 18
    ['L-Tryptophan','cpd00065'], #EXs : 19
    ['L-Tyrosine','cpd00069'], #EXs : 20
    ['L-Valine','cpd00156'], #EXs : 21
    ['H2O2','cpd00025'],
    ['L-Lactate','cpd00159'],
    ['Acetate','cpd00029'],
    ['Butyrate','cpd00211'],
#     ['isobutyrate','cpd01711'], 
    ['GABA','cpd00281'],
    ['ethanol','cpd00363'],
    ['Propionate','cpd00141'],
    ['formate','cpd00047'],
    ['Valerate','cpd00597'],
#     ['Isovaleric acid','cpd05178'], # Not in universal?
    ['TMAO','cpd00811'], # (CH3)3NO
#     ['Indole-3-(carb)aldehyde','cpd05401'],
#     ['Acetaldehyde','cpd00071'],
    ['Deoxycholate','cpd02733'],
    ['Chorismate','cpd00216'],
    ['Hexanoate','cpd01113']
]

carbon_sources = [
    ['D-Glucose','cpd00027'],
    ['4-Hydroxybenzoate','cpd00136'], #EXs : found in coconuts
    ['2-keto-3-deoxygluconate','cpd00176'], #EXs : degraded pectin product
    ['Amylotriose','cpd01262'], #EXs : 
#     ['CELB','cpd00158'], #EXs : Cellobiose
    ['D-Fructose','cpd00082'], #EXs : 
    ['D-Mannitol','cpd00314'], #EXs : sweetener the is poorly absorbed in the gut
    ['D-Mannose','cpd00138'], #EXs : related to mucin
    ['Ribose','cpd00105'], #EXs : 
    ['Dextrin','cpd11594'], #EXs : 
    ['Dulcose','cpd01171'], #EXs : Galactitol
    ['GLCN','cpd00222'], #EXs : Gluconate 
    ['GLUM','cpd00276'], #EXs : Glucosamine
    ['Galactose','cpd00108'], #EXs : 
    ['L-Arabinose','cpd00224'], #EXs : 
    ['L-Inositol','cpd00121'], #EXs : 
    ['L-Lactate','cpd00159'], #EXs : 
    ['L-Malate','cpd00130'], #EXs : 
    ['Glycerol','cpd00100'], #EXs : 
#     ['LACT','cpd00208'], #EXs : lactose
    ['Maltohexaose','cpd01329'], #EXs : 
#     ['Maltose','cpd00179'], #EXs : 
    ['Melibiose','cpd03198'], #EXs : 
    ['Palmitate','cpd00214'], #EXs : 
    ['Propionate','cpd00141'], #EXs : 
#     ['Salicin','cpd01030'], #EXs : 
    ['Sorbitol','cpd00588'], #EXs : 
    ['Stachyose','cpd01133'], #EXs : 
    ['Succinate','cpd00036'], #EXs : 
#     ['Sucrose','cpd00076'], #EXs : 
#     ['TRHL','cpd00794'], #EXs : Trehalose
    ['Ursin','cpd03696'], #EXs : Arbutin
    ['Xylose','cpd00154'], #EXs : 
    ['hexadecenoate','cpd15237'] #EXs : 
]

# Nitrogen Sources
nitrogen_sources = [
    ['NH3','cpd00013'], #EXs : 
    ['Allantoin','cpd01092'], #EXs : degradation product of purines
    ['BET','cpd00540'], #EXs : Betaine
    ['Choline','cpd00098'], #EXs : Found in milk
    ['Nitrate','cpd00209'], #EXs : 
    ['Nitrite','cpd00075'], #EXs : 
    ['Spermidine','cpd00264'], #EXs : 
    ['Urea','cpd00073'], #EXs : 
    ['crotonobetaine','cpd08305'] #EXs : 
]

print(str(len(products)*len(carbon_sources)*len(nitrogen_sources)*20/3600) + 'hours')
# Out:
# 51hours

# %%
len(products)
# Out:
# 37

# %%
len(carbon_sources)
# Out:
# 28

# %%
# pFBA gapfiller
def pfba_gapfill(model, reaction_bag, likelihoods, obj=None, obj_lb=10., obj_constraint=False,
                 iters=1, tasks=None, task_lb=0.05, 
                 add_exchanges=True, extracellular='e'):

    start_time = time.time()
    # Save some basic network info for downstream membership testing
    orig_rxn_ids = set([str(x.id) for x in model.reactions])
    orig_cpd_ids = set([str(y.id) for y in model.metabolites])

    # Get model objective reaction ID
    if obj == None:
        obj = get_objective(model)
    else:
        obj = obj
    
    # Modify universal reaction bag
    new_rxn_ids = set()
    with reaction_bag as universal:

        # Remove overlapping reactions from universal bag, and reset objective if needed
        orig_rxns = list(copy.deepcopy(model.reactions))
            
        # Add pFBA to universal model and add model reactions
        
        add_pfba_likely(universal, likelihoods)
        
        universal.add_reactions(orig_rxns)
        
        # If previous objective not set as constraint, set minimum lower bound
        if obj_constraint == False: 
            universal.reactions.get_by_id(obj).lower_bound = obj_lb
        
        # Run FBA and save solution
        solution = universal.optimize()
#         print([bound.id for bound in universal.boundary if bound.lower_bound != 0.0 and bound.upper_bound != 0.0 and bound.id.startswith('EX')])
        
        # Identify which reactions carry flux in solution
        rxns = list(solution.fluxes.index)
        fluxes = list(solution.fluxes)
        for flux in range(0, len(fluxes)):
            if abs(fluxes[flux]) > 1e-6:
                new_rxn_ids |= set([rxns[flux]])
        
    # Screen new reaction IDs
    if obj in new_rxn_ids: new_rxn_ids.remove(obj)
    for rxn in orig_rxn_ids:
        try:
            new_rxn_ids.remove(rxn)
        except:
            continue
    
    # Get reactions and metabolites to be added to the model
    new_rxns = copy.deepcopy([reaction_bag.reactions.get_by_id(rxn) for rxn in new_rxn_ids])
    new_cpd_ids = set()
    for rxn in new_rxns: new_cpd_ids |= set([str(x.id) for x in list(rxn.metabolites)])
    new_cpd_ids = new_cpd_ids.difference(orig_cpd_ids)
    new_cpds = copy.deepcopy([reaction_bag.metabolites.get_by_id(cpd) for cpd in new_cpd_ids])
    
    # Copy model and gapfill
    new_model = copy.deepcopy(model)
    new_model.add_metabolites(new_cpds)
    new_model.add_reactions(new_rxns)
    
    duration = int(round(time.time() - start_time))
    print('Took ' + str(duration) + ' seconds to gapfill ' + str(len(new_rxn_ids)) + \
          ' reactions and ' + str(len(new_cpd_ids)) + ' metabolites.') 
    
    return {'NewModel':new_model, 'gaps':new_rxn_ids, 'mets':new_cpd_ids}

def add_pfba_likely(model, likelihoods, objective=None, fraction_of_optimum=1.0):
    if objective is not None:
        model.objective = objective
    if model.solver.objective.name == '_pfba_objective':
        raise ValueError('The model already has a pFBA objective.')
    sutil.fix_objective_as_constraint(model, fraction=fraction_of_optimum)
    reaction_variables = ((rxn.forward_variable, rxn.reverse_variable)
                          for rxn in model.reactions)
    variables = chain(*reaction_variables)
    dict1 = {}
    fail_report = []
    model_reactions = [rxn.id.split('_')[0] for rxn in model.reactions if rxn.id.startswith('rxn')]
    for v in variables:
        if set([str(v.name.split('_')[0])]).issubset(set(model_reactions)) and str(v.name.split('_')[0]).startswith('rxn'):
            rxn_id = (v.name.split('_')[0] + '_c')
            try:
                dict1[v] = max([0.0, 1.0 - likelihoods[rxn_id]])
            except:
                try:
                    dict1[v] = 1.0
                except:
                    print('FAILED')
                    pass
                pass
            
        elif str(v.name.split('_')[0]).startswith('DM'):
            dict1[v] = 1.0
        else:
            fail_report.append(1)
    model.objective = model.problem.Objective(Zero, direction='min', sloppy=True, name="_pfba_objective")
    model.objective.set_linear_coefficients(dict1)

# %%
# Using pFBA with new media components (RNA bases + thymidine...) 
# Remove reaction likelihoods of zero from model
# Add demands for all metabolites in model to avoid any reactions being blocked
# Weighted pFBA gapfill solution

t = time.time()

sys.stdout.write('Loading in models...')

universal = cobra.io.load_json_model("../Data/GramPosUni.json")
genome_id = '220668.9'
model = cobra.io.read_sbml_model('../gap_models/'+ genome_id +'.xml')
likelihoods = pickle.load(open('../likelihoods/'+ genome_id +'.probs'))

sys.stdout.write('Adding Water...')

# Ensure free diffusion of water
model.reactions.get_by_id('rxn05319_c').name = "Water transport"
model.reactions.get_by_id('rxn05319_c').bounds = (-1000., 1000.)

sys.stdout.write('Set-up Universal...')

# Add demand for all metabolites in Universal model to stop blocked reactions
all_mets = []
for met in universal.metabolites:
    if (met.id.endswith('_c')):
        universal.add_boundary(met, type='demand')

### Set Up Model: remove low likelihood reactions
sys.stdout.write('Set-up Model...')
low_like_model = []
for rxn in model.reactions:
    if rxn.id.startswith('rxn'):
        try:
            if likelihoods[rxn.id] <= 0.1:
                low_like_model.append(rxn.id)
        except:
            pass
model_rxns_to_remove = [model.reactions.get_by_id(rxn) for rxn in low_like_model]
model.remove_reactions(model_rxns_to_remove)

# Create and set specific Media List
# media_list = bsm + M9_sources + rna_bases # + nitrogen + carbon
# set_media(model, media_list, universal, verbose=False)
# set_media(universal, media_list, universal, verbose=False)

# Remove model reactions from universal
orig_rxn_ids = set([str(x.id) for x in model.reactions])
univ_rxn_ids = set([str(z.id) for z in universal.reactions])
overlap_rxn_ids = univ_rxn_ids.intersection(orig_rxn_ids)
sys.stdout.write('removing reactions from universal...')
for rxn in overlap_rxn_ids: 
    universal.reactions.get_by_id(rxn).remove_from_model()

print(str(round(time.time() - t)) + 'seconds to complete')
# Out:
# Loading in models...Adding Water...Set-up Universal...Set-up Model...removing reactions from universal...42.0seconds to complete

# %%
# Run through each amino acid to check for production
global_time = time.time()
counter = 0

total_dataset_dict = {}
carb_idx = 0

for carbon in carbon_sources:
    nit_idx = 0
    for nitrogen in nitrogen_sources:
        # Create and set specific Media List
        media_list = bsm + M9_sources + rna_bases + [nitrogen] + [carbon]
        set_media(model, media_list, universal, verbose=False)
        
        product_idx = 0
        for product_list in products[27:28]:
            t = time.time()
            sys.stdout.write('\n'+ 'Loop' + str(counter) + ' ')
            product = product_list[1]+'_c'
            product_name = product_list[0]
            
            with model as temp_model, universal as temp_universal:
                
                try:
                    metabolite = temp_model.metabolites.get_by_id(product)
                    demand = temp_model.add_boundary(metabolite, type='demand')
                    temp_model.objective = demand
                except:
                    if set(product).issubset(set([met.id for met in model.metabolites])) == 0:
                        temp_model.add_metabolites(copy.deepcopy(temp_universal.metabolites.get_by_id(product)))
                        metabolite = temp_model.metabolites.get_by_id(product)
                        demand = temp_model.add_boundary(metabolite, type='demand')
                        temp_model.objective = demand
                
                temp_universal.reactions.get_by_id(demand.id).remove_from_model()
                
                sys.stdout.write('Gapfilling ' + product + '...')
                dont_continue = 0
#                 new_gapfill_data = pfba_gapfill(temp_model, temp_universal, likelihoods, obj=demand.id, obj_lb=10., obj_constraint=False, iters=1, add_exchanges=False)
                try:
                    new_gapfill_data = pfba_gapfill(temp_model, temp_universal, likelihoods, obj=demand.id, obj_lb=10., obj_constraint=False, iters=1, add_exchanges=False)
                except:
                    try:
                        sys.stdout.write('Restart Gapfilling...')
                        new_gapfill_data = pfba_gapfill(temp_model, temp_universal, likelihoods, obj=demand.id, obj_lb=10., obj_constraint=False, iters=1, add_exchanges=False)
                    except:
                        sys.stdout.write('Failed Gapfilling...')
                        dont_continue = 1
                        pass
                
                gaps_to_fill = new_gapfill_data['gaps']
                new_model = new_gapfill_data['NewModel']
                mets_added = new_gapfill_data['mets']
                
                if dont_continue == 0:
                    # Optimize with filled pathway
                    sys.stdout.write('pFBA...')
                    solution = pfba(new_model, objective = demand)
                    sys.stdout.write(str(round(new_model.slim_optimize())) + '...')
                    
                    if new_model.slim_optimize() <= 1.0:
                        dont_continue = 1 
                    
                    if dont_continue == 0:
                    
                        # Find reactions that carry flux
                        df = solution.fluxes.to_frame()
                        active = df.loc[(abs(df['fluxes'])) > 0.1]

                        demand_list = []
                        for rxn_id in active.index:
                            if rxn_id.startswith('DM') and rxn_id != demand.id:
                                demand_list.append(rxn_id)
                                print('demands added')

                        # Acquire likelihood scores for reactions that carry flux
                        flux_rxns = []
                        like_list = []
                        gap_flux_rxns = []
                        gap_like_list = []
                        path_flux_rxns = []
                        path_like_list = []
                        for rxn in list(active.index):
                            if rxn in gaps_to_fill and rxn.startswith('rxn'):
                                try:
                                    gap_flux_rxns.append([str(rxn),likelihoods[str(rxn)]])
                                    gap_like_list.append(likelihoods[str(rxn)])
                                except:
                                    pass
                            if rxn not in gaps_to_fill and rxn.startswith('rxn'):
                                try:
                                    path_flux_rxns.append([str(rxn),likelihoods[str(rxn)]])
                                    path_like_list.append(likelihoods[str(rxn)])
                                except:
                                    pass
                            if rxn.startswith('rxn'):
                                try:
                                    flux_rxns.append([str(rxn),likelihoods[str(rxn)]])
                                    like_list.append(likelihoods[str(rxn)])
                                except:
                                    pass
                        avg_like = np.mean(like_list)

                        opt_before = model.slim_optimize()
                        if opt_before > 0.0:
                            gap_avg_like = []
                        else:
                            gap_avg_like = np.mean(gap_like_list)
                        path_avg_like = np.mean(path_like_list)
                        sys.stdout.write('Ave likelihood of: ' + product + ' is ' + str(avg_like) + '...')

                        counter += 1

                        report_dict = {}
                        report_dict['Model_ID'] = genome_id
                        report_dict['Carbon'] = carbon
                        report_dict['Nitrogen'] = nitrogen
                        report_dict['objective'] = product_name
                        report_dict['opt_before'] = opt_before
                        report_dict['opt_after'] = new_model.slim_optimize()
                        report_dict['avg_path_like'] = avg_like
                        report_dict['gap_avg_like'] = gap_avg_like
                        report_dict['path_avg_like'] = path_avg_like
                        report_dict['gaps_filled'] = gaps_to_fill
                        report_dict['mets_added'] = mets_added
                        report_dict['reactions_w_flux'] = flux_rxns
                        report_dict['gaps_w_flux'] = gap_flux_rxns
                        report_dict['path_w_flux'] = path_flux_rxns
                        report_dict['active_rxns'] = active
                        report_dict['demands'] = demand_list

                        report_dict_ID = genome_id + ':' + str(carb_idx) + '.' + str(nit_idx) + '.' + str(product_idx)
                        total_dataset_dict[report_dict_ID] = report_dict
                        product_idx += 1 # Keep track to which product is being maximized
                    
#                     elapsed = time.time() - t
#                     sys.stdout.write('Run time: ' + str(elapsed/60) + " [mins]...")
                    
                if dont_continue == 1:
                    counter += 1
                    
                    report_dict = {}
                    report_dict['Model_ID'] = genome_id
                    report_dict['Carbon'] = carbon
                    report_dict['Nitrogen'] = nitrogen
                    report_dict['objective'] = product_name
                    report_dict['opt_before'] = "Failed to gapfill"
                    report_dict['opt_after'] = "Failed to gapfill"
                    report_dict['avg_path_like'] = "Failed to gapfill"
                    report_dict['gap_avg_like'] = "Failed to gapfill"
                    report_dict['path_avg_like'] = "Failed to gapfill"
                    report_dict['gaps_filled'] = "Failed to gapfill"
                    report_dict['mets_added'] = "Failed to gapfill"
                    report_dict['reactions_w_flux'] = "Failed to gapfill"
                    report_dict['gaps_w_flux'] = "Failed to gapfill"
                    report_dict['path_w_flux'] = "Failed to gapfill"
                    report_dict['active_rxns'] = "Failed to gapfill"
                    report_dict['demands'] = "Failed to gapfill"
                    
                    report_dict_ID = genome_id + ':' + str(carb_idx) + '.' + str(nit_idx) + '.' + str(product_idx)
                    total_dataset_dict[report_dict_ID] = report_dict
                    product_idx += 1 #Keep track to which product is being maximized
                    
#                     elapsed = time.time() - t
#                     sys.stdout.write('Run time: ' + str(elapsed/60) + " [mins]...")
        nit_idx += 1
    carb_idx += 1
file_name = "../metabolic_output/%s_V2.data" % (genome_id) # CHANGE BACK TO CORRECT NAME
pickle.dump(total_dataset_dict, open(file_name, "wb"))

print('\n'+ str((time.time() - global_time)/60) + 'mins to complete!')
# Out:
# Loop0 Gapfilling cpd00211_c...Took 21 seconds to gapfill 8 reactions and 3 metabolites.
# pFBA...250.0...Ave likelihood of: cpd00211_c is 0.5559515582601068...
# Loop1 Gapfilling cpd00211_c...Took 21 seconds to gapfill 8 reactions and 3 metabolites.
# pFBA...250.0...Ave likelihood of: cpd00211_c is 0.5559515582601068...
# Loop2 Gapfilling cpd00211_c...Took 20 seconds to gapfill 8 reactions and 3 metabolites.
# pFBA...250.0...Ave likelihood of: cpd00211_c is 0.5559515582601068...
# Loop3 Gapfilling cpd00211_c...Took 20 seconds to gapfill 8 reactions and 3 metabolites.
# pFBA...250.0...Ave likelihood of: cpd00211_c is 0.5559515582601068...
# Loop4 Gapfilling cpd00211_c...Took 20 seconds to gapfill 8 reactions and 3 metabolites.
# pFBA...250.0...Ave likelihood of: cpd00211_c is 0.5559515582601068...
# Loop5 Gapfilling cpd00211_c...Took 19 seconds to gapfill 8 reactions and 3 metabolites.
# pFBA...250.0...Ave likelihood of: cpd00211_c is 0.5559515582601068...
# Loop6 Gapfilling cpd00211_c...Took 19 seconds to gapfill 8 reactions and 3 metabolites.
# pFBA...250.0...Ave likelihood of: cpd00211_c is 0.5559515582601068...
# Loop7 Gapfilling cpd00211_c...Took 21 seconds to gapfill 8 reactions and 3 metabolites.
# pFBA...250.0...Ave likelihood of: cpd00211_c is 0.5559515582601068...
# Loop8 Gapfilling cpd00211_c...Took 19 seconds to gapfill 8 reactions and 3 metabolites.
# pFBA...250.0...Ave likelihood of: cpd00211_c is 0.5559515582601068...
# Loop9 Gapfilling cpd00211_c...Took 19 seconds to gapfill 13 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.5067286353185371...
# Loop10 Gapfilling cpd00211_c...Took 18 seconds to gapfill 13 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.49877527286228424...
# Loop11 Gapfilling cpd00211_c...Took 21 seconds to gapfill 13 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.5067286353185371...
# Loop12 Gapfilling cpd00211_c...Took 18 seconds to gapfill 13 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.5067286353185371...
# Loop13 Gapfilling cpd00211_c...Took 19 seconds to gapfill 13 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.5067286353185371...
# Loop14 Gapfilling cpd00211_c...Took 18 seconds to gapfill 13 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.49877527286228424...
# Loop15 Gapfilling cpd00211_c...Took 18 seconds to gapfill 13 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.5067286353185371...
# Loop16 Gapfilling cpd00211_c...Took 18 seconds to gapfill 13 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.5067286353185371...
# Loop17 Gapfilling cpd00211_c...Took 19 seconds to gapfill 13 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.5067286353185371...
# Loop18 Gapfilling cpd00211_c...Took 20 seconds to gapfill 13 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.49877527286228424...
# Loop19 Gapfilling cpd00211_c...Took 21 seconds to gapfill 13 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.5067286353185371...
# Loop20 Gapfilling cpd00211_c...Took 20 seconds to gapfill 13 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.5067286353185371...
# Loop21 Gapfilling cpd00211_c...Took 23 seconds to gapfill 13 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.49877527286228424...
# Loop22 Gapfilling cpd00211_c...Took 19 seconds to gapfill 13 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.5067286353185371...
# Loop23 Gapfilling cpd00211_c...Took 20 seconds to gapfill 13 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.5067286353185371...
# Loop24 Gapfilling cpd00211_c...Took 20 seconds to gapfill 13 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.49877527286228424...
# Loop25 Gapfilling cpd00211_c...Took 18 seconds to gapfill 13 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.5067286353185371...
# Loop26 Gapfilling cpd00211_c...Took 21 seconds to gapfill 13 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.5067286353185371...
# Loop27 Gapfilling cpd00211_c...Took 20 seconds to gapfill 10 reactions and 3 metabolites.
# pFBA...800.0...Ave likelihood of: cpd00211_c is 0.5313492696471144...
# Loop28 Gapfilling cpd00211_c...Took 18 seconds to gapfill 10 reactions and 3 metabolites.
# pFBA...800.0...Ave likelihood of: cpd00211_c is 0.5313492696471144...
# Loop29 Gapfilling cpd00211_c...Took 19 seconds to gapfill 10 reactions and 3 metabolites.
# pFBA...800.0...Ave likelihood of: cpd00211_c is 0.5313492696471144...
# Loop30 Gapfilling cpd00211_c...Took 21 seconds to gapfill 10 reactions and 3 metabolites.
# pFBA...800.0...Ave likelihood of: cpd00211_c is 0.5313492696471144...
# Loop31 Gapfilling cpd00211_c...Took 19 seconds to gapfill 10 reactions and 3 metabolites.
# pFBA...800.0...Ave likelihood of: cpd00211_c is 0.5313492696471144...
# Loop32 Gapfilling cpd00211_c...Took 19 seconds to gapfill 10 reactions and 3 metabolites.
# pFBA...800.0...Ave likelihood of: cpd00211_c is 0.5313492696471144...
# Loop33 Gapfilling cpd00211_c...Took 20 seconds to gapfill 9 reactions and 3 metabolites.
# pFBA...500.0...Ave likelihood of: cpd00211_c is 0.48641942609648775...
# Loop34 Gapfilling cpd00211_c...Took 20 seconds to gapfill 10 reactions and 3 metabolites.
# pFBA...800.0...Ave likelihood of: cpd00211_c is 0.5313492696471144...
# Loop35 Gapfilling cpd00211_c...Took 18 seconds to gapfill 10 reactions and 3 metabolites.
# pFBA...800.0...Ave likelihood of: cpd00211_c is 0.5313492696471144...
# Loop36 Gapfilling cpd00211_c...Took 19 seconds to gapfill 12 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.48410736443675395...
# Loop37 Gapfilling cpd00211_c...Took 18 seconds to gapfill 12 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.48410736443675395...
# Loop38 Gapfilling cpd00211_c...Took 20 seconds to gapfill 12 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.48410736443675395...
# Loop39 Gapfilling cpd00211_c...Took 18 seconds to gapfill 12 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.48410736443675395...
# Loop40 Gapfilling cpd00211_c...Took 19 seconds to gapfill 12 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.48410736443675395...
# Loop41 Gapfilling cpd00211_c...Took 18 seconds to gapfill 12 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.48410736443675395...
# Loop42 Gapfilling cpd00211_c...Took 21 seconds to gapfill 12 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.48410736443675395...
# Loop43 Gapfilling cpd00211_c...Took 19 seconds to gapfill 12 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.48410736443675395...
# Loop44 Gapfilling cpd00211_c...Took 18 seconds to gapfill 12 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.48410736443675395...
# Loop45 Gapfilling cpd00211_c...Took 21 seconds to gapfill 9 reactions and 3 metabolites.
# pFBA...500.0...Ave likelihood of: cpd00211_c is 0.5726479028988714...
# Loop46 Gapfilling cpd00211_c...Took 19 seconds to gapfill 9 reactions and 3 metabolites.
# pFBA...500.0...Ave likelihood of: cpd00211_c is 0.5726479028988714...
# Loop47 Gapfilling cpd00211_c...Took 20 seconds to gapfill 9 reactions and 3 metabolites.
# pFBA...500.0...Ave likelihood of: cpd00211_c is 0.5726479028988714...
# Loop48 Gapfilling cpd00211_c...Took 20 seconds to gapfill 9 reactions and 3 metabolites.
# pFBA...500.0...Ave likelihood of: cpd00211_c is 0.5726479028988714...
# Loop49 Gapfilling cpd00211_c...Took 20 seconds to gapfill 10 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.5575825030177164...
# Loop50 Gapfilling cpd00211_c...Took 19 seconds to gapfill 10 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.5575825030177164...
# Loop51 Gapfilling cpd00211_c...Took 19 seconds to gapfill 10 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.5575825030177164...
# Loop52 Gapfilling cpd00211_c...Took 19 seconds to gapfill 10 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.5575825030177164...
# Loop53 Gapfilling cpd00211_c...Took 19 seconds to gapfill 10 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.5575825030177164...
# Loop54 Gapfilling cpd00211_c...Took 18 seconds to gapfill 12 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.4988149226155005...
# Loop55 Gapfilling cpd00211_c...Took 19 seconds to gapfill 12 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.4988149226155005...
# Loop56 Gapfilling cpd00211_c...Took 19 seconds to gapfill 12 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.4988149226155005...
# Loop57 Gapfilling cpd00211_c...Took 18 seconds to gapfill 12 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.4988149226155005...
# Loop58 Gapfilling cpd00211_c...Took 18 seconds to gapfill 12 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.4988149226155005...
# Loop59 Gapfilling cpd00211_c...Took 19 seconds to gapfill 12 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.4988149226155005...
# Loop60 Gapfilling cpd00211_c...Took 19 seconds to gapfill 12 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.4988149226155005...
# Loop61 Gapfilling cpd00211_c...Took 20 seconds to gapfill 12 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.4988149226155005...
# Loop62 Gapfilling cpd00211_c...Took 19 seconds to gapfill 12 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.4988149226155005...
# Loop63 Gapfilling cpd00211_c...Took 20 seconds to gapfill 8 reactions and 3 metabolites.
# pFBA...167.0...Ave likelihood of: cpd00211_c is 0.5357441202519371...
# Loop64 Gapfilling cpd00211_c...Took 20 seconds to gapfill 8 reactions and 3 metabolites.
# pFBA...167.0...Ave likelihood of: cpd00211_c is 0.5222626861570318...
# Loop65 Gapfilling cpd00211_c...Took 20 seconds to gapfill 8 reactions and 3 metabolites.
# pFBA...167.0...Ave likelihood of: cpd00211_c is 0.5357441202519371...
# Loop66 Gapfilling cpd00211_c...Took 19 seconds to gapfill 8 reactions and 3 metabolites.
# pFBA...167.0...Ave likelihood of: cpd00211_c is 0.5357441202519371...
# Loop67 Gapfilling cpd00211_c...Took 21 seconds to gapfill 8 reactions and 3 metabolites.
# pFBA...167.0...Ave likelihood of: cpd00211_c is 0.5222626861570318...
# Loop68 Gapfilling cpd00211_c...Took 19 seconds to gapfill 8 reactions and 3 metabolites.
# pFBA...167.0...Ave likelihood of: cpd00211_c is 0.5222626861570318...
# Loop69 Gapfilling cpd00211_c...Took 21 seconds to gapfill 8 reactions and 3 metabolites.
# pFBA...167.0...Ave likelihood of: cpd00211_c is 0.5357441202519371...
# Loop70 Gapfilling cpd00211_c...Took 18 seconds to gapfill 8 reactions and 3 metabolites.
# pFBA...167.0...Ave likelihood of: cpd00211_c is 0.5357441202519371...
# Loop71 Gapfilling cpd00211_c...Took 20 seconds to gapfill 8 reactions and 3 metabolites.
# pFBA...167.0...Ave likelihood of: cpd00211_c is 0.5357441202519371...
# Loop72 Gapfilling cpd00211_c...Took 18 seconds to gapfill 9 reactions and 3 metabolites.
# pFBA...267.0...Ave likelihood of: cpd00211_c is 0.5465020760573049...
# Loop73 Gapfilling cpd00211_c...Took 19 seconds to gapfill 9 reactions and 3 metabolites.
# pFBA...267.0...Ave likelihood of: cpd00211_c is 0.5465020760573049...
# Loop74 Gapfilling cpd00211_c...Took 21 seconds to gapfill 9 reactions and 3 metabolites.
# pFBA...267.0...Ave likelihood of: cpd00211_c is 0.5465020760573049...
# Loop75 Gapfilling cpd00211_c...Took 20 seconds to gapfill 8 reactions and 3 metabolites.
# pFBA...267.0...Ave likelihood of: cpd00211_c is 0.5608703064146582...
# Loop76 Gapfilling cpd00211_c...Took 18 seconds to gapfill 9 reactions and 3 metabolites.
# pFBA...267.0...Ave likelihood of: cpd00211_c is 0.5465020760573049...
# Loop77 Gapfilling cpd00211_c...Took 19 seconds to gapfill 8 reactions and 3 metabolites.
# pFBA...267.0...Ave likelihood of: cpd00211_c is 0.5608703064146582...
# Loop78 Gapfilling cpd00211_c...Took 19 seconds to gapfill 8 reactions and 3 metabolites.
# pFBA...267.0...Ave likelihood of: cpd00211_c is 0.5641289517388055...
# Loop79 Gapfilling cpd00211_c...Took 20 seconds to gapfill 9 reactions and 3 metabolites.
# pFBA...267.0...Ave likelihood of: cpd00211_c is 0.5465020760573049...
# Loop80 Gapfilling cpd00211_c...Took 20 seconds to gapfill 9 reactions and 3 metabolites.
# pFBA...267.0...Ave likelihood of: cpd00211_c is 0.5465020760573049...
# Loop81 Gapfilling cpd00211_c...Took 20 seconds to gapfill 12 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.5307058398226576...
# Loop82 Gapfilling cpd00211_c...Took 18 seconds to gapfill 12 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.5307058398226576...
# Loop83 Gapfilling cpd00211_c...Took 20 seconds to gapfill 12 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.5307058398226576...
# Loop84 Gapfilling cpd00211_c...Took 19 seconds to gapfill 12 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.5307058398226576...
# Loop85 Gapfilling cpd00211_c...Took 17 seconds to gapfill 12 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.5307058398226576...
# Loop86 Gapfilling cpd00211_c...Took 20 seconds to gapfill 12 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.5307058398226576...
# Loop87 Gapfilling cpd00211_c...Took 19 seconds to gapfill 12 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.5307058398226576...
# Loop88 Gapfilling cpd00211_c...Took 20 seconds to gapfill 12 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.53643570011417...
# Loop89 Gapfilling cpd00211_c...Took 20 seconds to gapfill 12 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.5307058398226576...
# Loop90 Gapfilling cpd00211_c...Took 17 seconds to gapfill 12 reactions and 3 metabolites.
# pFBA...800.0...Ave likelihood of: cpd00211_c is 0.47589779535555354...
# Loop91 Gapfilling cpd00211_c...Took 19 seconds to gapfill 12 reactions and 3 metabolites.
# pFBA...800.0...Ave likelihood of: cpd00211_c is 0.46738083486978554...
# Loop92 Gapfilling cpd00211_c...Took 19 seconds to gapfill 11 reactions and 3 metabolites.
# pFBA...800.0...Ave likelihood of: cpd00211_c is 0.49856368035276655...
# Loop93 Gapfilling cpd00211_c...Took 21 seconds to gapfill 12 reactions and 3 metabolites.
# pFBA...800.0...Ave likelihood of: cpd00211_c is 0.46738083486978554...
# Loop94 Gapfilling cpd00211_c...Took 21 seconds to gapfill 12 reactions and 3 metabolites.
# pFBA...800.0...Ave likelihood of: cpd00211_c is 0.48023532411544534...
# Loop95 Gapfilling cpd00211_c...Took 19 seconds to gapfill 12 reactions and 3 metabolites.
# pFBA...800.0...Ave likelihood of: cpd00211_c is 0.4731225506360839...
# Loop96 Gapfilling cpd00211_c...Took 21 seconds to gapfill 10 reactions and 3 metabolites.
# pFBA...500.0...Ave likelihood of: cpd00211_c is 0.5020062042533697...
# Loop97 Gapfilling cpd00211_c...Took 20 seconds to gapfill 11 reactions and 3 metabolites.
# pFBA...800.0...Ave likelihood of: cpd00211_c is 0.4870682420576329...
# Loop98 Gapfilling cpd00211_c...Took 19 seconds to gapfill 12 reactions and 3 metabolites.
# pFBA...800.0...Ave likelihood of: cpd00211_c is 0.48023532411544534...
# Loop99 Gapfilling cpd00211_c...Took 20 seconds to gapfill 7 reactions and 3 metabolites.
# pFBA...250.0...Ave likelihood of: cpd00211_c is 0.5783053450897853...
# Loop100 Gapfilling cpd00211_c...Took 22 seconds to gapfill 8 reactions and 3 metabolites.
# pFBA...250.0...Ave likelihood of: cpd00211_c is 0.5502295226162388...
# Loop101 Gapfilling cpd00211_c...Took 21 seconds to gapfill 7 reactions and 3 metabolites.
# pFBA...250.0...Ave likelihood of: cpd00211_c is 0.5783053450897853...
# Loop102 Gapfilling cpd00211_c...Took 20 seconds to gapfill 7 reactions and 3 metabolites.
# pFBA...250.0...Ave likelihood of: cpd00211_c is 0.5783053450897853...
# Loop103 Gapfilling cpd00211_c...Took 22 seconds to gapfill 8 reactions and 3 metabolites.
# pFBA...250.0...Ave likelihood of: cpd00211_c is 0.5783053450897853...
# Loop104 Gapfilling cpd00211_c...Took 21 seconds to gapfill 8 reactions and 3 metabolites.
# pFBA...250.0...Ave likelihood of: cpd00211_c is 0.5783053450897853...
# Loop105 Gapfilling cpd00211_c...Took 20 seconds to gapfill 8 reactions and 3 metabolites.
# pFBA...250.0...Ave likelihood of: cpd00211_c is 0.5783053450897853...
# Loop106 Gapfilling cpd00211_c...Took 22 seconds to gapfill 8 reactions and 3 metabolites.
# pFBA...250.0...Ave likelihood of: cpd00211_c is 0.5783053450897853...
# Loop107 Gapfilling cpd00211_c...Took 21 seconds to gapfill 7 reactions and 3 metabolites.
# pFBA...250.0...Ave likelihood of: cpd00211_c is 0.5783053450897853...
# Loop108 Gapfilling cpd00211_c...Took 20 seconds to gapfill 11 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.5151952589548466...
# Loop109 Gapfilling cpd00211_c...Took 22 seconds to gapfill 11 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.5151952589548466...
# Loop110 Gapfilling cpd00211_c...Took 18 seconds to gapfill 11 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.5151952589548466...
# Loop111 Gapfilling cpd00211_c...Took 19 seconds to gapfill 11 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.5151952589548466...
# Loop112 Gapfilling cpd00211_c...Took 19 seconds to gapfill 11 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.5151952589548466...
# Loop113 Gapfilling cpd00211_c...Took 20 seconds to gapfill 11 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.5151952589548466...
# Loop114 Gapfilling cpd00211_c...Took 20 seconds to gapfill 11 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.5151952589548466...
# Loop115 Gapfilling cpd00211_c...Took 20 seconds to gapfill 11 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.5151952589548466...
# Loop116 Gapfilling cpd00211_c...Took 19 seconds to gapfill 11 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.5151952589548466...
# Loop117 Gapfilling cpd00211_c...Took 20 seconds to gapfill 8 reactions and 3 metabolites.
# pFBA...167.0...Ave likelihood of: cpd00211_c is 0.5565162672571499...
# Loop118 Gapfilling cpd00211_c...Took 21 seconds to gapfill 8 reactions and 3 metabolites.
# pFBA...167.0...Ave likelihood of: cpd00211_c is 0.5565162672571499...
# Loop119 Gapfilling cpd00211_c...Took 20 seconds to gapfill 8 reactions and 3 metabolites.
# pFBA...167.0...Ave likelihood of: cpd00211_c is 0.5565162672571499...
# Loop120 Gapfilling cpd00211_c...Took 19 seconds to gapfill 8 reactions and 3 metabolites.
# pFBA...167.0...Ave likelihood of: cpd00211_c is 0.5565162672571499...
# Loop121 Gapfilling cpd00211_c...Took 20 seconds to gapfill 8 reactions and 3 metabolites.
# pFBA...167.0...Ave likelihood of: cpd00211_c is 0.5565162672571499...
# Loop122 Gapfilling cpd00211_c...Took 20 seconds to gapfill 8 reactions and 3 metabolites.
# pFBA...167.0...Ave likelihood of: cpd00211_c is 0.5565162672571499...
# Loop123 Gapfilling cpd00211_c...Took 22 seconds to gapfill 8 reactions and 3 metabolites.
# pFBA...167.0...Ave likelihood of: cpd00211_c is 0.5565162672571499...
# Loop124 Gapfilling cpd00211_c...Took 20 seconds to gapfill 7 reactions and 3 metabolites.
# pFBA...167.0...Ave likelihood of: cpd00211_c is 0.5530518737037686...
# Loop125 Gapfilling cpd00211_c...Took 20 seconds to gapfill 8 reactions and 3 metabolites.
# pFBA...167.0...Ave likelihood of: cpd00211_c is 0.5565162672571499...
# Loop126 Gapfilling cpd00211_c...Took 20 seconds to gapfill 13 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.5067286353185371...
# Loop127 Gapfilling cpd00211_c...Took 18 seconds to gapfill 13 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.49877527286228424...
# Loop128 Gapfilling cpd00211_c...Took 19 seconds to gapfill 13 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.5067286353185371...
# Loop129 Gapfilling cpd00211_c...Took 19 seconds to gapfill 13 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.49877527286228424...
# Loop130 Gapfilling cpd00211_c...Took 19 seconds to gapfill 13 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.49877527286228424...
# Loop131 Gapfilling cpd00211_c...Took 19 seconds to gapfill 13 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.49877527286228424...
# Loop132 Gapfilling cpd00211_c...Took 19 seconds to gapfill 13 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.5067286353185371...
# Loop133 Gapfilling cpd00211_c...Took 22 seconds to gapfill 13 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.5067286353185371...
# Loop134 Gapfilling cpd00211_c...Took 19 seconds to gapfill 13 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.49877527286228424...
# Loop135 Gapfilling cpd00211_c...Took 17 seconds to gapfill 11 reactions and 3 metabolites.
# pFBA...621.0...Ave likelihood of: cpd00211_c is 0.5269482323952033...
# Loop136 Gapfilling cpd00211_c...Took 19 seconds to gapfill 11 reactions and 3 metabolites.
# pFBA...621.0...Ave likelihood of: cpd00211_c is 0.5269482323952033...
# Loop137 Gapfilling cpd00211_c...Took 19 seconds to gapfill 11 reactions and 3 metabolites.
# pFBA...621.0...Ave likelihood of: cpd00211_c is 0.5269482323952033...
# Loop138 Gapfilling cpd00211_c...Took 21 seconds to gapfill 13 reactions and 3 metabolites.
# pFBA...621.0...Ave likelihood of: cpd00211_c is 0.5053392962549232...
# Loop139 Gapfilling cpd00211_c...Took 17 seconds to gapfill 11 reactions and 3 metabolites.
# pFBA...621.0...Ave likelihood of: cpd00211_c is 0.5269482323952033...
# Loop140 Gapfilling cpd00211_c...Took 19 seconds to gapfill 11 reactions and 3 metabolites.
# pFBA...621.0...Ave likelihood of: cpd00211_c is 0.5269482323952033...
# Loop141 Gapfilling cpd00211_c...Took 18 seconds to gapfill 12 reactions and 3 metabolites.
# pFBA...621.0...Ave likelihood of: cpd00211_c is 0.5053392962549232...
# Loop142 Gapfilling cpd00211_c...Took 19 seconds to gapfill 12 reactions and 3 metabolites.
# pFBA...621.0...Ave likelihood of: cpd00211_c is 0.5269482323952033...
# Loop143 Gapfilling cpd00211_c...Took 19 seconds to gapfill 11 reactions and 3 metabolites.
# pFBA...621.0...Ave likelihood of: cpd00211_c is 0.5269482323952033...
# Loop144 Gapfilling cpd00211_c...Took 19 seconds to gapfill 11 reactions and 3 metabolites.
# pFBA...409.0...Ave likelihood of: cpd00211_c is 0.5237337832989376...
# Loop145 Gapfilling cpd00211_c...Took 19 seconds to gapfill 12 reactions and 3 metabolites.
# pFBA...409.0...Ave likelihood of: cpd00211_c is 0.5007454187729923...
# Loop146 Gapfilling cpd00211_c...Took 20 seconds to gapfill 12 reactions and 3 metabolites.
# pFBA...409.0...Ave likelihood of: cpd00211_c is 0.5007454187729923...
# Loop147 Gapfilling cpd00211_c...Took 20 seconds to gapfill 11 reactions and 3 metabolites.
# pFBA...409.0...Ave likelihood of: cpd00211_c is 0.5085559353420568...
# Loop148 Gapfilling cpd00211_c...Took 20 seconds to gapfill 12 reactions and 3 metabolites.
# pFBA...409.0...Ave likelihood of: cpd00211_c is 0.5007454187729923...
# Loop149 Gapfilling cpd00211_c...Took 18 seconds to gapfill 12 reactions and 3 metabolites.
# pFBA...409.0...Ave likelihood of: cpd00211_c is 0.5007454187729923...
# Loop150 Gapfilling cpd00211_c...Took 19 seconds to gapfill 11 reactions and 3 metabolites.
# pFBA...409.0...Ave likelihood of: cpd00211_c is 0.5237337832989376...
# Loop151 Gapfilling cpd00211_c...Took 21 seconds to gapfill 11 reactions and 3 metabolites.
# pFBA...409.0...Ave likelihood of: cpd00211_c is 0.5237337832989376...
# Loop152 Gapfilling cpd00211_c...Took 21 seconds to gapfill 11 reactions and 3 metabolites.
# pFBA...409.0...Ave likelihood of: cpd00211_c is 0.5237337832989376...
# Loop153 Gapfilling cpd00211_c...Took 20 seconds to gapfill 9 reactions and 3 metabolites.
# pFBA...563.0...Ave likelihood of: cpd00211_c is 0.48631934061347026...
# Loop154 Gapfilling cpd00211_c...Took 18 seconds to gapfill 10 reactions and 3 metabolites.
# pFBA...563.0...Ave likelihood of: cpd00211_c is 0.49650572965678497...
# Loop155 Gapfilling cpd00211_c...Took 19 seconds to gapfill 9 reactions and 3 metabolites.
# pFBA...562.0...Ave likelihood of: cpd00211_c is 0.48631934061347026...
# Loop156 Gapfilling cpd00211_c...Took 20 seconds to gapfill 10 reactions and 3 metabolites.
# pFBA...563.0...Ave likelihood of: cpd00211_c is 0.49650572965678497...
# Loop157 Gapfilling cpd00211_c...Took 19 seconds to gapfill 9 reactions and 3 metabolites.
# pFBA...563.0...Ave likelihood of: cpd00211_c is 0.48631934061347026...
# Loop158 Gapfilling cpd00211_c...Took 19 seconds to gapfill 10 reactions and 3 metabolites.
# pFBA...562.0...Ave likelihood of: cpd00211_c is 0.4722104747398015...
# Loop159 Gapfilling cpd00211_c...Took 19 seconds to gapfill 10 reactions and 3 metabolites.
# pFBA...562.0...Ave likelihood of: cpd00211_c is 0.47221047473980143...
# Loop160 Gapfilling cpd00211_c...Took 20 seconds to gapfill 10 reactions and 3 metabolites.
# pFBA...562.0...Ave likelihood of: cpd00211_c is 0.493977048232728...
# Loop161 Gapfilling cpd00211_c...Took 18 seconds to gapfill 10 reactions and 3 metabolites.
# pFBA...563.0...Ave likelihood of: cpd00211_c is 0.49650572965678497...
# Loop162 Gapfilling cpd00211_c...Took 19 seconds to gapfill 9 reactions and 3 metabolites.
# pFBA...267.0...Ave likelihood of: cpd00211_c is 0.537052415215354...
# Loop163 Gapfilling cpd00211_c...Took 19 seconds to gapfill 8 reactions and 3 metabolites.
# pFBA...267.0...Ave likelihood of: cpd00211_c is 0.5453122168811517...
# Loop164 Gapfilling cpd00211_c...Took 18 seconds to gapfill 9 reactions and 3 metabolites.
# pFBA...267.0...Ave likelihood of: cpd00211_c is 0.537052415215354...
# Loop165 Gapfilling cpd00211_c...Took 20 seconds to gapfill 9 reactions and 3 metabolites.
# pFBA...267.0...Ave likelihood of: cpd00211_c is 0.537052415215354...
# Loop166 Gapfilling cpd00211_c...Took 18 seconds to gapfill 9 reactions and 3 metabolites.
# pFBA...267.0...Ave likelihood of: cpd00211_c is 0.537052415215354...
# Loop167 Gapfilling cpd00211_c...Took 20 seconds to gapfill 8 reactions and 3 metabolites.
# pFBA...267.0...Ave likelihood of: cpd00211_c is 0.5484096971445095...
# Loop168 Gapfilling cpd00211_c...Took 20 seconds to gapfill 9 reactions and 3 metabolites.
# pFBA...267.0...Ave likelihood of: cpd00211_c is 0.537052415215354...
# Loop169 Gapfilling cpd00211_c...Took 20 seconds to gapfill 9 reactions and 3 metabolites.
# pFBA...267.0...Ave likelihood of: cpd00211_c is 0.537052415215354...
# Loop170 Gapfilling cpd00211_c...Took 20 seconds to gapfill 9 reactions and 3 metabolites.
# pFBA...267.0...Ave likelihood of: cpd00211_c is 0.537052415215354...
# Loop171 Gapfilling cpd00211_c...Took 20 seconds to gapfill 12 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.5060817734004041...
# Loop172 Gapfilling cpd00211_c...Took 18 seconds to gapfill 12 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.5060817734004041...
# Loop173 Gapfilling cpd00211_c...Took 19 seconds to gapfill 12 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.5060817734004041...
# Loop174 Gapfilling cpd00211_c...Took 19 seconds to gapfill 12 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.5060817734004041...
# Loop175 Gapfilling cpd00211_c...Took 19 seconds to gapfill 12 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.5060817734004041...
# Loop176 Gapfilling cpd00211_c...Took 18 seconds to gapfill 12 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.5060817734004041...
# Loop177 Gapfilling cpd00211_c...Took 17 seconds to gapfill 12 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.5060817734004041...
# Loop178 Gapfilling cpd00211_c...Took 20 seconds to gapfill 12 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.5060817734004041...
# Loop179 Gapfilling cpd00211_c...Took 18 seconds to gapfill 12 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.5060817734004041...
# Loop180 Gapfilling cpd00211_c...Took 20 seconds to gapfill 12 reactions and 3 metabolites.
# pFBA...1000.0...Ave likelihood of: cpd00211_c is 0.37011494631363406...
# Loop181 Gapfilling cpd00211_c...Took 21 seconds to gapfill 12 reactions and 3 metabolites.
# pFBA...1000.0...Ave likelihood of: cpd00211_c is 0.37011494631363406...
# Loop182 Gapfilling cpd00211_c...Took 21 seconds to gapfill 13 reactions and 3 metabolites.
# pFBA...1000.0...Ave likelihood of: cpd00211_c is 0.45930447328905133...
# Loop183 Gapfilling cpd00211_c...Took 21 seconds to gapfill 11 reactions and 3 metabolites.
# pFBA...1000.0...Ave likelihood of: cpd00211_c is 0.43937353123339423...
# Loop184 Gapfilling cpd00211_c...Took 19 seconds to gapfill 13 reactions and 3 metabolites.
# pFBA...1000.0...Ave likelihood of: cpd00211_c is 0.45930447328905133...
# Loop185 Gapfilling cpd00211_c...Took 19 seconds to gapfill 11 reactions and 3 metabolites.
# pFBA...1000.0...Ave likelihood of: cpd00211_c is 0.43937353123339423...
# Loop186 Gapfilling cpd00211_c...Took 18 seconds to gapfill 11 reactions and 3 metabolites.
# pFBA...1000.0...Ave likelihood of: cpd00211_c is 0.43937353123339423...
# Loop187 Gapfilling cpd00211_c...Took 20 seconds to gapfill 13 reactions and 3 metabolites.
# pFBA...1000.0...Ave likelihood of: cpd00211_c is 0.45930447328905133...
# Loop188 Gapfilling cpd00211_c...Took 20 seconds to gapfill 12 reactions and 3 metabolites.
# pFBA...1000.0...Ave likelihood of: cpd00211_c is 0.45930447328905133...
# Loop189 Gapfilling cpd00211_c...Took 19 seconds to gapfill 13 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.5067286353185371...
# Loop190 Gapfilling cpd00211_c...Took 19 seconds to gapfill 13 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.5067286353185371...
# Loop191 Gapfilling cpd00211_c...Took 19 seconds to gapfill 13 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.49877527286228424...
# Loop192 Gapfilling cpd00211_c...Took 21 seconds to gapfill 13 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.49877527286228424...
# Loop193 Gapfilling cpd00211_c...Took 22 seconds to gapfill 13 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.49877527286228424...
# Loop194 Gapfilling cpd00211_c...Took 20 seconds to gapfill 13 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.5067286353185371...
# Loop195 Gapfilling cpd00211_c...Took 20 seconds to gapfill 13 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.49877527286228424...
# Loop196 Gapfilling cpd00211_c...Took 19 seconds to gapfill 13 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.5067286353185371...
# Loop197 Gapfilling cpd00211_c...Took 19 seconds to gapfill 13 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.5067286353185371...
# Loop198 Gapfilling cpd00211_c...Took 21 seconds to gapfill 7 reactions and 3 metabolites.
# pFBA...500.0...Ave likelihood of: cpd00211_c is 0.5892614257628384...
# Loop199 Gapfilling cpd00211_c...Took 19 seconds to gapfill 8 reactions and 3 metabolites.
# pFBA...500.0...Ave likelihood of: cpd00211_c is 0.5892614257628384...
# Loop200 Gapfilling cpd00211_c...Took 22 seconds to gapfill 8 reactions and 3 metabolites.
# pFBA...500.0...Ave likelihood of: cpd00211_c is 0.5892614257628384...
# Loop201 Gapfilling cpd00211_c...Took 18 seconds to gapfill 8 reactions and 3 metabolites.
# pFBA...500.0...Ave likelihood of: cpd00211_c is 0.5892614257628384...
# Loop202 Gapfilling cpd00211_c...Took 21 seconds to gapfill 8 reactions and 3 metabolites.
# pFBA...500.0...Ave likelihood of: cpd00211_c is 0.5892614257628384...
# Loop203 Gapfilling cpd00211_c...Took 19 seconds to gapfill 8 reactions and 3 metabolites.
# pFBA...500.0...Ave likelihood of: cpd00211_c is 0.5892614257628384...
# Loop204 Gapfilling cpd00211_c...Took 19 seconds to gapfill 8 reactions and 3 metabolites.
# pFBA...500.0...Ave likelihood of: cpd00211_c is 0.5892614257628384...
# Loop205 Gapfilling cpd00211_c...Took 19 seconds to gapfill 8 reactions and 3 metabolites.
# pFBA...500.0...Ave likelihood of: cpd00211_c is 0.5892614257628384...
# Loop206 Gapfilling cpd00211_c...Took 20 seconds to gapfill 8 reactions and 3 metabolites.
# pFBA...500.0...Ave likelihood of: cpd00211_c is 0.5892614257628384...
# Loop207 Gapfilling cpd00211_c...Took 19 seconds to gapfill 12 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.527713737555452...
# Loop208 Gapfilling cpd00211_c...Took 19 seconds to gapfill 12 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.527713737555452...
# Loop209 Gapfilling cpd00211_c...Took 20 seconds to gapfill 12 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.527713737555452...
# Loop210 Gapfilling cpd00211_c...Took 20 seconds to gapfill 12 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.527713737555452...
# Loop211 Gapfilling cpd00211_c...Took 19 seconds to gapfill 12 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.527713737555452...
# Loop212 Gapfilling cpd00211_c...Took 20 seconds to gapfill 12 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.527713737555452...
# Loop213 Gapfilling cpd00211_c...Took 18 seconds to gapfill 12 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.527713737555452...
# Loop214 Gapfilling cpd00211_c...Took 21 seconds to gapfill 12 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.527713737555452...
# Loop215 Gapfilling cpd00211_c...Took 20 seconds to gapfill 12 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.527713737555452...
# Loop216 Gapfilling cpd00211_c...Took 20 seconds to gapfill 13 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.5067286353185371...
# Loop217 Gapfilling cpd00211_c...Took 19 seconds to gapfill 13 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.5067286353185371...
# Loop218 Gapfilling cpd00211_c...Took 20 seconds to gapfill 13 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.5067286353185371...
# Loop219 Gapfilling cpd00211_c...Took 18 seconds to gapfill 13 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.5067286353185371...
# Loop220 Gapfilling cpd00211_c...Took 19 seconds to gapfill 13 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.5067286353185371...
# Loop221 Gapfilling cpd00211_c...Took 18 seconds to gapfill 13 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.5067286353185371...
# Loop222 Gapfilling cpd00211_c...Took 20 seconds to gapfill 13 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.49877527286228424...
# Loop223 Gapfilling cpd00211_c...Took 20 seconds to gapfill 13 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.5067286353185371...
# Loop224 Gapfilling cpd00211_c...Took 19 seconds to gapfill 13 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.5067286353185371...
# Loop225 Gapfilling cpd00211_c...Took 19 seconds to gapfill 13 reactions and 3 metabolites.
# pFBA...857.0...demands added
# Ave likelihood of: cpd00211_c is 0.4776708026897744...
# Loop226 Gapfilling cpd00211_c...Took 18 seconds to gapfill 13 reactions and 3 metabolites.
# pFBA...857.0...demands added
# Ave likelihood of: cpd00211_c is 0.4776708026897744...
# Loop227 Gapfilling cpd00211_c...Took 19 seconds to gapfill 13 reactions and 3 metabolites.
# pFBA...857.0...demands added
# Ave likelihood of: cpd00211_c is 0.4776708026897744...
# Loop228 Gapfilling cpd00211_c...Took 19 seconds to gapfill 13 reactions and 3 metabolites.
# pFBA...857.0...demands added
# Ave likelihood of: cpd00211_c is 0.4776708026897744...
# Loop229 Gapfilling cpd00211_c...Took 19 seconds to gapfill 13 reactions and 3 metabolites.
# pFBA...857.0...demands added
# Ave likelihood of: cpd00211_c is 0.4776708026897744...
# Loop230 Gapfilling cpd00211_c...Took 21 seconds to gapfill 13 reactions and 3 metabolites.
# pFBA...857.0...demands added
# Ave likelihood of: cpd00211_c is 0.4776708026897744...
# Loop231 Gapfilling cpd00211_c...Took 20 seconds to gapfill 13 reactions and 3 metabolites.
# pFBA...857.0...demands added
# Ave likelihood of: cpd00211_c is 0.4776708026897744...
# Loop232 Gapfilling cpd00211_c...Took 20 seconds to gapfill 13 reactions and 3 metabolites.
# pFBA...857.0...demands added
# Ave likelihood of: cpd00211_c is 0.4776708026897744...
# Loop233 Gapfilling cpd00211_c...Took 18 seconds to gapfill 13 reactions and 3 metabolites.
# pFBA...857.0...demands added
# Ave likelihood of: cpd00211_c is 0.4776708026897744...
# Loop234 Gapfilling cpd00211_c...Took 21 seconds to gapfill 13 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.5067286353185371...
# Loop235 Gapfilling cpd00211_c...Took 20 seconds to gapfill 13 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.49877527286228424...
# Loop236 Gapfilling cpd00211_c...Took 18 seconds to gapfill 13 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.5067286353185371...
# Loop237 Gapfilling cpd00211_c...Took 19 seconds to gapfill 13 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.49877527286228424...
# Loop238 Gapfilling cpd00211_c...Took 19 seconds to gapfill 13 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.49877527286228424...
# Loop239 Gapfilling cpd00211_c...Took 19 seconds to gapfill 13 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.49877527286228424...
# Loop240 Gapfilling cpd00211_c...Took 20 seconds to gapfill 13 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.49877527286228424...
# Loop241 Gapfilling cpd00211_c...Took 19 seconds to gapfill 13 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.49877527286228424...
# Loop242 Gapfilling cpd00211_c...Took 19 seconds to gapfill 13 reactions and 3 metabolites.
# pFBA...857.0...Ave likelihood of: cpd00211_c is 0.49877527286228424...
# Loop243 Gapfilling cpd00211_c...Took 20 seconds to gapfill 9 reactions and 3 metabolites.
# pFBA...1000.0...Ave likelihood of: cpd00211_c is 0.43937353123339423...
# Loop244 Gapfilling cpd00211_c...Took 19 seconds to gapfill 7 reactions and 3 metabolites.
# pFBA...1000.0...Ave likelihood of: cpd00211_c is 0.43937353123339423...
# Loop245 Gapfilling cpd00211_c...Took 19 seconds to gapfill 8 reactions and 3 metabolites.
# pFBA...1000.0...Ave likelihood of: cpd00211_c is 0.3718575618916252...
# Loop246 Gapfilling cpd00211_c...Took 21 seconds to gapfill 8 reactions and 3 metabolites.
# pFBA...1000.0...Ave likelihood of: cpd00211_c is 0.3718575618916252...
# Loop247 Gapfilling cpd00211_c...Took 20 seconds to gapfill 8 reactions and 3 metabolites.
# pFBA...1000.0...Ave likelihood of: cpd00211_c is 0.3718575618916252...
# Loop248 Gapfilling cpd00211_c...Took 21 seconds to gapfill 8 reactions and 3 metabolites.
# pFBA...1000.0...Ave likelihood of: cpd00211_c is 0.3718575618916252...
# Loop249 Gapfilling cpd00211_c...Took 19 seconds to gapfill 9 reactions and 3 metabolites.
# pFBA...1000.0...Ave likelihood of: cpd00211_c is 0.43937353123339423...
# Loop250 Gapfilling cpd00211_c...Took 19 seconds to gapfill 8 reactions and 3 metabolites.
# pFBA...1000.0...Ave likelihood of: cpd00211_c is 0.4739469610796028...
# Loop251 Gapfilling cpd00211_c...Took 20 seconds to gapfill 8 reactions and 3 metabolites.
# pFBA...1000.0...Ave likelihood of: cpd00211_c is 0.43937353123339423...
# 82.326445214mins to complete!

# %%
total_dataset_dict
# Out:
# {'220668.9:0.0.0': {'Carbon': ['D-Glucose', 'cpd00027'],
#   'Model_ID': '220668.9',
#   'Nitrogen': ['NH3', 'cpd00013'],
#   'active_rxns':                     fluxes
#   rxn04082_c     -250.000000
#   rxn00416_c      104.166667
#   rxn00225_c     -104.166667
#   rxn00148_c     -250.000000
#   rxn00781_c      250.000000
#   rxn00614_c      250.000000
#   rxn05500_c     -250.000000
#   rxn00612_c     -250.000000
#   rxn05571_c     -500.000000
#   rxn01292_c     -250.000000
#   rxn01301_c      250.000000
#   rxn00499_c     -250.000000
#   rxn05573_c     1000.000000
#   rxn01100_c     -250.000000
#   rxn00173_c     -395.833333
#   rxn00187_c      104.166667
#   rxn01116_c      250.000000
#   rxn01763_c     -250.000000
#   rxn01106_c     -250.000000
#   rxn10042_c     -250.000000
#   rxn00548_c      250.000000
#   rxn05602_c     -250.000000
#   rxn01476_c      500.000000
#   rxn01333_c     -250.000000
#   rxn01302_c     -250.000000
#   rxn00459_c      250.000000
#   rxn01187_c      250.000000
#   rxn00216_c     1000.000000
#   rxn00558_c      500.000000
#   rxn01200_c      250.000000
#   rxn01275_c     -500.000000
#   rxn00342_c      104.166667
#   rxn00604_c      500.000000
#   EX_cpd00067_e  1000.000000
#   EX_cpd00224_e   250.000000
#   EX_cpd00222_e   500.000000
#   EX_cpd00027_e -1000.000000
#   EX_cpd00159_e   250.000000
#   DM_cpd00211_c   250.000000
#   rxn00777_c      250.000000
#   rxn00178_c      250.000000
#   rxn08443_c       41.666667
#   rxn00875_c      104.166667
#   rxn10074_c     -250.000000
#   rxn00873_c     -145.833333
#   rxn09469_c      -41.666667
#   rxn10663_c       41.666667,
#   'avg_path_like': 0.5559515582601068,
#   'demands': [],
#   'gap_avg_like': 0.19784440935550182,
#   'gaps_filled': {u'rxn00178_c',
#    u'rxn00777_c',
#    u'rxn00873_c',
#    u'rxn00875_c',
#    u'rxn08443_c',
#    u'rxn09469_c',
#    u'rxn10074_c',
#    u'rxn10663_c'},
#   'gaps_w_flux': [['rxn00777_c', 0.7913776374220073],
#    ['rxn00178_c', 0.0],
#    ['rxn00875_c', 0.0],
#    ['rxn00873_c', 0.0]],
#   'mets_added': {'cpd00120_c', 'cpd00982_c', 'cpd15238_c'},
#   'objective': 'Butyrate',
#   'opt_after': 249.99999999999966,
#   'opt_before': 0.0,
#   'path_avg_like': 0.5993584854000589,
#   'path_w_flux': [['rxn04082_c', 0.743772609547454],
#    ['rxn00416_c', 0.39405404313243647],
#    ['rxn00225_c', 0.7081615561511267],
#    ['rxn00148_c', 0.7321378826037916],
#    ['rxn00781_c', 0.5191220214505604],
#    ['rxn00614_c', 0.22013316862116666],
#    ['rxn05500_c', 0.6356445256659282],
#    ['rxn00612_c', 0.7484405309001277],
#    ['rxn05571_c', 0.22287311094173126],
#    ['rxn01292_c', 0.7509517121843206],
#    ['rxn01301_c', 0.7165696798161908],
#    ['rxn00499_c', 0.8302829270557739],
#    ['rxn05573_c', 0.16711061359245097],
#    ['rxn01100_c', 0.5916669155435752],
#    ['rxn00173_c', 0.7297596125397976],
#    ['rxn00187_c', 0.6839770327156126],
#    ['rxn01116_c', 0.7331256660930605],
#    ['rxn01763_c', 0.9794649761940855],
#    ['rxn01106_c', 0.2510839990368638],
#    ['rxn10042_c', 0.6189340413235531],
#    ['rxn00548_c', 0.7603672794410494],
#    ['rxn05602_c', 0.7777435465715274],
#    ['rxn01476_c', 0.6371698314027111],
#    ['rxn01333_c', 0.8979633240378723],
#    ['rxn01302_c', 0.7165696798161908],
#    ['rxn00459_c', 0.5819488983073209],
#    ['rxn01187_c', 0.7603672794410494],
#    ['rxn00216_c', 0.4759403048212528],
#    ['rxn00558_c', 0.13632578864588127],
#    ['rxn01200_c', 0.2340700358459846],
#    ['rxn01275_c', 0.4790450388155571],
#    ['rxn00342_c', 0.7358764039783672],
#    ['rxn00604_c', 0.608175981967571]],
#   'reactions_w_flux': [['rxn04082_c', 0.743772609547454],
#    ['rxn00416_c', 0.39405404313243647],
#    ['rxn00225_c', 0.7081615561511267],
#    ['rxn00148_c', 0.7321378826037916],
#    ['rxn00781_c', 0.5191220214505604],
#    ['rxn00614_c', 0.22013316862116666],
#    ['rxn05500_c', 0.6356445256659282],
#    ['rxn00612_c', 0.7484405309001277],
#    ['rxn05571_c', 0.22287311094173126],
#    ['rxn01292_c', 0.7509517121843206],
#    ['rxn01301_c', 0.7165696798161908],
#    ['rxn00499_c', 0.8302829270557739],
#    ['rxn05573_c', 0.16711061359245097],
#    ['rxn01100_c', 0.5916669155435752],
#    ['rxn00173_c', 0.7297596125397976],
#    ['rxn00187_c', 0.6839770327156126],
#    ['rxn01116_c', 0.7331256660930605],
#    ['rxn01763_c', 0.9794649761940855],
#    ['rxn01106_c', 0.2510839990368638],
#    ['rxn10042_c', 0.6189340413235531],
#    ['rxn00548_c', 0.7603672794410494],
#    ['rxn05602_c', 0.7777435465715274],
#    ['rxn01476_c', 0.6371698314027111],
#    ['rxn01333_c', 0.8979633240378723],
#    ['rxn01302_c', 0.7165696798161908],
#    ['rxn00459_c', 0.5819488983073209],
#    ['rxn01187_c', 0.7603672794410494],
#    ['rxn00216_c', 0.4759403048212528],
#    ['rxn00558_c', 0.13632578864588127],
#    ['rxn01200_c', 0.2340700358459846],
#    ['rxn01275_c', 0.4790450388155571],
#    ['rxn00342_c', 0.7358764039783672],
#    ['rxn00604_c', 0.608175981967571],
#    ['rxn00777_c', 0.7913776374220073],
#    ['rxn00178_c', 0.0],
#    ['rxn00875_c', 0.0],
#    ['rxn00873_c', 0.0]]},
#  '220668.9:0.1.0': {'Carbon': ['D-Glucose', 'cpd00027'],
#   'Model_ID': '220668.9',
#   'Nitrogen': ['Allantoin', 'cpd01092'],
#   'active_rxns':                     fluxes
#   rxn04082_c     -250.000000
#   rxn00416_c      104.166667
#   rxn00225_c     -104.166667
#   rxn00148_c     -250.000000
#   rxn00781_c      250.000000
#   rxn00614_c      250.000000
#   rxn05500_c     -250.000000
#   rxn00612_c     -250.000000
#   rxn05571_c     -500.000000
#   rxn01292_c     -250.000000
#   rxn01301_c      250.000000
#   rxn00499_c     -250.000000
#   rxn05573_c     1000.000000
#   rxn01100_c     -250.000000
#   rxn00173_c     -395.833333
#   rxn00187_c      104.166667
#   rxn01116_c      250.000000
#   rxn01763_c     -250.000000
#   rxn01106_c     -250.000000
#   rxn10042_c     -250.000000
#   rxn00548_c      250.000000
#   rxn05602_c     -250.000000
#   rxn01476_c      500.000000
#   rxn01333_c     -250.000000
#   rxn01302_c     -250.000000
#   rxn00459_c      250.000000
#   rxn01187_c      250.000000
#   rxn00216_c     1000.000000
#   rxn00558_c      500.000000
#   rxn01200_c      250.000000
#   rxn01275_c     -500.000000
#   rxn00342_c      104.166667
#   rxn00604_c      500.000000
#   EX_cpd00067_e  1000.000000
#   EX_cpd00224_e   250.000000
#   EX_cpd00222_e   500.000000
#   EX_cpd00027_e -1000.000000
#   EX_cpd00159_e   250.000000
#   DM_cpd00211_c   250.000000
#   rxn00777_c      250.000000
#   rxn00178_c      250.000000
#   rxn08443_c       41.666667
#   rxn00875_c      104.166667
#   rxn10074_c     -250.000000
#   rxn10663_c       41.666667
#   rxn00873_c     -145.833333
#   rxn09469_c      -41.666667,
#   'avg_path_like': 0.5559515582601068,
#   'demands': [],
#   'gap_avg_like': 0.19784440935550182,
#   'gaps_filled': {u'rxn00178_c',
#    u'rxn00777_c',
#    u'rxn00873_c',
#    u'rxn00875_c',
#    u'rxn08443_c',
#    u'rxn09469_c',
#    u'rxn10074_c',
#    u'rxn10663_c'},
#   'gaps_w_flux': [['rxn00777_c', 0.7913776374220073],
#    ['rxn00178_c', 0.0],
#    ['rxn00875_c', 0.0],
#    ['rxn00873_c', 0.0]],
#   'mets_added': {'cpd00120_c', 'cpd00982_c', 'cpd15238_c'},
#   'objective': 'Butyrate',
#   'opt_after': 250.00000000000017,
#   'opt_before': 0.0,
#   'path_avg_like': 0.5993584854000589,
#   'path_w_flux': [['rxn04082_c', 0.743772609547454],
#    ['rxn00416_c', 0.39405404313243647],
#    ['rxn00225_c', 0.7081615561511267],
#    ['rxn00148_c', 0.7321378826037916],
#    ['rxn00781_c', 0.5191220214505604],
#    ['rxn00614_c', 0.22013316862116666],
#    ['rxn05500_c', 0.6356445256659282],
#    ['rxn00612_c', 0.7484405309001277],
#    ['rxn05571_c', 0.22287311094173126],
#    ['rxn01292_c', 0.7509517121843206],
#    ['rxn01301_c', 0.7165696798161908],
#    ['rxn00499_c', 0.8302829270557739],
#    ['rxn05573_c', 0.16711061359245097],
#    ['rxn01100_c', 0.5916669155435752],
#    ['rxn00173_c', 0.7297596125397976],
#    ['rxn00187_c', 0.6839770327156126],
#    ['rxn01116_c', 0.7331256660930605],
#    ['rxn01763_c', 0.9794649761940855],
#    ['rxn01106_c', 0.2510839990368638],
#    ['rxn10042_c', 0.6189340413235531],
#    ['rxn00548_c', 0.7603672794410494],
#    ['rxn05602_c', 0.7777435465715274],
#    ['rxn01476_c', 0.6371698314027111],
#    ['rxn01333_c', 0.8979633240378723],
#    ['rxn01302_c', 0.7165696798161908],
#    ['rxn00459_c', 0.5819488983073209],
#    ['rxn01187_c', 0.7603672794410494],
#    ['rxn00216_c', 0.4759403048212528],
#    ['rxn00558_c', 0.13632578864588127],
#    ['rxn01200_c', 0.2340700358459846],
#    ['rxn01275_c', 0.4790450388155571],
#    ['rxn00342_c', 0.7358764039783672],
#    ['rxn00604_c', 0.608175981967571]],
#   'reactions_w_flux': [['rxn04082_c', 0.743772609547454],
#    ['rxn00416_c', 0.39405404313243647],
#    ['rxn00225_c', 0.7081615561511267],
#    ['rxn00148_c', 0.7321378826037916],
#    ['rxn00781_c', 0.5191220214505604],
#    ['rxn00614_c', 0.22013316862116666],
#    ['rxn05500_c', 0.6356445256659282],
#    ['rxn00612_c', 0.7484405309001277],
#    ['rxn05571_c', 0.22287311094173126],
#    ['rxn01292_c', 0.7509517121843206],
#    ['rxn01301_c', 0.7165696798161908],
#    ['rxn00499_c', 0.8302829270557739],
#    ['rxn05573_c', 0.16711061359245097],
#    ['rxn01100_c', 0.5916669155435752],
#    ['rxn00173_c', 0.7297596125397976],
#    ['rxn00187_c', 0.6839770327156126],
#    ['rxn01116_c', 0.7331256660930605],
#    ['rxn01763_c', 0.9794649761940855],
#    ['rxn01106_c', 0.2510839990368638],
#    ['rxn10042_c', 0.6189340413235531],
#    ['rxn00548_c', 0.7603672794410494],
#    ['rxn05602_c', 0.7777435465715274],
#    ['rxn01476_c', 0.6371698314027111],
#    ['rxn01333_c', 0.8979633240378723],
#    ['rxn01302_c', 0.7165696798161908],
#    ['rxn00459_c', 0.5819488983073209],
#    ['rxn01187_c', 0.7603672794410494],
#    ['rxn00216_c', 0.4759403048212528],
#    ['rxn00558_c', 0.13632578864588127],
#    ['rxn01200_c', 0.2340700358459846],
#    ['rxn01275_c', 0.4790450388155571],
#    ['rxn00342_c', 0.7358764039783672],
#    ['rxn00604_c', 0.608175981967571],
#    ['rxn00777_c', 0.7913776374220073],
#    ['rxn00178_c', 0.0],
#    ['rxn00875_c', 0.0],
#    ['rxn00873_c', 0.0]]},
#  '220668.9:0.2.0': {'Carbon': ['D-Glucose', 'cpd00027'],
#   'Model_ID': '220668.9',
#   'Nitrogen': ['BET', 'cpd00540'],
#   'active_rxns':                     fluxes
#   rxn04082_c     -250.000000
#   rxn00416_c      104.166667
#   rxn00225_c     -104.166667
#   rxn00148_c     -250.000000
#   rxn00781_c      250.000000
#   rxn00614_c      250.000000
#   rxn05500_c     -250.000000
#   rxn00612_c     -250.000000
#   rxn05571_c     -500.000000
#   rxn01292_c     -250.000000
#   rxn01301_c      250.000000
#   rxn00499_c     -250.000000
#   rxn05573_c     1000.000000
#   rxn01100_c     -250.000000
#   rxn00173_c     -395.833333
#   rxn00187_c      104.166667
#   rxn01116_c      250.000000
#   rxn01763_c     -250.000000
#   rxn01106_c     -250.000000
#   rxn10042_c     -250.000000
#   rxn00548_c      250.000000
#   rxn05602_c     -250.000000
#   rxn01476_c      500.000000
#   rxn01333_c     -250.000000
#   rxn01302_c     -250.000000
#   rxn00459_c      250.000000
#   rxn01187_c      250.000000
#   rxn00216_c     1000.000000
#   rxn00558_c      500.000000
#   rxn01200_c      250.000000
#   rxn01275_c     -500.000000
#   rxn00342_c      104.166667
#   rxn00604_c      500.000000
#   EX_cpd00067_e  1000.000000
#   EX_cpd00224_e   250.000000
#   EX_cpd00222_e   500.000000
#   EX_cpd00027_e -1000.000000
#   EX_cpd00159_e   250.000000
#   DM_cpd00211_c   250.000000
#   rxn00178_c      250.000000
#   rxn08443_c       41.666667
#   rxn00875_c      104.166667
#   rxn00777_c      250.000000
#   rxn10663_c       41.666667
#   rxn10074_c     -250.000000
#   rxn00873_c     -145.833333
#   rxn09469_c      -41.666667,
#   'avg_path_like': 0.5559515582601068,
#   'demands': [],
#   'gap_avg_like': 0.19784440935550182,
#   'gaps_filled': {u'rxn00178_c',
#    u'rxn00777_c',
#    u'rxn00873_c',
#    u'rxn00875_c',
#    u'rxn08443_c',
#    u'rxn09469_c',
#    u'rxn10074_c',
#    u'rxn10663_c'},
#   'gaps_w_flux': [['rxn00178_c', 0.0],
#    ['rxn00875_c', 0.0],
#    ['rxn00777_c', 0.7913776374220073],
#    ['rxn00873_c', 0.0]],
#   'mets_added': {'cpd00120_c', 'cpd00982_c', 'cpd15238_c'},
#   'objective': 'Butyrate',
#   'opt_after': 249.99999999999918,
#   'opt_before': 0.0,
#   'path_avg_like': 0.5993584854000589,
#   'path_w_flux': [['rxn04082_c', 0.743772609547454],
#    ['rxn00416_c', 0.39405404313243647],
#    ['rxn00225_c', 0.7081615561511267],
#    ['rxn00148_c', 0.7321378826037916],
#    ['rxn00781_c', 0.5191220214505604],
#    ['rxn00614_c', 0.22013316862116666],
#    ['rxn05500_c', 0.6356445256659282],
#    ['rxn00612_c', 0.7484405309001277],
#    ['rxn05571_c', 0.22287311094173126],
#    ['rxn01292_c', 0.7509517121843206],
#    ['rxn01301_c', 0.7165696798161908],
#    ['rxn00499_c', 0.8302829270557739],
#    ['rxn05573_c', 0.16711061359245097],
#    ['rxn01100_c', 0.5916669155435752],
#    ['rxn00173_c', 0.7297596125397976],
#    ['rxn00187_c', 0.6839770327156126],
#    ['rxn01116_c', 0.7331256660930605],
#    ['rxn01763_c', 0.9794649761940855],
#    ['rxn01106_c', 0.2510839990368638],
#    ['rxn10042_c', 0.6189340413235531],
#    ['rxn00548_c', 0.7603672794410494],
#    ['rxn05602_c', 0.7777435465715274],
#    ['rxn01476_c', 0.6371698314027111],
#    ['rxn01333_c', 0.8979633240378723],
#    ['rxn01302_c', 0.7165696798161908],
#    ['rxn00459_c', 0.5819488983073209],
#    ['rxn01187_c', 0.7603672794410494],
#    ['rxn00216_c', 0.4759403048212528],
#    ['rxn00558_c', 0.13632578864588127],
#    ['rxn01200_c', 0.2340700358459846],
#    ['rxn01275_c', 0.4790450388155571],
#    ['rxn00342_c', 0.7358764039783672],
#    ['rxn00604_c', 0.608175981967571]],
#   'reactions_w_flux': [['rxn04082_c', 0.743772609547454],
#    ['rxn00416_c', 0.39405404313243647],
#    ['rxn00225_c', 0.7081615561511267],
#    ['rxn00148_c', 0.7321378826037916],
#    ['rxn00781_c', 0.5191220214505604],
#    ['rxn00614_c', 0.22013316862116666],
#    ['rxn05500_c', 0.6356445256659282],
#    ['rxn00612_c', 0.7484405309001277],
#    ['rxn05571_c', 0.22287311094173126],
#    ['rxn01292_c', 0.7509517121843206],
#    ['rxn01301_c', 0.7165696798161908],
#    ['rxn00499_c', 0.8302829270557739],
#    ['rxn05573_c', 0.16711061359245097],
#    ['rxn01100_c', 0.5916669155435752],
#    ['rxn00173_c', 0.7297596125397976],
#    ['rxn00187_c', 0.6839770327156126],
#    ['rxn01116_c', 0.7331256660930605],
#    ['rxn01763_c', 0.9794649761940855],
#    ['rxn01106_c', 0.2510839990368638],
#    ['rxn10042_c', 0.6189340413235531],
#    ['rxn00548_c', 0.7603672794410494],
#    ['rxn05602_c', 0.7777435465715274],
#    ['rxn01476_c', 0.6371698314027111],
#    ['rxn01333_c', 0.8979633240378723],
#    ['rxn01302_c', 0.7165696798161908],
#    ['rxn00459_c', 0.5819488983073209],
#    ['rxn01187_c', 0.7603672794410494],
#    ['rxn00216_c', 0.4759403048212528],
#    ['rxn00558_c', 0.13632578864588127],
#    ['rxn01200_c', 0.2340700358459846],
#    ['rxn01275_c', 0.4790450388155571],
#    ['rxn00342_c', 0.7358764039783672],
#    ['rxn00604_c', 0.608175981967571],
#    ['rxn00178_c', 0.0],
#    ['rxn00875_c', 0.0],
#    ['rxn00777_c', 0.7913776374220073],
#    ['rxn00873_c', 0.0]]},
#  '220668.9:0.3.0': {'Carbon': ['D-Glucose', 'cpd00027'],
#   'Model_ID': '220668.9',
#   'Nitrogen': ['Choline', 'cpd00098'],
#   'active_rxns':                     fluxes
#   rxn04082_c     -250.000000
#   rxn00416_c      104.166667
#   rxn00225_c     -104.166667
#   rxn00148_c     -250.000000
#   rxn00781_c      250.000000
#   rxn00614_c      250.000000
#   rxn05500_c     -250.000000
#   rxn00612_c     -250.000000
#   rxn05571_c     -500.000000
#   rxn01292_c     -250.000000
#   rxn01301_c      250.000000
#   rxn00499_c     -250.000000
#   rxn05573_c     1000.000000
#   rxn01100_c     -250.000000
#   rxn00173_c     -395.833333
#   rxn00187_c      104.166667
#   rxn01116_c      250.000000
#   rxn01763_c     -250.000000
#   rxn01106_c     -250.000000
#   rxn10042_c     -250.000000
#   rxn00548_c      250.000000
#   rxn05602_c     -250.000000
#   rxn01476_c      500.000000
#   rxn01333_c     -250.000000
#   rxn01302_c     -250.000000
#   rxn00459_c      250.000000
#   rxn01187_c      250.000000
#   rxn00216_c     1000.000000
#   rxn00558_c      500.000000
#   rxn01200_c      250.000000
#   rxn01275_c     -500.000000
#   rxn00342_c      104.166667
#   rxn00604_c      500.000000
#   EX_cpd00067_e  1000.000000
#   EX_cpd00224_e   250.000000
#   EX_cpd00222_e   500.000000
#   EX_cpd00027_e -1000.000000
#   EX_cpd00159_e   250.000000
#   DM_cpd00211_c   250.000000
#   rxn00178_c      250.000000
#   rxn08443_c       41.666667
#   rxn00875_c      104.166667
#   rxn00777_c      250.000000
#   rxn10074_c     -250.000000
#   rxn10663_c       41.666667
#   rxn00873_c     -145.833333
#   rxn09469_c      -41.666667,
#   'avg_path_like': 0.5559515582601068,
#   'demands': [],
#   'gap_avg_like': 0.19784440935550182,
#   'gaps_filled': {u'rxn00178_c',
#    u'rxn00777_c',
#    u'rxn00873_c',
#    u'rxn00875_c',
#    u'rxn08443_c',
#    u'rxn09469_c',
#    u'rxn10074_c',
#    u'rxn10663_c'},
#   'gaps_w_flux': [['rxn00178_c', 0.0],
#    ['rxn00875_c', 0.0],
#    ['rxn00777_c', 0.7913776374220073],
#    ['rxn00873_c', 0.0]],
#   'mets_added': {'cpd00120_c', 'cpd00982_c', 'cpd15238_c'},
#   'objective': 'Butyrate',
#   'opt_after': 249.99999999999918,
#   'opt_before': 0.0,
#   'path_avg_like': 0.5993584854000589,
#   'path_w_flux': [['rxn04082_c', 0.743772609547454],
#    ['rxn00416_c', 0.39405404313243647],
#    ['rxn00225_c', 0.7081615561511267],
#    ['rxn00148_c', 0.7321378826037916],
#    ['rxn00781_c', 0.5191220214505604],
#    ['rxn00614_c', 0.22013316862116666],
#    ['rxn05500_c', 0.6356445256659282],
#    ['rxn00612_c', 0.7484405309001277],
#    ['rxn05571_c', 0.22287311094173126],
#    ['rxn01292_c', 0.7509517121843206],
#    ['rxn01301_c', 0.7165696798161908],
#    ['rxn00499_c', 0.8302829270557739],
#    ['rxn05573_c', 0.16711061359245097],
#    ['rxn01100_c', 0.5916669155435752],
#    ['rxn00173_c', 0.7297596125397976],
#    ['rxn00187_c', 0.6839770327156126],
#    ['rxn01116_c', 0.7331256660930605],
#    ['rxn01763_c', 0.9794649761940855],
#    ['rxn01106_c', 0.2510839990368638],
#    ['rxn10042_c', 0.6189340413235531],
#    ['rxn00548_c', 0.7603672794410494],
#    ['rxn05602_c', 0.7777435465715274],
#    ['rxn01476_c', 0.6371698314027111],
#    ['rxn01333_c', 0.8979633240378723],
#    ['rxn01302_c', 0.7165696798161908],
#    ['rxn00459_c', 0.5819488983073209],
#    ['rxn01187_c', 0.7603672794410494],
#    ['rxn00216_c', 0.4759403048212528],
#    ['rxn00558_c', 0.13632578864588127],
#    ['rxn01200_c', 0.2340700358459846],
#    ['rxn01275_c', 0.4790450388155571],
#    ['rxn00342_c', 0.7358764039783672],
#    ['rxn00604_c', 0.608175981967571]],
#   'reactions_w_flux': [['rxn04082_c', 0.743772609547454],
#    ['rxn00416_c', 0.39405404313243647],
#    ['rxn00225_c', 0.7081615561511267],
#    ['rxn00148_c', 0.7321378826037916],
#    ['rxn00781_c', 0.5191220214505604],
#    ['rxn00614_c', 0.22013316862116666],
#    ['rxn05500_c', 0.6356445256659282],
#    ['rxn00612_c', 0.7484405309001277],
#    ['rxn05571_c', 0.22287311094173126],
#    ['rxn01292_c', 0.7509517121843206],
#    ['rxn01301_c', 0.7165696798161908],
#    ['rxn00499_c', 0.8302829270557739],
#    ['rxn05573_c', 0.16711061359245097],
#    ['rxn01100_c', 0.5916669155435752],
#    ['rxn00173_c', 0.7297596125397976],
#    ['rxn00187_c', 0.6839770327156126],
#    ['rxn01116_c', 0.7331256660930605],
#    ['rxn01763_c', 0.9794649761940855],
#    ['rxn01106_c', 0.2510839990368638],
#    ['rxn10042_c', 0.6189340413235531],
#    ['rxn00548_c', 0.7603672794410494],
#    ['rxn05602_c', 0.7777435465715274],
#    ['rxn01476_c', 0.6371698314027111],
#    ['rxn01333_c', 0.8979633240378723],
#    ['rxn01302_c', 0.7165696798161908],
#    ['rxn00459_c', 0.5819488983073209],
#    ['rxn01187_c', 0.7603672794410494],
#    ['rxn00216_c', 0.4759403048212528],
#    ['rxn00558_c', 0.13632578864588127],
#    ['rxn01200_c', 0.2340700358459846],
#    ['rxn01275_c', 0.4790450388155571],
#    ['rxn00342_c', 0.7358764039783672],
#    ['rxn00604_c', 0.608175981967571],
#    ['rxn00178_c', 0.0],
#    ['rxn00875_c', 0.0],
#    ['rxn00777_c', 0.7913776374220073],
#    ['rxn00873_c', 0.0]]},
#  '220668.9:0.4.0': {'Carbon': ['D-Glucose', 'cpd00027'],
#   'Model_ID': '220668.9',
#   'Nitrogen': ['Nitrate', 'cpd00209'],
#   'active_rxns':                     fluxes
#   rxn04082_c     -250.000000
#   rxn00416_c      104.166667
#   rxn00225_c     -104.166667
#   rxn00148_c     -250.000000
#   rxn00781_c      250.000000
#   rxn00614_c      250.000000
#   rxn05500_c     -250.000000
#   rxn00612_c     -250.000000
#   rxn05571_c     -500.000000
#   rxn01292_c     -250.000000
#   rxn01301_c      250.000000
#   rxn00499_c     -250.000000
#   rxn05573_c     1000.000000
#   rxn01100_c     -250.000000
#   rxn00173_c     -395.833333
#   rxn00187_c      104.166667
#   rxn01116_c      250.000000
#   rxn01763_c     -250.000000
#   rxn01106_c     -250.000000
#   rxn10042_c     -250.000000
#   rxn00548_c      250.000000
#   rxn05602_c     -250.000000
#   rxn01476_c      500.000000
#   rxn01333_c     -250.000000
#   rxn01302_c     -250.000000
#   rxn00459_c      250.000000
#   rxn01187_c      250.000000
#   rxn00216_c     1000.000000
#   rxn00558_c      500.000000
#   rxn01200_c      250.000000
#   rxn01275_c     -500.000000
#   rxn00342_c      104.166667
#   rxn00604_c      500.000000
#   EX_cpd00067_e  1000.000000
#   EX_cpd00224_e   250.000000
#   EX_cpd00222_e   500.000000
#   EX_cpd00027_e -1000.000000
#   EX_cpd00159_e   250.000000
#   DM_cpd00211_c   250.000000
#   rxn00178_c      250.000000
#   rxn08443_c       41.666667
#   rxn00875_c      104.166667
#   rxn00777_c      250.000000
#   rxn10663_c       41.666667
#   rxn10074_c     -250.000000
#   rxn00873_c     -145.833333
#   rxn09469_c      -41.666667,
#   'avg_path_like': 0.5559515582601068,
#   'demands': [],
#   'gap_avg_like': 0.19784440935550182,
#   'gaps_filled': {u'rxn00178_c',
#    u'rxn00777_c',
#    u'rxn00873_c',
#    u'rxn00875_c',
#    u'rxn08443_c',
#    u'rxn09469_c',
#    u'rxn10074_c',
#    u'rxn10663_c'},
#   'gaps_w_flux': [['rxn00178_c', 0.0],
#    ['rxn00875_c', 0.0],
#    ['rxn00777_c', 0.7913776374220073],
#    ['rxn00873_c', 0.0]],
#   'mets_added': {'cpd00120_c', 'cpd00982_c', 'cpd15238_c'},
#   'objective': 'Butyrate',
#   'opt_after': 250.00000000000017,
#   'opt_before': 0.0,
#   'path_avg_like': 0.5993584854000589,
#   'path_w_flux': [['rxn04082_c', 0.743772609547454],
#    ['rxn00416_c', 0.39405404313243647],
#    ['rxn00225_c', 0.7081615561511267],
#    ['rxn00148_c', 0.7321378826037916],
#    ['rxn00781_c', 0.5191220214505604],
#    ['rxn00614_c', 0.22013316862116666],
#    ['rxn05500_c', 0.6356445256659282],
#    ['rxn00612_c', 0.7484405309001277],
#    ['rxn05571_c', 0.22287311094173126],
#    ['rxn01292_c', 0.7509517121843206],
#    ['rxn01301_c', 0.7165696798161908],
#    ['rxn00499_c', 0.8302829270557739],
#    ['rxn05573_c', 0.16711061359245097],
#    ['rxn01100_c', 0.5916669155435752],
#    ['rxn00173_c', 0.7297596125397976],
#    ['rxn00187_c', 0.6839770327156126],
#    ['rxn01116_c', 0.7331256660930605],
#    ['rxn01763_c', 0.9794649761940855],
#    ['rxn01106_c', 0.2510839990368638],
#    ['rxn10042_c', 0.6189340413235531],
#    ['rxn00548_c', 0.7603672794410494],
#    ['rxn05602_c', 0.7777435465715274],
#    ['rxn01476_c', 0.6371698314027111],
#    ['rxn01333_c', 0.8979633240378723],
#    ['rxn01302_c', 0.7165696798161908],
#    ['rxn00459_c', 0.5819488983073209],
#    ['rxn01187_c', 0.7603672794410494],
#    ['rxn00216_c', 0.4759403048212528],
#    ['rxn00558_c', 0.13632578864588127],
#    ['rxn01200_c', 0.2340700358459846],
#    ['rxn01275_c', 0.4790450388155571],
#    ['rxn00342_c', 0.7358764039783672],
#    ['rxn00604_c', 0.608175981967571]],
#   'reactions_w_flux': [['rxn04082_c', 0.743772609547454],
#    ['rxn00416_c', 0.39405404313243647],
#    ['rxn00225_c', 0.7081615561511267],
#    ['rxn00148_c', 0.7321378826037916],
#    ['rxn00781_c', 0.5191220214505604],
#    ['rxn00614_c', 0.22013316862116666],
#    ['rxn05500_c', 0.6356445256659282],
#    ['rxn00612_c', 0.7484405309001277],
#    ['rxn05571_c', 0.22287311094173126],
#    ['rxn01292_c', 0.7509517121843206],
#    ['rxn01301_c', 0.7165696798161908],
#    ['rxn00499_c', 0.8302829270557739],
#    ['rxn05573_c', 0.16711061359245097],
#    ['rxn01100_c', 0.5916669155435752],
#    ['rxn00173_c', 0.7297596125397976],
#    ['rxn00187_c', 0.6839770327156126],
#    ['rxn01116_c', 0.7331256660930605],
#    ['rxn01763_c', 0.9794649761940855],
#    ['rxn01106_c', 0.2510839990368638],
#    ['rxn10042_c', 0.6189340413235531],
#    ['rxn00548_c', 0.7603672794410494],
#    ['rxn05602_c', 0.7777435465715274],
#    ['rxn01476_c', 0.6371698314027111],
#    ['rxn01333_c', 0.8979633240378723],
#    ['rxn01302_c', 0.7165696798161908],
#    ['rxn00459_c', 0.5819488983073209],
#    ['rxn01187_c', 0.7603672794410494],
#    ['rxn00216_c', 0.4759403048212528],
#    ['rxn00558_c', 0.13632578864588127],
#    ['rxn01200_c', 0.2340700358459846],
#    ['rxn01275_c', 0.4790450388155571],
#    ['rxn00342_c', 0.7358764039783672],
#    ['rxn00604_c', 0.608175981967571],
#    ['rxn00178_c', 0.0],
#    ['rxn00875_c', 0.0],
#    ['rxn00777_c', 0.7913776374220073],
#    ['rxn00873_c', 0.0]]},
#  '220668.9:0.5.0': {'Carbon': ['D-Glucose', 'cpd00027'],
#   'Model_ID': '220668.9',
#   'Nitrogen': ['Nitrite', 'cpd00075'],
#   'active_rxns':                     fluxes
#   rxn04082_c     -250.000000
#   rxn00416_c      104.166667
#   rxn00225_c     -104.166667
#   rxn00148_c     -250.000000
#   rxn00781_c      250.000000
#   rxn00614_c      250.000000
#   rxn05500_c     -250.000000
#   rxn00612_c     -250.000000
#   rxn05571_c     -500.000000
#   rxn01292_c     -250.000000
#   rxn01301_c      250.000000
#   rxn00499_c     -250.000000
#   rxn05573_c     1000.000000
#   rxn01100_c     -250.000000
#   rxn00173_c     -395.833333
#   rxn00187_c      104.166667
#   rxn01116_c      250.000000
#   rxn01763_c     -250.000000
#   rxn01106_c     -250.000000
#   rxn10042_c     -250.000000
#   rxn00548_c      250.000000
#   rxn05602_c     -250.000000
#   rxn01476_c      500.000000
#   rxn01333_c     -250.000000
#   rxn01302_c     -250.000000
#   rxn00459_c      250.000000
#   rxn01187_c      250.000000
#   rxn00216_c     1000.000000
#   rxn00558_c      500.000000
#   rxn01200_c      250.000000
#   rxn01275_c     -500.000000
#   rxn00342_c      104.166667
#   rxn00604_c      500.000000
#   EX_cpd00067_e  1000.000000
#   EX_cpd00224_e   250.000000
#   EX_cpd00222_e   500.000000
#   EX_cpd00027_e -1000.000000
#   EX_cpd00159_e   250.000000
#   DM_cpd00211_c   250.000000
#   rxn00777_c      250.000000
#   rxn00178_c      250.000000
#   rxn08443_c       41.666667
#   rxn00875_c      104.166667
#   rxn10074_c     -250.000000
#   rxn10663_c       41.666667
#   rxn00873_c     -145.833333
#   rxn09469_c      -41.666667,
#   'avg_path_like': 0.5559515582601068,
#   'demands': [],
#   'gap_avg_like': 0.19784440935550182,
#   'gaps_filled': {u'rxn00178_c',
#    u'rxn00777_c',
#    u'rxn00873_c',
#    u'rxn00875_c',
#    u'rxn08443_c',
#    u'rxn09469_c',
#    u'rxn10074_c',
#    u'rxn10663_c'},
#   'gaps_w_flux': [['rxn00777_c', 0.7913776374220073],
#    ['rxn00178_c', 0.0],
#    ['rxn00875_c', 0.0],
#    ['rxn00873_c', 0.0]],
#   'mets_added': {'cpd00120_c', 'cpd00982_c', 'cpd15238_c'},
#   'objective': 'Butyrate',
#   'opt_after': 250.00000000000017,
#   'opt_before': 0.0,
#   'path_avg_like': 0.5993584854000589,
#   'path_w_flux': [['rxn04082_c', 0.743772609547454],
#    ['rxn00416_c', 0.39405404313243647],
#    ['rxn00225_c', 0.7081615561511267],
#    ['rxn00148_c', 0.7321378826037916],
#    ['rxn00781_c', 0.5191220214505604],
#    ['rxn00614_c', 0.22013316862116666],
#    ['rxn05500_c', 0.6356445256659282],
#    ['rxn00612_c', 0.7484405309001277],
#    ['rxn05571_c', 0.22287311094173126],
#    ['rxn01292_c', 0.7509517121843206],
#    ['rxn01301_c', 0.7165696798161908],
#    ['rxn00499_c', 0.8302829270557739],
#    ['rxn05573_c', 0.16711061359245097],
#    ['rxn01100_c', 0.5916669155435752],
#    ['rxn00173_c', 0.7297596125397976],
#    ['rxn00187_c', 0.6839770327156126],
#    ['rxn01116_c', 0.7331256660930605],
#    ['rxn01763_c', 0.9794649761940855],
#    ['rxn01106_c', 0.2510839990368638],
#    ['rxn10042_c', 0.6189340413235531],
#    ['rxn00548_c', 0.7603672794410494],
#    ['rxn05602_c', 0.7777435465715274],
#    ['rxn01476_c', 0.6371698314027111],
#    ['rxn01333_c', 0.8979633240378723],
#    ['rxn01302_c', 0.7165696798161908],
#    ['rxn00459_c', 0.5819488983073209],
#    ['rxn01187_c', 0.7603672794410494],
#    ['rxn00216_c', 0.4759403048212528],
#    ['rxn00558_c', 0.13632578864588127],
#    ['rxn01200_c', 0.2340700358459846],
#    ['rxn01275_c', 0.4790450388155571],
#    ['rxn00342_c', 0.7358764039783672],
#    ['rxn00604_c', 0.608175981967571]],
#   'reactions_w_flux': [['rxn04082_c', 0.743772609547454],
#    ['rxn00416_c', 0.39405404313243647],
#    ['rxn00225_c', 0.7081615561511267],
#    ['rxn00148_c', 0.7321378826037916],
#    ['rxn00781_c', 0.5191220214505604],
#    ['rxn00614_c', 0.22013316862116666],
#    ['rxn05500_c', 0.6356445256659282],
#    ['rxn00612_c', 0.7484405309001277],
#    ['rxn05571_c', 0.22287311094173126],
#    ['rxn01292_c', 0.7509517121843206],
#    ['rxn01301_c', 0.7165696798161908],
#    ['rxn00499_c', 0.8302829270557739],
#    ['rxn05573_c', 0.16711061359245097],
#    ['rxn01100_c', 0.5916669155435752],
#    ['rxn00173_c', 0.7297596125397976],
#    ['rxn00187_c', 0.6839770327156126],
#    ['rxn01116_c', 0.7331256660930605],
#    ['rxn01763_c', 0.9794649761940855],
#    ['rxn01106_c', 0.2510839990368638],
#    ['rxn10042_c', 0.6189340413235531],
#    ['rxn00548_c', 0.7603672794410494],
#    ['rxn05602_c', 0.7777435465715274],
#    ['rxn01476_c', 0.6371698314027111],
#    ['rxn01333_c', 0.8979633240378723],
#    ['rxn01302_c', 0.7165696798161908],
#    ['rxn00459_c', 0.5819488983073209],
#    ['rxn01187_c', 0.7603672794410494],
#    ['rxn00216_c', 0.4759403048212528],
#    ['rxn00558_c', 0.13632578864588127],
#    ['rxn01200_c', 0.2340700358459846],
#    ['rxn01275_c', 0.4790450388155571],
#    ['rxn00342_c', 0.7358764039783672],
#    ['rxn00604_c', 0.608175981967571],
#    ['rxn00777_c', 0.7913776374220073],
#    ['rxn00178_c', 0.0],
#    ['rxn00875_c', 0.0],
#    ['rxn00873_c', 0.0]]},
#  '220668.9:0.6.0': {'Carbon': ['D-Glucose', 'cpd00027'],
#   'Model_ID': '220668.9',
#   'Nitrogen': ['Spermidine', 'cpd00264'],
#   'active_rxns':                     fluxes
#   rxn04082_c     -250.000000
#   rxn00416_c      104.166667
#   rxn00225_c     -104.166667
#   rxn00148_c     -250.000000
#   rxn00781_c      250.000000
#   rxn00614_c      250.000000
#   rxn05500_c     -250.000000
#   rxn00612_c     -250.000000
#   rxn05571_c     -500.000000
#   rxn01292_c     -250.000000
#   rxn01301_c      250.000000
#   rxn00499_c     -250.000000
#   rxn05573_c     1000.000000
#   rxn01100_c     -250.000000
#   rxn00173_c     -395.833333
#   rxn00187_c      104.166667
#   rxn01116_c      250.000000
#   rxn01763_c     -250.000000
#   rxn01106_c     -250.000000
#   rxn10042_c     -250.000000
#   rxn00548_c      250.000000
#   rxn05602_c     -250.000000
#   rxn01476_c      500.000000
#   rxn01333_c     -250.000000
#   rxn01302_c     -250.000000
#   rxn00459_c      250.000000
#   rxn01187_c      250.000000
#   rxn00216_c     1000.000000
#   rxn00558_c      500.000000
#   rxn01200_c      250.000000
#   rxn01275_c     -500.000000
#   rxn00342_c      104.166667
#   rxn00604_c      500.000000
#   EX_cpd00067_e  1000.000000
#   EX_cpd00224_e   250.000000
#   EX_cpd00222_e   500.000000
#   EX_cpd00027_e -1000.000000
#   EX_cpd00159_e   250.000000
#   DM_cpd00211_c   250.000000
#   rxn00777_c      250.000000
#   rxn00178_c      250.000000
#   rxn08443_c       41.666667
#   rxn00875_c      104.166667
#   rxn10074_c     -250.000000
#   rxn10663_c       41.666667
#   rxn00873_c     -145.833333
#   rxn09469_c      -41.666667,
#   'avg_path_like': 0.5559515582601068,
#   'demands': [],
#   'gap_avg_like': 0.19784440935550182,
#   'gaps_filled': {u'rxn00178_c',
#    u'rxn00777_c',
#    u'rxn00873_c',
#    u'rxn00875_c',
#    u'rxn08443_c',
#    u'rxn09469_c',
#    u'rxn10074_c',
#    u'rxn10663_c'},
#   'gaps_w_flux': [['rxn00777_c', 0.7913776374220073],
#    ['rxn00178_c', 0.0],
#    ['rxn00875_c', 0.0],
#    ['rxn00873_c', 0.0]],
#   'mets_added': {'cpd00120_c', 'cpd00982_c', 'cpd15238_c'},
#   'objective': 'Butyrate',
#   'opt_after': 249.99999999999918,
#   'opt_before': 0.0,
#   'path_avg_like': 0.5993584854000589,
#   'path_w_flux': [['rxn04082_c', 0.743772609547454],
#    ['rxn00416_c', 0.39405404313243647],
#    ['rxn00225_c', 0.7081615561511267],
#    ['rxn00148_c', 0.7321378826037916],
#    ['rxn00781_c', 0.5191220214505604],
#    ['rxn00614_c', 0.22013316862116666],
#    ['rxn05500_c', 0.6356445256659282],
#    ['rxn00612_c', 0.7484405309001277],
#    ['rxn05571_c', 0.22287311094173126],
#    ['rxn01292_c', 0.7509517121843206],
#    ['rxn01301_c', 0.7165696798161908],
#    ['rxn00499_c', 0.8302829270557739],
#    ['rxn05573_c', 0.16711061359245097],
#    ['rxn01100_c', 0.5916669155435752],
#    ['rxn00173_c', 0.7297596125397976],
#    ['rxn00187_c', 0.6839770327156126],
#    ['rxn01116_c', 0.7331256660930605],
#    ['rxn01763_c', 0.9794649761940855],
#    ['rxn01106_c', 0.2510839990368638],
#    ['rxn10042_c', 0.6189340413235531],
#    ['rxn00548_c', 0.7603672794410494],
#    ['rxn05602_c', 0.7777435465715274],
#    ['rxn01476_c', 0.6371698314027111],
#    ['rxn01333_c', 0.8979633240378723],
#    ['rxn01302_c', 0.7165696798161908],
#    ['rxn00459_c', 0.5819488983073209],
#    ['rxn01187_c', 0.7603672794410494],
#    ['rxn00216_c', 0.4759403048212528],
#    ['rxn00558_c', 0.13632578864588127],
#    ['rxn01200_c', 0.2340700358459846],
#    ['rxn01275_c', 0.4790450388155571],
#    ['rxn00342_c', 0.7358764039783672],
#    ['rxn00604_c', 0.608175981967571]],
#   'reactions_w_flux': [['rxn04082_c', 0.743772609547454],
#    ['rxn00416_c', 0.39405404313243647],
#    ['rxn00225_c', 0.7081615561511267],
#    ['rxn00148_c', 0.7321378826037916],
#    ['rxn00781_c', 0.5191220214505604],
#    ['rxn00614_c', 0.22013316862116666],
#    ['rxn05500_c', 0.6356445256659282],
#    ['rxn00612_c', 0.7484405309001277],
#    ['rxn05571_c', 0.22287311094173126],
#    ['rxn01292_c', 0.7509517121843206],
#    ['rxn01301_c', 0.7165696798161908],
#    ['rxn00499_c', 0.8302829270557739],
#    ['rxn05573_c', 0.16711061359245097],
#    ['rxn01100_c', 0.5916669155435752],
#    ['rxn00173_c', 0.7297596125397976],
#    ['rxn00187_c', 0.6839770327156126],
#    ['rxn01116_c', 0.7331256660930605],
#    ['rxn01763_c', 0.9794649761940855],
#    ['rxn01106_c', 0.2510839990368638],
#    ['rxn10042_c', 0.6189340413235531],
#    ['rxn00548_c', 0.7603672794410494],
#    ['rxn05602_c', 0.7777435465715274],
#    ['rxn01476_c', 0.6371698314027111],
#    ['rxn01333_c', 0.8979633240378723],
#    ['rxn01302_c', 0.7165696798161908],
#    ['rxn00459_c', 0.5819488983073209],
#    ['rxn01187_c', 0.7603672794410494],
#    ['rxn00216_c', 0.4759403048212528],
#    ['rxn00558_c', 0.13632578864588127],
#    ['rxn01200_c', 0.2340700358459846],
#    ['rxn01275_c', 0.4790450388155571],
#    ['rxn00342_c', 0.7358764039783672],
#    ['rxn00604_c', 0.608175981967571],
#    ['rxn00777_c', 0.7913776374220073],
#    ['rxn00178_c', 0.0],
#    ['rxn00875_c', 0.0],
#    ['rxn00873_c', 0.0]]},
#  '220668.9:0.7.0': {'Carbon': ['D-Glucose', 'cpd00027'],
#   'Model_ID': '220668.9',
#   'Nitrogen': ['Urea', 'cpd00073'],
#   'active_rxns':                     fluxes
#   rxn04082_c     -250.000000
#   rxn00416_c      104.166667
#   rxn00225_c     -104.166667
#   rxn00148_c     -250.000000
#   rxn00781_c      250.000000
#   rxn00614_c      250.000000
#   rxn05500_c     -250.000000
#   rxn00612_c     -250.000000
#   rxn05571_c     -500.000000
#   rxn01292_c     -250.000000
#   rxn01301_c      250.000000
#   rxn00499_c     -250.000000
#   rxn05573_c     1000.000000
#   rxn01100_c     -250.000000
#   rxn00173_c     -395.833333
#   rxn00187_c      104.166667
#   rxn01116_c      250.000000
#   rxn01763_c     -250.000000
#   rxn01106_c     -250.000000
#   rxn10042_c     -250.000000
#   rxn00548_c      250.000000
#   rxn05602_c     -250.000000
#   rxn01476_c      500.000000
#   rxn01333_c     -250.000000
#   rxn01302_c     -250.000000
#   rxn00459_c      250.000000
#   rxn01187_c      250.000000
#   rxn00216_c     1000.000000
#   rxn00558_c      500.000000
#   rxn01200_c      250.000000
#   rxn01275_c     -500.000000
#   rxn00342_c      104.166667
#   rxn00604_c      500.000000
#   EX_cpd00067_e  1000.000000
#   EX_cpd00224_e   250.000000
#   EX_cpd00222_e   500.000000
#   EX_cpd00027_e -1000.000000
#   EX_cpd00159_e   250.000000
#   DM_cpd00211_c   250.000000
#   rxn00777_c      250.000000
#   rxn00178_c      250.000000
#   rxn08443_c       41.666667
#   rxn00875_c      104.166667
#   rxn10074_c     -250.000000
#   rxn00873_c     -145.833333
#   rxn09469_c      -41.666667
#   rxn10663_c       41.666667,
#   'avg_path_like': 0.5559515582601068,
#   'demands': [],
#   'gap_avg_like': 0.19784440935550182,
#   'gaps_filled': {u'rxn00178_c',
#    u'rxn00777_c',
#    u'rxn00873_c',
#    u'rxn00875_c',
#    u'rxn08443_c',
#    u'rxn09469_c',
#    u'rxn10074_c',
#    u'rxn10663_c'},
#   'gaps_w_flux': [['rxn00777_c', 0.7913776374220073],
#    ['rxn00178_c', 0.0],
#    ['rxn00875_c', 0.0],
#    ['rxn00873_c', 0.0]],
#   'mets_added': {'cpd00120_c', 'cpd00982_c', 'cpd15238_c'},
#   'objective': 'Butyrate',
#   'opt_after': 250.00000000000017,
#   'opt_before': 0.0,
#   'path_avg_like': 0.5993584854000589,
#   'path_w_flux': [['rxn04082_c', 0.743772609547454],
#    ['rxn00416_c', 0.39405404313243647],
#    ['rxn00225_c', 0.7081615561511267],
#    ['rxn00148_c', 0.7321378826037916],
#    ['rxn00781_c', 0.5191220214505604],
#    ['rxn00614_c', 0.22013316862116666],
#    ['rxn05500_c', 0.6356445256659282],
#    ['rxn00612_c', 0.7484405309001277],
#    ['rxn05571_c', 0.22287311094173126],
#    ['rxn01292_c', 0.7509517121843206],
#    ['rxn01301_c', 0.7165696798161908],
#    ['rxn00499_c', 0.8302829270557739],
#    ['rxn05573_c', 0.16711061359245097],
#    ['rxn01100_c', 0.5916669155435752],
#    ['rxn00173_c', 0.7297596125397976],
#    ['rxn00187_c', 0.6839770327156126],
#    ['rxn01116_c', 0.7331256660930605],
#    ['rxn01763_c', 0.9794649761940855],
#    ['rxn01106_c', 0.2510839990368638],
#    ['rxn10042_c', 0.6189340413235531],
#    ['rxn00548_c', 0.7603672794410494],
#    ['rxn05602_c', 0.7777435465715274],
#    ['rxn01476_c', 0.6371698314027111],
#    ['rxn01333_c', 0.8979633240378723],
#    ['rxn01302_c', 0.7165696798161908],
#    ['rxn00459_c', 0.5819488983073209],
#    ['rxn01187_c', 0.7603672794410494],
#    ['rxn00216_c', 0.4759403048212528],
#    ['rxn00558_c', 0.13632578864588127],
#    ['rxn01200_c', 0.2340700358459846],
#    ['rxn01275_c', 0.4790450388155571],
#    ['rxn00342_c', 0.7358764039783672],
#    ['rxn00604_c', 0.608175981967571]],
#   'reactions_w_flux': [['rxn04082_c', 0.743772609547454],
#    ['rxn00416_c', 0.39405404313243647],
#    ['rxn00225_c', 0.7081615561511267],
#    ['rxn00148_c', 0.7321378826037916],
#    ['rxn00781_c', 0.5191220214505604],
#    ['rxn00614_c', 0.22013316862116666],
#    ['rxn05500_c', 0.6356445256659282],
#    ['rxn00612_c', 0.7484405309001277],
#    ['rxn05571_c', 0.22287311094173126],
#    ['rxn01292_c', 0.7509517121843206],
#    ['rxn01301_c', 0.7165696798161908],
#    ['rxn00499_c', 0.8302829270557739],
#    ['rxn05573_c', 0.16711061359245097],
#    ['rxn01100_c', 0.5916669155435752],
#    ['rxn00173_c', 0.7297596125397976],
#    ['rxn00187_c', 0.6839770327156126],
#    ['rxn01116_c', 0.7331256660930605],
#    ['rxn01763_c', 0.9794649761940855],
#    ['rxn01106_c', 0.2510839990368638],
#    ['rxn10042_c', 0.6189340413235531],
#    ['rxn00548_c', 0.7603672794410494],
#    ['rxn05602_c', 0.7777435465715274],
#    ['rxn01476_c', 0.6371698314027111],
#    ['rxn01333_c', 0.8979633240378723],
#    ['rxn01302_c', 0.7165696798161908],
#    ['rxn00459_c', 0.5819488983073209],
#    ['rxn01187_c', 0.7603672794410494],
#    ['rxn00216_c', 0.4759403048212528],
#    ['rxn00558_c', 0.13632578864588127],
#    ['rxn01200_c', 0.2340700358459846],
#    ['rxn01275_c', 0.4790450388155571],
#    ['rxn00342_c', 0.7358764039783672],
#    ['rxn00604_c', 0.608175981967571],
#    ['rxn00777_c', 0.7913776374220073],
#    ['rxn00178_c', 0.0],
#    ['rxn00875_c', 0.0],
#    ['rxn00873_c', 0.0]]},
#  '220668.9:0.8.0': {'Carbon': ['D-Glucose', 'cpd00027'],
#   'Model_ID': '220668.9',
#   'Nitrogen': ['crotonobetaine', 'cpd08305'],
#   'active_rxns':                     fluxes
#   rxn04082_c     -250.000000
#   rxn00416_c      104.166667
#   rxn00225_c     -104.166667
#   rxn00148_c     -250.000000
#   rxn00781_c      250.000000
#   rxn00614_c      250.000000
#   rxn05500_c     -250.000000
#   rxn00612_c     -250.000000
#   rxn05571_c     -500.000000
#   rxn01292_c     -250.000000
#   rxn01301_c      250.000000
#   rxn00499_c     -250.000000
#   rxn05573_c     1000.000000
#   rxn01100_c     -250.000000
#   rxn00173_c     -395.833333
#   rxn00187_c      104.166667
#   rxn01116_c      250.000000
#   rxn01763_c     -250.000000
#   rxn01106_c     -250.000000
#   rxn10042_c     -250.000000
#   rxn00548_c      250.000000
#   rxn05602_c     -250.000000
#   rxn01476_c      500.000000
#   rxn01333_c     -250.000000
#   rxn01302_c     -250.000000
#   rxn00459_c      250.000000
#   rxn01187_c      250.000000
#   rxn00216_c     1000.000000
#   rxn00558_c      500.000000
#   rxn01200_c      250.000000
#   rxn01275_c     -500.000000
#   rxn00342_c      104.166667
#   rxn00604_c      500.000000
#   EX_cpd00067_e  1000.000000
#   EX_cpd00224_e   250.000000
#   EX_cpd00222_e   500.000000
#   EX_cpd00027_e -1000.000000
#   EX_cpd00159_e   250.000000
#   DM_cpd00211_c   250.000000
#   rxn00777_c      250.000000
#   rxn00178_c      250.000000
#   rxn08443_c       41.666667
#   rxn00875_c      104.166667
#   rxn10074_c     -250.000000
#   rxn00873_c     -145.833333
#   rxn09469_c      -41.666667
#   rxn10663_c       41.666667,
#   'avg_path_like': 0.5559515582601068,
#   'demands': [],
#   'gap_avg_like': 0.19784440935550182,
#   'gaps_filled': {u'rxn00178_c',
#    u'rxn00777_c',
#    u'rxn00873_c',
#    u'rxn00875_c',
#    u'rxn08443_c',
#    u'rxn09469_c',
#    u'rxn10074_c',
#    u'rxn10663_c'},
#   'gaps_w_flux': [['rxn00777_c', 0.7913776374220073],
#    ['rxn00178_c', 0.0],
#    ['rxn00875_c', 0.0],
#    ['rxn00873_c', 0.0]],
#   'mets_added': {'cpd00120_c', 'cpd00982_c', 'cpd15238_c'},
#   'objective': 'Butyrate',
#   'opt_after': 250.00000000000017,
#   'opt_before': 0.0,
#   'path_avg_like': 0.5993584854000589,
#   'path_w_flux': [['rxn04082_c', 0.743772609547454],
#    ['rxn00416_c', 0.39405404313243647],
#    ['rxn00225_c', 0.7081615561511267],
#    ['rxn00148_c', 0.7321378826037916],
#    ['rxn00781_c', 0.5191220214505604],
#    ['rxn00614_c', 0.22013316862116666],
#    ['rxn05500_c', 0.6356445256659282],
#    ['rxn00612_c', 0.7484405309001277],
#    ['rxn05571_c', 0.22287311094173126],
#    ['rxn01292_c', 0.7509517121843206],
#    ['rxn01301_c', 0.7165696798161908],
#    ['rxn00499_c', 0.8302829270557739],
#    ['rxn05573_c', 0.16711061359245097],
#    ['rxn01100_c', 0.5916669155435752],
#    ['rxn00173_c', 0.7297596125397976],
#    ['rxn00187_c', 0.6839770327156126],
#    ['rxn01116_c', 0.7331256660930605],
#    ['rxn01763_c', 0.9794649761940855],
#    ['rxn01106_c', 0.2510839990368638],
#    ['rxn10042_c', 0.6189340413235531],
#    ['rxn00548_c', 0.7603672794410494],
#    ['rxn05602_c', 0.7777435465715274],
#    ['rxn01476_c', 0.6371698314027111],
#    ['rxn01333_c', 0.8979633240378723],
#    ['rxn01302_c', 0.7165696798161908],
#    ['rxn00459_c', 0.5819488983073209],
#    ['rxn01187_c', 0.7603672794410494],
#    ['rxn00216_c', 0.4759403048212528],
#    ['rxn00558_c', 0.13632578864588127],
#    ['rxn01200_c', 0.2340700358459846],
#    ['rxn01275_c', 0.4790450388155571],
#    ['rxn00342_c', 0.7358764039783672],
#    ['rxn00604_c', 0.608175981967571]],
#   'reactions_w_flux': [['rxn04082_c', 0.743772609547454],
#    ['rxn00416_c', 0.39405404313243647],
#    ['rxn00225_c', 0.7081615561511267],
#    ['rxn00148_c', 0.7321378826037916],
#    ['rxn00781_c', 0.5191220214505604],
#    ['rxn00614_c', 0.22013316862116666],
#    ['rxn05500_c', 0.6356445256659282],
#    ['rxn00612_c', 0.7484405309001277],
#    ['rxn05571_c', 0.22287311094173126],
#    ['rxn01292_c', 0.7509517121843206],
#    ['rxn01301_c', 0.7165696798161908],
#    ['rxn00499_c', 0.8302829270557739],
#    ['rxn05573_c', 0.16711061359245097],
#    ['rxn01100_c', 0.5916669155435752],
#    ['rxn00173_c', 0.7297596125397976],
#    ['rxn00187_c', 0.6839770327156126],
#    ['rxn01116_c', 0.7331256660930605],
#    ['rxn01763_c', 0.9794649761940855],
#    ['rxn01106_c', 0.2510839990368638],
#    ['rxn10042_c', 0.6189340413235531],
#    ['rxn00548_c', 0.7603672794410494],
#    ['rxn05602_c', 0.7777435465715274],
#    ['rxn01476_c', 0.6371698314027111],
#    ['rxn01333_c', 0.8979633240378723],
#    ['rxn01302_c', 0.7165696798161908],
#    ['rxn00459_c', 0.5819488983073209],
#    ['rxn01187_c', 0.7603672794410494],
#    ['rxn00216_c', 0.4759403048212528],
#    ['rxn00558_c', 0.13632578864588127],
#    ['rxn01200_c', 0.2340700358459846],
#    ['rxn01275_c', 0.4790450388155571],
#    ['rxn00342_c', 0.7358764039783672],
#    ['rxn00604_c', 0.608175981967571],
#    ['rxn00777_c', 0.7913776374220073],
#    ['rxn00178_c', 0.0],
#    ['rxn00875_c', 0.0],
#    ['rxn00873_c', 0.0]]},
#  '220668.9:1.0.0': {'Carbon': ['4-Hydroxybenzoate', 'cpd00136'],
#   'Model_ID': '220668.9',
#   'Nitrogen': ['NH3', 'cpd00013'],
#   'active_rxns':                     fluxes
#   rxn00225_c     -107.142857
#   rxn00148_c     -607.142857
#   rxn01102_c      142.857143
#   rxn00781_c      464.285714
#   rxn00612_c     -142.857143
#   rxn00747_c      142.857143
#   rxn01100_c     -464.285714
#   rxn00173_c    -1000.000000
#   rxn10122_c     -107.142857
#   rxn00187_c      995.535714
#   rxn01116_c      607.142857
#   rxn01106_c     -607.142857
#   rxn00412_c      995.535714
#   rxn10042_c     -183.035714
#   rxn00410_c     -995.535714
#   rxn00459_c      607.142857
#   rxn05209_c     -607.142857
#   rxn01366_c      607.142857
#   rxn00615_c     -142.857143
#   rxn01187_c      607.142857
#   rxn00763_c      142.857143
#   rxn05468_c     -250.000000
#   rxn05197_c     -607.142857
#   rxn01286_c      142.857143
#   rxn05467_c     -607.142857
#   EX_cpd00067_e   357.142857
#   EX_cpd00007_e   250.000000
#   EX_cpd00092_e   607.142857
#   EX_cpd00011_e   607.142857
#   EX_cpd00029_e  -500.000000
#   EX_cpd00249_e  -607.142857
#   DM_cpd00211_c   857.142857
#   rxn00178_c      857.142857
#   rxn10878_c      500.000000
#   rxn00777_c      607.142857
#   rxn00778_c      607.142857
#   rxn08443_c      142.857143
#   rxn09470_c     -142.857143
#   rxn00875_c      714.285714
#   rxn10074_c     -857.142857
#   rxn10663_c      142.857143
#   rxn00873_c     -142.857143
#   rxn09167_c      107.142857
#   rxn10895_c      607.142857
#   rxn10904_c     -500.000000,
#   'avg_path_like': 0.5067286353185371,
#   'demands': [],
#   'gap_avg_like': 0.2007646280727164,
#   'gaps_filled': {u'rxn00178_c',
#    u'rxn00777_c',
#    u'rxn00778_c',
#    u'rxn00873_c',
#    u'rxn00875_c',
#    u'rxn08443_c',
#    u'rxn09167_c',
#    u'rxn09470_c',
#    u'rxn10074_c',
#    u'rxn10663_c',
#    u'rxn10878_c',
#    u'rxn10895_c',
#    u'rxn10904_c'},
#   'gaps_w_flux': [['rxn00178_c', 0.0],
#    ['rxn00777_c', 0.7913776374220073],
#    ['rxn00778_c', 0.0],
#    ['rxn00875_c', 0.0],
#    ['rxn00873_c', 0.0],
#    ['rxn09167_c', 0.012703775408356745],
#    ['rxn10895_c', 0.6012709836786505]],
#   'mets_added': {'cpd00120_c', 'cpd00982_c', 'cpd15238_c'},
#   'objective': 'Butyrate',
#   'opt_after': 857.142857142871,
#   'opt_before': 0.0,
#   'path_avg_like': 0.5998481157846564,
#   'path_w_flux': [['rxn00225_c', 0.7081615561511267],
#    ['rxn00148_c', 0.7321378826037916],
#    ['rxn01102_c', 0.7573252964069241],
#    ['rxn00781_c', 0.5191220214505604],
#    ['rxn00612_c', 0.7484405309001277],
#    ['rxn00747_c', 0.24052218400619058],
#    ['rxn01100_c', 0.5916669155435752],
#    ['rxn00173_c', 0.7297596125397976],
#    ['rxn10122_c', 0.1179088482915993],
#    ['rxn00187_c', 0.6839770327156126],
#    ['rxn01116_c', 0.7331256660930605],
#    ['rxn01106_c', 0.2510839990368638],
#    ['rxn00412_c', 0.7170985764696824],
#    ['rxn10042_c', 0.6189340413235531],
#    ['rxn00410_c', 0.7170985764696824],
#    ['rxn00459_c', 0.5819488983073209],
#    ['rxn05209_c', 0.5212610480083402],
#    ['rxn01366_c', 0.9155773306778857],
#    ['rxn00615_c', 0.7256203031125679],
#    ['rxn01187_c', 0.7603672794410494],
#    ['rxn00763_c', 0.33407902943193785],
#    ['rxn05197_c', 0.6939166287158228],
#    ['rxn01286_c', 0.39737340535002535]],
#   'reactions_w_flux': [['rxn00225_c', 0.7081615561511267],
#    ['rxn00148_c', 0.7321378826037916],
#    ['rxn01102_c', 0.7573252964069241],
#    ['rxn00781_c', 0.5191220214505604],
#    ['rxn00612_c', 0.7484405309001277],
#    ['rxn00747_c', 0.24052218400619058],
#    ['rxn01100_c', 0.5916669155435752],
#    ['rxn00173_c', 0.7297596125397976],
#    ['rxn10122_c', 0.1179088482915993],
#    ['rxn00187_c', 0.6839770327156126],
#    ['rxn01116_c', 0.7331256660930605],
#    ['rxn01106_c', 0.2510839990368638],
#    ['rxn00412_c', 0.7170985764696824],
#    ['rxn10042_c', 0.6189340413235531],
#    ['rxn00410_c', 0.7170985764696824],
#    ['rxn00459_c', 0.5819488983073209],
#    ['rxn05209_c', 0.5212610480083402],
#    ['rxn01366_c', 0.9155773306778857],
#    ['rxn00615_c', 0.7256203031125679],
#    ['rxn01187_c', 0.7603672794410494],
#    ['rxn00763_c', 0.33407902943193785],
#    ['rxn05197_c', 0.6939166287158228],
#    ['rxn01286_c', 0.39737340535002535],
#    ['rxn00178_c', 0.0],
#    ['rxn00777_c', 0.7913776374220073],
#    ['rxn00778_c', 0.0],
#    ['rxn00875_c', 0.0],
#    ['rxn00873_c', 0.0],
#    ['rxn09167_c', 0.012703775408356745],
#    ['rxn10895_c', 0.6012709836786505]]},
#  '220668.9:1.1.0': {'Carbon': ['4-Hydroxybenzoate', 'cpd00136'],
#   'Model_ID': '220668.9',
#   'Nitrogen': ['Allantoin', 'cpd01092'],
#   'active_rxns':                     fluxes
#   rxn00225_c     -107.142857
#   rxn00148_c     -607.142857
#   rxn01102_c      142.857143
#   rxn00781_c      464.285714
# ...
#    ['rxn00611_c', 0.7484405309001277],
#    ['rxn01106_c', 0.2510839990368638],
#    ['rxn00412_c', 0.7170985764696824],
#    ['rxn10042_c', 0.6189340413235531],
#    ['rxn00548_c', 0.7603672794410494],
#    ['rxn00410_c', 0.7170985764696824],
#    ['rxn01333_c', 0.8979633240378723],
#    ['rxn00459_c', 0.5819488983073209],
#    ['rxn02318_c', 0.7509517121843206],
#    ['rxn03856_c', 0.5239026565791284],
#    ['rxn01187_c', 0.7603672794410494],
#    ['rxn00355_c', 0.9252997619225354],
#    ['rxn00216_c', 0.4759403048212528],
#    ['rxn00558_c', 0.13632578864588127],
#    ['rxn01200_c', 0.2340700358459846],
#    ['rxn00808_c', 0.7901306232473094],
#    ['rxn01343_c', 0.7297578149014129],
#    ['rxn00777_c', 0.7913776374220073],
#    ['rxn00178_c', 0.0],
#    ['rxn01334_c', 0.025276721182982728],
#    ['rxn00875_c', 0.0],
#    ['rxn00873_c', 0.0],
#    ['rxn00703_c', 0.0]]},
#  '220668.9:9.6.0': {'Carbon': ['Dulcose', 'cpd01171'],
#   'Model_ID': '220668.9',
#   'Nitrogen': ['Spermidine', 'cpd00264'],
#   'active_rxns':                     fluxes
#   rxn00022_c      315.789474
#   rxn00225_c     -714.285714
#   rxn00148_c     -360.902256
#   rxn00781_c      360.902256
#   rxn05319_c      992.481203
#   rxn00614_c      135.338346
#   rxn00747_c      270.676692
#   rxn00213_c     -631.578947
#   rxn05567_c      631.578947
#   rxn01100_c     -360.902256
#   rxn00214_c     -631.578947
#   rxn00173_c    -1000.000000
#   rxn00187_c       71.428571
#   rxn01116_c      451.127820
#   rxn05566_c      631.578947
#   rxn00611_c     -135.338346
#   rxn01106_c     -360.902256
#   rxn00412_c       71.428571
#   rxn10042_c     -372.180451
#   rxn00548_c      451.127820
#   rxn00410_c      -71.428571
#   rxn01333_c     -180.451128
#   rxn00459_c      360.902256
#   rxn02318_c     -631.578947
#   rxn03856_c      631.578947
#   rxn01187_c      902.255639
#   rxn00355_c      631.578947
#   rxn00216_c      631.578947
#   rxn00558_c      631.578947
#   rxn01200_c      451.127820
#   rxn05468_c     -180.451128
#   rxn00808_c      631.578947
#   rxn01343_c     -270.676692
#   rxn05467_c     -360.902256
#   EX_cpd00067_e   857.142857
#   EX_cpd00001_e   992.481203
#   EX_cpd01171_e  -631.578947
#   EX_cpd00007_e   180.451128
#   EX_cpd00011_e   360.902256
#   DM_cpd00211_c   857.142857
#   rxn10878_c      360.902256
#   rxn00777_c      451.127820
#   rxn11342_c     -631.578947
#   rxn00178_c      857.142857
#   rxn08443_c      142.857143
#   rxn01334_c     -270.676692
#   rxn00875_c      714.285714
#   rxn10074_c     -857.142857
#   rxn00873_c     -142.857143
#   rxn09469_c     -142.857143
#   rxn00703_c      315.789474
#   rxn10663_c      142.857143,
#   'avg_path_like': 0.5307058398226576,
#   'demands': [],
#   'gap_avg_like': 0.13610905976749835,
#   'gaps_filled': {u'rxn00178_c',
#    u'rxn00703_c',
#    u'rxn00777_c',
#    u'rxn00873_c',
#    u'rxn00875_c',
#    u'rxn01334_c',
#    u'rxn08443_c',
#    u'rxn09469_c',
#    u'rxn10074_c',
#    u'rxn10663_c',
#    u'rxn10878_c',
#    u'rxn11342_c'},
#   'gaps_w_flux': [['rxn00777_c', 0.7913776374220073],
#    ['rxn00178_c', 0.0],
#    ['rxn01334_c', 0.025276721182982728],
#    ['rxn00875_c', 0.0],
#    ['rxn00873_c', 0.0],
#    ['rxn00703_c', 0.0]],
#   'mets_added': {'cpd00120_c', 'cpd00982_c', 'cpd15238_c'},
#   'objective': 'Butyrate',
#   'opt_after': 857.1428571428584,
#   'opt_before': 0.0,
#   'path_avg_like': 0.6070794101559143,
#   'path_w_flux': [['rxn00022_c', 0.4931770333104928],
#    ['rxn00225_c', 0.7081615561511267],
#    ['rxn00148_c', 0.7321378826037916],
#    ['rxn00781_c', 0.5191220214505604],
#    ['rxn00614_c', 0.22013316862116666],
#    ['rxn00747_c', 0.24052218400619058],
#    ['rxn00213_c', 0.6979569017663277],
#    ['rxn05567_c', 0.633362331689781],
#    ['rxn01100_c', 0.5916669155435752],
#    ['rxn00214_c', 0.5810336791009042],
#    ['rxn00173_c', 0.7297596125397976],
#    ['rxn00187_c', 0.6839770327156126],
#    ['rxn01116_c', 0.7331256660930605],
#    ['rxn05566_c', 0.6356445256659282],
#    ['rxn00611_c', 0.7484405309001277],
#    ['rxn01106_c', 0.2510839990368638],
#    ['rxn00412_c', 0.7170985764696824],
#    ['rxn10042_c', 0.6189340413235531],
#    ['rxn00548_c', 0.7603672794410494],
#    ['rxn00410_c', 0.7170985764696824],
#    ['rxn01333_c', 0.8979633240378723],
#    ['rxn00459_c', 0.5819488983073209],
#    ['rxn02318_c', 0.7509517121843206],
#    ['rxn03856_c', 0.5239026565791284],
#    ['rxn01187_c', 0.7603672794410494],
#    ['rxn00355_c', 0.9252997619225354],
#    ['rxn00216_c', 0.4759403048212528],
#    ['rxn00558_c', 0.13632578864588127],
#    ['rxn01200_c', 0.2340700358459846],
#    ['rxn00808_c', 0.7901306232473094],
#    ['rxn01343_c', 0.7297578149014129]],
#   'reactions_w_flux': [['rxn00022_c', 0.4931770333104928],
#    ['rxn00225_c', 0.7081615561511267],
#    ['rxn00148_c', 0.7321378826037916],
#    ['rxn00781_c', 0.5191220214505604],
#    ['rxn00614_c', 0.22013316862116666],
#    ['rxn00747_c', 0.24052218400619058],
#    ['rxn00213_c', 0.6979569017663277],
#    ['rxn05567_c', 0.633362331689781],
#    ['rxn01100_c', 0.5916669155435752],
#    ['rxn00214_c', 0.5810336791009042],
#    ['rxn00173_c', 0.7297596125397976],
#    ['rxn00187_c', 0.6839770327156126],
#    ['rxn01116_c', 0.7331256660930605],
#    ['rxn05566_c', 0.6356445256659282],
#    ['rxn00611_c', 0.7484405309001277],
#    ['rxn01106_c', 0.2510839990368638],
#    ['rxn00412_c', 0.7170985764696824],
#    ['rxn10042_c', 0.6189340413235531],
#    ['rxn00548_c', 0.7603672794410494],
#    ['rxn00410_c', 0.7170985764696824],
#    ['rxn01333_c', 0.8979633240378723],
#    ['rxn00459_c', 0.5819488983073209],
#    ['rxn02318_c', 0.7509517121843206],
#    ['rxn03856_c', 0.5239026565791284],
#    ['rxn01187_c', 0.7603672794410494],
#    ['rxn00355_c', 0.9252997619225354],
#    ['rxn00216_c', 0.4759403048212528],
#    ['rxn00558_c', 0.13632578864588127],
#    ['rxn01200_c', 0.2340700358459846],
#    ['rxn00808_c', 0.7901306232473094],
#    ['rxn01343_c', 0.7297578149014129],
#    ['rxn00777_c', 0.7913776374220073],
#    ['rxn00178_c', 0.0],
#    ['rxn01334_c', 0.025276721182982728],
#    ['rxn00875_c', 0.0],
#    ['rxn00873_c', 0.0],
#    ['rxn00703_c', 0.0]]},
#  '220668.9:9.7.0': {'Carbon': ['Dulcose', 'cpd01171'],
#   'Model_ID': '220668.9',
#   'Nitrogen': ['Urea', 'cpd00073'],
#   'active_rxns':                     fluxes
#   rxn00022_c      315.789474
#   rxn00225_c     -714.285714
#   rxn00148_c     -360.902256
#   rxn00781_c      360.902256
#   rxn05319_c      992.481203
#   rxn00614_c      278.195489
#   rxn00612_c     -142.857143
#   rxn00747_c      270.676692
#   rxn00213_c     -631.578947
#   rxn05567_c      631.578947
#   rxn01100_c     -360.902256
#   rxn00214_c     -631.578947
#   rxn00173_c    -1000.000000
#   rxn00187_c       71.428571
#   rxn01116_c      451.127820
#   rxn05566_c      631.578947
#   rxn00611_c     -135.338346
#   rxn01106_c     -360.902256
#   rxn00412_c       71.428571
#   rxn10042_c     -372.180451
#   rxn00548_c      451.127820
#   rxn00410_c      -71.428571
#   rxn01333_c     -180.451128
#   rxn00459_c      360.902256
#   rxn02318_c     -631.578947
#   rxn03856_c      631.578947
#   rxn01187_c      902.255639
#   rxn00355_c      631.578947
#   rxn00216_c      631.578947
#   rxn00558_c      631.578947
#   rxn01200_c      451.127820
#   rxn05468_c     -180.451128
#   rxn00808_c      631.578947
#   rxn01343_c     -270.676692
#   rxn05467_c     -360.902256
#   EX_cpd00067_e   857.142857
#   EX_cpd00001_e   992.481203
#   EX_cpd01171_e  -631.578947
#   EX_cpd00007_e   180.451128
#   EX_cpd00011_e   360.902256
#   DM_cpd00211_c   857.142857
#   rxn10878_c      360.902256
#   rxn00777_c      451.127820
#   rxn11342_c     -631.578947
#   rxn00178_c      857.142857
#   rxn08443_c      142.857143
#   rxn09470_c     -142.857143
#   rxn01334_c     -270.676692
#   rxn00875_c      714.285714
#   rxn10074_c     -857.142857
#   rxn00873_c     -142.857143
#   rxn00703_c      315.789474
#   rxn10663_c      142.857143,
#   'avg_path_like': 0.53643570011417,
#   'demands': [],
#   'gap_avg_like': 0.13610905976749835,
#   'gaps_filled': {u'rxn00178_c',
#    u'rxn00703_c',
#    u'rxn00777_c',
#    u'rxn00873_c',
#    u'rxn00875_c',
#    u'rxn01334_c',
#    u'rxn08443_c',
#    u'rxn09470_c',
#    u'rxn10074_c',
#    u'rxn10663_c',
#    u'rxn10878_c',
#    u'rxn11342_c'},
#   'gaps_w_flux': [['rxn00777_c', 0.7913776374220073],
#    ['rxn00178_c', 0.0],
#    ['rxn01334_c', 0.025276721182982728],
#    ['rxn00875_c', 0.0],
#    ['rxn00873_c', 0.0],
#    ['rxn00703_c', 0.0]],
#   'mets_added': {'cpd00120_c', 'cpd00982_c', 'cpd15238_c'},
#   'objective': 'Butyrate',
#   'opt_after': 857.1428571428585,
#   'opt_before': 0.0,
#   'path_avg_like': 0.611496945179171,
#   'path_w_flux': [['rxn00022_c', 0.4931770333104928],
#    ['rxn00225_c', 0.7081615561511267],
#    ['rxn00148_c', 0.7321378826037916],
#    ['rxn00781_c', 0.5191220214505604],
#    ['rxn00614_c', 0.22013316862116666],
#    ['rxn00612_c', 0.7484405309001277],
#    ['rxn00747_c', 0.24052218400619058],
#    ['rxn00213_c', 0.6979569017663277],
#    ['rxn05567_c', 0.633362331689781],
#    ['rxn01100_c', 0.5916669155435752],
#    ['rxn00214_c', 0.5810336791009042],
#    ['rxn00173_c', 0.7297596125397976],
#    ['rxn00187_c', 0.6839770327156126],
#    ['rxn01116_c', 0.7331256660930605],
#    ['rxn05566_c', 0.6356445256659282],
#    ['rxn00611_c', 0.7484405309001277],
#    ['rxn01106_c', 0.2510839990368638],
#    ['rxn00412_c', 0.7170985764696824],
#    ['rxn10042_c', 0.6189340413235531],
#    ['rxn00548_c', 0.7603672794410494],
#    ['rxn00410_c', 0.7170985764696824],
#    ['rxn01333_c', 0.8979633240378723],
#    ['rxn00459_c', 0.5819488983073209],
#    ['rxn02318_c', 0.7509517121843206],
#    ['rxn03856_c', 0.5239026565791284],
#    ['rxn01187_c', 0.7603672794410494],
#    ['rxn00355_c', 0.9252997619225354],
#    ['rxn00216_c', 0.4759403048212528],
#    ['rxn00558_c', 0.13632578864588127],
#    ['rxn01200_c', 0.2340700358459846],
#    ['rxn00808_c', 0.7901306232473094],
#    ['rxn01343_c', 0.7297578149014129]],
#   'reactions_w_flux': [['rxn00022_c', 0.4931770333104928],
#    ['rxn00225_c', 0.7081615561511267],
#    ['rxn00148_c', 0.7321378826037916],
#    ['rxn00781_c', 0.5191220214505604],
#    ['rxn00614_c', 0.22013316862116666],
#    ['rxn00612_c', 0.7484405309001277],
#    ['rxn00747_c', 0.24052218400619058],
#    ['rxn00213_c', 0.6979569017663277],
#    ['rxn05567_c', 0.633362331689781],
#    ['rxn01100_c', 0.5916669155435752],
#    ['rxn00214_c', 0.5810336791009042],
#    ['rxn00173_c', 0.7297596125397976],
#    ['rxn00187_c', 0.6839770327156126],
#    ['rxn01116_c', 0.7331256660930605],
#    ['rxn05566_c', 0.6356445256659282],
#    ['rxn00611_c', 0.7484405309001277],
#    ['rxn01106_c', 0.2510839990368638],
#    ['rxn00412_c', 0.7170985764696824],
#    ['rxn10042_c', 0.6189340413235531],
#    ['rxn00548_c', 0.7603672794410494],
#    ['rxn00410_c', 0.7170985764696824],
#    ['rxn01333_c', 0.8979633240378723],
#    ['rxn00459_c', 0.5819488983073209],
#    ['rxn02318_c', 0.7509517121843206],
#    ['rxn03856_c', 0.5239026565791284],
#    ['rxn01187_c', 0.7603672794410494],
#    ['rxn00355_c', 0.9252997619225354],
#    ['rxn00216_c', 0.4759403048212528],
#    ['rxn00558_c', 0.13632578864588127],
#    ['rxn01200_c', 0.2340700358459846],
#    ['rxn00808_c', 0.7901306232473094],
#    ['rxn01343_c', 0.7297578149014129],
#    ['rxn00777_c', 0.7913776374220073],
#    ['rxn00178_c', 0.0],
#    ['rxn01334_c', 0.025276721182982728],
#    ['rxn00875_c', 0.0],
#    ['rxn00873_c', 0.0],
#    ['rxn00703_c', 0.0]]},
#  '220668.9:9.8.0': {'Carbon': ['Dulcose', 'cpd01171'],
#   'Model_ID': '220668.9',
#   'Nitrogen': ['crotonobetaine', 'cpd08305'],
#   'active_rxns':                     fluxes
#   rxn00022_c      315.789474
#   rxn00545_c     -270.676692
#   rxn00225_c     -714.285714
#   rxn00148_c     -360.902256
#   rxn00781_c      360.902256
#   rxn05319_c      992.481203
#   rxn00614_c      135.338346
#   rxn00747_c      270.676692
#   rxn00213_c     -631.578947
#   rxn05567_c      631.578947
#   rxn01100_c     -360.902256
#   rxn00214_c     -631.578947
#   rxn00173_c    -1000.000000
#   rxn00187_c       71.428571
#   rxn01116_c      451.127820
#   rxn05566_c      631.578947
#   rxn00611_c     -135.338346
#   rxn01106_c     -360.902256
#   rxn00412_c       71.428571
#   rxn10042_c     -372.180451
#   rxn00548_c      451.127820
#   rxn00410_c      -71.428571
#   rxn01333_c     -451.127820
#   rxn00459_c      360.902256
#   rxn02318_c     -631.578947
#   rxn03856_c      631.578947
#   rxn01187_c      902.255639
#   rxn00355_c      631.578947
#   rxn00216_c      631.578947
#   rxn00558_c      631.578947
#   rxn01200_c      451.127820
#   rxn05468_c     -180.451128
#   rxn00808_c      631.578947
#   rxn05467_c     -360.902256
#   EX_cpd00067_e   857.142857
#   EX_cpd00001_e   992.481203
#   EX_cpd01171_e  -631.578947
#   EX_cpd00007_e   180.451128
#   EX_cpd00011_e   360.902256
#   DM_cpd00211_c   857.142857
#   rxn00178_c      857.142857
#   rxn10878_c      360.902256
#   rxn00777_c      451.127820
#   rxn11342_c     -631.578947
#   rxn08443_c      142.857143
#   rxn00875_c      714.285714
#   rxn00786_c     -270.676692
#   rxn10663_c      142.857143
#   rxn10074_c     -857.142857
#   rxn00873_c     -142.857143
#   rxn09469_c     -142.857143
#   rxn00703_c      315.789474,
#   'avg_path_like': 0.5307058398226576,
#   'demands': [],
#   'gap_avg_like': 0.13610905976749835,
#   'gaps_filled': {u'rxn00178_c',
#    u'rxn00703_c',
#    u'rxn00777_c',
#    u'rxn00786_c',
#    u'rxn00873_c',
#    u'rxn00875_c',
#    u'rxn08443_c',
#    u'rxn09469_c',
#    u'rxn10074_c',
#    u'rxn10663_c',
#    u'rxn10878_c',
#    u'rxn11342_c'},
#   'gaps_w_flux': [['rxn00178_c', 0.0],
#    ['rxn00777_c', 0.7913776374220073],
#    ['rxn00875_c', 0.0],
#    ['rxn00786_c', 0.025276721182982728],
#    ['rxn00873_c', 0.0],
#    ['rxn00703_c', 0.0]],
#   'mets_added': {'cpd00120_c', 'cpd00982_c', 'cpd15238_c'},
#   'objective': 'Butyrate',
#   'opt_after': 857.1428571428542,
#   'opt_before': 0.0,
#   'path_avg_like': 0.6070794101559144,
#   'path_w_flux': [['rxn00022_c', 0.4931770333104928],
#    ['rxn00545_c', 0.7297578149014129],
#    ['rxn00225_c', 0.7081615561511267],
#    ['rxn00148_c', 0.7321378826037916],
#    ['rxn00781_c', 0.5191220214505604],
#    ['rxn00614_c', 0.22013316862116666],
#    ['rxn00747_c', 0.24052218400619058],
#    ['rxn00213_c', 0.6979569017663277],
#    ['rxn05567_c', 0.633362331689781],
#    ['rxn01100_c', 0.5916669155435752],
#    ['rxn00214_c', 0.5810336791009042],
#    ['rxn00173_c', 0.7297596125397976],
#    ['rxn00187_c', 0.6839770327156126],
#    ['rxn01116_c', 0.7331256660930605],
#    ['rxn05566_c', 0.6356445256659282],
#    ['rxn00611_c', 0.7484405309001277],
#    ['rxn01106_c', 0.2510839990368638],
#    ['rxn00412_c', 0.7170985764696824],
#    ['rxn10042_c', 0.6189340413235531],
#    ['rxn00548_c', 0.7603672794410494],
#    ['rxn00410_c', 0.7170985764696824],
#    ['rxn01333_c', 0.8979633240378723],
#    ['rxn00459_c', 0.5819488983073209],
#    ['rxn02318_c', 0.7509517121843206],
#    ['rxn03856_c', 0.5239026565791284],
#    ['rxn01187_c', 0.7603672794410494],
#    ['rxn00355_c', 0.9252997619225354],
#    ['rxn00216_c', 0.4759403048212528],
#    ['rxn00558_c', 0.13632578864588127],
#    ['rxn01200_c', 0.2340700358459846],
#    ['rxn00808_c', 0.7901306232473094]],
#   'reactions_w_flux': [['rxn00022_c', 0.4931770333104928],
#    ['rxn00545_c', 0.7297578149014129],
#    ['rxn00225_c', 0.7081615561511267],
#    ['rxn00148_c', 0.7321378826037916],
#    ['rxn00781_c', 0.5191220214505604],
#    ['rxn00614_c', 0.22013316862116666],
#    ['rxn00747_c', 0.24052218400619058],
#    ['rxn00213_c', 0.6979569017663277],
#    ['rxn05567_c', 0.633362331689781],
#    ['rxn01100_c', 0.5916669155435752],
#    ['rxn00214_c', 0.5810336791009042],
#    ['rxn00173_c', 0.7297596125397976],
#    ['rxn00187_c', 0.6839770327156126],
#    ['rxn01116_c', 0.7331256660930605],
#    ['rxn05566_c', 0.6356445256659282],
#    ['rxn00611_c', 0.7484405309001277],
#    ['rxn01106_c', 0.2510839990368638],
#    ['rxn00412_c', 0.7170985764696824],
#    ['rxn10042_c', 0.6189340413235531],
#    ['rxn00548_c', 0.7603672794410494],
#    ['rxn00410_c', 0.7170985764696824],
#    ['rxn01333_c', 0.8979633240378723],
#    ['rxn00459_c', 0.5819488983073209],
#    ['rxn02318_c', 0.7509517121843206],
#    ['rxn03856_c', 0.5239026565791284],
#    ['rxn01187_c', 0.7603672794410494],
#    ['rxn00355_c', 0.9252997619225354],
#    ['rxn00216_c', 0.4759403048212528],
#    ['rxn00558_c', 0.13632578864588127],
#    ['rxn01200_c', 0.2340700358459846],
#    ['rxn00808_c', 0.7901306232473094],
#    ['rxn00178_c', 0.0],
#    ['rxn00777_c', 0.7913776374220073],
#    ['rxn00875_c', 0.0],
#    ['rxn00786_c', 0.025276721182982728],
#    ['rxn00873_c', 0.0],
#    ['rxn00703_c', 0.0]]}}

# %%
# model.solver = 'scipy'

# %%
universal.solver = 'glpk'
universal.solver

# %%
# model.solver
