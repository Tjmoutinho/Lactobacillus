# %%
import cobra
# import cobra.test
import numpy as np
# import csv
import glob
import pickle
import pandas as pd
import math
import json
# import copy
# import time
# import random
# import time
import sys

# %%
uni_sm = cobra.io.load_json_model("../Data/GramPositive.json")
uni_lg = cobra.io.load_json_model("../Data/universal_w_OK_rxns.json")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-50f60a9121b9> in <module>()
# ----> 1 uni_sm = cobra.io.load_json_model("../Data/GramPositive.json")
#       2 uni_lg = cobra.io.load_json_model("../Data/universal_w_OK_rxns.json")
#
# /home/tjmoutinho/.virtualenvs/mackinac/local/lib/python2.7/site-packages/cobra/io/json.pyc in load_json_model(filename)
#     131     if isinstance(filename, string_types):
#     132         with open(filename, "r") as file_handle:
# --> 133             return model_from_dict(json.load(file_handle))
#     134     else:
#     135         return model_from_dict(json.load(filename))
#
# /home/tjmoutinho/.virtualenvs/mackinac/local/lib/python2.7/site-packages/cobra/io/dict.pyc in model_from_dict(obj)
#     213     model = Model()
#     214     model.add_metabolites(
# ...

# %%
with open("../Data/GramPositive.json") as f:
    uni_sm_dict = json.loads(f.read())

# %%
uni_sm_dict
# Out:
# {u'biochemistry_ref': u'/chenry/public/modelsupport/biochemistry/default.biochem',
#  u'biomasses': [{u'cellwall': 0.25,
#    u'cofactor': 0.1,
#    u'dna': 0.026,
#    u'energy': 41.257,
#    u'id': u'bio1',
#    u'lipid': 0.075,
#    u'name': u'GramPositiveBiomass',
#    u'other': 0.0,
#    u'protein': 0.5284,
#    u'rna': 0.0655,
#    u'templateBiomassComponents': [{u'class': u'rna',
#      u'coefficient': -0.262,
#      u'coefficient_type': u'MOLFRACTION',
#      u'link_coefficients': [-1.0],
#      u'linked_compound_refs': [u'~/compcompounds/id/cpd00012_c'],
#      u'templatecompcompound_ref': u'~/compcompounds/id/cpd00002_c'},
#     {u'class': u'rna',
#      u'coefficient': -0.323,
#      u'coefficient_type': u'MOLFRACTION',
#      u'link_coefficients': [-1.0],
#      u'linked_compound_refs': [u'~/compcompounds/id/cpd00012_c'],
#      u'templatecompcompound_ref': u'~/compcompounds/id/cpd00038_c'},
#     {u'class': u'rna',
#      u'coefficient': -0.199,
# ...

# %%
uni_sm
# Out:
# <Model GramPositive.modeltemplate at 0x7f80cbf4a650>

# %%
uni_lg
# Out:
# <Model MicrobialNegative at 0x7f80c270b810>

# %%
uni_sm['roles']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-b6bbb8bdf79b> in <module>()
# ----> 1 uni_sm['roles']
#
# TypeError: 'Model' object has no attribute '__getitem__'
