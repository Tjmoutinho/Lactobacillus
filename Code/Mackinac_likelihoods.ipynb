# %%
from __future__ import print_function

import cobra
import cobra.test
import mackinac
import numpy as np
import csv
import glob
import pickle
import pandas as pd

# %%
mackinac.get_token('tjmoutinho')
# Out:
# patric password: ········
# u'tjmoutinho@patricbrc.org'

# %%
# Read in list of genome IDs
with open('../Data/20_species_1023_genomes.csv') as csvfile:
    genome_ids_list = []
    for line in csvfile:
        genome_ids_list.append(line.strip())
len(genome_ids_list)
# Out:
# 1023

# %%
'220668.9'

# %%
mackinac.download_data_files()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-aac6ecb868d4> in <module>()
# ----> 1 mackinac.download_data_files()
#
# TypeError: download_data_files() takes at least 4 arguments (0 given)

# %%
mackinac.list_workspace_objects('/chenry/public/modelsupport', print_output=True)
# Out:
# Contents of /chenry/public/modelsupport:
# drr chenry    	         0	2015-05-05T06:47:43Z	folder      	/chenry/public/modelsupport/classifiers
# drr chenry    	         0	2015-05-11T05:34:10Z	folder      	/chenry/public/modelsupport/media
# drr chenry    	         0	2015-05-05T06:47:43Z	folder      	/chenry/public/modelsupport/biochemistry
# drr chenry    	         0	2015-05-05T07:08:32Z	folder      	/chenry/public/modelsupport/templates
# drr chenry    	         0	2015-06-12T04:34:10Z	folder      	/chenry/public/modelsupport/patric-media
# -rr chenry    	   2924763	2015-05-05T07:08:22Z	mapping     	/chenry/public/modelsupport/biochemistry/default.mapping
# -rr chenry    	  24537619	2015-05-05T07:08:22Z	biochemistry	/chenry/public/modelsupport/biochemistry/default.biochem
# -rr seaver    	  65175584	2015-08-12T02:46:02Z	biochemistry	/chenry/public/modelsupport/biochemistry/plantdefault.biochem
# ...
