# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt
import glob
import time
import sys
import cobra

# %%
# Create TSV for mean/median genome likelihood values
t = time.time()

# genome_ids = glob.glob('../metabolic_output/*.data')
# genome_ids = [x.replace("../metabolic_output/","").replace(".data","") for x in genome_ids]
genome_ids = pickle.load(open("../Data/Filtered_lacto_genome_ids.data", "rb"))

# sys.stdout.write('Loading in model...')

output_file = '../Data/genome_likelihoods.tsv'

output_file = open(output_file, 'w')
header = 'genomes\t' + 'mean\t' + 'median\n'
output_file.write(header)

for genome_id in genome_ids:
    try:
        model = cobra.io.read_sbml_model('../gap_models/'+ genome_id +'.xml')
        likelihoods = pickle.load(open('../likelihoods/'+ genome_id +'.probs'))
        model.reactions.get_by_id('rxn05319_c').name = "Water transport"
        model.reactions.get_by_id('rxn05319_c').bounds = (-1000., 1000.)
        ### Set Up Model: remove low likelihood reactions
        low_like_model = []
        for rxn in model.reactions:
            if rxn.id.startswith('rxn'):
                try:
                    if likelihoods[rxn.id] <= 0.1:
                        low_like_model.append(rxn.id)
                except:
                    pass
        model_rxns_to_remove = [model.reactions.get_by_id(rxn) for rxn in low_like_model]
        model.remove_reactions(model_rxns_to_remove)
        # Generate list of likelihoods for all reactions in model
        model_rxn_likes = []
        for rxn in model.reactions:
            try:
                model_rxn_likes.append(likelihoods[rxn.id])
            except:
                pass
        # Write info to tsv file
        output_file.write(genome_id + '\t')
        output_file.write(str(np.mean(model_rxn_likes)) + '\t')
        output_file.write(str(np.median(model_rxn_likes)) + '\n')
    except:
        continue

print(str(round(time.time() - t)) + 'seconds to complete')
# Out:
# 2059.0seconds to complete

# %%
# Create TSV for genome size
t = time.time()

# genome_ids = glob.glob('../metabolic_output/*.data')
# genome_ids = [x.replace("../metabolic_output/","").replace(".data","") for x in genome_ids]
genome_ids = pickle.load(open("../Data/Filtered_lacto_genome_ids.data", "rb"))

# sys.stdout.write('Loading in model...')

output_file = '../Data/genome_sizes.tsv'  

output_file = open(output_file, 'w')
header = 'genomes\t' + 'size\t' + 'placeholder\n'
output_file.write(header)

for genome_id in genome_ids:
    try:
        model = cobra.io.read_sbml_model('../gap_models/'+ genome_id +'.xml')
        likelihoods = pickle.load(open('../likelihoods/'+ genome_id +'.probs'))
        model.reactions.get_by_id('rxn05319_c').name = "Water transport"
        model.reactions.get_by_id('rxn05319_c').bounds = (-1000., 1000.)
        ### Set Up Model: remove low likelihood reactions
        low_like_model = []
        for rxn in model.reactions:
            if rxn.id.startswith('rxn'):
                try:
                    if likelihoods[rxn.id] <= 0.1:
                        low_like_model.append(rxn.id)
                except:
                    pass
        model_rxns_to_remove = [model.reactions.get_by_id(rxn) for rxn in low_like_model]
        model.remove_reactions(model_rxns_to_remove)

        # Write info to tsv file
        output_file.write(genome_id + '\t')
        output_file.write(str(len(model.reactions)) + '\t')
        output_file.write('0\n')
    except:
        continue

print(str(round(time.time() - t)) + 'seconds to complete')
# Out:
# 2080.0seconds to complete

# %%
# Stats by reaction
t = time.time()
genome_ids = pickle.load(open("../Data/Filtered_lacto_genome_ids.data", "rb"))

output_file = '../Data/reaction_likelihoods_all_genomes.tsv'  

output_file = open(output_file, 'w')
likelihoods = pickle.load(open('../likelihoods_py3/'+ genome_ids[0] +'.probs'))
rxn_list = likelihoods.keys()

header = 'genome_id\t'
for n in range(0,len(likelihoods.keys())):
    header = header + str(likelihoods.keys()[n]) + '\t'
header = header + 'placeholder\n'
output_file.write(header)

for genome_id in genome_ids:
    if not genome_id == '1590.482':
        likelihoods = pickle.load(open('../likelihoods_py3/'+ genome_id +'.probs'))
        output_file.write(genome_id + '\t')
        for rxn in rxn_list:
            output_file.write(str(likelihoods[rxn]) + '\t')
        output_file.write('0\n')

print(str(round(time.time() - t)) + 'seconds to complete')
# Out:
# 21.0seconds to complete

# %%
# one genome does not have reaction likelihoods
for genome_id in genome_ids:
    if not genome_id == '1590.482':
        try:
            likelihoods = pickle.load(open('../likelihoods_py3/'+ genome_id +'.probs'))
        except:
            print(genome_id)

# %%
universal = cobra.io.load_json_model("../Data/GramPosUni.json")

# %%
# Look into reactions with greatest median values to find examples to use

# read file
with open('../Data/reaction_medians.csv') as csvfile:
    reaction_medians_w_names = []
    for line in csvfile:
        line = line.strip()
#         print(line)
#         try:
        rxn_id = line.split(',')[1].strip('"')
        like = line.split(',')[2]
        try:
            reaction_medians_w_names.append([rxn_id,like,universal.reactions.get_by_id(rxn_id).name])
        except:
            print(rxn_id)
#         except:
#             continue
reaction_medians_w_names
# Out:
# rxn_id
# placeholder
# [['rxn10336_c', '0.995880714273', u'stearoyl-cardiolipin synthase'],
#  ['rxn10337_c', '0.995880714273', u'isoheptadecanoyl-cardiolipin synthase'],
#  ['rxn10338_c',
#   '0.995880714273',
#   u'anteisoheptadecanoyl-cardiolipin synthase'],
#  ['rxn10335_c', '0.995880714273', u'myristoyl-cardiolipin synthase'],
#  ['rxn10342_c', '0.995880714273', u'isohexadecanoyl-cardiolipin synthase'],
#  ['rxn10340_c', '0.995880714273', u'isopentadecanoyl-cardiolipin synthase'],
#  ['rxn10334_c', '0.995880714273', u'palmitoyl-cardiolipin synthase'],
#  ['rxn10339_c', '0.995880714273', u'isotetradecanoyl-cardiolipin synthase'],
#  ['rxn10341_c',
#   '0.995880714273',
#   u'anteisopentadecanoyl-cardiolipin synthase'],
#  ['rxn10113_c',
#   '0.993026664715',
#   u'cytochrome oxidase bo3 (ubiquinol-8: 2.5 protons)'],
#  ['rxn10806_c',
#   '0.993026664715',
#   u'cytochrome oxidase bd (menaquinol-8: 2 protons) (periplasm)'],
#  ['rxn05581_c', '0.9677412644275', u'RXN0-1683.ce.maizeexp.GLYCEROL_GLYCEROL'],
#  ['rxn03135_c', '0.9670273094435', u'R04558'],
#  ['rxn10174_c',
#   '0.965013040472',
#   u'maltohexaose transport via ABC system (periplasm)'],
#  ['rxn05206_c', '0.96414487982', u'TRANS-RXN-187.ce'],
#  ['rxn10311_c',
#   '0.962874245664',
#   u'anteisoheptadecanoyl-lipoteichoic acid synthesis (n=24), linked, N-acetylglucosamine substituted'],
#  ['rxn10307_c',
#   '0.962874245664',
#   u'palmitoyl-lipoteichoic acid synthesis (n=24), linked, N-acetylglucosamine substituted'],
#  ['rxn10314_c',
#   '0.962874245664',
#   u'anteisopentadecanoyl-lipoteichoic acid synthesis (n=24), linked, N-acetylglucosamine substituted'],
#  ['rxn10313_c',
#   '0.962874245664',
#   u'isopentadecanoyl-lipoteichoic acid synthesis (n=24), linked, N-acetylglucosamine substituted'],
#  ['rxn08040_c',
#   '0.962874245664',
#   u'UDP-N-acetyl-D-glucosamine:undecaprenyl-phosphate N-acetyl-D-glucosamine phosphotransferase'],
#  ['rxn10310_c',
#   '0.962874245664',
#   u'isoheptadecanoyl-lipoteichoic acid synthesis (n=24), linked, N-acetylglucosamine substituted'],
#  ['rxn10309_c',
#   '0.962874245664',
#   u'stearoyl-lipoteichoic acid synthesis (n=24), linked, N-acetylglucosamine substituted'],
#  ['rxn10315_c',
#   '0.962874245664',
#   u'isohexadecanoyl-lipoteichoic acid synthesis (n=24), linked, N-acetylglucosamine substituted'],
#  ['rxn10308_c',
#   '0.962874245664',
#   u'myristoyl-lipoteichoic acid synthesis (n=24), linked, N-acetylglucosamine substituted'],
#  ['rxn10312_c',
#   '0.962874245664',
#   u'isotetradecanoyl-lipoteichoic acid synthesis (n=24), linked, N-acetylglucosamine substituted'],
#  ['rxn00714_c',
#   '0.96060213567',
#   u"P1,P4-bis(5'-uridyl)-tetraphosphate uridylohydrolase"],
#  ['rxn10317_c',
#   '0.958332956186',
#   u'myristoyl-lipoteichoic acid synthesis (n=24), unlinked, D-alanine substituted'],
#  ['rxn10322_c',
#   '0.958332956186',
#   u'isopentadecanoyl-lipoteichoic acid synthesis (n=24), unlinked, D-alanine substituted'],
#  ['rxn10319_c',
#   '0.958332956186',
#   u'isoheptadecanoyl-lipoteichoic acid synthesis (n=24), unlinked, D-alanine substituted'],
#  ['rxn10321_c',
#   '0.958332956186',
#   u'isotetradecanoyl-lipoteichoic acid synthesis (n=24), unlinked, D-alanine substituted'],
#  ['rxn10316_c',
#   '0.958332956186',
#   u'palmitoyl-lipoteichoic acid synthesis (n=24), unlinked, D-alanine substituted'],
#  ['rxn10324_c',
#   '0.958332956186',
#   u'isohexadecanoyl-lipoteichoic acid synthesis (n=24), unlinked, D-alanine substituted'],
#  ['rxn10323_c',
#   '0.958332956186',
#   u'anteisopentadecanoyl-lipoteichoic acid synthesis (n=24), unlinked, D-alanine substituted'],
#  ['rxn10320_c',
#   '0.958332956186',
#   u'anteisoheptadecanoyl-lipoteichoic acid synthesis (n=24), unlinked, D-alanine substituted'],
#  ['rxn10318_c',
#   '0.958332956186',
#   u'stearoyl-lipoteichoic acid synthesis (n=24), unlinked, D-alanine substituted'],
#  ['rxn05207_c', '0.9536625153975', u'Na+/malate symporter'],
#  ['rxn05493_c',
#   '0.9536625153975',
#   u'Transport of a-ketoglutarate, extracellular'],
#  ['rxn05605_c', '0.9536625153975', u'Maltose permease MAL31'],
#  ['rxn05158_c',
#   '0.945360350891',
#   u'ATP phosphohydrolase (glycerol-3-phosphate-importing)'],
#  ['rxn00355_c',
#   '0.902233751764',
#   u'UTP:alpha-D-galactose-1-phosphate uridylyltransferase'],
#  ['rxn01974_c', '0.847567056109', u'LL-2,6-Diaminoheptanedioate 2-epimerase'],
#  ['rxn01518_c', '0.834052205395', u"ATP:deoxyuridine 5'-phosphotransferase"],
#  ['rxn01143_c', '0.834052205395', u"ATP:thymidine 5'-phosphotransferase"],
#  ['rxn00340_c', '0.831268848649', u'L-aspartate:ammonia ligase (AMP-forming)'],
#  ['rxn08084_c',
#   '0.820516751418',
#   u'1-tetradecanoyl-sn-glycerol 3-phosphate O-acyltransferase (n-C14:0)'],
#  ['rxn10214_c',
#   '0.820516751418',
#   u'isoheptadecanoyl-1-acylglycerol-3-phosphate O-acyltransferase'],
#  ['rxn08083_c',
#   '0.820516751418',
#   u'1-tetradecanoyl-sn-glycerol 3-phosphate O-acyltransferase (n-C12:0)'],
#  ['rxn10213_c',
#   '0.820516751418',
#   u'stearoyl-1-acylglycerol-3-phosphate O-acyltransferase'],
#  ['rxn08086_c',
#   '0.820516751418',
#   u'1-hexadecanoyl-sn-glycerol 3-phosphate O-acyltransferase (n-C16:0)'],
#  ['rxn10216_c',
#   '0.820516751418',
#   u'isotetradecanoyl-1-acylglycerol-3-phosphate O-acyltransferase'],
#  ['rxn08085_c',
#   '0.820516751418',
#   u'1-tetradec-7-enoyl-sn-glycerol 3-phosphate O-acyltransferase (n-C14:1)'],
#  ['rxn10215_c',
#   '0.820516751418',
#   u'anteisoheptadecanoyl-1-acylglycerol-3-phosphate O-acyltransferase'],
#  ['rxn08089_c',
#   '0.820516751418',
#   u'1-octadec-7-enoyl-sn-glycerol 3-phosphate O-acyltransferase (n-C18:1)'],
#  ['rxn10219_c',
#   '0.820516751418',
#   u'isohexadecanoyl-1-acylglycerol-3-phosphate O-acyltransferase'],
#  ['rxn08088_c',
#   '0.820516751418',
#   u'1-octadecanoyl-sn-glycerol 3-phosphate O-acyltransferase (n-C18:0)'],
#  ['rxn08087_c',
#   '0.820516751418',
#   u'1-hexadec-7-enoyl-sn-glycerol 3-phosphate O-acyltransferase (n-C16:1)'],
#  ['rxn10218_c',
#   '0.820516751418',
#   u'anteisopentadecanoyl-1-acylglycerol-3-phosphate O-acyltransferase'],
#  ['rxn10217_c',
#   '0.820516751418',
#   u'isopentadecanoyl-1-acylglycerol-3-phosphate O-acyltransferase'],
#  ['rxn10212_c',
#   '0.820516751418',
#   u'myristoyl-1-acylglycerol-3-phosphate O-acyltransferase'],
#  ['rxn10211_c',
#   '0.820516751418',
#   u'palmitoyl-1-acylglycerol-3-phosphate O-acyltransferase'],
#  ['rxn01607_c', '0.8089565926125', u'ATP:(R)-mevalonate 5-phosphotransferase'],
#  ['rxn00559_c',
#   '0.808679362525',
#   u'D-mannose-6-phosphate aldose-ketose-isomerase'],
#  ['rxn01454_c',
#   '0.808453235355',
#   u'acetyl-CoA:acetoacetyl-CoA C-acetyltransferase (thioester-hydrolysing, carboxymethyl-forming)'],
#  ['rxn00830_c',
#   '0.807869902075',
#   u'Isopentenyl-diphosphate delta3-delta2-isomerase'],
#  ['rxn00303_c', '0.807684045294', u"ATP:GTP 3'-diphosphotransferase"],
#  ['rxn00829_c',
#   '0.807009026602',
#   u'ATP:(R)-5-diphosphomevalonate carboxy-lyase (adding ATP; isopentenyl-diphosphate-forming)'],
#  ['rxn05170_c',
#   '0.80631487577',
#   u'TRANS-RXNAVI-26732.ce.brachyexp.CPD-3609_CPD-3609'],
#  ['rxn00816_c', '0.804039744509', u'Lactose galactohydrolase'],
#  ['rxn01519_c', '0.801422228835', u'dUTP nucleotidohydrolase'],
#  ['rxn00547_c', '0.8008414019205', u'ATP:D-fructose 6-phosphotransferase'],
#  ['rxn02339_c',
#   '0.799653288436',
#   u'4-Hydroxy-L-glutamate:2-oxoglutarate aminotransferase'],
#  ['rxn00527_c',
#   '0.799653288436',
#   u'L-tyrosine:2-oxoglutarate aminotransferase'],
#  ['rxn00260_c',
#   '0.799653288436',
#   u'L-Aspartate:2-oxoglutarate aminotransferase'],
#  ['rxn02322_c',
#   '0.79887731591',
#   u'ATP:(R)-5-phosphomevalonate phosphotransferase'],
#  ['rxn01575_c',
#   '0.798587635126',
#   u'L-Isoleucine:2-oxoglutarate aminotransferase'],
#  ['rxn00903_c', '0.798587635126', u'L-Valine:2-oxoglutarate aminotransferase'],
#  ['rxn00806_c',
#   '0.798587635126',
#   u'L-Leucine:2-oxoglutarate aminotransferase'],
#  ['rxn08792_c', '0.797829342936', u'lactate oxidation'],
#  ['rxn00499_c', '0.797829342936', u'(S)-Lactate:NAD+ oxidoreductase'],
#  ['rxn00145_c',
#   '0.797829342936',
#   u'(S)-Lactate:ferricytochrome-c 2-oxidoreductase'],
#  ['rxn02228_c', '0.797829342936', u'3-Mercaptolactate:NAD+ oxidoreductase'],
#  ['rxn08793_c', '0.797829342936', u'L-Lactate dehydrogenase (menaquinone)'],
#  ['rxn00808_c', '0.791175869719', u'ATP:D-galactose 1-phosphotransferase'],
#  ['rxn01069_c',
#   '0.789821969333',
#   u'O-phospho-L-homoserine phosphate-lyase (adding water;L-threonine-forming)'],
#  ['rxn03446_c',
#   '0.789821969333',
#   u'O-Phospho-4-hydroxy-L-threonine phospho-lyase (adding water)'],
#  ['rxn00247_c',
#   '0.7843256434345',
#   u'ATP:oxaloacetate carboxy-lyase (transphosphorylating;phosphoenolpyruvate-forming)'],
#  ['rxn00337_c', '0.782183460035', u'ATP:L-aspartate 4-phosphotransferase'],
#  ['rxn00157_c', '0.77895448061', u'Acetyl-CoA:formate C-acetyltransferase'],
#  ['rxn00552_c',
#   '0.778201293061',
#   u'D-glucosamine-6-phosphate aminohydrolase (ketol isomerizing)'],
#  ['rxn00546_c',
#   '0.7721226557225',
#   u'D-Mannitol-1-phosphate:NAD+ 5-oxidoreductase'],
#  ['rxn10199_c', '0.768983811615', u'Peptidoglycan subunit synthesis'],
#  ['rxn00001_c', '0.766325904738', u'diphosphate phosphohydrolase'],
#  ['rxn08296_c', '0.764503414665', u'diacylglycerol kinase (n-C14:1)'],
#  ['rxn10254_c',
#   '0.764503414665',
#   u'anteisoheptadecanoyl-Diacylglycerol kinase'],
#  ['rxn10256_c', '0.764503414665', u'isopentadecanoyl-Diacylglycerol kinase'],
#  ['rxn08300_c', '0.764503414665', u'diacylglycerol kinase (n-C18:1)'],
#  ['rxn08297_c', '0.764503414665', u'diacylglycerol kinase (n-C16:0)'],
#  ['rxn10258_c', '0.764503414665', u'isohexadecanoyl-Diacylglycerol kinase'],
#  ['rxn08299_c', '0.764503414665', u'diacylglycerol kinase (n-C18:0)'],
#  ['rxn10257_c',
#   '0.764503414665',
#   u'anteisopentadecanoyl-Diacylglycerol kinase'],
#  ['rxn10253_c', '0.764503414665', u'isoheptadecanoyl-Diacylglycerol kinase'],
#  ['rxn08294_c', '0.764503414665', u'diacylglycerol kinase (n-C12:0)'],
#  ['rxn10255_c', '0.764503414665', u'isotetradecanoyl-Diacylglycerol kinase'],
#  ['rxn08295_c', '0.764503414665', u'diacylglycerol kinase (n-C14:0)'],
#  ['rxn05160_c', '0.764432830749', u'monosaccharide-transporting ATPase'],
#  ['rxn01300_c', '0.764168440162', u'ATP:L-homoserine O-phosphotransferase'],
#  ['rxn00777_c',
#   '0.76286920981',
#   u'D-ribose-5-phosphate aldose-ketose-isomerase'],
#  ['rxn00548_c',
#   '0.760717563325',
#   u'D-fructose-6-phosphate D-erythrose-4-phosphate-lyase (adding phosphate; acetyl-phosphate-forming)'],
#  ['rxn01187_c',
#   '0.760717563325',
#   u'D-Xylulose 5-phosphate D-glyceraldehyde-3-phosphate-lyase (adding phosphate; acetyl-phosphate-forming)'],
#  ['rxn03908_c',
#   '0.759889864967',
#   u"ATP:4-(Cytidine 5'-diphospho)-2-C-methyl-D-erythritol 2-phosphotransferase"],
#  ['rxn06023_c',
#   '0.759596191192',
#   u'CoA:apo-[acyl-carrier-protein] pantetheinephosphotransferase'],
#  ['rxn05518_c', '0.758930764964', u'cellobiose transport via PEP:Pyr PTS'],
#  ['rxn05243_c', '0.7587233437165', u'TRANS-RXNBWI-115637.ce.maizeexp.LEU_LEU'],
#  ['rxn05244_c', '0.7587233437165', u'TRANS-RXNBWI-115637.ce.maizeexp.ILE_ILE'],
#  ['rxn05669_c', '0.7587233437165', u'TRANS-RXNBWI-115637.ce.maizeexp.VAL_VAL'],
#  ['rxn10262_c',
#   '0.757053697287',
#   u'isopentadecanoyl-CDPdiacylglycerol:sn-glycerol-3-phosphate 3-phosphatidyltransferase'],
#  ['rxn10263_c',
#   '0.757053697287',
#   u'anteisopentadecanoyl-CDPdiacylglycerol:sn-glycerol-3-phosphate 3-phosphatidyltransferase'],
#  ['rxn09111_c', '0.757053697287', u'Phosphatidylglycerol synthase (n-C16:0)'],
#  ['rxn10264_c',
#   '0.757053697287',
#   u'isohexadecanoyl-CDPdiacylglycerol:sn-glycerol-3-phosphate 3-phosphatidyltransferase'],
#  ['rxn09113_c', '0.757053697287', u'Phosphatidylglycerol synthase (n-C18:0)'],
#  ['rxn09110_c', '0.757053697287', u'Phosphatidylglycerol synthase (n-C14:1)'],
#  ['rxn10260_c',
#   '0.757053697287',
#   u'anteisoheptadecanoyl-CDPdiacylglycerol:sn-glycerol-3-phosphate 3-phosphatidyltransferase'],
#  ['rxn09109_c', '0.757053697287', u'Phosphatidylglycerol synthase (n-C14:0)'],
#  ['rxn10259_c',
#   '0.757053697287',
#   u'isoheptadecanoyl-CDPdiacylglycerol:sn-glycerol-3-phosphate 3-phosphatidyltransferase'],
#  ['rxn10261_c',
#   '0.757053697287',
#   u'isotetradecanoyl-CDPdiacylglycerol:sn-glycerol-3-phosphate 3-phosphatidyltransferase'],
#  ['rxn09108_c', '0.757053697287', u'Phosphatidylglycerol synthase (n-C12:0)'],
#  ['rxn09112_c', '0.757053697287', u'Phosphatidylglycerol synthase (n-C16:1)'],
#  ['rxn09114_c', '0.757053697287', u'Phosphatidylglycerol synthase (n-C18:1)'],
#  ['rxn00283_c', '0.756340090628', u'alanine racemase'],
#  ['rxn14090_c',
#   '0.755741740036',
#   u"dimethylallyl-diphosphate:leachianone-G 2''-dimethylallyltransferase"],
#  ['rxn03030_c',
#   '0.753739824359',
#   u'Acetyl-CoA:L-2,3,4,5-tetrahydrodipicolinate N2-acetyltransferase'],
#  ['rxn10225_c',
#   '0.752291544806',
#   u'isohexadecanoyl-phosphatidate cytidylyltransferase'],
#  ['rxn08308_c', '0.752291544806', u'CDP-diacylglycerol synthetase (n-C14:1)'],
#  ['rxn10222_c',
#   '0.752291544806',
#   u'isotetradecanoyl-phosphatidate cytidylyltransferase'],
#  ['rxn08311_c', '0.752291544806', u'CDP-diacylglycerol synthetase (n-C18:0)'],
#  ['rxn08306_c', '0.752291544806', u'CDP-diacylglycerol synthetase (n-C12:0)'],
#  ['rxn08310_c', '0.752291544806', u'CDP-diacylglycerol synthetase (n-C16:1)'],
#  ['rxn10224_c',
#   '0.752291544806',
#   u'anteisopentadecanoyl-phosphatidate cytidylyltransferase'],
#  ['rxn10221_c',
#   '0.752291544806',
#   u'anteisoheptadecanoyl-phosphatidate cytidylyltransferase'],
#  ['rxn08312_c', '0.752291544806', u'CDP-diacylglycerol synthetase (n-C18:1)'],
#  ['rxn08309_c', '0.752291544806', u'CDP-diacylglycerol synthetase (n-C16:0)'],
#  ['rxn10223_c',
#   '0.752291544806',
#   u'isopentadecanoyl-phosphatidate cytidylyltransferase'],
#  ['rxn10220_c',
#   '0.752291544806',
#   u'isoheptadecanoyl-phosphatidate cytidylyltransferase'],
#  ['rxn08307_c', '0.752291544806', u'CDP-diacylglycerol synthetase (n-C14:0)'],
#  ['rxn00612_c',
#   '0.7486948094585',
#   u'sn-Glycerol-3-phosphate:NADP+ 2-oxidoreductase'],
#  ['rxn00611_c',
#   '0.7486948094585',
#   u'sn-Glycerol-3-phosphate:NAD+ 2-oxidoreductase'],
#  ['rxn00193_c', '0.748073905944', u'glutamate racemase'],
#  ['rxn01520_c',
#   '0.7476523076445',
#   u'5,10-Methylenetetrahydrofolate:dUMP C-methyltransferase'],
#  ['rxn00931_c', '0.746341682626', u'L-Proline:NADP+ 5-oxidoreductase'],
#  ['rxn00929_c', '0.746341682626', u'L-Proline:NAD+ 5-oxidoreductase'],
#  ['rxn01967_c',
#   '0.745874860278',
#   u'beta-D-Glucose 1-phosphate 1,6-phosphomutase'],
#  ['rxn10209_c',
#   '0.74428620085',
#   u'anteisopentadecanoyl-glycerol-3-phosphate O-acyltransferase'],
#  ['rxn10205_c',
#   '0.74428620085',
#   u'isoheptadecanoyl-glycerol-3-phosphate O-acyltransferase'],
#  ['rxn08551_c',
#   '0.74428620085',
#   u'glycerol-3-phosphate acyltransferase (C18:0)'],
#  ['rxn10208_c',
#   '0.74428620085',
#   u'isopentadecanoyl-glycerol-3-phosphate O-acyltransferase'],
#  ['rxn10204_c',
#   '0.74428620085',
#   u'acyl-CoA:sn-glycerol-3-phosphate 1-O-acyltransferase'],
#  ['rxn08546_c',
#   '0.74428620085',
#   u'glycerol-3-phosphate acyltransferase (C12:0)'],
#  ['rxn08547_c',
#   '0.74428620085',
#   u'glycerol-3-phosphate acyltransferase (C14:0)'],
#  ['rxn10207_c',
#   '0.74428620085',
#   u'isotetradecanoyl-glycerol-3-phosphate O-acyltransferase'],
#  ['rxn10203_c',
#   '0.74428620085',
#   u'myristoyl-glycerol-3-phosphate O-acyltransferase'],
#  ['rxn08552_c',
#   '0.74428620085',
#   u'glycerol-3-phosphate acyltransferase (C18:1)'],
#  ['rxn10210_c',
#   '0.74428620085',
#   u'isohexadecanoyl-glycerol-3-phosphate O-acyltransferase'],
#  ['rxn08548_c',
#   '0.74428620085',
#   u'glycerol-3-phosphate acyltransferase (C14:1)'],
#  ['rxn10206_c',
#   '0.74428620085',
#   u'anteisoheptadecanoyl-glycerol-3-phosphate O-acyltransferase'],
#  ['rxn10202_c',
#   '0.74428620085',
#   u'glycerol-3-phosphate: acyl-coa acyltransferase (16:0)'],
#  ['rxn08550_c',
#   '0.74428620085',
#   u'glycerol-3-phosphate acyltransferase (C16:1)'],
#  ['rxn08549_c',
#   '0.74428620085',
#   u'glycerol-3-phosphate acyltransferase (C16:0)'],
#  ['rxn04082_c', '0.743519718394', u'L-ribulose-5-phosphate 4-epimerase'],
#  ['rxn01844_c', '0.743499574492', u'Sphingomyelin cholinephosphohydrolase'],
#  ['rxn02762_c', '0.743499574492', u"2',3'-Cyclic CMP 3'-nucleotidohydrolase"],
#  ['rxn02522_c', '0.743499574492', u"2',3'-Cyclic UMP 3'-nucleotidohydrolase"],
#  ['rxn02521_c', '0.743499574492', u"2',3'-Cyclic AMP 3'-nucleotidohydrolase"],
#  ['rxn03483_c', '0.743499574492', u"2',3'-Cyclic GMP 3'-nucleotidohydrolase"],
#  ['rxn00789_c',
#   '0.7417815933535',
#   u'1-(5-phospho-D-ribosyl)-ATP:diphosphate phospho-alpha-D-ribosyl-transferase'],
#  ['rxn00555_c',
#   '0.741373464499',
#   u'L-glutamine:D-fructose-6-phosphate isomerase (deaminating)'],
#  ['rxn00658_c', '0.740449921765', u'N-Acetyl-beta-alanine amidohydrolase'],
#  ['rxn01484_c',
#   '0.740449921765',
#   u'N-Acetyl-D-glucosamine-6-phosphate amidohydrolase'],
#  ['rxn03909_c',
#   '0.739390178829',
#   u'1-Deoxy-D-xylulose-5-phosphate pyruvate-lyase (carboxylating)'],
#  ['rxn00817_c', '0.7378568272715', u'melibiose galactohydrolase'],
#  ['rxn00818_c', '0.7378568272715', u'Raffinose galactohydrolase'],
#  ['rxn02596_c', '0.7378568272715', u'R03634'],
#  ['rxn01280_c', '0.737199900448', u'(R)-Glycerate:NAD+ oxidoreductase'],
#  ['rxn01281_c', '0.737199900448', u'(R)-Glycerate:NADP+ oxidoreductase'],
#  ['rxn00179_c', '0.7361527447915', u'ATP:L-glutamate 5-phosphotransferase'],
#  ['rxn01673_c', '0.734889432965', u'ATP:dCDP phosphotransferase'],
#  ['rxn00237_c', '0.734889432965', u'ATP:GDP phosphotransferase'],
#  ['rxn01678_c', '0.734889432965', u'ATP:dUDP phosphotransferase'],
#  ['rxn00515_c', '0.734889432965', u'ATP:IDP phosphotransferase'],
#  ['rxn01353_c', '0.734889432965', u'ATP:dGDP phosphotransferase'],
#  ['rxn01512_c', '0.734889432965', u'ATP:dTDP phosphotransferase'],
#  ['rxn00409_c', '0.734889432965', u'ATP:CDP phosphotransferase'],
#  ['rxn00117_c', '0.734889432965', u'ATP:UDP phosphotransferase'],
#  ['rxn01643_c',
#   '0.734768481784',
#   u'L-Aspartate-4-semialdehyde:NADP+ oxidoreductase (phosphorylating)'],
#  ['rxn02262_c',
#   '0.73395786562',
#   u'ATP:6-deoxy-L-galactose 1-phosphotransferase'],
#  ['rxn00184_c',
#   '0.733536583184',
#   u'L-Glutamate:NADP+ oxidoreductase (deaminating)'],
#  ['rxn00342_c', '0.733239989315', u'L-Asparagine amidohydrolase'],
#  ['rxn00148_c', '0.731557032251', u'ATP:pyruvate 2-O-phosphotransferase'],
#  ['rxn04794_c',
#   '0.7310373349005',
#   u'propanoyl-CoA:formate C-propanoyltransferase'],
#  ['rxn01116_c', '0.730430579794', u'D-Ribulose-5-phosphate 3-epimerase'],
#  ['rxn02373_c',
#   '0.7294122466965',
#   u'L-glutamate-5-semialdehyde:NADP+ 5-oxidoreductase (phosphorylating)'],
#  ['rxn00545_c',
#   '0.72930015435',
#   u'ATP:D-fructose-6-phosphate 1-phosphotransferase'],
#  ['rxn02314_c',
#   '0.72930015435',
#   u'ATP:D-tagatose-6-phosphate 1-phosphotransferase'],
#  ['rxn01215_c',
#   '0.72930015435',
#   u'3-phospho-D-glyceroyl-phosphate:alpha-D-glucose-1-phosphate 6-phosphotransferase'],
#  ['rxn01343_c',
#   '0.72930015435',
#   u'ATP:Sedoheptulose 7-phosphate 1-phosphotransferase'],
#  ['rxn01102_c', '0.7281506439095', u'ATP:(R)-glycerate 3-phosphotransferase'],
#  ['rxn00173_c', '0.727166667469', u'acetyl-CoA:phosphate acetyltransferase'],
#  ['rxn00670_c',
#   '0.727166667469',
#   u'propanoyl-CoA:phosphate propanoyltransferase'],
#  ['rxn00615_c', '0.725620303113', u'ATP:glycerol 3-phosphotransferase'],
#  ['rxn02159_c', '0.724543005718', u'L-Histidinol:NAD+ oxidoreductase'],
#  ['rxn00863_c', '0.724543005718', u'L-histidinal:NAD+ oxidoreductase'],
#  ['rxn03175_c',
#   '0.7232383184875',
#   u"N-(5'-Phospho-D-ribosylformimino)-5-amino-1- (5''-phospho-D-ribosyl)-4-imidazolecarboxamide ketol-isomerase"],
#  ['rxn02760_c', '0.722564700048', u'Sucrose 6-phosphate fructohydrolase'],
#  ['rxn01737_c', '0.722564700048', u'Raffinose fructohydrolase'],
#  ['rxn00113_c',
#   '0.7176760442195',
#   u'Carbon-dioxide:ammonia ligase (ADP-forming,carbamate-phosphorylating)'],
#  ['rxn00412_c',
#   '0.7176760442195',
#   u'UTP:L-glutamine amido-ligase (ADP-forming)'],
#  ['rxn00410_c', '0.7176760442195', u'UTP:ammonia ligase (ADP-forming)'],
#  ['rxn05457_c', '0.717197891944', u'[Acyl-carrier-protein] acetyltransferase'],
#  ['rxn05453_c',
#   '0.717197891944',
#   u'13-methyl-tetra-decanoyl-ACP:[acyl-carrier-protein] transferase'],
#  ['rxn05408_c',
#   '0.717197891944',
#   u'2-methylpropionyl-CoA:[acyl-carrier-protein] transferase'],
#  ['rxn05458_c', '0.717197891944', u'[Acyl-carrier-protein] acetyltransferase'],
#  ['rxn05452_c',
#   '0.717197891944',
#   u'14-methyl-hexa-decanoyl-ACP:[acyl-carrier-protein] transferase'],
#  ['rxn05465_c',
#   '0.717197891944',
#   u'Malonyl-CoA:[acyl-carrier-protein] S-malonyltransferase'],
#  ['rxn05459_c',
#   '0.717197891944',
#   u'stearyl-ACP:[acyl-carrier-protein] transferase'],
#  ['rxn05451_c',
#   '0.717197891944',
#   u'12-methyl-tetra-decanoyl-ACP:[acyl-carrier-protein] transferase'],
#  ['rxn05455_c',
#   '0.717197891944',
#   u'12-methyl-tridecanoyl-ACP:[acyl-carrier-protein] transferase'],
#  ['rxn05454_c',
#   '0.717197891944',
#   u'15-methyl-hexa-decanoyl-ACP:[acyl-carrier-protein] transferase'],
#  ['rxn05358_c',
#   '0.717197891944',
#   u'2-methylbutanoyl-CoA:[acyl-carrier-protein] transferase'],
#  ['rxn05456_c',
#   '0.717197891944',
#   u'14-methyl-pentadecanoyl-ACP:[acyl-carrier-protein] transferase'],
#  ['rxn02473_c',
#   '0.717125262091',
#   u'D-erythro-1-(Imidazol-4-yl)glycerol 3-phosphate hydro-lyase'],
#  ['rxn01301_c', '0.715932522549', u'L-Homoserine:NAD+ oxidoreductase'],
#  ['rxn01302_c', '0.715932522549', u'L-homoserine:NADP+ oxidoreductase'],
#  ['rxn00313_c',
#   '0.710898111393',
#   u'meso-2,6-diaminoheptanedioate carboxy-lyase (L-lysine-forming)'],
#  ['rxn02508_c',
#   '0.7100806955745',
#   u'N-(5-Phospho-beta-D-ribosyl)anthranilate ketol-isomerase'],
#  ['rxn00048_c',
#   '0.7062283724685',
#   u'6,7-Dimethyl-8-(1-D-ribityl)lumazine:6,7-dimethyl-8-(1-D-ribityl)lumazine 2,3-butanediyltransferase'],
#  ['rxn00692_c',
#   '0.705995867916',
#   u'5,10-Methylenetetrahydrofolate:glycine hydroxymethyltransferase'],
#  ['rxn01485_c',
#   '0.705832452345',
#   u'D-Glucosamine 1-phosphate 1,6-phosphomutase'],
#  ['rxn01513_c', '0.705700913934', u'ATP:dTMP phosphotransferase'],
#  ['rxn00225_c', '0.704677335708', u'ATP:acetate phosphotransferase'],
#  ['rxn00985_c', '0.704677335708', u'ATP:propanoate phosphotransferase'],
#  ['rxn03843_c',
#   '0.702423804612',
#   u'Farnesyl diphosphate:Isopentenyl diphosphate farnesyl cistransferase'],
#  ['rxn09345_c', '0.702423804612', u'Undecaprenyl diphosphate synthase'],
#  ['rxn06673_c',
#   '0.701397096183',
#   u'Acetyl-CoA:carbon-dioxide ligase (ADP-forming)'],
#  ['rxn05596_c', '0.7005408053795', u'TRANS-RXNBWI-115525.ce.maizeexp.K+_K+'],
#  ['rxn03762_c', '0.697956489043', u'R05465'],
#  ['rxn00461_c',
#   '0.697956489043',
#   u'Phosphoenolpyruvate:UDP-N-acetyl-D-glucosamine 1-carboxyvinyl-transferase'],
#  ['rxn00213_c',
#   '0.696900261433',
#   u'UTP:alpha-D-glucose-1-phosphate uridylyltransferase'],
#  ['rxn00292_c', '0.696454467222', u'UDP-N-acetyl-D-glucosamine 2-epimerase'],
#  ['rxn02975_c', '0.696454467222', u'CDP-3,6-dideoxy-D-glucose 2-epimerase'],
#  ['rxn00297_c', '0.696454467222', u'UDP-N-acetyl-D-glucosamine 2-epimerase'],
#  ['rxn06937_c',
#   '0.695362809831',
#   u'L-glutamate:tRNA(Glu) ligase (AMP-forming)'],
#  ['rxn01333_c',
#   '0.692885021207',
#   u'sedoheptulose-7-phosphate:D-glyceraldehyde-3-phosphate glyceronetransferase'],
#  ['rxn05197_c', '0.692458656768', u'Uracil permease'],
#  ['rxn02160_c', '0.690817825292', u'L-Histidinol-phosphate phosphohydrolase'],
#  ['rxn00646_c',
#   '0.685421389317',
#   u'L-glutamate:L-cysteine gamma-ligase (ADP-forming)'],
#  ['rxn00187_c', '0.683622673184', u'L-Glutamate:ammonia ligase (ADP-forming)'],
#  ['rxn03406_c',
#   '0.68083310417',
#   u'Undecaprenyl-diphospho-N-acetylmuramoyl-(N-acetylglucosamine)-'],
#  ['rxn03407_c',
#   '0.68083310417',
#   u'Undecaprenyl-diphospho-N-acetylmuramoyl-(N-acetylglucosamine)-L-alanyl-gamma-D-glutamyl-L-lysyl-D-alanyl-D-alanine:ammonia ligase (ADP-forming)'],
#  ['rxn03409_c',
#   '0.68083310417',
#   u'Undecaprenyl-diphospho-N-acetylmuramoyl-(N-acetylglucosamine)-'],
#  ['rxn01366_c',
#   '0.679740642715',
#   u'Uridine:phosphate alpha-D-ribosyltransferase'],
#  ['rxn01101_c',
#   '0.673815424657',
#   u'3-Phospho-D-glycerate:NAD+ 2-oxidoreductase'],
#  ['rxn00772_c', '0.673305759465', u'ATP:D-ribose 5-phosphotransferase'],
#  ['rxn01987_c', '0.673305759465', u'R02750'],
#  ['rxn01972_c',
#   '0.6696263446175',
#   u'N6-Acetyl-LL-2,6-diaminoheptanedioate amidohydrolase'],
#  ['rxn01705_c', '0.666796063588', u"dCTP:cytidine 5'-phosphotransferase"],
#  ['rxn01129_c', '0.666796063588', u"dATP:uridine 5'-phosphotransferase"],
#  ['rxn01516_c', '0.666796063588', u"dTTP:uridine 5'-phosphotransferase"],
#  ['rxn00369_c', '0.666796063588', u"GTP:cytidine 5'-phosphotransferase"],
#  ['rxn00712_c', '0.666796063588', u"UTP:uridine 5'-phosphotransferase"],
#  ['rxn01706_c', '0.666796063588', u"dUTP:cytidine 5'-phosphotransferase"],
#  ['rxn01515_c', '0.666796063588', u"dTTP:cytidine 5'-phosphotransferase"],
#  ['rxn01370_c', '0.666796063588', u"dGTP:uridine 5'-phosphotransferase"],
#  ['rxn00365_c', '0.666796063588', u"ATP:cytidine 5'-phosphotransferase"],
#  ['rxn00368_c', '0.666796063588', u"UTP:cytidine 5'-phosphotransferase"],
#  ['rxn01128_c', '0.666796063588', u"dATP:cytidine 5'-phosphotransferase"],
#  ['rxn00713_c', '0.666796063588', u"GTP:uridine 5'-phosphotransferase"],
#  ['rxn01510_c', '0.666796063588', u"dGTP:cytidine 5'-phosphotransferase"],
#  ['rxn00709_c', '0.666796063588', u"ATP:uridine 5'-phosphotransferase"],
#  ['rxn01674_c', '0.666796063588', u"dCTP:uridine 5'-phosphotransferase"],
#  ['rxn01679_c', '0.666796063588', u"dUTP:uridine 5'-phosphotransferase"],
#  ['rxn00715_c', '0.666796063588', u"ITP:uridine 5'-phosphotransferase"],
#  ['rxn05440_c',
#   '0.666786703775',
#   u'7-methyl-trans-oct-2-enoyl-ACP:NAD+ oxidoreductase (A-specific)'],
#  ['rxn05444_c',
#   '0.666786703775',
#   u'15-methyl-trans-hexa-dec-2-enoyl-ACP:NAD+ oxidoreductase (A-specific)'],
#  ['rxn05434_c',
#   '0.666786703775',
#   u'6-methyl-trans-oct-2-enoyl-ACP:NAD+ oxidoreductase (A-specific)'],
#  ['rxn05437_c',
#   '0.666786703775',
#   u'12-methyl-trans-tetra-dec-2-enoyl-ACP:NAD+ oxidoreductase (A-specific)'],
#  ['rxn05324_c',
#   '0.666786703775',
#   u'Dodecanoyl-[acyl-carrier protein]:malonyl-CoA C-acyltransferase(decarboxylating, oxoacyl- and enoyl-reducing)'],
#  ['rxn05435_c',
#   '0.666786703775',
#   u'8-methyl-trans-dec-2-enoyl-ACP:NAD+ oxidoreductase (A-specific)'],
#  ['rxn05450_c',
#   '0.666786703775',
#   u'14-methyl-trans-pentadec-2-enoyl-ACP:NAD+ oxidoreductase (A-specific)'],
#  ['rxn05443_c',
#   '0.666786703775',
#   u'13-methyl-trans-tetra-dec-2-enoyl-ACP:NAD+ oxidoreductase (A-specific)'],
#  ['rxn05448_c',
#   '0.666786703775',
#   u'10-methyl-trans-undec-2-enoyl-ACP:NAD+ oxidoreductase (A-specific)'],
#  ['rxn05446_c',
#   '0.666786703775',
#   u'6-methyl-trans-hept-2-enoyl-ACP:NAD+ oxidoreductase (A-specific)'],
#  ['rxn05327_c',
#   '0.666786703775',
#   u'Decanoyl-[acyl-carrier protein]:malonyl-CoA C-acyltransferase(decarboxylating, oxoacyl- and enoyl-reducing)'],
#  ['rxn05322_c',
#   '0.666786703775',
#   u'Butyryl-[acyl-carrier protein]:malonyl-CoA C-acyltransferase(decarboxylating, oxoacyl- and enoyl-reducing)'],
#  ['rxn07579_c', '0.666786703775', u'R07765'],
#  ['rxn05325_c',
#   '0.666786703775',
#   u'Octanoyl-[acyl-carrier protein]:malonyl-CoA C-acyltransferase(decarboxylating, oxoacyl- and enoyl-reducing)'],
#  ['rxn05442_c',
#   '0.666786703775',
#   u'11-methyl-trans-dodec-2-enoyl-ACP:NAD+ oxidoreductase (A-specific)'],
#  ['rxn05441_c',
#   '0.666786703775',
#   u'9-methyl-trans-dec-2-enoyl-ACP:NAD+ oxidoreductase (A-specific)'],
#  ['rxn05445_c',
#   '0.666786703775',
#   u'4-methyl-trans-pent-2-enoyl-ACP:NAD+ oxidoreductase (A-specific)'],
#  ['rxn05449_c',
#   '0.666786703775',
#   u'12-methyl-trans-tridec-2-enoyl-ACP:NAD+ oxidoreductase (A-specific)'],
#  ['rxn05328_c',
#   '0.666786703775',
#   u'Hexadecanoyl-[acyl-carrier protein]:malonyl-CoA C-acyltransferase(decarboxylating, oxoacyl- and enoyl-reducing)'],
#  ['rxn05323_c',
#   '0.666786703775',
#   u'Tetradecanoyl-[acyl-carrier protein]:malonyl-CoA C-acyltransferase(decarboxylating, oxoacyl- and enoyl-reducing)'],
#  ['rxn05438_c',
#   '0.666786703775',
#   u'14-methyl-trans-hexa-dec-2-enoyl-ACP:NAD+ oxidoreductase (A-specific)'],
#  ['rxn05433_c',
#   '0.666786703775',
#   u'4-methyl-trans-hex-2-enoyl-ACP:NAD+ oxidoreductase (A-specific)'],
#  ['rxn05447_c',
#   '0.666786703775',
#   u'8-methyl-trans-non-2-enoyl-ACP:NAD+ oxidoreductase (A-specific)'],
#  ['rxn05326_c',
#   '0.666786703775',
#   u'Hexanoyl-[acyl-carrier protein]:malonyl-CoA C-acyltransferase(decarboxylating, oxoacyl- and enoyl-reducing)'],
#  ['rxn05464_c',
#   '0.666786703775',
#   u'trans-Octodec-2-enoyl-ACP:NAD+ oxidoreductase (A-specific)'],
#  ['rxn05436_c',
#   '0.666786703775',
#   u'10-methyl-trans-dodec-2-enoyl-ACP:NAD+ oxidoreductase (A-specific)'],
#  ['rxn05439_c',
#   '0.666786703775',
#   u'5-methyl-trans-hex-2-enoyl-ACP:NAD+ oxidoreductase (A-specific)'],
#  ['rxn08669_c', '0.661092375148', u'Glycerophosphodiester phosphodiesterase'],
#  ['rxn00758_c',
#   '0.661092375148',
#   u'sn-Glycero-3-phosphocholine glycerophosphohydrolase'],
#  ['rxn01073_c',
#   '0.661092375148',
#   u'sn-Glycero-3-phosphoethanolamine glycerophosphohydrolase'],
#  ['rxn05145_c', '0.658835304824', u'phosphate-transporting ATPase'],
#  ['rxn01171_c', '0.657653905541', u'D-glucose 1-epimerase'],
#  ['rxn01951_c',
#   '0.655838841077',
#   u'ATP:N-acyl-D-mannosamine 6-phosphotransferase'],
#  ['rxn05466_c', '0.647347610136', u'TRANS-RXN-173.ce'],
#  ['rxn10060_c', '0.642978695706', u'NAD kinase (dTTP)'],
#  ['rxn00077_c', '0.642978695706', u"ATP:NAD+ 2'-phosphotransferase"],
#  ['rxn05671_c', '0.639404650282', u'D-xylose transport in via proton symport'],
#  ['rxn05740_c', '0.639077991651', u'1,4-alpha-glucan-branching enzyme'],
#  ['rxn06062_c', '0.637169831403', u'O-Acylcarnitine acylhydrolase'],
#  ['rxn01476_c',
#   '0.637169831403',
#   u'6-Phospho-D-glucono-1,5-lactone lactonohydrolase'],
#  ['rxn05569_c', '0.636095901067', u'D-glucosamine transport via PEP:Pyr PTS'],
#  ['rxn02835_c',
#   '0.634433770324',
#   u'1-(5-phospho-D-ribosyl)-AMP 1,6-hydrolase'],
#  ['rxn02834_c', '0.634433770324', u'Phosphoribosyl-ATP pyrophosphohydrolase'],
#  ['rxn05567_c', '0.63336233169', u'Galactitol transport via PEP:Pyr PTS'],
#  ['rxn05618_c',
#   '0.629363044841',
#   u'manganese transport in via proton symport'],
#  ['rxn00711_c',
#   '0.627019610593',
#   u'UMP:diphosphate phospho-alpha-D-ribosyltransferase'],
#  ['rxn00146_c',
#   '0.625932919125',
#   u'(R)-Lactate:ferricytochrome-c 2-oxidoreductase'],
#  ['rxn00500_c', '0.625932919125', u'(R)-Lactate:NAD+ oxidoreductase'],
#  ['rxn08783_c',
#   '0.625932919125',
#   u'DLACTDEHYDROGFAD-RXN.c.metaexp.CPD-9956_UBIQUINONE-8'],
#  ['rxn10042_c', '0.618934041324', u'F(1)-ATPase'],
#  ['rxn00161_c',
#   '0.618740340692',
#   u'(S)-Malate:NADP+ oxidoreductase(oxaloacetate-decarboxylating)'],
#  ['rxn00392_c', '0.613516929019', u"ATP:riboflavin 5'-phosphotransferase"],
#  ['rxn00122_c', '0.613516929019', u'ATP:FMN adenylyltransferase'],
#  ['rxn01133_c', '0.6047575523425', u'Acetyl-CoA:maltose O-acetyltransferase'],
#  ['rxn00604_c',
#   '0.604620752757',
#   u'D-glucose-6-phosphate:NADP+ 1-oxidoreductase'],
#  ['rxn01975_c',
#   '0.604620752757',
#   u'beta-D-Glucose-6-phosphate:NADP+ 1-oxoreductase'],
#  ['rxn14264_c',
#   '0.5956757484935',
#   u'dimethylallyl-diphosphate:naringenin 8-dimethylallyltransferase'],
#  ['rxn05289_c',
#   '0.595543411979',
#   u'NADPH:oxidized-thioredoxin oxidoreductase'],
#  ['rxn03638_c',
#   '0.592480760125',
#   u'Acetyl-CoA:D-glucosamine-1-phosphate N-acetyltransferase'],
#  ['rxn01100_c',
#   '0.591666915544',
#   u'ATP:3-phospho-D-glycerate 1-phosphotransferase'],
#  ['rxn00171_c',
#   '0.589222276065',
#   u'acetaldehyde:NAD+ oxidoreductase (CoA-acetylating)'],
#  ['rxn00869_c',
#   '0.589222276065',
#   u'butanal:NAD+ oxidoreductase (CoA-acylating)'],
#  ['rxn00459_c',
#   '0.581783566374',
#   u'2-phospho-D-glycerate hydro-lyase (phosphoenolpyruvate-forming)'],
#  ['rxn02737_c', '0.580639938909', u'UDPglucosamine 4-epimerase'],
#  ['rxn00295_c', '0.580639938909', u'UDP-N-acetyl-D-glucosamine 4-epimerase'],
#  ['rxn00214_c', '0.580639938909', u'UDP-glucose 4-epimerase'],
#  ['rxn10191_c', '0.559993341826', u'D-alanine-poly(phosphoribitol) ligase'],
#  ['rxn05733_c',
#   '0.552525342389',
#   u'O3-acetyl-L-serine:thiosulfate 2-amino-2-carboxyethyltransferase (reducing, L-cysteine-forming)'],
#  ['rxn00649_c',
#   '0.552525342389',
#   u'O3-acetyl-L-serine:hydrogen-sulfide 2-amino-2-carboxyethyltransferase'],
#  ['rxn00066_c', '0.550003877376', u'NADH:hydrogen-peroxide oxidoreductase'],
#  ['rxn00347_c', '0.545112073727', u'L-Aspartate ammonia-lyase'],
#  ['rxn02090_c', '0.543713599798', u'Creatinine iminohydrolase'],
#  ['rxn00300_c',
#   '0.543713599798',
#   u'GTP 7,8-8,9-dihydrolase (diphosphate-forming)'],
#  ['rxn05040_c',
#   '0.538192415146',
#   u'D-ribulose 5-phosphate formate-lyase (L-3,4-dihydroxybutan-2-one 4-phosphate-forming)'],
#  ['rxn01329_c', '0.533447223268', u'D-mannose 6-phosphate 1,6-phosphomutase'],
#  ['rxn00022_c', '0.531822436118', u'maltose glucohydrolase'],
#  ['rxn00781_c',
#   '0.528245299257',
#   u'D-glyceraldehyde-3-phosphate:NAD+ oxidoreductase (phosphorylating)'],
#  ['rxn01331_c',
#   '0.528245299257',
#   u'D-erythrose 4-phosphate:NAD+ oxidoreductase'],
#  ['rxn05209_c', '0.52186040665', u'TRANS-RXNBWI-115525.ce.maizeexp.NA+_NA+'],
#  ['rxn00358_c', '0.516062641032', u'UDP-D-galactopyranose furanomutase'],
#  ['rxn01018_c',
#   '0.514589206681',
#   u'carbamoyl-phosphate:L-aspartate carbamoyltransferase'],
#  ['rxn03482_c', '0.507067495483', u'Salicin 6-phosphate glucohydrolase'],
#  ['rxn03481_c', '0.507067495483', u'Arbutin 6-phosphate glucohydrolase'],
#  ['rxn08025_c', '0.507067495483', u'Arbutin 6-phosphate glucohydrolase'],
#  ['rxn09992_c', '0.507067495483', u'6-phospho-beta-glucosidase'],
#  ['rxn00608_c',
#   '0.507067495483',
#   u'6-phospho-beta-D-glucosyl-(1->4)-D-glucose 6-phosphoglucohydrolase'],
#  ['rxn05208_c', '0.503076658684', u'Na+ lactate / malate H+ antiporter'],
#  ['rxn05604_c', '0.503076658684', u'malate-H+/Na+-lactate antiporter'],
#  ['rxn00056_c', '0.502358294079', u'Fe(II):oxygen oxidoreductase'],
#  ['rxn01270_c',
#   '0.501450295145',
#   u'L-arogenate:2-oxoglutarate aminotransferase'],
#  ['rxn05614_c',
#   '0.493405451789',
#   u'L-methionine R-oxide transport via ABC system'],
#  ['rxn05219_c', '0.493405451789', u'nonpolar-amino-acid-transporting ATPase'],
#  ['rxn05183_c', '0.493405451789', u'D-methionine transport via ABC system'],
#  ['rxn05613_c',
#   '0.493405451789',
#   u'L-methionine S-oxide transport via ABC system'],
#  ['rxn00566_c',
#   '0.487038398139',
#   u'L-Cysteine hydrogen-sulfide-lyase (deaminating; pyruvate-forming)'],
#  ['rxn00742_c',
#   '0.487038398139',
#   u'L-cystathionine cysteine-lyase (deaminating; 2-oxobutanoate-forming)'],
#  ['rxn01740_c', '0.48130720307', u'Shikimate:NADP+ 3-oxidoreductase'],
#  ['rxn05173_c', '0.481282840492', u'L-arabinose transport via ABC system'],
#  ['rxn01169_c', '0.477561681126', u'ATP:beta-D-glucose 6-phosphotransferase'],
#  ['rxn00216_c', '0.477561681126', u'ATP:D-glucose 6-phosphotransferase'],
#  ['rxn09310_c', '0.4772215480845', u'thiazole phosphate synthesis'],
#  ['rxn01966_c',
#   '0.475606222309',
#   u'alpha,alpha-Trehalose:orthophosphate beta-D-glucosyltransferase'],
#  ['rxn01132_c',
#   '0.475606222309',
#   u'Maltose:phosphate 1-beta-D-glucosyltransferase'],
#  ['rxn00416_c',
#   '0.4649515028655',
#   u'L-aspartate:L-glutamine amido-ligase (AMP-forming)'],
#  ['rxn02011_c',
#   '0.463203835681',
#   u'UDP-N-acetylmuramoyl-L-alanyl-D-glutamate:(L)-meso-2,6-diaminoheptanedioate gamma-ligase (ADP-forming)'],
#  ['rxn05655_c', '0.461953620695', u'sucrose transport via PEP:Pyr PTS'],
#  ['rxn03463_c', '0.454638078267', u'R05113'],
#  ['rxn03185_c', '0.454638078267', u'R04661'],
#  ['rxn06750_c', '0.454638078267', u'R04632'],
#  ['rxn06735_c',
#   '0.454638078267',
#   u'CMP-N-acetylneuraminate:alpha-N-acetylneuraminyl-2,3-beta-D-galactoside alpha-2,8-N-acetylneuraminyltransferase'],
#  ['rxn06728_c',
#   '0.454638078267',
#   u'CMP-N-acetylneuraminate:alpha-N-acetylneuraminyl-2,3-beta-D-galactoside alpha-2,8-N-acetylneuraminyltransferase'],
#  ['rxn01466_c',
#   '0.454638078267',
#   u'Geranyl-diphosphate:isopentenyl-diphosphate geranyltrans-transferase'],
#  ['rxn06759_c', '0.454638078267', u'R04649'],
#  ['rxn00490_c',
#   '0.447407603547',
#   u'L-arogenate hydro-lyase (decarboxylating; L-phenylalanine-forming)'],
#  ['rxn05401_c',
#   '0.436078967177',
#   u'13-methyl-3-oxo-tetra-decanoyl-ACP:NADP+ oxidoreductase'],
#  ['rxn05418_c',
#   '0.436078967177',
#   u'8-methyl-3-oxo-nonanoyl-ACP:NADP+ oxidoreductase'],
#  ['rxn05461_c',
#   '0.436078967177',
#   u'3-Hydroxyoctodecanoyl-ACP:NADP+ oxidoreductase'],
#  ['rxn05410_c',
#   '0.436078967177',
#   u'4-methyl-3-oxo-pentanoyl-ACP:NADP+ oxidoreductase'],
#  ['rxn05422_c',
#   '0.436078967177',
#   u'10-methyl-3-oxo-undecanoyl-ACP:NADP+ oxidoreductase'],
#  ['rxn05385_c',
#   '0.436078967177',
#   u'5-methyl-3-oxo-hexanoyl-ACP:NADP+ oxidoreductase'],
#  ['rxn05336_c',
#   '0.436078967177',
#   u'(3R)-3-Hydroxypalmitoyl-[acyl-carrier-protein]:NADP+ oxidoreductase'],
#  ['rxn05340_c',
#   '0.436078967177',
#   u'(3R)-3-Hydroxydodecanoyl-[acyl-carrier-protein]:NADP+ oxidoreductase'],
#  ['rxn05389_c',
#   '0.436078967177',
#   u'7-methyl-3-oxo-octanoyl-ACP:NADP+ oxidoreductase'],
#  ['rxn05364_c',
#   '0.436078967177',
#   u'6-methyl-3-oxo-octanoyl-ACP:NADP+ oxidoreductase'],
#  ['rxn05338_c',
#   '0.436078967177',
#   u'(3R)-3-Hydroxydecanoyl-[acyl-carrier-protein]:NADP+ oxidoreductase'],
#  ['rxn05337_c',
#   '0.436078967177',
#   u'(3R)-3-Hydroxyhexanoyl-[acyl-carrier-protein]:NADP+ oxidoreductase'],
#  ['rxn05430_c',
#   '0.436078967177',
#   u'14-methyl-3-oxo-pentadecanoyl-ACP:NADP+ oxidoreductase'],
#  ['rxn05376_c',
#   '0.436078967177',
#   u'12-methyl-3-oxo-tetra-decanoyl-ACP:NADP+ oxidoreductase'],
#  ['rxn05380_c',
#   '0.436078967177',
#   u'14-methyl-3-oxo-hexa-decanoyl-ACP:NADP+ oxidoreductase'],
#  ['rxn05397_c',
#   '0.436078967177',
#   u'11-methyl-3-oxo-dodecanoyl-ACP:NADP+ oxidoreductase'],
#  ['rxn05405_c',
#   '0.436078967177',
#   u'15-methyl-3-oxo-hexa-decanoyl-ACP:NADP+ oxidoreductase'],
#  ['rxn05339_c',
#   '0.436078967177',
#   u'(3R)-3-Hydroxybutanoyl-[acyl-carrier protein]:NADP+ oxidoreductase'],
#  ['rxn05342_c',
#   '0.436078967177',
#   u'(3R)-3-Hydroxytetradecanoyl-[acyl-carrier-protein]:NADP+ oxidoreductase'],
#  ['rxn05393_c',
#   '0.436078967177',
#   u'9-methyl-3-oxo-decanoyl-ACP:NADP+ oxidoreductase'],
#  ['rxn05341_c',
#   '0.436078967177',
#   u'(3R)-3-Hydroxyoctanoyl-[acyl-carrier-protein]:NADP+ oxidoreductase'],
#  ['rxn05414_c',
#   '0.436078967177',
#   u'6-methyl-3-oxo-heptanoyl-ACP:NADP+ oxidoreductase'],
#  ['rxn05368_c',
#   '0.436078967177',
#   u'8-methyl-3-oxo-decanoyl-ACP:NADP+ oxidoreductase'],
#  ['rxn05360_c',
#   '0.436078967177',
#   u'4-methyl-3-oxo-hexanoyl-ACP:NADP+ oxidoreductase'],
#  ['rxn05372_c',
#   '0.436078967177',
#   u'10-methyl-3-oxo-dodecanoyl-ACP:NADP+ oxidoreductase'],
#  ['rxn05426_c',
#   '0.436078967177',
#   u'12-methyl-3-oxo-tridecanoyl-ACP:NADP+ oxidoreductase'],
#  ['rxn01019_c',
#   '0.429484877357',
#   u'Carbamoyl-phosphate:L-ornithine carbamoyltransferase'],
#  ['rxn03164_c',
#   '0.428377786396',
#   u'UDP-N-acetylmuramoyl-L-alanyl-D-glutamyl-meso-2,6-diaminoheptanedioate:D-alanyl-D-alanine ligase(ADP-forming)'],
#  ['rxn03167_c',
#   '0.426357010999',
#   u'2-Amino-4-hydroxy-6-(erythro-1,2,3-trihydroxypropyl) dihydropteridine triphosphate phosphohydrolase (alkaline optimum)'],
#  ['rxn00743_c', '0.426357010999', u'Glycerone phosphate phosphohydrolase'],
#  ['rxn02166_c', '0.426357010999', u'4-Nitrophenyl phosphate phosphohydrolase'],
#  ['rxn05176_c', '0.419470503737', u'thiosulfate transport via ABC system'],
#  ['rxn02285_c',
#   '0.417641026056',
#   u'UDP-N-acetylmuramate:NADP+ oxidoreductase'],
#  ['rxn05500_c',
#   '0.4175868344875',
#   u'L-arabinose transport via proton symport'],
#  ['rxn05566_c',
#   '0.4175868344875',
#   u'D-galactose transport in via proton symport'],
#  ['rxn01973_c',
#   '0.416456759014',
#   u'N-Succinyl-LL-2,6-diaminoheptanedioate amidohydrolase'],
#  ['rxn05202_c', '0.415516753833', u'TRANS-RXN-206.ce'],
#  ['rxn01257_c', '0.413864621259', u'chorismate:L-glutamine aminotransferase'],
#  ['rxn00178_c',
#   '0.405208846029',
#   u'Acetyl-CoA:acetyl-CoA C-acetyltransferase'],
#  ['rxn00874_c',
#   '0.405208846029',
#   u'butanoyl-CoA:acetyl-CoA C-butanoyltransferase'],
#  ['rxn00543_c', '0.401209671564', u'ethanol:NAD+ oxidoreductase'],
#  ['rxn00763_c', '0.401209671564', u'Glycerol:NAD+ oxidoreductase'],
#  ['rxn01602_c', '0.40066281215', u'dihydrofolate:NADP+ oxidoreductase'],
#  ['rxn00686_c',
#   '0.40066281215',
#   u'5,6,7,8-tetrahydrofolate:NADP+ oxidoreductase'],
#  ['rxn00159_c',
#   '0.398595179174',
#   u'(S)-malate:NAD+ oxidoreductase (decarboxylating)'],
#  ['rxn05147_c', '0.388994087708', u'D-Glucose-ABC transport'],
#  ['rxn00776_c',
#   '0.386682147039',
#   u"uracil hydro-lyase (adding D-ribose 5-phosphate;pseudouridine-5'-phosphate-forming)"],
#  ['rxn06672_c',
#   '0.385901828733',
#   u'biotin-carboxyl-carrier-protein:carbon-dioxide ligase (ADP-forming)'],
#  ['rxn05555_c', '0.385430267656', u'iron (II) transport via ABC system'],
#  ['rxn01218_c',
#   '0.382008147836',
#   u"2'-Deoxycytidine 5'-monophosphate phosphohydrolase"],
#  ['rxn02400_c',
#   '0.382008147836',
#   u'Nicotinate D-ribonucleotide phosphohydrolase'],
#  ['rxn00913_c',
#   '0.382008147836',
#   u"Guanosine 5'-monophosphate phosphohydrolase"],
#  ['rxn01445_c',
#   '0.382008147836',
#   u"2'-Deoxyguanosine 5'-monophosphate phosphohydrolase"],
#  ['rxn00708_c',
#   '0.382008147836',
#   u"Uridine 5'-monophosphate phosphohydrolase"],
#  ['rxn00132_c',
#   '0.382008147836',
#   u"Adenosine 5'-monophosphate phosphohydrolase"],
#  ['rxn00363_c',
#   '0.382008147836',
#   u"Cytidine-5'-monophosphate phosphohydrolase"],
#  ['rxn01670_c',
#   '0.382008147836',
#   u'Nicotinamide ribonucleotide phosphohydrolase'],
#  ['rxn00831_c',
#   '0.382008147836',
#   u"Inosine 5'-monophosphate phosphohydrolase"],
#  ['rxn01145_c', '0.382008147836', u"Thymidylate 5'-phosphohydrolase"],
#  ['rxn01961_c', '0.382008147836', u"Xanthosine 5'-phosphate phosphohydrolase"],
#  ['rxn00550_c',
#   '0.382008147836',
#   u'beta-D-fructose-2,6-bisphosphate 2-phosphohydrolase'],
#  ['rxn01507_c',
#   '0.382008147836',
#   u"2'-Deoxyadenosine 5'-monophosphate phosphohydrolase"],
#  ['rxn01521_c',
#   '0.382008147836',
#   u"2'-Deoxyuridine 5'-monophosphate phosphohydrolase"],
#  ['rxn01800_c', '0.378677018327', u'Deoxycytidine aminohydrolase'],
#  ['rxn01368_c', '0.378677018327', u'Cytidine aminohydrolase'],
#  ['rxn10857_c', '0.375269646736', u'cytidine transport in via sodium symport'],
#  ['rxn10892_c',
#   '0.375269646736',
#   u'thymidine transport in via sodium symport'],
#  ['rxn10895_c', '0.375269646736', u'uridine transport in via sodium symport'],
#  ['rxn05564_c', '0.370022295197', u'Proline-specific permease'],
#  ['rxn08556_c',
#   '0.367963789596',
#   u'sn-glycerol 3-phosphate:ubiquinone-8 oxidoreductase'],
#  ['rxn00616_c',
#   '0.367963789596',
#   u'sn-Glycerol-3-phosphate:(acceptor) 2-oxidoreductase'],
#  ['rxn08557_c',
#   '0.367963789596',
#   u'glycerol-3-phosphate dehydrogenase (menaquinone-8)'],
#  ['rxn08558_c',
#   '0.367963789596',
#   u'anaerobic glycerol-3-phosphate dehydrogenase'],
#  ['rxn09296_c',
#   '0.364642521417',
#   u'hydrogen peroxide reductase (thioredoxin)'],
#  ['rxn02788_c', '0.359035203948', u'R03966'],
#  ['rxn07431_c', '0.358773786441', u'R07600'],
#  ['rxn07434_c', '0.358773786441', u'R07603'],
#  ['rxn07433_c', '0.358773786441', u'R07602'],
#  ['rxn07435_c', '0.358773786441', u'R07604'],
#  ['rxn07430_c', '0.358773786441', u'R07599'],
#  ['rxn07432_c', '0.358773786441', u'R07601'],
#  ['rxn00606_c',
#   '0.356022696861',
#   u'alpha,alpha-Trehalose-6-phosphate phosphoglucohydrolase'],
#  ['rxn03248_c',
#   '0.349975544207',
#   u'Hexanoyl-CoA:acetyl-CoA C-acyltransferase'],
#  ['rxn02680_c',
#   '0.349975544207',
#   u'Octanoyl-CoA:acetyl-CoA C-acyltransferase'],
#  ['rxn02804_c',
#   '0.349975544207',
#   u'myristoyl-CoA:acetylCoA C-myristoyltransferase'],
#  ['rxn03243_c',
#   '0.349975544207',
#   u'Decanoyl-CoA:acetyl-CoA C-acyltransferase'],
#  ['rxn00676_c',
#   '0.349975544207',
#   u'acetyl-CoA:propanoyl-CoA 2-C-acetyltransferase'],
#  ['rxn06510_c', '0.349975544207', u'Lauroyl-CoA:acetyl-CoA C-acyltransferase'],
#  ['rxn00020_c', '0.3470087125115', u'cellobiose glucohydrolase'],
#  ['rxn00222_c', '0.3392494747515', u'cellobiose glucohydrolase'],
#  ['rxn09978_c',
#   '0.3392494747515',
#   u'beta-glucosidase (methyl-alpha-D-glucoside)'],
#  ['rxn09979_c', '0.3392494747515', u'beta-glucosidase'],
#  ['rxn02320_c',
#   '0.330466337227',
#   u'5-Amino-2-oxopentanoate:2-oxoglutarate aminotransferase'],
#  ['rxn02318_c', '0.327091396127', u'D-Galactose 6-phosphate ketol-isomerase'],
#  ['rxn01199_c', '0.32515866037', u'ATP:D-xylulose 5-phosphotransferase'],
#  ['rxn03086_c', '0.315410307323', u'R04467'],
#  ['rxn01217_c', '0.314630610954', u'dCMP aminohydrolase'],
#  ['rxn04781_c', '0.314630610954', u'R06972'],
#  ['rxn04779_c', '0.314630610954', u'R06970'],
#  ['rxn04780_c', '0.314630610954', u'R06971'],
#  ['rxn01275_c', '0.314211567492', u'ATP:D-Gluconate 6-phosphotransferase'],
#  ['rxn02842_c', '0.310721019566', u'R04049'],
#  ['rxn01124_c',
#   '0.310721019566',
#   u'2-Dehydro-3-deoxy-D-gluconate:NAD+ 5-oxidoreductase'],
#  ['rxn02005_c', '0.298786920067', u'trehalose transport via PEP:Pyr PTS'],
#  ['rxn01925_c',
#   '0.297421675244',
#   u'2-methylpropanoyl-CoA:enzyme N6-(dihydrolipoyl)lysine S-(2-methylpropanoyl)transferase'],
#  ['rxn06586_c',
#   '0.297421675244',
#   u'3-methylbutanoyl-CoA:enzyme N6-(dihydrolipoyl)lysine S-(3-methylbutanoyl)transferase'],
#  ['rxn06335_c',
#   '0.297421675244',
#   u'(S)-2-methylbutanoyl-CoA:enzyme N6-(dihydrolipoyl)lysine S-(2-methylbutanoyl)transferase'],
#  ['rxn10270_c',
#   '0.295909413936',
#   u'isohexadecanoyl-Phosphatidylglycerophosphate phosphohydrolase'],
#  ['rxn09105_c',
#   '0.295909413936',
#   u'phosphatidylglycerol phosphate phosphatase (periplasm, n-C16:1)'],
#  ['rxn09106_c',
#   '0.295909413936',
#   u'phosphatidylglycerol phosphate phosphatase (periplasm, n-C18:0)'],
#  ['rxn09103_c',
#   '0.295909413936',
#   u'phosphatidylglycerol phosphate phosphatase (periplasm, n-C14:1)'],
#  ['rxn10265_c',
#   '0.295909413936',
#   u'isoheptadecanoyl-Phosphatidylglycerophosphate phosphohydrolase'],
#  ['rxn10269_c',
#   '0.295909413936',
#   u'anteisopentadecanoyl-Phosphatidylglycerophosphate phosphohydrolase'],
#  ['rxn10266_c',
#   '0.295909413936',
#   u'anteisoheptadecanoyl-Phosphatidylglycerophosphate phosphohydrolase'],
#  ['rxn09102_c',
#   '0.295909413936',
#   u'phosphatidylglycerol phosphate phosphatase (periplasm, n-C14:0)'],
#  ['rxn09101_c',
#   '0.295909413936',
#   u'phosphatidylglycerol phosphate phosphatase (periplasm, n-C14:0)'],
#  ['rxn10267_c',
#   '0.295909413936',
#   u'isotetradecanoyl-Phosphatidylglycerophosphate phosphohydrolase'],
#  ['rxn09104_c',
#   '0.295909413936',
#   u'phosphatidylglycerol phosphate phosphatase (periplasm, n-C16:0)'],
#  ['rxn09107_c',
#   '0.295909413936',
#   u'phosphatidylglycerol phosphate phosphatase (periplasm, n-C18:1)'],
#  ['rxn10268_c',
#   '0.295909413936',
#   u'isopentadecanoyl-Phosphatidylglycerophosphate phosphohydrolase'],
#  ['rxn01021_c',
#   '0.291809946161',
#   u'Methylthioadenosine methylthioribohydrolase'],
#  ['rxn00143_c',
#   '0.291809946161',
#   u'S-Adenosyl-L-homocysteine homocysteinylribohydrolase'],
#  ['rxn06493_c', '0.285892987517', u'dihydrolipoylprotein:NAD+ oxidoreductase'],
#  ['rxn06600_c',
#   '0.285892987517',
#   u'S-aminomethyldihydrolipoylprotein:(6S)-tetrahydrofolate aminomethyltransferase (ammonia-forming)'],
#  ['rxn03147_c',
#   '0.283941817181',
#   u'1-(5-Phosphoribosyl)-5-amino-4-carboxyimidazole:L-aspartate ligase (ADP-forming)'],
#  ['rxn03886_c',
#   '0.276848792906',
#   u'D-sorbitol-6-phosphate:NAD 2-oxidoreductase'],
#  ['rxn00242_c',
#   '0.261571195083',
#   u"guanosine-3',5'-bis(diphosphate) 3'-diphosphohydrolase"],
#  ['rxn12008_c', '0.25396832566', u'R05611'],
#  ['rxn01486_c',
#   '0.25396832566',
#   u'trans,trans-Farnesyl-diphosphate:isopentenyl-diphosphate farnesyltranstransferase'],
#  ['rxn03891_c', '0.25396832566', u'R05612'],
#  ['rxn05287_c',
#   '0.25396832566',
#   u'geranylgeranyl-diphosphate:isopentenyl-diphosphate transtransferase'],
#  ['rxn03892_c', '0.25396832566', u'R05613'],
#  ['rxn08934_c', '0.250494720902', u'Maltodextrin glucosidase (maltopentaose)'],
#  ['rxn01259_c', '0.250494720902', u'Isomaltose 6-alpha-D-glucanohydrolase'],
#  ['rxn05746_c', '0.250494720902', u'Maltodextrin glucosidase (maltotriose)'],
#  ['rxn09989_c', '0.250494720902', u'Maltodextrin glucosidase (dextrin)'],
#  ['rxn08935_c', '0.250494720902', u'Maltodextrin glucosidase (maltohexaose)'],
#  ['rxn00575_c', '0.250494720902', u'sucrose glucohydrolase'],
# ...
#  ['rxn05544_c', '0.00850867089824', u'oligopeptide-transporting ATPase'],
#  ['rxn05537_c', '0.00850867089824', u'oligopeptide-transporting ATPase'],
#  ['rxn05538_c',
#   '0.00850867089824',
#   u'Dipeptide transport via ABC system (gly-pro-L)'],
#  ['rxn12849_c', '0.00850867089824', u'Gly-Leu ABC transporters'],
#  ['rxn05534_c',
#   '0.00850867089824',
#   u'Dipeptide transport via ABC system (gly-glu)'],
#  ['rxn05540_c', '0.00850867089824', u'oligopeptide-transporting ATPase'],
#  ['rxn05536_c',
#   '0.00850867089824',
#   u'Dipeptide transport via ABC system (met-ala)'],
#  ['rxn05546_c',
#   '0.00850867089824',
#   u'Dipeptide transport via ABC system (gly-asn)'],
#  ['rxn05543_c', '0.00850867089824', u'oligopeptide-transporting ATPase'],
#  ['rxn05617_c', '0.00840368924473', u'mannitol transport via PEP:Pyr PTS'],
#  ['rxn00147_c', '0.00833749397673', u'ATP:pyruvate,water phosphotransferase'],
#  ['rxn05485_c',
#   '0.00826071650303',
#   u'N-Acetyl-D-glucosamine transport via PEP:Pyr PTS'],
#  ['rxn00695_c',
#   '0.00799792604114',
#   u'ATP:alpha-D-glucose-1-phosphate adenylyltransferase'],
#  ['rxn03439_c',
#   '0.00798807132981',
#   u'CMP-3-deoxy-D-manno-oct-2-ulosonate:(KDO)-lipid IVA 3-deoxy-D-manno-oct-2-ulosonate transferase'],
#  ['rxn03182_c',
#   '0.00798807132981',
#   u'CMP-3-deoxy-D-manno-oct-2-ulosonate:lipid IVA 3-deoxy-D-manno-oct-2-ulosonate transferase'],
#  ['rxn00126_c', '0.00795019498015', u'ATP:L-methionine S-adenosyltransferase'],
#  ['rxn03194_c',
#   '0.00778635245161',
#   u'(S)-2-Aceto-2-hydroxybutanoate pyruvate-lyase (carboxylating)'],
#  ['rxn05334_c',
#   '0.00771469922009',
#   u'(3R)-3-Hydroxybutanoyl-[acyl-carrier-protein] hydro-lyase'],
#  ['rxn05377_c',
#   '0.00771469922009',
#   u'12-methyl-3-hydroxy-tetra-decanoyl-ACP hydro-lyase'],
#  ['rxn05427_c',
#   '0.00771469922009',
#   u'12-methyl-3-hydroxy-tridecanoyl-ACP hydro-lyase'],
#  ['rxn05369_c',
#   '0.00771469922009',
#   u'8-methyl-3-hydroxy-decanoyl-ACP hydro-lyase'],
#  ['rxn05386_c',
#   '0.00771469922009',
#   u'5-methyl-3-hydroxy-hexanoyl-ACP hydro-lyase'],
#  ['rxn05390_c',
#   '0.00771469922009',
#   u'7-methyl-3-hydroxy-octanoyl-ACP hydro-lyase'],
#  ['rxn05329_c',
#   '0.00771469922009',
#   u'(3R)-3-Hydroxybutanoyl-[acyl-carrier-protein] hydro-lyase'],
#  ['rxn05335_c',
#   '0.00771469922009',
#   u'(3R)-3-Hydroxypalmitoyl-[acyl-carrier-protein] hydro-lyase'],
#  ['rxn05419_c',
#   '0.00771469922009',
#   u'8-methyl-3-hydroxy-nonanoyl-ACP hydro-lyase'],
#  ['rxn05398_c',
#   '0.00771469922009',
#   u'11-methyl-3-hydroxy-dodecanoyl-ACP hydro-lyase'],
#  ['rxn05365_c',
#   '0.00771469922009',
#   u'6-methyl-3-hydroxy-octanoyl-ACP hydro-lyase'],
#  ['rxn05381_c',
#   '0.00771469922009',
#   u'14-methyl-3-hydroxy-hexa-decanoyl-ACP hydro-lyase'],
#  ['rxn05406_c',
#   '0.00771469922009',
#   u'15-methyl-3-hydroxy-hexa-decanoyl-ACP hydro-lyase'],
#  ['rxn05423_c',
#   '0.00771469922009',
#   u'10-methyl-3-hydroxy-undecanoyl-ACP hydro-lyase'],
#  ['rxn05402_c',
#   '0.00771469922009',
#   u'13-methyl-3-hydroxy-tetra-decanoyl-ACP hydro-lyase'],
#  ['rxn05373_c',
#   '0.00771469922009',
#   u'10-methyl-3-hydroxy-dodecanoyl-ACP hydro-lyase'],
#  ['rxn05330_c',
#   '0.00771469922009',
#   u'(3R)-3-Hydroxybutanoyl-[acyl-carrier-protein] hydro-lyase'],
#  ['rxn05411_c',
#   '0.00771469922009',
#   u'4-methyl-3-hydroxy-pentanoyl-ACP hydro-lyase'],
#  ['rxn05394_c',
#   '0.00771469922009',
#   u'9-methyl-3-hydroxy-decanoyl-ACP hydro-lyase'],
#  ['rxn05462_c', '0.00771469922009', u'trans-Octodec-2-enoyl-ACP hydro-lyase'],
#  ['rxn05331_c',
#   '0.00771469922009',
#   u'(3R)-3-Hydroxybutanoyl-[acyl-carrier-protein] hydro-lyase'],
#  ['rxn05415_c',
#   '0.00771469922009',
#   u'6-methyl-3-hydroxy-heptanoyl-ACP hydro-lyase'],
#  ['rxn05431_c',
#   '0.00771469922009',
#   u'14-methyl-3-hydroxy-pentadecanoyl-ACP hydro-lyase'],
#  ['rxn05361_c',
#   '0.00771469922009',
#   u'4-methyl-3-hydroxy-hexanoyl-ACP hydro-lyase'],
#  ['rxn05332_c',
#   '0.00771469922009',
#   u'(3R)-3-Hydroxypalmitoyl-[acyl-carrier-protein] hydro-lyase'],
#  ['rxn05333_c',
#   '0.00771469922009',
#   u'(3R)-3-Hydroxybutanoyl-[acyl-carrier-protein] hydro-lyase'],
#  ['rxn13783_c', '0.00736646954323', u'DNA replication'],
#  ['rxn01434_c',
#   '0.007302601667',
#   u'L-Citrulline:L-aspartate ligase (AMP-forming)'],
#  ['rxn00717_c', '0.00717148014155', u'Cytosine aminohydrolase'],
#  ['rxn01025_c', '0.00717148014155', u'5-Methylcytosine aminohydrolase'],
#  ['rxn04600_c',
#   '0.0067716074772',
#   u'(2E)-3-(cis-5,6-dihydroxycyclohexa-1,3-dien-1-yl)prop-2-enoate:NAD+ oxidoreductase'],
#  ['rxn04599_c',
#   '0.0067716074772',
#   u'3-(cis-5,6-dihydroxycyclohexa-1,3-dien-1-yl)propanoate:NAD+ oxidoreductase'],
#  ['rxn00832_c', '0.00663573249199', u'IMP 1,2-hydrolase (decyclizing)'],
#  ['rxn01639_c',
#   '0.00663573249199',
#   u'N-Formimino-L-glutamate formiminohydrolase'],
#  ['rxn03137_c',
#   '0.00663573249199',
#   u"10-Formyltetrahydrofolate:5'-phosphoribosyl-5-amino-4-imidazolecarboxamide formyltransferase"],
#  ['rxn13784_c', '0.00660414377165', u'RNA transcription'],
#  ['rxn01041_c', '0.00621286834615', u'D-xylose:NAD+ 1-oxidoreductase'],
#  ['rxn01775_c', '0.00606341204163', u'D-Mannonate:NAD+ 5-oxidoreductase'],
#  ['rxn00420_c', '0.00589077956579', u'O-phospho-L-serine phosphohydrolase'],
#  ['rxn00503_c',
#   '0.0058633758245',
#   u'(S)-1-pyrroline-5-carboxylate:NAD+ oxidoreductase'],
#  ['rxn00183_c',
#   '0.0058633758245',
#   u'L-Glutamate 5-semialdehyde:NAD+ oxidoreductase'],
#  ['rxn00205_c',
#   '0.00552808617191',
#   u'glutathione:hydrogen-peroxide oxidoreductase'],
#  ['rxn01739_c', '0.00545235447039', u'ATP:shikimate 3-phosphotransferase'],
#  ['rxn03511_c',
#   '0.00534470582351',
#   u'ADP-D-glycero-D-manno-heptose 6-epimerase'],
#  ['rxn00151_c',
#   '0.00517237538541',
#   u'ATP:pyruvate,phosphate phosphotransferase'],
#  ['rxn10122_c',
#   '0.00508484017561',
#   u'NADH dehydrogenase (ubiquinone-8 & 3.5 protons)'],
#  ['rxn05392_c',
#   '0.00497347941456',
#   u'7-methyl-octanoyl-ACP:malonyl-[acyl-carrier-protein] C-acyltransferase (decarboxylating)'],
#  ['rxn05367_c',
#   '0.00497347941456',
#   u'6-methyl-octanoyl-ACP:malonyl-[acyl-carrier-protein] C-acyltransferase (decarboxylating)'],
#  ['rxn05404_c',
#   '0.00497347941456',
#   u'13-methyl-tetra-decanoyl-ACP:malonyl-[acyl-carrier-protein] C-acyltransferase (decarboxylating)'],
#  ['rxn05400_c',
#   '0.00497347941456',
#   u'11-methyl-dodecanoyl-ACP:malonyl-[acyl-carrier-protein] C-acyltransferase (decarboxylating)'],
#  ['rxn05409_c',
#   '0.00497347941456',
#   u'2-methylpropionyl-ACP:malonyl-[acyl-carrier-protein] C-acyltransferase (decarboxylating)'],
#  ['rxn05413_c',
#   '0.00497347941456',
#   u'4-methyl-pentanoyl-ACP:malonyl-[acyl-carrier-protein] C-acyltransferase (decarboxylating)'],
#  ['rxn05417_c',
#   '0.00497347941456',
#   u'6-methyl-heptanoyl-ACP:malonyl-[acyl-carrier-protein] C-acyltransferase (decarboxylating)'],
#  ['rxn05359_c',
#   '0.00497347941456',
#   u'4-methyl-3-oxo-hexanoyl-ACP:malonyl-[acyl-carrier-protein] C-acyltransferase (decarboxylating)'],
#  ['rxn05371_c',
#   '0.00497347941456',
#   u'8-methyl-decanoyl-ACP:malonyl-[acyl-carrier-protein] C-acyltransferase (decarboxylating)'],
#  ['rxn05396_c',
#   '0.00497347941456',
#   u'9-methyl-decanoyl-ACP:malonyl-[acyl-carrier-protein] C-acyltransferase (decarboxylating)'],
#  ['rxn05429_c',
#   '0.00497347941456',
#   u'12-methyl-tridecanoyl-ACP:malonyl-[acyl-carrier-protein] C-acyltransferase (decarboxylating)'],
#  ['rxn05388_c',
#   '0.00497347941456',
#   u'5-methyl-hexanoyl-ACP:malonyl-[acyl-carrier-protein] C-acyltransferase (decarboxylating)'],
#  ['rxn05363_c',
#   '0.00497347941456',
#   u'4-methyl-hexanoyl-ACP:malonyl-[acyl-carrier-protein] C-acyltransferase (decarboxylating)'],
#  ['rxn05460_c',
#   '0.00497347941456',
#   u'3-Oxooctodecanoyl-ACP:malonyl-[acyl-carrier-protein] C-acyltransferase (decarboxylating)'],
#  ['rxn05349_c',
#   '0.00497347941456',
#   u'acetyl-CoA:[acyl-carrier-protein] S-acetyltransferase'],
#  ['rxn05379_c',
#   '0.00497347941456',
#   u'12-methyl-tetra-decanoyl-ACP:malonyl-[acyl-carrier-protein] C-acyltransferase (decarboxylating)'],
#  ['rxn05375_c',
#   '0.00497347941456',
#   u'10-methyl-dodecanoyl-ACP:malonyl-[acyl-carrier-protein] C-acyltransferase (decarboxylating)'],
#  ['rxn05425_c',
#   '0.00497347941456',
#   u'10-methyl-undecanoyl-ACP:malonyl-[acyl-carrier-protein] C-acyltransferase (decarboxylating)'],
#  ['rxn05384_c',
#   '0.00497347941456',
#   u'3-methylbutanoyl-ACP:malonyl-[acyl-carrier-protein] C-acyltransferase (decarboxylating)'],
#  ['rxn05421_c',
#   '0.00497347941456',
#   u'8-methyl-nonanoyl-ACP:malonyl-[acyl-carrier-protein] C-acyltransferase (decarboxylating)'],
#  ['rxn00991_c',
#   '0.00472615403809',
#   u'(S)-3-hydroxy-3-methylglutaryl-CoA acetoacetate-lyase (acetyl-CoA-forming)'],
#  ['rxn02213_c', '0.0045978486364', u'3-Dehydroquinate hydro-lyase'],
#  ['rxn00917_c',
#   '0.00456678698551',
#   u"Xanthosine-5'-phosphate:L-glutamine amido-ligase (AMP-forming)"],
#  ['rxn00013_c',
#   '0.00441629766858',
#   u'D-Glucose-1-phosphate:D-glucose-1-phosphate 6-phosphotransferase'],
#  ['rxn00705_c',
#   '0.00441629766858',
#   u'D-Glucose-1-phosphate:D-glucose-1-phosphate 6-phosphotransferase'],
#  ['rxn01791_c',
#   '0.00440398464133',
#   u'(R)-Pantoate:beta-alanine ligase (AMP-forming)'],
#  ['rxn00501_c',
#   '0.00437425593219',
#   u'3-Oxopropanoate:NAD+ oxidoreductase (decarboxylating, CoA-acetylating)'],
#  ['rxn00671_c',
#   '0.00437425593219',
#   u'2-Methyl-3-oxopropanoate:NAD+ oxidoreductase (CoA-propanoylating)'],
#  ['rxn01117_c',
#   '0.00427950052905',
#   u'D-arabinose-5-phosphate aldose-ketose-isomerase'],
#  ['rxn05557_c',
#   '0.00419921600796',
#   u'iron (III) dicitrate transport via ABC system'],
#  ['rxn10147_c', '0.0040956985256', u'ABC-5-RXN.cp'],
#  ['rxn05515_c',
#   '0.0040956985256',
#   u'ATP phosphohydrolase (vitamin B12-importing)'],
#  ['rxn05187_c', '0.0040956985256', u'Vitamin ABC transport'],
#  ['rxn01355_c',
#   '0.00408495357116',
#   u'Propanoyl-CoA:carbon-dioxide ligase (ADP-forming)'],
#  ['rxn02938_c',
#   '0.00402643018921',
#   u'1-(5-phospho-D-ribosyl)-5-amino-4-imidazolecarboxylate carboxy-lyase'],
#  ['rxn05229_c', '0.00402643018921', u'NCAIR synthetase and NCAIR mutase'],
#  ['rxn02832_c',
#   '0.00380089476028',
#   u'(1R,6R)-6-hydroxy-2-succinylcyclohexa-2,4-diene-1-carboxylate hydrolyase (2-succinylbenzoate-forming)'],
#  ['rxn08094_c', '0.00371314545305', u'2-Oxoglutarate dehydrogenase complex'],
#  ['rxn03910_c',
#   '0.00353860064779',
#   u"2-Phospho-4-(cytidine 5'-diphospho)-2-C-methyl-D-erythritol CMP-lyase (cyclizing)"],
#  ['rxn02362_c', '0.00353860064779', u'R03298'],
#  ['rxn05188_c', '0.00350038921214', u'ferrichrome transport via ABC system'],
#  ['rxn02302_c',
#   '0.003413853885655',
#   u'O-Acetyl-L-homoserine succinate-lyase (adding cysteine)'],
#  ['rxn00740_c',
#   '0.003413853885655',
#   u'O-Succinyl-L-homoserine succinate-lyase (deaminating; 2-oxobutanoate-forming)'],
#  ['rxn01816_c', '0.003413853885655', u'R02508'],
#  ['rxn01225_c', '0.003275192966615', u'Guanine aminohydrolase'],
#  ['rxn05177_c', '0.003250298750165', u'thiamine transport via ABC system'],
#  ['rxn13782_c', '0.00323240826845', u'Protein biosynthesis'],
#  ['rxn02475_c',
#   '0.00320748865019',
#   u'2,5-Diamino-6-hydroxy-4-(5-phosphoribosylamino)-pyrimidine 2-aminohydrolase'],
#  ['rxn02474_c',
#   '0.00320748865019',
#   u"5-amino-6-(5-phosphoribitylamino)uracil:NADP+ 1'-oxidoreductase"],
#  ['rxn00802_c',
#   '0.00316993297762',
#   u'2-(Nomega-L-arginino)succinate arginine-lyase (fumarate-forming)'],
#  ['rxn06078_c',
#   '0.00309272704229',
#   u'O-acetyl-L-homoserine acetate-lyase (L-homocysteine forming)'],
#  ['rxn00952_c',
#   '0.00309272704229',
#   u'O-acetyl-L-homoserine:hydrogen sulfide S-(3-amino-3-carboxypropyl)transferase'],
#  ['rxn00371_c', '0.00306984783041', u'Formate:NAD+ oxidoreductase'],
#  ['rxn09188_c', '0.00303528284823', u'Proline dehydrogenase'],
#  ['rxn02359_c',
#   '0.00303528284823',
#   u'trans-4-Hydroxy-L-proline:(acceptor) oxidoreductase'],
#  ['rxn01879_c', '0.00296024527041', u'Propane-1,2-diol:NAD+ 1-oxidoreductase'],
#  ['rxn04385_c',
#   '0.00290921152991',
#   u'L-threonine-O-3-phosphate carboxy-lyase'],
#  ['rxn01871_c',
#   '0.00289285667736',
#   u'acetyl-CoA:enzyme N6-(dihydrolipoyl)lysine S-acetyltransferase'],
#  ['rxn01322_c',
#   '0.00279502143372',
#   u'N-Acetylneuraminate pyruvate-lyase (N-acetyl-D-mannosamine-forming)'],
#  ['rxn07879_c',
#   '0.00279502143372',
#   u'3-hydroxy-3-(4-methylpent-3-en-1-yl)glutaryl-CoA acetate-lyase (7-methyl-3-oxooct-6-enoyl-CoA-forming)'],
#  ['rxn00784_c',
#   '0.00274263839777',
#   u'2-deoxy-D-ribose-5-phosphate acetaldehyde-lyase (D-glyceraldehyde-3-phosphate-forming)'],
#  ['rxn00165_c', '0.00267525236937', u'L-serine ammonia-lyase'],
#  ['rxn00837_c',
#   '0.00258921610525',
#   u"inosine-5'-phosphate:NADP+ oxidoreductase (aminating)"],
#  ['rxn00572_c', '0.00258921610525', u'nitrite:NADP+ oxidoreductase'],
#  ['rxn02342_c', '0.00256081381569', u'R03270'],
#  ['rxn00508_c',
#   '0.00243687684962',
#   u'Succinate-semialdehyde:NAD+ oxidoreductase'],
#  ['rxn00526_c', '0.00239487451518', u'L-arogenate:NADP+ oxidoreductase'],
#  ['rxn00525_c', '0.00239487451518', u'L-arogenate:NAD+ oxidoreductase'],
#  ['rxn07587_c',
#   '0.00223670702147',
#   u'S-adenosyl-L-methionine:cobalt-precorrin-5B (C1)-methyltransferase'],
#  ['rxn01274_c', '0.00222111871165', u'(R)-S-Lactoylglutathione hydrolase'],
#  ['rxn07584_c', '0.00213698697822', u'ATP:lipoate adenylyltransferase'],
#  ['rxn02286_c',
#   '0.0019410860663',
#   u'UDP-N-acetylmuramate:L-alanine ligase (ADP-forming)'],
#  ['rxn04070_c', '0.00182325407001', u"pyridoxine 5'-phosphate synthase"],
#  ['rxn00533_c',
#   '0.00181938266',
#   u'Acetyl-CoA:carbon-dioxide ligase (ADP-forming)'],
#  ['rxn09953_c', '0.00172095083412', u'acetyl-CoA:acetoin O-acetyltransferase'],
#  ['rxn02831_c',
#   '0.00163184573206',
#   u'O-Succinylbenzoate:CoA ligase (AMP-forming)'],
#  ['rxn10344_c', '0.00162835877004', u'Lead (Pb+2) ABC transporter'],
#  ['rxn05516_c', '0.00162835877004', u'Cadmium-translocating P-type ATPase'],
#  ['rxn10481_c', '0.00162835877004', u'Copper transport via ABC system'],
#  ['rxn05528_c', '0.00162835877004', u'Copper-transporting ATPase'],
#  ['rxn10343_c',
#   '0.00162835877004',
#   u'Mercury (Hg+2) ABC transporter (periplasm)'],
#  ['rxn02404_c',
#   '0.00153387265393',
#   u'3-Deoxy-D-manno-octulosonate-8-phosphate 8-phosphohydrolase'],
#  ['rxn00250_c',
#   '0.001460191349755',
#   u'Pyruvate:carbon-dioxide ligase (ADP-forming)'],
#  ['rxn08118_c', '0.00137801883324', u'D-allulose-6-phosphate 3-epimerase'],
#  ['rxn07488_c', '0.00137801883324', u'R07673'],
#  ['rxn14112_c',
#   '0.00137801883324',
#   u'dTDP-4-oxo-2,6-dideoxy-D-glucose 3,5-epimerase'],
#  ['rxn03816_c',
#   '0.00137801883324',
#   u'dTDP-4-oxo-2,6-dideoxy-D-glucose 5-epimerase'],
#  ['rxn14342_c',
#   '0.00137801883324',
#   u'UDP-N-acetyl-D-glucosaminuronate 4-epimerase'],
#  ['rxn00779_c',
#   '0.0013209788957',
#   u'D-glyceraldehyde 3-phosphate:NADP+ oxidoreductase'],
#  ['rxn00727_c',
#   '0.00130293854913',
#   u'Chorismate pyruvate-lyase (amino-accepting)'],
#  ['rxn00726_c',
#   '0.00130293854913',
#   u'chorismate pyruvate-lyase (amino-accepting; anthranilate-forming)'],
#  ['rxn02270_c', '0.00129603973425', u'Branched-chain acyl-CoA dehydrogenase'],
#  ['rxn01924_c', '0.00129603973425', u'isobutyryl-CoA dehydrogenase'],
#  ['rxn03884_c',
#   '0.0012940262267',
#   u'2-dehydro-3-deoxy-D-gluconate-6-phosphate D-glyceraldehyde-3-phosphate-lyase'],
#  ['rxn00328_c',
#   '0.0012940262267',
#   u'4-hydroxy-2-oxoglutarate glyoxylate-lyase (pyruvate-forming)'],
#  ['rxn03080_c',
#   '0.00125410836221',
#   u'5-amino-6-(D-ribitylamino)uracil butanedionetransferase'],
#  ['rxn04020_c',
#   '0.001152177890845',
#   u'trehalose 6-phosphate:phosphate b-D-glucosyltransferase'],
#  ['rxn05585_c',
#   '0.00112844321093',
#   u'hexanesulfonate transport via ABC system'],
#  ['rxn05552_c',
#   '0.00112844321093',
#   u'ethanesulfonate transport via ABC system'],
#  ['rxn05172_c',
#   '0.00112844321093',
#   u'ATP phosphohydrolase (taurine-importing)'],
#  ['rxn05594_c', '0.00112844321093', u'Isethionate transport via ABC system'],
#  ['rxn05512_c',
#   '0.00112844321093',
#   u'butanesulfonate transport via ABC system'],
#  ['rxn05599_c', '0.00112844321093', u'cysteate transport via ABC system'],
#  ['rxn05620_c', '0.00112844321093', u'MOPS transport via ABC system'],
#  ...]

# %%
universal.reactions.get_by_id('rxn10338_c').name
# Out:
# u'anteisoheptadecanoyl-cardiolipin synthase'
