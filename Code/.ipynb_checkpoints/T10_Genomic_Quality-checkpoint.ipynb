# %%
from __future__ import print_function

import cobra
import cobra.test
import mackinac
import numpy as np
import csv
import glob
import pickle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
mackinac.get_token('tjmoutinho')

# %%
#!/usr/bin/python2.7
'''USAGE: contigStats.py seqFile
This script calculates various statistics about the provided fasta or fastq file.
'''
import sys
import math

# This function reads in fasta file, appends the length of each sequence to a list, and counts all Gs & Cs.
        # It returns a sorted list of sequence lengths with the G+C % as the last element.
def read_lengths(fasta):

        len_lst = []
        gc_cnt = 0
        n_cnt = 0
        all_cnt = 0
        seq = ''
        firstLine = 'placeholder'
        while firstLine[0] != '>' or firstLine == '\n':
                firstLine = fasta.readline()

        for line in fasta:
                if line[0] == '>': 
                        gc_cnt += seq.count('G')
                        gc_cnt += seq.count('C')
                        n_cnt += seq.count('N')
                        all_cnt += len(seq)
                        len_lst.append(len(seq))
                        seq = ''
                else:
                        seq += line.strip().upper()

        gc_cnt += seq.count('G')
        gc_cnt += seq.count('C')
        n_cnt += seq.count('N')
        all_cnt += len(seq)
        len_lst.append(len(seq))

        gc_prcnt = round((float(gc_cnt) / float(all_cnt)) * 100.0, 2)
        len_lst.sort()

        return(len_lst, gc_prcnt, n_cnt)


# Function t0 calculate standard deviation for a list of numbers
def standDev(values):
        x_mean = sum(values) / len(values)
        sd_list = []
        for x in values:
                y = (x - x_mean) ** 2
                sd_list.append(y)
        y_mean = sum(sd_list) / len(sd_list)   
        sd = math.sqrt(y_mean)
        return(sd)


# This function calculates and returns all the printed statistics.
def calc_stats(lengths):

#         shortest = lengths[0]
#         longest = lengths[-1]
#         total_contigs = len(lengths) # Total number of sequences
        len_sum = sum(lengths) # Total number of residues
        total_Mb = len_sum/1000000.00 # Total number of residues expressed in Megabases
#         mid_pos = int(round(total_contigs/2))

#         median_len = lengths[mid_pos] # Median sequence length
#         q1 = lengths[0:mid_pos][int(len(lengths[0:mid_pos])/2)]
#         q3 = lengths[mid_pos:-1][int(len(lengths[mid_pos:-1])/2)]
#         iqr = q3 - q1

#         mean_len = sum(lengths) / len(lengths)
#         sd = standDev(lengths)

#         # Pearsons Coefficient of Skewness
#         skew = ((mean_len - median_len) * 3) / sd
#         mean_len = round(mean_len, 2)
#         sd = round(sd, 2)
#         skew = round(skew, 3)
 
#         current_bases = 0
#         n50 = 0
#         n90 = 0
#         seqs_1000 = 0
#         seqs_5000 = 0
#         seqs_10000 = 0
#         percent50_bases = int(round(len_sum*0.5))
#         percent90_bases = int(round(len_sum*0.1))

#         for x in lengths:

#                 current_bases += x

#                 if x > 1000:
#                         seqs_1000 += 1
#                 if x > 5000:
#                         seqs_5000 += 1
#                 if x > 10000:
#                         seqs_10000 += 1

#                 if current_bases >= percent50_bases and n50 == 0:
#                         n50 = x
#                 if current_bases >= percent90_bases and n90 == 0:
#                         n90 = x

#         l50 = lengths.count(n50)
#         short_contigs = total_contigs - seqs_1000

#         return(total_contigs, total_Mb, n50, l50, n90, median_len, q1, q3, iqr, seqs_1000, seqs_5000, seqs_10000, shortest, longest, mean_len, sd, skew, short_contigs)
        return(total_Mb)

def frange(start, stop, step):
    i = start
    while i < stop:
        yield i
        i += step

# %%
fasta_file_paths = glob.glob('../nt_fastas/*.faa')

total_dataset_dict = {}
passed = []
# input_file = fasta_file_paths[2]
for input_file in fasta_file_paths:
    with open(input_file, 'r') as contigs:
            contig_lengths, gc_content, n_count = read_lengths(open(input_file, 'r'))

#     if len(contig_lengths) < 5:
#             print('\nToo few contigs in ' + str(input_file) + ' to calculate useful statistics. Exiting.\n')
#             sys.exit()

#     stat_list = calc_stats(contig_lengths)
#     stat_list = list(stat_list)
#     stat_list.append(gc_content)
#     stat_list.append(n_count)

    # output_string = """
    # Assembly:       {filename}
    # Contigs:        {total_contigs}
    # Bases(Mb):      {total_mb}
    # Ns:             {ns}
    # G+C(%):         {gc}
    # -----------------------------------
    # N50:            {n50}
    # L50:            {l50}
    # N90:            {n90}
    # -----------------------------------
    # Median:         {median_len}
    # Q1:             {q1}
    # Q3:             {q3}
    # IQR:            {iqr}
    # Mean:           {mean}
    # Std:            {sd}
    # Skewness:       {skewness}
    # -----------------------------------
    # Shortest:       {short}
    # Longest:        {long}
    # Contigs<1kb:    {short_contigs}
    # Contigs>1kb:    {seqs_1k}
    # Contigs>5kb:    {seqs_5k}
    # Contigs>10kb:   {seqs_10k}

    # ###################################""".format(filename = str(input_file).split('/')[-1],  
    #         total_contigs = stat_list[0], 
    #         total_mb = "%.2f" % stat_list[1], 
    #         n50 = stat_list[2],
    #         l50 = stat_list[3],
    #         n90 = stat_list[4],
    #         median_len = stat_list[5], 
    #         q1 = stat_list[6], 
    #         q3 = stat_list[7],
    #         iqr = stat_list[8],
    #         mean = stat_list[14],
    #         sd = stat_list[15],
    #         skewness = stat_list[16],
    #         short = stat_list[12], 
    #         long = stat_list[13],
    #         short_contigs = stat_list[17], 
    #         seqs_1k = stat_list[9], 
    #         seqs_5k = stat_list[10],
    #         seqs_10k = stat_list[11],
    #         gc = stat_list[18],
    #         ns = stat_list[19])

    # print(output_string)
    try:
        filename = str(input_file).split('/')[-1]
        genome_id = filename.replace(".faa","")

        output = mackinac.get_genome_summary(genome_id)
        output['contigs']

        dict_out = {}
        dict_out['Model_ID'] = genome_id
        dict_out['Ns'] = n_count
        dict_out['GC'] = gc_content
        dict_out['contigs'] = output['contigs']
        dict_out['sequences'] = output['sequences']
        dict_out['Mb'] = calc_stats(contig_lengths)

        dict_out_ID = genome_id
        total_dataset_dict[dict_out_ID] = dict_out
    except:
        passed.append(str(input_file).split('/')[-1])

# %%
len(passed)
# Out:
# 24

# %%
passed
# Out:
# ['1598.339.faa',
#  '1624.68.faa',
#  '1679.51.faa',
#  '1680.108.faa',
#  '1681.109.faa',
#  '1681.114.faa',
#  '1682.37.faa',
#  '1685.178.faa',
#  '1685.179.faa',
#  '1685.180.faa',
#  '1685.181.faa',
#  '1685.182.faa',
#  '1685.183.faa',
#  '1685.184.faa',
#  '216816.254.faa',
#  '216816.255.faa',
#  '216816.256.faa',
#  '216816.257.faa',
#  '216816.258.faa',
#  '216816.259.faa',
#  '216816.260.faa',
#  '216816.261.faa',
#  '216816.262.faa',
#  '302911.62.faa']

# %%
# fasta_file_paths = glob.glob('../nt_fastas/*.faa')
# fasta_genome_ids = [x.replace("../nt_fastas/","").replace(".faa","") for x in fasta_file_paths]

# Mbs = []
# contigs = []
# sequences = []
# GC_content = []
# Ns_all = []
# percent_n = []
# complete_genomes = []

# for genome_id in fasta_genome_ids:
#     try:
#         mb_temp = total_dataset_dict[genome_id]['Mb']
#         Mbs.append(mb_temp)
#         sequences.append(total_dataset_dict[genome_id]['sequences'])
#         GC_content.append(total_dataset_dict[genome_id]['GC'])
#         n_temp = total_dataset_dict[genome_id]['Ns']
#         Ns_all.append(n_temp)
#         percent_n_temp = round(n_temp/(mb_temp*1000000), 4)
#         percent_n.append(percent_n_temp)
#         if total_dataset_dict[genome_id]['sequences'] == 1:
#             complete_genomes.append(genome_id)
            
#     except:
#         pass

# # Read in Meta
# with open('../Data/PATRIC_genome_1508_with_meta_short_1023_slim.csv','r') as csvfile:
#     species_dict = {}
#     line_count = 0
#     for line in csvfile:
#         if line_count == 0:
#             line_count = 1
#             continue
#         if str(line.strip()).split(",")[0] in set(complete_genomes):
#             species_dict[str(line.strip()).split(",")[0]] = str(line.strip()).split(",")[1]

# plt.hist(Mbs, bins='auto')  #list(frange(0,1.05,0.05)), range=(0,1)
# plt.title("Mega-bases")
# plt.show()

# plt.hist(GC_content, bins='auto')  #list(frange(0,1.05,0.05)), range=(0,1)
# plt.title("GC_content")
# plt.show()

# %%
# def species_gc_plot(species_of_interest, species_dict, total_dataset_dict):
#     genome_id_int = []
#     for key in species_dict.keys():
#         if species_dict[key] == species_of_interest:
#             genome_id_int.append(key)
#     GC_content = []
#     for genome_id in set(genome_id_int):
#         if genome_id == '1579.33' or genome_id == '29397.12' or genome_id == '1613.113' or genome_id == '47715.249':
#             continue
#         GC_content.append(total_dataset_dict[genome_id]['GC'])
#     ref_GC = np.mean(GC_content)

#     species_GC_spread = []
#     with open('../Data/PATRIC_genome_1508_with_meta_short_1023_slim.csv','r') as csvfile:
#         line_count = 0
#         for line in csvfile:
#             if line_count == 0:
#                 line_count = 1
#                 continue
#             genome_id = str(line.strip()).split(",")[0]
#             species_in_question = str(line.strip()).split(",")[1]
#     #         print(species_in_question)
#             if species_in_question == species_of_interest:
#                 try:
#                     species_GC_spread.append(total_dataset_dict[genome_id]['GC'])
#                 except:
#                     pass

#     # print(ref_GC)
    
    
#     plt.hist(GC_content, list(frange(30,55,0.5)), range=(30,55)) #
#     plt.title(species_of_interest + " GC Reference Spread")
#     plt.show()
    
#     plt.hist(species_GC_spread, list(frange(30,55,0.5)), range=(30,55)) #
#     plt.title(species_of_interest + " GC spread: Reference = " + str(ref_GC))
#     plt.show()

# %%
# # Remove outlier Acidophilus
# species_of_interest = 'acidophilus'
# for key in species_dict.keys():
#     if species_dict[key] == species_of_interest:
#         if total_dataset_dict[key]['GC'] > 50:
#             print(species_of_interest + ': ' + key)
            
# # Remove outlier Acidophilus
# species_of_interest = 'delbrueckii'
# for key in species_dict.keys():
#     if species_dict[key] == species_of_interest:
#         if total_dataset_dict[key]['GC'] < 46:
#             print(species_of_interest + ': ' + key)

# # Remove outlier Fermentum
# species_of_interest = 'fermentum'
# for key in species_dict.keys():
#     if species_dict[key] == species_of_interest:
#         if total_dataset_dict[key]['GC'] < 46:
#             print(species_of_interest + ': ' + key)
            
# # Remove outlier rhamnosus
# species_of_interest = 'rhamnosus'
# for key in species_dict.keys():
#     if species_dict[key] == species_of_interest:
#         if total_dataset_dict[key]['GC'] < 47:
#             print(species_of_interest + ': ' + key)

# %%
# species_w_refs = []
# for key in species_dict.keys():
#     species_w_refs.append(species_dict[key])
# species_w_refs = set(species_w_refs)

# for species_of_interest in species_w_refs:
#     species_gc_plot(species_of_interest, species_dict, total_dataset_dict)
    
# Expecting to lose 15 genomes

# %%
# plt.hist(sequences, bins='auto')  #list(frange(0,1.05,0.05)), range=(0,1)
# plt.title("sequences")
# plt.show()

# %%
# contigs_to_keep = []
# count = 0
# for n in sequences:
#     if n < 301:
#         contigs_to_keep.append(n)
#     else:
#         count = count + 1
# print(len(contigs_to_keep))
# print(count)

# %%
# plt.hist(contigs_to_keep, bins='auto')  #list(frange(0,1.05,0.05)), range=(0,1)
# plt.title("sequences")
# plt.show()

# %%
# percent_n_bad = []
# count = 0
# for n in percent_n:
#     if n > .0005:
#         percent_n_bad.append(n)
#     else:
#         count = count + 1
# print(len(percent_n_bad))
# print(count)

# %%
# plt.hist(percent_n, bins=list(frange(0,.01,0.0001)), range=(0,0.01))  #list(frange(0,1.05,0.05)), range=(0,1)
# plt.title("Percent_Ns")
# plt.show()

# %%
total_dataset_dict
# Out:
# {'1582.99': {'GC': 48.76,
#   'Mb': 2.809158,
#   'Model_ID': '1582.99',
#   'Ns': 0,
#   'contigs': 1,
#   'sequences': 1},
#  '1423767.3': {'GC': 38.39,
#   'Mb': 1.726345,
#   'Model_ID': '1423767.3',
#   'Ns': 502,
#   'contigs': 45,
#   'sequences': 45},
#  '1218493.3': {'GC': 35.78,
#   'Mb': 1.90267,
#   'Model_ID': '1218493.3',
#   'Ns': 39587,
#   'contigs': 7,
#   'sequences': 7},
#  '1226677.3': {'GC': 35.38,
#   'Mb': 1.811818,
#   'Model_ID': '1226677.3',
#   'Ns': 0,
#   'contigs': 19,
#   'sequences': 19},
#  '1423765.4': {'GC': 35.82,
#   'Mb': 2.455841,
#   'Model_ID': '1423765.4',
#   'Ns': 218,
#   'contigs': 28,
#   'sequences': 28},
#  '1423765.3': {'GC': 35.82,
#   'Mb': 2.432956,
#   'Model_ID': '1423765.3',
#   'Ns': 0,
#   'contigs': 30,
#   'sequences': 30},
#  '1263084.3': {'GC': 38.91,
#   'Mb': 1.637031,
#   'Model_ID': '1263084.3',
#   'Ns': 2274,
#   'contigs': 55,
#   'sequences': 55},
#  '998820.3': {'GC': 46.99,
#   'Mb': 2.779632,
#   'Model_ID': '998820.3',
#   'Ns': 1,
#   'contigs': 2,
#   'sequences': 2},
#  '596326.3': {'GC': 34.81,
#   'Mb': 2.946637,
#   'Model_ID': '596326.3',
#   'Ns': 0,
#   'contigs': 216,
#   'sequences': 216},
#  '1423773.3': {'GC': 53.43,
#   'Mb': 2.123144,
#   'Model_ID': '1423773.3',
#   'Ns': 458,
#   'contigs': 69,
#   'sequences': 69},
#  '1256217.3': {'GC': 46.67,
#   'Mb': 2.116257,
#   'Model_ID': '1256217.3',
#   'Ns': 4,
#   'contigs': 998,
#   'sequences': 998},
#  '1624.57': {'GC': 33.14,
#   'Mb': 1.805962,
#   'Model_ID': '1624.57',
#   'Ns': 2240,
#   'contigs': 50,
#   'sequences': 50},
#  '1624.56': {'GC': 33.15,
#   'Mb': 1.808333,
#   'Model_ID': '1624.56',
#   'Ns': 2348,
#   'contigs': 50,
#   'sequences': 50},
#  '1624.55': {'GC': 33.48,
#   'Mb': 1.737526,
#   'Model_ID': '1624.55',
#   'Ns': 1613,
#   'contigs': 48,
#   'sequences': 48},
#  '1624.54': {'GC': 33.29,
#   'Mb': 1.634365,
#   'Model_ID': '1624.54',
#   'Ns': 1895,
#   'contigs': 47,
#   'sequences': 47},
#  '1624.53': {'GC': 33.29,
#   'Mb': 1.627585,
#   'Model_ID': '1624.53',
#   'Ns': 1338,
#   'contigs': 45,
#   'sequences': 45},
#  '1624.52': {'GC': 33.33,
#   'Mb': 1.749671,
#   'Model_ID': '1624.52',
#   'Ns': 3178,
#   'contigs': 46,
#   'sequences': 46},
#  '1423775.4': {'GC': 38.24,
#   'Mb': 2.427055,
#   'Model_ID': '1423775.4',
#   'Ns': 280,
#   'contigs': 22,
#   'sequences': 22},
#  '1423775.5': {'GC': 38.25,
#   'Mb': 2.426704,
#   'Model_ID': '1423775.5',
#   'Ns': 0,
#   'contigs': 24,
#   'sequences': 24},
#  '1256219.3': {'GC': 47.04,
#   'Mb': 2.515893,
#   'Model_ID': '1256219.3',
#   'Ns': 0,
#   'contigs': 144,
#   'sequences': 144},
#  '1624.59': {'GC': 33.32,
#   'Mb': 1.705945,
#   'Model_ID': '1624.59',
#   'Ns': 1356,
#   'contigs': 20,
#   'sequences': 20},
#  '1624.58': {'GC': 33.29,
#   'Mb': 1.775192,
#   'Model_ID': '1624.58',
#   'Ns': 460,
#   'contigs': 51,
#   'sequences': 51},
#  '1423777.3': {'GC': 38.46,
#   'Mb': 1.817583,
#   'Model_ID': '1423777.3',
#   'Ns': 165,
#   'contigs': 43,
#   'sequences': 43},
#  '28038.49': {'GC': 42.45,
#   'Mb': 1.955364,
#   'Model_ID': '28038.49',
#   'Ns': 0,
#   'contigs': 1,
#   'sequences': 1},
#  '28038.48': {'GC': 42.93,
#   'Mb': 1.966431,
#   'Model_ID': '28038.48',
#   'Ns': 0,
#   'contigs': 2,
#   'sequences': 2},
#  '28038.42': {'GC': 42.29,
#   'Mb': 1.701278,
#   'Model_ID': '28038.42',
#   'Ns': 7221,
#   'contigs': 2,
#   'sequences': 2},
#  '552531.14': {'GC': 60.44,
#   'Mb': 1.773021,
#   'Model_ID': '552531.14',
#   'Ns': 0,
#   'contigs': 99,
#   'sequences': 99},
#  '47770.35': {'GC': 37.64,
#   'Mb': 1.978926,
#   'Model_ID': '47770.35',
#   'Ns': 1151,
#   'contigs': 258,
#   'sequences': 258},
#  '47770.33': {'GC': 37.63,
#   'Mb': 2.133515,
#   'Model_ID': '47770.33',
#   'Ns': 0,
#   'contigs': 255,
#   'sequences': 255},
#  '1585.12': {'GC': 49.68,
#   'Mb': 2.220657,
#   'Model_ID': '1585.12',
#   'Ns': 0,
#   'contigs': 536,
#   'sequences': 536},
#  '1579.56': {'GC': 35.32,
#   'Mb': 1.832321,
#   'Model_ID': '1579.56',
#   'Ns': 0,
#   'contigs': 25,
#   'sequences': 25},
#  '1585.10': {'GC': 50.75,
#   'Mb': 1.688277,
#   'Model_ID': '1585.10',
#   'Ns': 17404,
#   'contigs': 14,
#   'sequences': 14},
#  '1585.17': {'GC': 51.5,
#   'Mb': 1.635379,
#   'Model_ID': '1585.17',
#   'Ns': 0,
#   'contigs': 59,
#   'sequences': 59},
#  '1585.15': {'GC': 51.31,
#   'Mb': 1.580953,
#   'Model_ID': '1585.15',
#   'Ns': 0,
#   'contigs': 44,
#   'sequences': 44},
#  '1585.18': {'GC': 51.42,
#   'Mb': 1.5513,
#   'Model_ID': '1585.18',
#   'Ns': 2716,
#   'contigs': 56,
#   'sequences': 56},
#  '1434657.3': {'GC': 34.52,
#   'Mb': 1.487861,
#   'Model_ID': '1434657.3',
#   'Ns': 166,
#   'contigs': 74,
#   'sequences': 74},
#  '1423757.3': {'GC': 40.6,
#   'Mb': 2.232113,
#   'Model_ID': '1423757.3',
#   'Ns': 39,
#   'contigs': 125,
#   'sequences': 125},
#  '1207543.3': {'GC': 63.01,
#   'Mb': 1.587908,
#   'Model_ID': '1207543.3',
#   'Ns': 0,
#   'contigs': 571,
#   'sequences': 571},
#  '216816.127': {'GC': 60.88,
#   'Mb': 2.19579,
#   'Model_ID': '216816.127',
#   'Ns': 100,
#   'contigs': 1,
#   'sequences': 1},
#  '216816.126': {'GC': 60.85,
#   'Mb': 2.070106,
#   'Model_ID': '216816.126',
#   'Ns': 0,
#   'contigs': 1,
#   'sequences': 1},
#  '1434655.3': {'GC': 34.75,
#   'Mb': 1.527552,
#   'Model_ID': '1434655.3',
#   'Ns': 30,
#   'contigs': 65,
#   'sequences': 65},
#  '216816.128': {'GC': 60.96,
#   'Mb': 2.334618,
#   'Model_ID': '216816.128',
#   'Ns': 0,
#   'contigs': 6,
#   'sequences': 6},
#  '1685.98': {'GC': 59.76,
#   'Mb': 2.209746,
#   'Model_ID': '1685.98',
#   'Ns': 0,
#   'contigs': 1,
#   'sequences': 1},
#  '1685.99': {'GC': 59.44,
#   'Mb': 2.045993,
#   'Model_ID': '1685.99',
#   'Ns': 0,
#   'contigs': 1,
#   'sequences': 1},
#  '1685.96': {'GC': 59.44,
#   'Mb': 2.045105,
#   'Model_ID': '1685.96',
#   'Ns': 0,
#   'contigs': 1,
#   'sequences': 1},
#  '1685.97': {'GC': 59.71,
#   'Mb': 2.178621,
#   'Model_ID': '1685.97',
#   'Ns': 0,
#   'contigs': 1,
#   'sequences': 1},
#  '1685.94': {'GC': 59.44,
#   'Mb': 2.045555,
#   'Model_ID': '1685.94',
#   'Ns': 0,
#   'contigs': 1,
#   'sequences': 1},
#  '1685.95': {'GC': 59.46,
#   'Mb': 2.043116,
#   'Model_ID': '1685.95',
#   'Ns': 0,
#   'contigs': 1,
#   'sequences': 1},
#  '1685.92': {'GC': 59.44,
#   'Mb': 2.045789,
#   'Model_ID': '1685.92',
#   'Ns': 0,
#   'contigs': 1,
#   'sequences': 1},
#  '1685.93': {'GC': 59.45,
#   'Mb': 2.044054,
#   'Model_ID': '1685.93',
#   'Ns': 0,
#   'contigs': 1,
#   'sequences': 1},
#  '1685.90': {'GC': 59.55,
#   'Mb': 2.173874,
#   'Model_ID': '1685.90',
#   'Ns': 0,
#   'contigs': 1,
#   'sequences': 1},
#  '1685.91': {'GC': 59.76,
#   'Mb': 2.199728,
#   'Model_ID': '1685.91',
#   'Ns': 0,
#   'contigs': 1,
#   'sequences': 1},
#  '616990.3': {'GC': 50.31,
#   'Mb': 2.018399,
#   'Model_ID': '616990.3',
#   'Ns': 393,
#   'contigs': 167,
#   'sequences': 167},
#  '440497.10': {'GC': 35.15,
#   'Mb': 1.54363,
#   'Model_ID': '440497.10',
#   'Ns': 0,
#   'contigs': 11,
#   'sequences': 11},
#  '1226335.3': {'GC': 37.73,
#   'Mb': 2.158587,
#   'Model_ID': '1226335.3',
#   'Ns': 0,
#   'contigs': 203,
#   'sequences': 203},
#  '326425.4': {'GC': 37.79,
#   'Mb': 2.112704,
#   'Model_ID': '326425.4',
#   'Ns': 0,
#   'contigs': 1,
#   'sequences': 1},
#  '1366052.3': {'GC': 50.03,
#   'Mb': 2.508958,
#   'Model_ID': '1366052.3',
#   'Ns': 0,
#   'contigs': 116,
#   'sequences': 116},
#  '334390.5': {'GC': 53.0,
#   'Mb': 1.776952,
#   'Model_ID': '334390.5',
#   'Ns': 0,
#   'contigs': 1,
#   'sequences': 1},
#  '28025.18': {'GC': 61.05,
#   'Mb': 1.820688,
#   'Model_ID': '28025.18',
#   'Ns': 0,
#   'contigs': 3,
#   'sequences': 3},
#  '28025.19': {'GC': 61.3,
#   'Mb': 1.76528,
#   'Model_ID': '28025.19',
#   'Ns': 0,
#   'contigs': 1,
#   'sequences': 1},
#  '880633.7': {'GC': 37.71,
#   'Mb': 2.149959,
#   'Model_ID': '880633.7',
#   'Ns': 4,
#   'contigs': 4,
#   'sequences': 4},
#  '1385941.3': {'GC': 59.65,
#   'Mb': 2.04747,
#   'Model_ID': '1385941.3',
#   'Ns': 0,
#   'contigs': 1,
#   'sequences': 1},
#  '28025.12': {'GC': 61.26,
#   'Mb': 1.724356,
#   'Model_ID': '28025.12',
#   'Ns': 0,
#   'contigs': 75,
#   'sequences': 75},
#  '28025.13': {'GC': 61.26,
#   'Mb': 1.714595,
#   'Model_ID': '28025.13',
#   'Ns': 0,
#   'contigs': 46,
#   'sequences': 46},
#  '28025.10': {'GC': 61.32,
#   'Mb': 1.791374,
#   'Model_ID': '28025.10',
#   'Ns': 0,
#   'contigs': 1,
#   'sequences': 1},
#  '1318635.3': {'GC': 46.91,
#   'Mb': 2.726897,
#   'Model_ID': '1318635.3',
#   'Ns': 0,
#   'contigs': 2,
#   'sequences': 2},
#  '1339267.4': {'GC': 53.52,
#   'Mb': 1.61446,
#   'Model_ID': '1339267.4',
#   'Ns': 0,
#   'contigs': 445,
#   'sequences': 445},
#  '930942.3': {'GC': 42.14,
#   'Mb': 1.696625,
#   'Model_ID': '930942.3',
#   'Ns': 0,
#   'contigs': 32,
#   'sequences': 32},
#  '518634.19': {'GC': 59.67,
#   'Mb': 1.990015,
#   'Model_ID': '518634.19',
#   'Ns': 0,
#   'contigs': 29,
#   'sequences': 29},
#  '1263057.3': {'GC': 60.29,
#   'Mb': 1.710593,
#   'Model_ID': '1263057.3',
#   'Ns': 2486,
#   'contigs': 124,
#   'sequences': 124},
#  '1590.323': {'GC': 45.22,
#   'Mb': 3.180781,
#   'Model_ID': '1590.323',
#   'Ns': 0,
#   'contigs': 29,
#   'sequences': 29},
#  '1590.326': {'GC': 45.07,
#   'Mb': 3.032612,
#   'Model_ID': '1590.326',
#   'Ns': 0,
#   'contigs': 92,
#   'sequences': 92},
#  '1590.327': {'GC': 44.95,
#   'Mb': 3.149314,
#   'Model_ID': '1590.327',
#   'Ns': 0,
#   'contigs': 234,
#   'sequences': 234},
#  '1590.324': {'GC': 45.52,
#   'Mb': 2.841095,
#   'Model_ID': '1590.324',
#   'Ns': 0,
#   'contigs': 77,
#   'sequences': 77},
#  '1590.325': {'GC': 45.47,
#   'Mb': 2.821518,
#   'Model_ID': '1590.325',
#   'Ns': 0,
#   'contigs': 74,
#   'sequences': 74},
#  '1590.328': {'GC': 45.61,
#   'Mb': 2.796029,
#   'Model_ID': '1590.328',
#   'Ns': 0,
#   'contigs': 60,
#   'sequences': 60},
#  '1590.329': {'GC': 45.61,
#   'Mb': 2.805432,
#   'Model_ID': '1590.329',
#   'Ns': 0,
#   'contigs': 63,
#   'sequences': 63},
#  '1580.49': {'GC': 46.51,
#   'Mb': 2.244658,
#   'Model_ID': '1580.49',
#   'Ns': 26,
#   'contigs': 110,
#   'sequences': 110},
#  '1423804.4': {'GC': 48.09,
#   'Mb': 2.962743,
#   'Model_ID': '1423804.4',
#   'Ns': 3575,
#   'contigs': 181,
#   'sequences': 181},
#  '1423804.3': {'GC': 48.12,
#   'Mb': 2.920777,
#   'Model_ID': '1423804.3',
#   'Ns': 0,
#   'contigs': 176,
#   'sequences': 176},
#  '1256205.3': {'GC': 46.95,
#   'Mb': 2.597257,
#   'Model_ID': '1256205.3',
#   'Ns': 1,
#   'contigs': 188,
#   'sequences': 188},
#  '83526.5': {'GC': 35.82,
#   'Mb': 2.470559,
#   'Model_ID': '83526.5',
#   'Ns': 0,
#   'contigs': 37,
#   'sequences': 37},
#  '83526.4': {'GC': 35.92,
#   'Mb': 2.5885,
#   'Model_ID': '83526.4',
#   'Ns': 0,
#   'contigs': 29,
#   'sequences': 29},
#  '1256203.3': {'GC': 46.91,
#   'Mb': 2.478069,
#   'Model_ID': '1256203.3',
#   'Ns': 0,
#   'contigs': 295,
#   'sequences': 295},
#  '1423821.4': {'GC': 41.05,
#   'Mb': 1.52416,
#   'Model_ID': '1423821.4',
#   'Ns': 439,
#   'contigs': 24,
#   'sequences': 24},
#  '1582.49': {'GC': 46.81,
#   'Mb': 2.645224,
#   'Model_ID': '1582.49',
#   'Ns': 10124,
#   'contigs': 194,
#   'sequences': 194},
#  '1582.48': {'GC': 47.24,
#   'Mb': 2.586565,
#   'Model_ID': '1582.48',
#   'Ns': 0,
#   'contigs': 86,
#   'sequences': 86},
#  '1590.185': {'GC': 46.1,
#   'Mb': 2.588064,
#   'Model_ID': '1590.185',
#   'Ns': 0,
#   'contigs': 1,
#   'sequences': 1},
#  '1590.180': {'GC': 45.53,
#   'Mb': 2.856361,
#   'Model_ID': '1590.180',
#   'Ns': 0,
#   'contigs': 27,
#   'sequences': 27},
#  '1590.181': {'GC': 45.54,
#   'Mb': 2.803474,
#   'Model_ID': '1590.181',
#   'Ns': 0,
#   'contigs': 25,
#   'sequences': 25},
#  '879297.3': {'GC': 33.1,
#   'Mb': 1.161054,
#   'Model_ID': '879297.3',
#   'Ns': 0,
#   'contigs': 92,
#   'sequences': 92},
#  '1582.47': {'GC': 47.07,
#   'Mb': 2.770243,
#   'Model_ID': '1582.47',
#   'Ns': 199,
#   'contigs': 58,
#   'sequences': 58},
#  '1582.46': {'GC': 48.73,
#   'Mb': 2.633458,
#   'Model_ID': '1582.46',
#   'Ns': 0,
#   'contigs': 26,
#   'sequences': 26},
#  '1597.112': {'GC': 46.82,
#   'Mb': 2.885802,
#   'Model_ID': '1597.112',
#   'Ns': 0,
#   'contigs': 127,
#   'sequences': 127},
#  '1597.113': {'GC': 47.02,
#   'Mb': 2.803977,
#   'Model_ID': '1597.113',
#   'Ns': 279,
#   'contigs': 49,
#   'sequences': 49},
#  '1597.111': {'GC': 46.92,
#   'Mb': 3.074358,
#   'Model_ID': '1597.111',
#   'Ns': 0,
#   'contigs': 4,
#   'sequences': 4},
#  '1597.114': {'GC': 47.02,
#   'Mb': 2.633718,
#   'Model_ID': '1597.114',
#   'Ns': 255,
#   'contigs': 41,
#   'sequences': 41},
#  '1597.115': {'GC': 47.05,
#   'Mb': 2.786991,
#   'Model_ID': '1597.115',
#   'Ns': 184,
#   'contigs': 35,
#   'sequences': 35},
#  '1203076.3': {'GC': 52.21,
#   'Mb': 1.732189,
#   'Model_ID': '1203076.3',
#   'Ns': 0,
#   'contigs': 40,
#   'sequences': 40},
#  '1590.618': {'GC': 45.6,
#   'Mb': 2.757451,
#   'Model_ID': '1590.618',
#   'Ns': 0,
#   'contigs': 68,
#   'sequences': 68},
#  '1300227.3': {'GC': 60.93,
#   'Mb': 2.11437,
#   'Model_ID': '1300227.3',
#   'Ns': 0,
#   'contigs': 1,
#   'sequences': 1},
#  '1590.616': {'GC': 45.61,
#   'Mb': 2.758511,
#   'Model_ID': '1590.616',
#   'Ns': 0,
#   'contigs': 67,
#   'sequences': 67},
#  '1590.617': {'GC': 45.6,
#   'Mb': 2.76845,
#   'Model_ID': '1590.617',
#   'Ns': 0,
#   'contigs': 68,
#   'sequences': 68},
#  '1590.614': {'GC': 45.61,
#   'Mb': 2.758441,
#   'Model_ID': '1590.614',
#   'Ns': 0,
#   'contigs': 69,
#   'sequences': 69},
#  '1590.615': {'GC': 45.6,
#   'Mb': 2.768938,
#   'Model_ID': '1590.615',
#   'Ns': 0,
#   'contigs': 73,
#   'sequences': 73},
#  '1590.612': {'GC': 45.6,
#   'Mb': 2.767596,
#   'Model_ID': '1590.612',
#   'Ns': 0,
#   'contigs': 77,
#   'sequences': 77},
#  '1590.613': {'GC': 45.6,
#   'Mb': 2.763756,
#   'Model_ID': '1590.613',
#   'Ns': 0,
#   'contigs': 72,
#   'sequences': 72},
#  '1590.610': {'GC': 45.6,
#   'Mb': 2.784185,
#   'Model_ID': '1590.610',
#   'Ns': 0,
#   'contigs': 28,
#   'sequences': 28},
#  '1590.611': {'GC': 45.6,
#   'Mb': 2.762863,
#   'Model_ID': '1590.611',
#   'Ns': 0,
#   'contigs': 73,
#   'sequences': 73},
#  '1300221.4': {'GC': 45.77,
#   'Mb': 2.795988,
#   'Model_ID': '1300221.4',
#   'Ns': 0,
#   'contigs': 3,
#   'sequences': 3},
#  '767468.48': {'GC': 45.78,
#   'Mb': 2.767875,
#   'Model_ID': '767468.48',
#   'Ns': 0,
#   'contigs': 7,
#   'sequences': 7},
#  '1300223.3': {'GC': 47.47,
#   'Mb': 2.635104,
#   'Model_ID': '1300223.3',
#   'Ns': 1,
#   'contigs': 24,
#   'sequences': 24},
#  '1423806.3': {'GC': 39.46,
#   'Mb': 2.116674,
#   'Model_ID': '1423806.3',
#   'Ns': 467,
#   'contigs': 18,
#   'sequences': 18},
#  '1457185.3': {'GC': 60.71,
#   'Mb': 1.980207,
#   'Model_ID': '1457185.3',
#   'Ns': 2,
#   'contigs': 28,
#   'sequences': 28},
#  '1108963.3': {'GC': 33.84,
#   'Mb': 1.919586,
#   'Model_ID': '1108963.3',
#   'Ns': 0,
#   'contigs': 10,
#   'sequences': 10},
#  '1682.17': {'GC': 60.85,
#   'Mb': 2.418421,
#   'Model_ID': '1682.17',
#   'Ns': 0,
#   'contigs': 50,
#   'sequences': 50},
#  '1682.16': {'GC': 60.97,
#   'Mb': 2.45416,
#   'Model_ID': '1682.16',
#   'Ns': 0,
#   'contigs': 54,
#   'sequences': 54},
#  '1682.15': {'GC': 60.88,
#   'Mb': 2.423745,
#   'Model_ID': '1682.15',
#   'Ns': 0,
#   'contigs': 60,
#   'sequences': 60},
#  '1682.14': {'GC': 60.89,
#   'Mb': 2.507849,
#   'Model_ID': '1682.14',
#   'Ns': 0,
#   'contigs': 68,
#   'sequences': 68},
#  '1682.13': {'GC': 60.88,
#   'Mb': 2.419747,
#   'Model_ID': '1682.13',
#   'Ns': 0,
#   'contigs': 57,
#   'sequences': 57},
#  '1365956.3': {'GC': 60.96,
#   'Mb': 1.894431,
#   'Model_ID': '1365956.3',
#   'Ns': 254,
#   'contigs': 11,
#   'sequences': 11},
#  '1682.19': {'GC': 60.91,
#   'Mb': 2.419211,
#   'Model_ID': '1682.19',
#   'Ns': 0,
#   'contigs': 56,
#   'sequences': 56},
#  '1682.18': {'GC': 60.87,
#   'Mb': 2.425411,
#   'Model_ID': '1682.18',
#   'Ns': 0,
#   'contigs': 51,
#   'sequences': 51},
#  '1423808.3': {'GC': 42.98,
#   'Mb': 2.375267,
#   'Model_ID': '1423808.3',
#   'Ns': 15,
#   'contigs': 79,
#   'sequences': 79},
#  '537973.8': {'GC': 47.02,
#   'Mb': 2.493774,
#   'Model_ID': '537973.8',
#   'Ns': 0,
#   'contigs': 30,
#   'sequences': 30},
#  '1365966.3': {'GC': 59.39,
#   'Mb': 2.107254,
#   'Model_ID': '1365966.3',
#   'Ns': 164,
#   'contigs': 23,
#   'sequences': 23},
#  '1390386.3': {'GC': 47.47,
#   'Mb': 2.474054,
#   'Model_ID': '1390386.3',
#   'Ns': 0,
#   'contigs': 67,
#   'sequences': 67},
#  '1613.113': {'GC': 40.95,
#   'Mb': 2.318147,
#   'Model_ID': '1613.113',
#   'Ns': 517604,
#   'contigs': 1,
#   'sequences': 1},
#  '1613.112': {'GC': 52.61,
#   'Mb': 1.918548,
#   'Model_ID': '1613.112',
#   'Ns': 0,
#   'contigs': 1,
#   'sequences': 1},
#  '1365964.3': {'GC': 59.79,
#   'Mb': 2.200391,
#   'Model_ID': '1365964.3',
#   'Ns': 2,
#   'contigs': 33,
#   'sequences': 33},
#  '1390384.3': {'GC': 47.6,
#   'Mb': 2.550322,
#   'Model_ID': '1390384.3',
#   'Ns': 0,
#   'contigs': 51,
#   'sequences': 51},
#  '1681.83': {'GC': 63.13,
#   'Mb': 1.957198,
#   'Model_ID': '1681.83',
#   'Ns': 0,
#   'contigs': 32,
#   'sequences': 32},
#  '1681.82': {'GC': 63.4,
#   'Mb': 1.998206,
#   'Model_ID': '1681.82',
#   'Ns': 92,
#   'contigs': 21,
#   'sequences': 21},
#  '1624.51': {'GC': 33.4,
#   'Mb': 1.768327,
#   'Model_ID': '1624.51',
#   'Ns': 1474,
#   'contigs': 60,
#   'sequences': 60},
#  '1624.50': {'GC': 33.06,
#   'Mb': 1.994033,
#   'Model_ID': '1624.50',
#   'Ns': 4454,
#   'contigs': 78,
#   'sequences': 78},
#  '1423796.3': {'GC': 41.41,
#   'Mb': 2.016796,
#   'Model_ID': '1423796.3',
#   'Ns': 1042,
#   'contigs': 106,
#   'sequences': 106},
#  '1681.60': {'GC': 63.36,
#   'Mb': 1.952597,
#   'Model_ID': '1681.60',
#   'Ns': 0,
#   'contigs': 26,
#   'sequences': 26},
#  '1291734.4': {'GC': 57.76,
#   'Mb': 2.07164,
#   'Model_ID': '1291734.4',
#   'Ns': 935,
#   'contigs': 35,
#   'sequences': 35},
#  '1291734.3': {'GC': 57.62,
#   'Mb': 1.978609,
#   'Model_ID': '1291734.3',
#   'Ns': 0,
#   'contigs': 184,
#   'sequences': 184},
#  '47715.207': {'GC': 47.4,
#   'Mb': 2.652759,
#   'Model_ID': '47715.207',
#   'Ns': 0,
#   'contigs': 98,
#   'sequences': 98},
#  '47715.206': {'GC': 47.6,
#   'Mb': 2.646068,
#   'Model_ID': '47715.206',
#   'Ns': 0,
#   'contigs': 1,
#   'sequences': 1},
#  '944562.4': {'GC': 51.17,
#   'Mb': 1.934892,
#   'Model_ID': '944562.4',
#   'Ns': 0,
#   'contigs': 20,
#   'sequences': 20},
#  '890402.3': {'GC': 60.91,
#   'Mb': 1.984506,
#   'Model_ID': '890402.3',
#   'Ns': 0,
#   'contigs': 1,
#   'sequences': 1},
#  '47715.209': {'GC': 47.06,
#   'Mb': 2.77651,
#   'Model_ID': '47715.209',
#   'Ns': 14453,
#   'contigs': 69,
#   'sequences': 69},
#  '47715.208': {'GC': 47.33,
#   'Mb': 2.584041,
#   'Model_ID': '47715.208',
#   'Ns': 7339,
#   'contigs': 37,
#   'sequences': 37},
#  '1423814.6': {'GC': 41.32,
#   'Mb': 1.58991,
#   'Model_ID': '1423814.6',
#   'Ns': 235,
#   'contigs': 149,
#   'sequences': 149},
#  '1423792.3': {'GC': 49.69,
#   'Mb': 2.987118,
#   'Model_ID': '1423792.3',
#   'Ns': 18,
#   'contigs': 101,
#   'sequences': 101},
#  '411481.5': {'GC': 60.42,
#   'Mb': 2.030037,
#   'Model_ID': '411481.5',
#   'Ns': 0,
#   'contigs': 40,
#   'sequences': 40},
#  '941770.4': {'GC': 39.76,
#   'Mb': 1.248047,
#   'Model_ID': '941770.4',
#   'Ns': 2,
#   'contigs': 16,
#   'sequences': 16},
#  '1423790.3': {'GC': 39.43,
#   'Mb': 1.67247,
#   'Model_ID': '1423790.3',
#   'Ns': 4,
#   'contigs': 44,
#   'sequences': 44},
#  '1218507.3': {'GC': 36.45,
#   'Mb': 1.900183,
#   'Model_ID': '1218507.3',
#   'Ns': 15785,
#   'contigs': 9,
#   'sequences': 9},
#  '1578.21': {'GC': 46.26,
#   'Mb': 2.631561,
#   'Model_ID': '1578.21',
#   'Ns': 0,
#   'contigs': 619,
#   'sequences': 619},
#  '1624.45': {'GC': 33.5,
#   'Mb': 1.753897,
#   'Model_ID': '1624.45',
#   'Ns': 3066,
#   'contigs': 58,
#   'sequences': 58},
#  '1624.46': {'GC': 33.55,
#   'Mb': 1.813602,
#   'Model_ID': '1624.46',
#   'Ns': 1599,
#   'contigs': 58,
#   'sequences': 58},
#  '1624.47': {'GC': 33.47,
#   'Mb': 1.676329,
#   'Model_ID': '1624.47',
#   'Ns': 1568,
#   'contigs': 62,
#   'sequences': 62},
#  '1380360.3': {'GC': 35.87,
#   'Mb': 1.826737,
#   'Model_ID': '1380360.3',
#   'Ns': 0,
#   'contigs': 3,
#   'sequences': 3},
#  '1624.48': {'GC': 33.46,
#   'Mb': 1.889973,
#   'Model_ID': '1624.48',
#   'Ns': 3637,
#   'contigs': 171,
#   'sequences': 171},
#  '1624.49': {'GC': 33.24,
#   'Mb': 1.566857,
#   'Model_ID': '1624.49',
#   'Ns': 1950,
#   'contigs': 45,
#   'sequences': 45},
#  '148814.20': {'GC': 38.05,
#   'Mb': 1.391792,
#   'Model_ID': '148814.20',
#   'Ns': 0,
#   'contigs': 8,
#   'sequences': 8},
#  '148814.25': {'GC': 37.66,
#   'Mb': 1.441059,
#   'Model_ID': '148814.25',
#   'Ns': 64,
#   'contigs': 25,
#   'sequences': 25},
#  '396268.3': {'GC': 48.95,
#   'Mb': 1.479369,
#   'Model_ID': '396268.3',
#   'Ns': 50,
#   'contigs': 11,
#   'sequences': 11},
#  '927703.3': {'GC': 39.42,
#   'Mb': 1.749247,
#   'Model_ID': '927703.3',
#   'Ns': 0,
#   'contigs': 138,
#   'sequences': 138},
#  '525330.7': {'GC': 35.07,
#   'Mb': 1.597219,
#   'Model_ID': '525330.7',
#   'Ns': 12,
#   'contigs': 37,
#   'sequences': 37},
#  '525330.3': {'GC': 35.11,
#   'Mb': 1.585507,
#   'Model_ID': '525330.3',
#   'Ns': 0,
#   'contigs': 32,
#   'sequences': 32},
#  '1579.60': {'GC': 40.42,
#   'Mb': 0.005979,
#   'Model_ID': '1579.60',
#   'Ns': 0,
#   'contigs': 25,
#   'sequences': 25},
#  '575596.3': {'GC': 37.77,
#   'Mb': 1.88555,
#   'Model_ID': '575596.3',
#   'Ns': 0,
#   'contigs': 45,
#   'sequences': 45},
#  '1069534.5': {'GC': 44.56,
#   'Mb': 1.825431,
#   'Model_ID': '1069534.5',
#   'Ns': 3,
#   'contigs': 1,
#   'sequences': 1},
#  '1291052.5': {'GC': 54.75,
#   'Mb': 2.132851,
#   'Model_ID': '1291052.5',
#   'Ns': 466,
#   'contigs': 57,
#   'sequences': 57},
#  '1291052.4': {'GC': 54.67,
#   'Mb': 2.149147,
#   'Model_ID': '1291052.4',
#   'Ns': 0,
#   'contigs': 64,
#   'sequences': 64},
#  '216816.156': {'GC': 66.89,
#   'Mb': 0.003078,
#   'Model_ID': '216816.156',
#   'Ns': 0,
#   'contigs': 1,
#   'sequences': 1},
#  '216816.157': {'GC': 62.84,
#   'Mb': 0.009216,
#   'Model_ID': '216816.157',
#   'Ns': 0,
#   'contigs': 1,
#   'sequences': 1},
#  '216816.154': {'GC': 63.3,
#   'Mb': 0.004128,
#   'Model_ID': '216816.154',
#   'Ns': 0,
#   'contigs': 1,
#   'sequences': 1},
#  '216816.155': {'GC': 60.22,
#   'Mb': 0.002778,
#   'Model_ID': '216816.155',
#   'Ns': 0,
#   'contigs': 1,
#   'sequences': 1},
#  '1321951.5': {'GC': 46.99,
#   'Mb': 2.838659,
#   'Model_ID': '1321951.5',
#   'Ns': 2001,
#   'contigs': 2,
#   'sequences': 2},
#  '216816.153': {'GC': 66.33,
#   'Mb': 0.002658,
#   'Model_ID': '216816.153',
#   'Ns': 0,
#   'contigs': 1,
#   'sequences': 1},
#  '1365968.3': {'GC': 59.54,
#   'Mb': 1.948867,
#   'Model_ID': '1365968.3',
#   'Ns': 0,
#   'contigs': 15,
#   'sequences': 15},
#  '216816.158': {'GC': 66.28,
#   'Mb': 0.003105,
#   'Model_ID': '216816.158',
#   'Ns': 0,
#   'contigs': 1,
#   'sequences': 1},
#  '216816.159': {'GC': 60.94,
#   'Mb': 0.002586,
#   'Model_ID': '216816.159',
#   'Ns': 0,
#   'contigs': 1,
#   'sequences': 1},
#  '1267003.4': {'GC': 50.4,
#   'Mb': 2.184118,
#   'Model_ID': '1267003.4',
#   'Ns': 29,
#   'contigs': 133,
#   'sequences': 133},
#  '1226298.3': {'GC': 47.26,
#   'Mb': 2.660238,
#   'Model_ID': '1226298.3',
#   'Ns': 0,
#   'contigs': 3,
#   'sequences': 3},
#  '1739473.3': {'GC': 47.17,
#   'Mb': 2.72755,
#   'Model_ID': '1739473.3',
#   'Ns': 14000,
#   'contigs': 102,
#   'sequences': 102},
#  '1267003.3': {'GC': 50.64,
#   'Mb': 2.132144,
#   'Model_ID': '1267003.3',
#   'Ns': 0,
#   'contigs': 95,
#   'sequences': 95},
#  '1423784.4': {'GC': 44.41,
#   'Mb': 2.259629,
#   'Model_ID': '1423784.4',
#   'Ns': 100,
#   'contigs': 50,
#   'sequences': 50},
#  '1423784.5': {'GC': 44.41,
#   'Mb': 2.250629,
#   'Model_ID': '1423784.5',
#   'Ns': 0,
#   'contigs': 98,
#   'sequences': 98},
#  '1600.15': {'GC': 33.26,
#   'Mb': 1.096401,
#   'Model_ID': '1600.15',
#   'Ns': 114361,
#   'contigs': 138,
#   'sequences': 138},
#  '1585.11': {'GC': 50.74,
#   'Mb': 1.679726,
#   'Model_ID': '1585.11',
#   'Ns': 7975,
#   'contigs': 14,
#   'sequences': 14},
#  '1624.101': {'GC': 33.53,
#   'Mb': 2.010371,
#   'Model_ID': '1624.101',
#   'Ns': 0,
#   'contigs': 100,
#   'sequences': 100},
#  '1600.17': {'GC': 34.27,
#   'Mb': 1.133586,
#   'Model_ID': '1600.17',
#   'Ns': 88676,
#   'contigs': 133,
#   'sequences': 133},
#  '575606.3': {'GC': 34.62,
#   'Mb': 1.424883,
#   'Model_ID': '575606.3',
#   'Ns': 0,
#   'contigs': 13,
#   'sequences': 13},
#  '1685.8': {'GC': 59.7,
#   'Mb': 2.007129,
#   'Model_ID': '1685.8',
#   'Ns': 0,
#   'contigs': 31,
#   'sequences': 31},
#  '1685.9': {'GC': 59.53,
#   'Mb': 2.167949,
#   'Model_ID': '1685.9',
#   'Ns': 3,
#   'contigs': 28,
#   'sequences': 28},
#  '33959.153': {'GC': 34.88,
#   'Mb': 1.89224,
#   'Model_ID': '33959.153',
#   'Ns': 2,
#   'contigs': 49,
#   'sequences': 49},
#  '1739469.3': {'GC': 47.05,
#   'Mb': 2.657135,
#   'Model_ID': '1739469.3',
#   'Ns': 12600,
#   'contigs': 172,
#   'sequences': 172},
#  '97478.22': {'GC': 47.94,
#   'Mb': 1.668628,
#   'Model_ID': '97478.22',
#   'Ns': 4730,
#   'contigs': 32,
#   'sequences': 32},
#  '97478.21': {'GC': 48.06,
#   'Mb': 1.667039,
#   'Model_ID': '97478.21',
#   'Ns': 1900,
#   'contigs': 38,
#   'sequences': 38},
#  '97478.20': {'GC': 48.12,
#   'Mb': 1.665378,
#   'Model_ID': '97478.20',
#   'Ns': 0,
#   'contigs': 39,
#   'sequences': 39},
#  '1590.335': {'GC': 45.4,
#   'Mb': 2.871565,
#   'Model_ID': '1590.335',
#   'Ns': 0,
#   'contigs': 77,
#   'sequences': 77},
#  '1590.334': {'GC': 45.56,
#   'Mb': 2.839269,
#   'Model_ID': '1590.334',
#   'Ns': 0,
#   'contigs': 57,
#   'sequences': 57},
#  '1590.337': {'GC': 45.44,
#   'Mb': 2.88511,
#   'Model_ID': '1590.337',
#   'Ns': 0,
#   'contigs': 50,
#   'sequences': 50},
#  '1590.336': {'GC': 45.61,
#   'Mb': 2.743325,
#   'Model_ID': '1590.336',
#   'Ns': 0,
#   'contigs': 39,
#   'sequences': 39},
#  '1590.331': {'GC': 45.61,
#   'Mb': 2.794661,
#   'Model_ID': '1590.331',
#   'Ns': 0,
#   'contigs': 46,
#   'sequences': 46},
#  '1590.330': {'GC': 45.51,
#   'Mb': 2.777467,
#   'Model_ID': '1590.330',
#   'Ns': 0,
#   'contigs': 51,
#   'sequences': 51},
#  '1590.333': {'GC': 45.51,
#   'Mb': 2.774749,
#   'Model_ID': '1590.333',
#   'Ns': 0,
#   'contigs': 92,
#   'sequences': 92},
#  '1590.332': {'GC': 45.5,
#   'Mb': 2.77681,
#   'Model_ID': '1590.332',
#   'Ns': 0,
#   'contigs': 65,
#   'sequences': 65},
#  '1590.339': {'GC': 45.37,
#   'Mb': 2.907871,
#   'Model_ID': '1590.339',
#   'Ns': 0,
#   'contigs': 37,
#   'sequences': 37},
#  '1590.338': {'GC': 45.45,
#   'Mb': 2.869636,
#   'Model_ID': '1590.338',
#   'Ns': 0,
#   'contigs': 101,
#   'sequences': 101},
#  '1381124.3': {'GC': 52.78,
#   'Mb': 2.021975,
#   'Model_ID': '1381124.3',
#   'Ns': 0,
#   'contigs': 284,
#   'sequences': 284},
#  '1580.58': {'GC': 46.32,
#   'Mb': 2.340172,
#   'Model_ID': '1580.58',
#   'Ns': 0,
#   'contigs': 138,
#   'sequences': 138},
#  '303541.3': {'GC': 36.53,
#   'Mb': 1.536432,
#   'Model_ID': '303541.3',
#   'Ns': 42507,
#   'contigs': 7,
#   'sequences': 7},
#  '1580.57': {'GC': 46.95,
#   'Mb': 2.143609,
#   'Model_ID': '1580.57',
#   'Ns': 0,
#   'contigs': 99,
#   'sequences': 99},
#  '1580.50': {'GC': 46.43,
#   'Mb': 2.455895,
#   'Model_ID': '1580.50',
#   'Ns': 0,
#   'contigs': 103,
#   'sequences': 103},
#  '1580.51': {'GC': 47.03,
#   'Mb': 2.15492,
#   'Model_ID': '1580.51',
#   'Ns': 20,
#   'contigs': 46,
#   'sequences': 46},
#  '1580.52': {'GC': 46.55,
#   'Mb': 2.373826,
#   'Model_ID': '1580.52',
#   'Ns': 5582,
#   'contigs': 11,
#   'sequences': 11},
#  '1580.53': {'GC': 47.04,
#   'Mb': 2.197969,
#   'Model_ID': '1580.53',
#   'Ns': 675,
#   'contigs': 33,
#   'sequences': 33},
#  '525338.3': {'GC': 45.77,
#   'Mb': 2.671616,
#   'Model_ID': '525338.3',
#   'Ns': 0,
#   'contigs': 52,
#   'sequences': 52},
#  '1423770.3': {'GC': 39.31,
#   'Mb': 2.054082,
#   'Model_ID': '1423770.3',
#   'Ns': 1211,
#   'contigs': 103,
#   'sequences': 103},
#  '596325.3': {'GC': 35.05,
#   'Mb': 1.518161,
#   'Model_ID': '596325.3',
#   'Ns': 0,
#   'contigs': 57,
#   'sequences': 57},
#  '1302250.4': {'GC': 46.24,
#   'Mb': 2.373491,
#   'Model_ID': '1302250.4',
#   'Ns': 115,
#   'contigs': 87,
#   'sequences': 87},
#  '1590.198': {'GC': 45.49,
#   'Mb': 2.84948,
#   'Model_ID': '1590.198',
#   'Ns': 508,
#   'contigs': 76,
#   'sequences': 76},
#  '47770.66': {'GC': 37.7,
#   'Mb': 1.830378,
#   'Model_ID': '47770.66',
#   'Ns': 0,
#   'contigs': 73,
#   'sequences': 73},
#  '714313.3': {'GC': 35.56,
#   'Mb': 1.262978,
#   'Model_ID': '714313.3',
#   'Ns': 0,
#   'contigs': 3,
#   'sequences': 3},
#  '1302250.3': {'GC': 46.34,
#   'Mb': 2.214433,
#   'Model_ID': '1302250.3',
#   'Ns': 0,
#   'contigs': 47,
#   'sequences': 47},
#  '1590.191': {'GC': 45.45,
#   'Mb': 2.86849,
#   'Model_ID': '1590.191',
#   'Ns': 7,
#   'contigs': 171,
#   'sequences': 171},
#  '1423772.3': {'GC': 40.85,
#   'Mb': 1.955084,
#   'Model_ID': '1423772.3',
#   'Ns': 1747,
#   'contigs': 176,
#   'sequences': 176},
#  '1590.192': {'GC': 45.65,
#   'Mb': 2.825297,
#   'Model_ID': '1590.192',
#   'Ns': 0,
#   'contigs': 1,
#   'sequences': 1},
#  '1590.195': {'GC': 45.63,
#   'Mb': 2.873658,
#   'Model_ID': '1590.195',
#   'Ns': 0,
#   'contigs': 4,
#   'sequences': 4},
#  '1423772.4': {'GC': 40.85,
#   'Mb': 1.893452,
#   'Model_ID': '1423772.4',
#   'Ns': 0,
#   'contigs': 139,
#   'sequences': 139},
#  '1590.197': {'GC': 45.45,
#   'Mb': 2.800725,
#   'Model_ID': '1590.197',
#   'Ns': 260,
#   'contigs': 85,
#   'sequences': 85},
#  '1385938.3': {'GC': 59.75,
#   'Mb': 2.00394,
#   'Model_ID': '1385938.3',
#   'Ns': 0,
#   'contigs': 1,
#   'sequences': 1},
#  '387344.15': {'GC': 47.11,
#   'Mb': 2.011245,
#   'Model_ID': '387344.15',
#   'Ns': 0,
#   'contigs': 3,
#   'sequences': 3},
#  '575604.3': {'GC': 35.46,
#   'Mb': 1.809233,
#   'Model_ID': '575604.3',
#   'Ns': 0,
#   'contigs': 43,
#   'sequences': 43},
#  '1597.107': {'GC': 46.93,
#   'Mb': 2.689396,
#   'Model_ID': '1597.107',
#   'Ns': 97,
#   'contigs': 86,
#   'sequences': 86},
#  '1597.106': {'GC': 46.8,
#   'Mb': 2.682562,
#   'Model_ID': '1597.106',
#   'Ns': 31,
#   'contigs': 58,
#   'sequences': 58},
#  '1423811.3': {'GC': 34.54,
#   'Mb': 1.952283,
#   'Model_ID': '1423811.3',
#   'Ns': 417,
#   'contigs': 51,
#   'sequences': 51},
#  '1597.108': {'GC': 46.97,
#   'Mb': 2.645696,
#   'Model_ID': '1597.108',
#   'Ns': 83,
#   'contigs': 125,
#   'sequences': 125},
#  '1590.601': {'GC': 45.26,
#   'Mb': 3.141981,
#   'Model_ID': '1590.601',
#   'Ns': 0,
#   'contigs': 3,
#   'sequences': 3},
#  '1590.603': {'GC': 45.59,
#   'Mb': 2.76715,
#   'Model_ID': '1590.603',
#   'Ns': 0,
#   'contigs': 65,
#   'sequences': 65},
#  '1590.602': {'GC': 45.61,
#   'Mb': 2.820795,
#   'Model_ID': '1590.602',
#   'Ns': 0,
#   'contigs': 71,
#   'sequences': 71},
#  '1590.605': {'GC': 45.61,
#   'Mb': 2.75895,
#   'Model_ID': '1590.605',
#   'Ns': 0,
#   'contigs': 70,
#   'sequences': 70},
#  '1590.604': {'GC': 45.6,
#   'Mb': 2.76894,
#   'Model_ID': '1590.604',
#   'Ns': 0,
#   'contigs': 66,
#   'sequences': 66},
#  '1590.607': {'GC': 45.61,
#   'Mb': 2.760412,
#   'Model_ID': '1590.607',
#   'Ns': 0,
#   'contigs': 73,
#   'sequences': 73},
#  '1590.606': {'GC': 45.61,
#   'Mb': 2.770741,
#   'Model_ID': '1590.606',
#   'Ns': 0,
#   'contigs': 80,
#   'sequences': 80},
#  '1590.609': {'GC': 45.6,
#   'Mb': 2.784333,
#   'Model_ID': '1590.609',
#   'Ns': 0,
#   'contigs': 28,
#   'sequences': 28},
#  '1590.608': {'GC': 45.6,
#   'Mb': 2.765634,
#   'Model_ID': '1590.608',
#   'Ns': 0,
#   'contigs': 63,
#   'sequences': 63},
#  '47770.68': {'GC': 37.69,
#   'Mb': 1.834282,
#   'Model_ID': '47770.68',
#   'Ns': 80,
#   'contigs': 64,
#   'sequences': 64},
#  '1606.59': {'GC': 41.22,
#   'Mb': 1.486599,
#   'Model_ID': '1606.59',
#   'Ns': 2,
#   'contigs': 53,
#   'sequences': 53},
#  '1606.58': {'GC': 41.13,
#   'Mb': 1.492975,
#   'Model_ID': '1606.58',
#   'Ns': 227,
#   'contigs': 62,
#   'sequences': 62},
#  '1606.57': {'GC': 41.16,
#   'Mb': 1.486983,
#   'Model_ID': '1606.57',
#   'Ns': 113,
#   'contigs': 62,
#   'sequences': 62},
#  '1606.56': {'GC': 41.17,
#   'Mb': 1.492764,
#   'Model_ID': '1606.56',
#   'Ns': 70,
#   'contigs': 62,
#   'sequences': 62},
#  '1606.55': {'GC': 41.11,
#   'Mb': 1.47635,
#   'Model_ID': '1606.55',
#   'Ns': 2,
#   'contigs': 67,
#   'sequences': 67},
#  '1606.54': {'GC': 41.2,
#   'Mb': 1.498549,
#   'Model_ID': '1606.54',
#   'Ns': 106,
#   'contigs': 70,
#   'sequences': 70},
#  '1606.53': {'GC': 41.24,
#   'Mb': 1.485662,
#   'Model_ID': '1606.53',
#   'Ns': 54,
#   'contigs': 60,
#   'sequences': 60},
#  '1606.52': {'GC': 41.25,
#   'Mb': 1.49968,
#   'Model_ID': '1606.52',
#   'Ns': 178,
#   'contigs': 70,
#   'sequences': 70},
#  '1606.51': {'GC': 41.18,
#   'Mb': 1.495943,
#   'Model_ID': '1606.51',
#   'Ns': 102,
#   'contigs': 55,
#   'sequences': 55},
#  '1606.50': {'GC': 41.07,
#   'Mb': 1.480963,
#   'Model_ID': '1606.50',
#   'Ns': 2,
#   'contigs': 63,
#   'sequences': 63},
#  '219334.4': {'GC': 48.8,
#   'Mb': 2.60846,
#   'Model_ID': '219334.4',
#   'Ns': 0,
#   'contigs': 3,
#   'sequences': 3},
#  '1946729.3': {'GC': 38.9,
#   'Mb': 1.433242,
#   'Model_ID': '1946729.3',
#   'Ns': 1466,
#   'contigs': 45,
#   'sequences': 45},
#  '1419324.3': {'GC': 37.84,
#   'Mb': 1.414122,
#   'Model_ID': '1419324.3',
#   'Ns': 0,
#   'contigs': 55,
#   'sequences': 55},
#  '1715181.3': {'GC': 47.07,
#   'Mb': 2.555335,
#   'Model_ID': '1715181.3',
#   'Ns': 13400,
#   'contigs': 59,
#   'sequences': 59},
#  '1680.10': {'GC': 59.72,
#   'Mb': 2.014711,
#   'Model_ID': '1680.10',
#   'Ns': 14746,
#   'contigs': 17,
#   'sequences': 17},
#  '1122150.3': {'GC': 37.47,
#   'Mb': 2.218938,
#   'Model_ID': '1122150.3',
#   'Ns': 242,
#   'contigs': 44,
#   'sequences': 44},
#  '1680.18': {'GC': 60.25,
#   'Mb': 2.041489,
#   'Model_ID': '1680.18',
#   'Ns': 0,
#   'contigs': 45,
#   'sequences': 45},
#  '1078018.5': {'GC': 47.32,
#   'Mb': 2.375443,
#   'Model_ID': '1078018.5',
#   'Ns': 0,
#   'contigs': 396,
#   'sequences': 396},
#  '1122152.4': {'GC': 36.17,
#   'Mb': 1.427151,
#   'Model_ID': '1122152.4',
#   'Ns': 214,
#   'contigs': 50,
#   'sequences': 50},
#  '1613.168': {'GC': 52.09,
#   'Mb': 1.774548,
#   'Model_ID': '1613.168',
#   'Ns': 6489,
#   'contigs': 138,
#   'sequences': 138},
#  '1122152.3': {'GC': 36.18,
#   'Mb': 1.410756,
#   'Model_ID': '1122152.3',
#   'Ns': 0,
#   'contigs': 26,
#   'sequences': 26},
#  '1613.165': {'GC': 53.02,
#   'Mb': 1.786896,
#   'Model_ID': '1613.165',
#   'Ns': 0,
#   'contigs': 108,
#   'sequences': 108},
#  '1613.166': {'GC': 52.63,
#   'Mb': 1.867048,
#   'Model_ID': '1613.166',
#   'Ns': 0,
#   'contigs': 111,
#   'sequences': 111},
#  '1613.167': {'GC': 52.64,
#   'Mb': 1.854945,
#   'Model_ID': '1613.167',
#   'Ns': 0,
#   'contigs': 110,
#   'sequences': 110},
#  '1681.104': {'GC': 63.52,
#   'Mb': 1.981905,
#   'Model_ID': '1681.104',
#   'Ns': 0,
#   'contigs': 27,
#   'sequences': 27},
#  '47715.161': {'GC': 47.44,
#   'Mb': 2.593895,
#   'Model_ID': '47715.161',
#   'Ns': 0,
#   'contigs': 71,
#   'sequences': 71},
#  '1681.92': {'GC': 63.45,
#   'Mb': 1.921761,
#   'Model_ID': '1681.92',
#   'Ns': 0,
#   'contigs': 13,
#   'sequences': 13},
#  '1681.93': {'GC': 62.85,
#   'Mb': 0.003594,
#   'Model_ID': '1681.93',
#   'Ns': 0,
#   'contigs': 1,
#   'sequences': 1},
#  '1423782.3': {'GC': 48.84,
#   'Mb': 1.963114,
#   'Model_ID': '1423782.3',
#   'Ns': 0,
#   'contigs': 219,
#   'sequences': 219},
#  '1423782.4': {'GC': 49.38,
#   'Mb': 1.794044,
#   'Model_ID': '1423782.4',
#   'Ns': 375,
#   'contigs': 150,
#   'sequences': 150},
#  '1681.94': {'GC': 63.5,
#   'Mb': 1.99472,
#   'Model_ID': '1681.94',
#   'Ns': 0,
#   'contigs': 1,
#   'sequences': 1},
#  '909954.3': {'GC': 35.39,
#   'Mb': 1.820275,
#   'Model_ID': '909954.3',
#   'Ns': 0,
#   'contigs': 1,
#   'sequences': 1},
#  '1681.70': {'GC': 63.63,
#   'Mb': 1.886076,
#   'Model_ID': '1681.70',
#   'Ns': 0,
#   'contigs': 15,
#   'sequences': 15},
#  '879304.3': {'GC': 32.82,
#   'Mb': 1.139441,
#   'Model_ID': '879304.3',
#   'Ns': 0,
#   'contigs': 25,
#   'sequences': 25},
#  '1681.78': {'GC': 63.54,
#   'Mb': 1.467548,
#   'Model_ID': '1681.78',
#   'Ns': 3473,
#   'contigs': 33,
#   'sequences': 33},
#  '942150.3': {'GC': 46.34,
#   'Mb': 2.573539,
#   'Model_ID': '942150.3',
#   'Ns': 1076,
#   'contigs': 103,
#   'sequences': 103},
#  '1256226.3': {'GC': 46.96,
#   'Mb': 2.628321,
#   'Model_ID': '1256226.3',
#   'Ns': 0,
#   'contigs': 131,
#   'sequences': 131},
#  '47715.211': {'GC': 47.37,
#   'Mb': 2.528556,
#   'Model_ID': '47715.211',
#   'Ns': 7240,
#   'contigs': 31,
#   'sequences': 31},
#  '1205679.3': {'GC': 60.87,
#   'Mb': 2.069071,
#   'Model_ID': '1205679.3',
#   'Ns': 0,
#   'contigs': 128,
#   'sequences': 128},
#  '1605.9': {'GC': 42.17,
#   'Mb': 1.638581,
#   'Model_ID': '1605.9',
#   'Ns': 0,
#   'contigs': 30,
#   'sequences': 30},
#  '1256206.3': {'GC': 46.64,
#   'Mb': 1.861613,
#   'Model_ID': '1256206.3',
#   'Ns': 10,
#   'contigs': 1355,
#   'sequences': 1355},
#  '1122146.4': {'GC': 34.35,
#   'Mb': 1.270641,
#   'Model_ID': '1122146.4',
#   'Ns': 1365,
#   'contigs': 26,
#   'sequences': 26},
#  '1122146.3': {'GC': 34.36,
#   'Mb': 1.21525,
#   'Model_ID': '1122146.3',
#   'Ns': 0,
#   'contigs': 19,
#   'sequences': 19},
#  '1256204.3': {'GC': 46.97,
#   'Mb': 2.436038,
#   'Model_ID': '1256204.3',
#   'Ns': 2,
#   'contigs': 436,
#   'sequences': 436},
#  '1596.33': {'GC': 35.08,
#   'Mb': 2.252628,
#   'Model_ID': '1596.33',
#   'Ns': 410,
#   'contigs': 1422,
#   'sequences': 1422},
#  '1291742.4': {'GC': 38.95,
#   'Mb': 1.98866,
#   'Model_ID': '1291742.4',
#   'Ns': 0,
#   'contigs': 67,
#   'sequences': 67},
#  '1596.34': {'GC': 35.49,
#   'Mb': 1.983695,
#   'Model_ID': '1596.34',
#   'Ns': 213,
#   'contigs': 47,
#   'sequences': 47},
#  '1596.36': {'GC': 35.52,
#   'Mb': 1.750167,
#   'Model_ID': '1596.36',
#   'Ns': 1800,
#   'contigs': 64,
#   'sequences': 64},
#  '1596.38': {'GC': 35.35,
#   'Mb': 1.924522,
#   'Model_ID': '1596.38',
#   'Ns': 0,
#   'contigs': 85,
#   'sequences': 85},
#  '1435342.4': {'GC': 44.81,
#   'Mb': 2.215489,
#   'Model_ID': '1435342.4',
#   'Ns': 260,
#   'contigs': 87,
#   'sequences': 87},
#  '1322347.4': {'GC': 60.77,
#   'Mb': 2.166223,
#   'Model_ID': '1322347.4',
#   'Ns': 5601,
#   'contigs': 1,
#   'sequences': 1},
#  '1423720.3': {'GC': 36.21,
#   'Mb': 2.094431,
#   'Model_ID': '1423720.3',
#   'Ns': 478,
#   'contigs': 46,
#   'sequences': 46},
#  '1046596.4': {'GC': 37.02,
#   'Mb': 2.307105,
#   'Model_ID': '1046596.4',
#   'Ns': 0,
#   'contigs': 122,
#   'sequences': 122},
#  '1046596.6': {'GC': 37.0,
#   'Mb': 2.26386,
#   'Model_ID': '1046596.6',
#   'Ns': 151,
#   'contigs': 209,
#   'sequences': 209},
#  '1624.71': {'GC': 33.53,
#   'Mb': 1.897773,
#   'Model_ID': '1624.71',
#   'Ns': 1742,
#   'contigs': 134,
#   'sequences': 134},
#  '1624.70': {'GC': 33.44,
#   'Mb': 1.966584,
#   'Model_ID': '1624.70',
#   'Ns': 2196,
#   'contigs': 101,
#   'sequences': 101},
#  '1624.73': {'GC': 33.36,
#   'Mb': 1.658587,
#   'Model_ID': '1624.73',
#   'Ns': 1205,
#   'contigs': 36,
#   'sequences': 36},
#  '1624.72': {'GC': 33.66,
#   'Mb': 1.748327,
#   'Model_ID': '1624.72',
#   'Ns': 768,
#   'contigs': 59,
#   'sequences': 59},
#  '1624.74': {'GC': 33.7,
#   'Mb': 2.091913,
#   'Model_ID': '1624.74',
#   'Ns': 0,
#   'contigs': 166,
#   'sequences': 166},
#  '1624.77': {'GC': 33.48,
#   'Mb': 1.70488,
#   'Model_ID': '1624.77',
#   'Ns': 0,
#   'contigs': 50,
#   'sequences': 50},
#  '1624.76': {'GC': 33.43,
#   'Mb': 1.645627,
#   'Model_ID': '1624.76',
#   'Ns': 0,
#   'contigs': 45,
#   'sequences': 45},
#  '1624.79': {'GC': 34.21,
#   'Mb': 2.107885,
#   'Model_ID': '1624.79',
#   'Ns': 0,
#   'contigs': 3,
#   'sequences': 3},
#  '1407052.3': {'GC': 53.45,
#   'Mb': 1.708417,
#   'Model_ID': '1407052.3',
#   'Ns': 0,
#   'contigs': 72,
#   'sequences': 72},
#  '759350.3': {'GC': 60.93,
#   'Mb': 2.091641,
#   'Model_ID': '759350.3',
#   'Ns': 0,
#   'contigs': 1,
#   'sequences': 1},
#  '1597.53': {'GC': 46.89,
#   'Mb': 2.711521,
#   'Model_ID': '1597.53',
#   'Ns': 0,
#   'contigs': 87,
#   'sequences': 87},
#  '1598.292': {'GC': 39.53,
#   'Mb': 1.851425,
#   'Model_ID': '1598.292',
#   'Ns': 0,
#   'contigs': 145,
#   'sequences': 145},
#  '1598.293': {'GC': 39.37,
#   'Mb': 1.885809,
#   'Model_ID': '1598.293',
#   'Ns': 0,
#   'contigs': 149,
#   'sequences': 149},
#  '1598.290': {'GC': 39.67,
#   'Mb': 2.043607,
#   'Model_ID': '1598.290',
#   'Ns': 344,
#   'contigs': 179,
#   'sequences': 179},
#  '1598.291': {'GC': 39.34,
#   'Mb': 1.875848,
#   'Model_ID': '1598.291',
#   'Ns': 949,
#   'contigs': 93,
#   'sequences': 93},
#  '1598.296': {'GC': 39.63,
#   'Mb': 1.892065,
#   'Model_ID': '1598.296',
#   'Ns': 0,
#   'contigs': 169,
#   'sequences': 169},
#  '1598.297': {'GC': 39.63,
#   'Mb': 1.860088,
#   'Model_ID': '1598.297',
#   'Ns': 0,
#   'contigs': 149,
#   'sequences': 149},
#  '1598.294': {'GC': 39.31,
#   'Mb': 2.432666,
#   'Model_ID': '1598.294',
#   'Ns': 0,
#   'contigs': 392,
#   'sequences': 392},
#  '1598.295': {'GC': 39.41,
#   'Mb': 1.964295,
#   'Model_ID': '1598.295',
#   'Ns': 0,
#   'contigs': 154,
#   'sequences': 154},
#  '1598.298': {'GC': 39.58,
#   'Mb': 1.774941,
#   'Model_ID': '1598.298',
#   'Ns': 0,
#   'contigs': 136,
#   'sequences': 136},
#  '1598.299': {'GC': 39.55,
#   'Mb': 1.789786,
#   'Model_ID': '1598.299',
#   'Ns': 0,
#   'contigs': 228,
#   'sequences': 228},
#  '1122148.5': {'GC': 34.8,
#   'Mb': 1.293133,
#   'Model_ID': '1122148.5',
#   'Ns': 0,
#   'contigs': 28,
#   'sequences': 28},
#  '1122148.6': {'GC': 34.79,
#   'Mb': 1.310388,
#   'Model_ID': '1122148.6',
#   'Ns': 347,
#   'contigs': 36,
#   'sequences': 36},
#  '1122148.7': {'GC': 34.67,
#   'Mb': 1.306685,
#   'Model_ID': '1122148.7',
#   'Ns': 5545,
#   'contigs': 31,
#   'sequences': 31},
#  '2042043.3': {'GC': 37.39,
#   'Mb': 1.782997,
#   'Model_ID': '2042043.3',
#   'Ns': 0,
#   'contigs': 155,
#   'sequences': 155},
#  '1585.34': {'GC': 51.0,
#   'Mb': 1.806734,
#   'Model_ID': '1585.34',
#   'Ns': 0,
#   'contigs': 1,
#   'sequences': 1},
#  '28025.4': {'GC': 61.42,
#   'Mb': 1.713426,
#   'Model_ID': '28025.4',
#   'Ns': 0,
#   'contigs': 1,
#   'sequences': 1},
#  '1598.276': {'GC': 39.96,
#   'Mb': 2.375754,
#   'Model_ID': '1598.276',
#   'Ns': 0,
#   'contigs': 14,
#   'sequences': 14},
#  '216816.145': {'GC': 60.81,
#   'Mb': 2.162145,
#   'Model_ID': '216816.145',
#   'Ns': 142,
#   'contigs': 109,
#   'sequences': 109},
#  '216816.144': {'GC': 60.77,
#   'Mb': 2.253806,
#   'Model_ID': '216816.144',
#   'Ns': 41,
#   'contigs': 55,
#   'sequences': 55},
#  '216816.147': {'GC': 60.77,
#   'Mb': 2.133394,
#   'Model_ID': '216816.147',
#   'Ns': 0,
#   'contigs': 43,
#   'sequences': 43},
#  '216816.146': {'GC': 61.04,
#   'Mb': 2.261669,
#   'Model_ID': '216816.146',
#   'Ns': 621,
#   'contigs': 47,
#   'sequences': 47},
#  '216816.140': {'GC': 60.97,
#   'Mb': 2.092121,
#   'Model_ID': '216816.140',
#   'Ns': 0,
#   'contigs': 97,
#   'sequences': 97},
#  '216816.143': {'GC': 60.8,
#   'Mb': 2.236998,
#   'Model_ID': '216816.143',
#   'Ns': 376,
#   'contigs': 41,
#   'sequences': 41},
#  '216816.148': {'GC': 59.26,
#   'Mb': 1.662815,
#   'Model_ID': '216816.148',
#   'Ns': 42054,
#   'contigs': 227,
#   'sequences': 227},
#  '1051661.4': {'GC': 47.05,
#   'Mb': 2.314429,
#   'Model_ID': '1051661.4',
#   'Ns': 35,
#   'contigs': 144,
#   'sequences': 144},
#  '1392007.3': {'GC': 40.23,
#   'Mb': 1.846204,
#   'Model_ID': '1392007.3',
#   'Ns': 0,
#   'contigs': 203,
#   'sequences': 203},
#  '1051661.3': {'GC': 47.18,
#   'Mb': 2.420352,
#   'Model_ID': '1051661.3',
#   'Ns': 0,
#   'contigs': 122,
#   'sequences': 122},
#  '81857.3': {'GC': 46.59,
#   'Mb': 1.952327,
#   'Model_ID': '81857.3',
#   'Ns': 25739,
#   'contigs': 100,
#   'sequences': 100},
#  '81857.4': {'GC': 47.34,
#   'Mb': 1.877407,
#   'Model_ID': '81857.4',
#   'Ns': 5,
#   'contigs': 32,
#   'sequences': 32},
#  '1423823.3': {'GC': 51.5,
#   'Mb': 1.564675,
#   'Model_ID': '1423823.3',
#   'Ns': 6133,
#   'contigs': 188,
#   'sequences': 188},
#  '1423823.4': {'GC': 50.44,
#   'Mb': 2.042012,
#   'Model_ID': '1423823.4',
#   'Ns': 100,
#   'contigs': 1,
#   'sequences': 1},
#  '742729.3': {'GC': 61.44,
#   'Mb': 1.708136,
#   'Model_ID': '742729.3',
#   'Ns': 0,
#   'contigs': 1,
#   'sequences': 1},
#  '2042041.3': {'GC': 37.22,
#   'Mb': 1.752194,
#   'Model_ID': '2042041.3',
#   'Ns': 0,
#   'contigs': 157,
#   'sequences': 157},
#  '1946731.3': {'GC': 41.14,
#   'Mb': 0.862766,
#   'Model_ID': '1946731.3',
#   'Ns': 10768,
#   'contigs': 93,
#   'sequences': 93},
#  '1074467.3': {'GC': 37.94,
#   'Mb': 2.303756,
#   'Model_ID': '1074467.3',
#   'Ns': 0,
#   'contigs': 79,
#   'sequences': 79},
#  '148814.6': {'GC': 37.7,
#   'Mb': 1.428014,
#   'Model_ID': '148814.6',
#   'Ns': 0,
#   'contigs': 21,
#   'sequences': 21},
#  '148814.7': {'GC': 35.18,
#   'Mb': 1.475044,
#   'Model_ID': '148814.7',
#   'Ns': 74106,
#   'contigs': 8,
#   'sequences': 8},
#  '148814.5': {'GC': 37.7,
#   'Mb': 1.421163,
#   'Model_ID': '148814.5',
#   'Ns': 0,
#   'contigs': 44,
#   'sequences': 44},
#  '148814.8': {'GC': 38.51,
#   'Mb': 1.419002,
#   'Model_ID': '148814.8',
#   'Ns': 0,
#   'contigs': 7,
#   'sequences': 7},
#  '148814.9': {'GC': 37.89,
#   'Mb': 1.434448,
#   'Model_ID': '148814.9',
#   'Ns': 0,
#   'contigs': 47,
#   'sequences': 47},
#  '97478.10': {'GC': 48.42,
#   'Mb': 2.357416,
#   'Model_ID': '97478.10',
#   'Ns': 0,
#   'contigs': 38,
#   'sequences': 38},
#  '1051651.3': {'GC': 46.94,
#   'Mb': 2.955844,
#   'Model_ID': '1051651.3',
#   'Ns': 4,
#   'contigs': 75,
#   'sequences': 75},
#  '349123.13': {'GC': 39.71,
#   'Mb': 2.240155,
#   'Model_ID': '349123.13',
#   'Ns': 4,
#   'contigs': 2,
#   'sequences': 2},
#  '33959.343': {'GC': 34.76,
#   'Mb': 1.384562,
#   'Model_ID': '33959.343',
#   'Ns': 2360,
#   'contigs': 160,
#   'sequences': 160},
#  '1051657.3': {'GC': 46.99,
#   'Mb': 2.773624,
#   'Model_ID': '1051657.3',
#   'Ns': 0,
#   'contigs': 78,
#   'sequences': 78},
#  '1051655.5': {'GC': 47.12,
#   'Mb': 2.559318,
#   'Model_ID': '1051655.5',
#   'Ns': 2,
#   'contigs': 76,
#   'sequences': 76},
#  '442563.4': {'GC': 61.49,
#   'Mb': 1.672872,
#   'Model_ID': '442563.4',
#   'Ns': 0,
#   'contigs': 1,
#   'sequences': 1},
#  '1580.63': {'GC': 46.79,
#   'Mb': 2.164142,
#   'Model_ID': '1580.63',
#   'Ns': 0,
#   'contigs': 50,
#   'sequences': 50},
#  '941770.3': {'GC': 39.78,
#   'Mb': 1.278952,
#   'Model_ID': '941770.3',
#   'Ns': 0,
#   'contigs': 11,
#   'sequences': 11},
#  '1580.65': {'GC': 54.17,
#   'Mb': 2.539248,
#   'Model_ID': '1580.65',
#   'Ns': 11750,
#   'contigs': 271,
#   'sequences': 271},
#  '1580.64': {'GC': 46.39,
#   'Mb': 2.326635,
#   'Model_ID': '1580.64',
#   'Ns': 0,
#   'contigs': 123,
#   'sequences': 123},
#  '1580.66': {'GC': 46.77,
#   'Mb': 2.261185,
#   'Model_ID': '1580.66',
#   'Ns': 2,
#   'contigs': 1,
#   'sequences': 1},
#  '552531.3': {'GC': 61.54,
#   'Mb': 1.633797,
#   'Model_ID': '552531.3',
#   'Ns': 0,
#   'contigs': 1,
#   'sequences': 1},
#  '1051659.3': {'GC': 47.11,
#   'Mb': 2.702053,
#   'Model_ID': '1051659.3',
#   'Ns': 14,
#   'contigs': 116,
#   'sequences': 116},
#  '1582.26': {'GC': 47.24,
#   'Mb': 2.470134,
#   'Model_ID': '1582.26',
#   'Ns': 0,
#   'contigs': 89,
#   'sequences': 89},
#  '1423759.3': {'GC': 35.59,
#   'Mb': 2.015979,
#   'Model_ID': '1423759.3',
#   'Ns': 947,
#   'contigs': 137,
#   'sequences': 137},
#  '1715170.3': {'GC': 47.13,
#   'Mb': 2.533162,
#   'Model_ID': '1715170.3',
#   'Ns': 10600,
#   'contigs': 41,
#   'sequences': 41},
#  '1590.293': {'GC': 45.85,
#   'Mb': 2.765126,
#   'Model_ID': '1590.293',
#   'Ns': 0,
#   'contigs': 2,
#   'sequences': 2},
#  '1590.290': {'GC': 45.74,
#   'Mb': 2.720468,
#   'Model_ID': '1590.290',
#   'Ns': 10,
#   'contigs': 24,
#   'sequences': 24},
#  '29397.9': {'GC': 49.06,
#   'Mb': 1.914683,
#   'Model_ID': '29397.9',
#   'Ns': 65828,
#   'contigs': 23,
#   'sequences': 23},
#  '575595.3': {'GC': 37.6,
#   'Mb': 1.846614,
#   'Model_ID': '575595.3',
#   'Ns': 0,
#   'contigs': 30,
#   'sequences': 30},
#  '1580.134': {'GC': 46.24,
#   'Mb': 2.467315,
#   'Model_ID': '1580.134',
#   'Ns': 0,
#   'contigs': 198,
#   'sequences': 198},
#  '1580.130': {'GC': 46.24,
#   'Mb': 2.417691,
#   'Model_ID': '1580.130',
#   'Ns': 0,
#   'contigs': 173,
#   'sequences': 173},
#  '1580.131': {'GC': 46.27,
#   'Mb': 2.436984,
#   'Model_ID': '1580.131',
#   'Ns': 0,
#   'contigs': 192,
#   'sequences': 192},
#  '1580.132': {'GC': 46.82,
#   'Mb': 2.17738,
#   'Model_ID': '1580.132',
#   'Ns': 0,
#   'contigs': 144,
#   'sequences': 144},
#  '1580.133': {'GC': 46.41,
#   'Mb': 2.378765,
#   'Model_ID': '1580.133',
#   'Ns': 0,
#   'contigs': 181,
#   'sequences': 181},
#  '575597.3': {'GC': 37.59,
#   'Mb': 1.967391,
#   'Model_ID': '575597.3',
#   'Ns': 0,
#   'contigs': 76,
#   'sequences': 76},
#  '1226676.3': {'GC': 35.23,
#   'Mb': 1.818187,
#   'Model_ID': '1226676.3',
#   'Ns': 0,
#   'contigs': 45,
#   'sequences': 45},
#  '722911.3': {'GC': 60.91,
#   'Mb': 2.083155,
#   'Model_ID': '722911.3',
#   'Ns': 0,
#   'contigs': 1,
#   'sequences': 1},
#  '1293597.3': {'GC': 49.41,
#   'Mb': 1.741492,
#   'Model_ID': '1293597.3',
#   'Ns': 0,
#   'contigs': 114,
#   'sequences': 114},
#  '1293597.4': {'GC': 49.25,
#   'Mb': 1.818559,
#   'Model_ID': '1293597.4',
#   'Ns': 102,
#   'contigs': 182,
#   'sequences': 182},
#  '1400520.3': {'GC': 46.02,
#   'Mb': 2.971751,
#   'Model_ID': '1400520.3',
#   'Ns': 1,
#   'contigs': 111,
#   'sequences': 111},
#  '1598.146': {'GC': 39.65,
#   'Mb': 1.829203,
#   'Model_ID': '1598.146',
#   'Ns': 0,
#   'contigs': 45,
#   'sequences': 45},
#  '405566.6': {'GC': 37.96,
#   'Mb': 1.805426,
#   'Model_ID': '405566.6',
#   'Ns': 0,
#   'contigs': 1,
#   'sequences': 1},
#  '1682.30': {'GC': 60.46,
#   'Mb': 2.338496,
#   'Model_ID': '1682.30',
#   'Ns': 8123,
#   'contigs': 44,
#   'sequences': 44},
#  '1682.32': {'GC': 60.24,
#   'Mb': 2.32722,
#   'Model_ID': '1682.32',
#   'Ns': 19,
#   'contigs': 26,
#   'sequences': 26},
#  '391904.20': {'GC': 60.84,
#   'Mb': 2.376357,
#   'Model_ID': '391904.20',
#   'Ns': 0,
#   'contigs': 176,
#   'sequences': 176},
#  '1365959.3': {'GC': 60.87,
#   'Mb': 1.768405,
#   'Model_ID': '1365959.3',
#   'Ns': 293,
#   'contigs': 10,
#   'sequences': 10},
#  '1685.167': {'GC': 59.59,
#   'Mb': 2.074207,
#   'Model_ID': '1685.167',
#   'Ns': 198,
#   'contigs': 16,
#   'sequences': 16},
#  '33960.6': {'GC': 47.3,
#   'Mb': 3.097859,
#   'Model_ID': '33960.6',
#   'Ns': 0,
#   'contigs': 127,
#   'sequences': 127},
#  '555970.3': {'GC': 61.47,
#   'Mb': 1.677497,
#   'Model_ID': '555970.3',
#   'Ns': 0,
#   'contigs': 1,
#   'sequences': 1},
#  '1403312.3': {'GC': 35.47,
#   'Mb': 1.849837,
#   'Model_ID': '1403312.3',
#   'Ns': 0,
#   'contigs': 2,
#   'sequences': 2},
#  '1681.43': {'GC': 63.32,
#   'Mb': 1.884154,
#   'Model_ID': '1681.43',
#   'Ns': 9919,
#   'contigs': 16,
#   'sequences': 16},
#  '1681.42': {'GC': 63.42,
#   'Mb': 1.944498,
#   'Model_ID': '1681.42',
#   'Ns': 0,
#   'contigs': 1,
#   'sequences': 1},
#  '1681.45': {'GC': 63.48,
#   'Mb': 1.925157,
#   'Model_ID': '1681.45',
#   'Ns': 0,
#   'contigs': 2,
#   'sequences': 2},
#  '1681.44': {'GC': 63.45,
#   'Mb': 1.909526,
#   'Model_ID': '1681.44',
#   'Ns': 1,
#   'contigs': 17,
#   'sequences': 17},
#  '1681.47': {'GC': 63.64,
#   'Mb': 1.981578,
#   'Model_ID': '1681.47',
#   'Ns': 2,
#   'contigs': 17,
#   'sequences': 17},
#  '1681.46': {'GC': 63.76,
#   'Mb': 2.067245,
#   'Model_ID': '1681.46',
#   'Ns': 1,
#   'contigs': 9,
#   'sequences': 9},
#  '1681.49': {'GC': 63.59,
#   'Mb': 1.945318,
#   'Model_ID': '1681.49',
#   'Ns': 0,
#   'contigs': 6,
#   'sequences': 6},
#  '1681.48': {'GC': 63.68,
#   'Mb': 1.910038,
#   'Model_ID': '1681.48',
#   'Ns': 1,
#   'contigs': 15,
#   'sequences': 15},
# ...
#   'sequences': 17},
#  '1680.43': {'GC': 59.89,
#   'Mb': 1.985749,
#   'Model_ID': '1680.43',
#   'Ns': 12,
#   'contigs': 12,
#   'sequences': 12},
#  '1680.40': {'GC': 60.79,
#   'Mb': 2.170847,
#   'Model_ID': '1680.40',
#   'Ns': 11,
#   'contigs': 26,
#   'sequences': 26},
#  '1680.41': {'GC': 60.13,
#   'Mb': 2.166996,
#   'Model_ID': '1680.41',
#   'Ns': 19,
#   'contigs': 33,
#   'sequences': 33},
#  '1680.46': {'GC': 60.72,
#   'Mb': 1.925592,
#   'Model_ID': '1680.46',
#   'Ns': 7,
#   'contigs': 33,
#   'sequences': 33},
#  '1680.44': {'GC': 60.14,
#   'Mb': 1.886444,
#   'Model_ID': '1680.44',
#   'Ns': 0,
#   'contigs': 8,
#   'sequences': 8},
#  '1680.45': {'GC': 60.28,
#   'Mb': 1.855213,
#   'Model_ID': '1680.45',
#   'Ns': 0,
#   'contigs': 7,
#   'sequences': 7},
#  '1590.210': {'GC': 45.53,
#   'Mb': 2.709476,
#   'Model_ID': '1590.210',
#   'Ns': 0,
#   'contigs': 190,
#   'sequences': 190},
#  '47715.151': {'GC': 47.27,
#   'Mb': 2.631157,
#   'Model_ID': '47715.151',
#   'Ns': 0,
#   'contigs': 114,
#   'sequences': 114},
#  '47715.150': {'GC': 47.47,
#   'Mb': 2.537515,
#   'Model_ID': '47715.150',
#   'Ns': 0,
#   'contigs': 108,
#   'sequences': 108},
#  '47715.153': {'GC': 47.6,
#   'Mb': 2.495904,
#   'Model_ID': '47715.153',
#   'Ns': 0,
#   'contigs': 134,
#   'sequences': 134},
#  '1680.6': {'GC': 60.4,
#   'Mb': 2.027737,
#   'Model_ID': '1680.6',
#   'Ns': 1,
#   'contigs': 145,
#   'sequences': 145},
#  '1446494.3': {'GC': 47.2,
#   'Mb': 2.669951,
#   'Model_ID': '1446494.3',
#   'Ns': 0,
#   'contigs': 5,
#   'sequences': 5},
#  '47715.154': {'GC': 47.5,
#   'Mb': 2.490194,
#   'Model_ID': '47715.154',
#   'Ns': 0,
#   'contigs': 148,
#   'sequences': 148},
#  '29397.19': {'GC': 49.52,
#   'Mb': 2.41962,
#   'Model_ID': '29397.19',
#   'Ns': 0,
#   'contigs': 1,
#   'sequences': 1},
#  '47715.156': {'GC': 47.38,
#   'Mb': 2.643288,
#   'Model_ID': '47715.156',
#   'Ns': 0,
#   'contigs': 92,
#   'sequences': 92},
#  '29397.17': {'GC': 49.4,
#   'Mb': 2.867423,
#   'Model_ID': '29397.17',
#   'Ns': 0,
#   'contigs': 5,
#   'sequences': 5},
#  '29397.16': {'GC': 51.24,
#   'Mb': 1.972563,
#   'Model_ID': '29397.16',
#   'Ns': 0,
#   'contigs': 1,
#   'sequences': 1},
#  '29397.15': {'GC': 49.6,
#   'Mb': 2.48322,
#   'Model_ID': '29397.15',
#   'Ns': 0,
#   'contigs': 1,
#   'sequences': 1},
#  '1457186.3': {'GC': 61.0,
#   'Mb': 2.193108,
#   'Model_ID': '1457186.3',
#   'Ns': 107,
#   'contigs': 39,
#   'sequences': 39},
#  '29397.11': {'GC': 51.07,
#   'Mb': 1.800115,
#   'Model_ID': '29397.11',
#   'Ns': 6640,
#   'contigs': 10,
#   'sequences': 10},
#  '29397.10': {'GC': 47.72,
#   'Mb': 1.881633,
#   'Model_ID': '29397.10',
#   'Ns': 120459,
#   'contigs': 75,
#   'sequences': 75},
#  '1285582.4': {'GC': 41.71,
#   'Mb': 1.814108,
#   'Model_ID': '1285582.4',
#   'Ns': 0,
#   'contigs': 39,
#   'sequences': 39},
#  '1679.29': {'GC': 60.66,
#   'Mb': 2.013798,
#   'Model_ID': '1679.29',
#   'Ns': 0,
#   'contigs': 40,
#   'sequences': 40},
#  '1679.20': {'GC': 61.22,
#   'Mb': 2.394189,
#   'Model_ID': '1679.20',
#   'Ns': 0,
#   'contigs': 80,
#   'sequences': 80},
#  '1679.21': {'GC': 60.9,
#   'Mb': 2.821212,
#   'Model_ID': '1679.21',
#   'Ns': 0,
#   'contigs': 71,
#   'sequences': 71},
#  '1679.22': {'GC': 60.86,
#   'Mb': 2.376909,
#   'Model_ID': '1679.22',
#   'Ns': 0,
#   'contigs': 49,
#   'sequences': 49},
#  '1679.23': {'GC': 60.84,
#   'Mb': 2.33074,
#   'Model_ID': '1679.23',
#   'Ns': 0,
#   'contigs': 85,
#   'sequences': 85},
#  '1679.24': {'GC': 61.08,
#   'Mb': 2.206454,
#   'Model_ID': '1679.24',
#   'Ns': 0,
#   'contigs': 97,
#   'sequences': 97},
#  '1679.26': {'GC': 61.06,
#   'Mb': 2.191865,
#   'Model_ID': '1679.26',
#   'Ns': 0,
#   'contigs': 1,
#   'sequences': 1},
#  '911598.3': {'GC': 61.48,
#   'Mb': 1.706997,
#   'Model_ID': '911598.3',
#   'Ns': 0,
#   'contigs': 7,
#   'sequences': 7},
#  '1256229.3': {'GC': 46.98,
#   'Mb': 2.599891,
#   'Model_ID': '1256229.3',
#   'Ns': 0,
#   'contigs': 141,
#   'sequences': 141},
#  '585520.12': {'GC': 37.53,
#   'Mb': 1.618806,
#   'Model_ID': '585520.12',
#   'Ns': 473,
#   'contigs': 257,
#   'sequences': 257},
#  '1580.119': {'GC': 46.26,
#   'Mb': 2.609639,
#   'Model_ID': '1580.119',
#   'Ns': 0,
#   'contigs': 9,
#   'sequences': 9},
#  '1423783.5': {'GC': 53.7,
#   'Mb': 2.123646,
#   'Model_ID': '1423783.5',
#   'Ns': 0,
#   'contigs': 197,
#   'sequences': 197},
#  '1423783.4': {'GC': 53.74,
#   'Mb': 2.172784,
#   'Model_ID': '1423783.4',
#   'Ns': 3036,
#   'contigs': 62,
#   'sequences': 62},
#  '1423783.3': {'GC': 53.88,
#   'Mb': 2.119943,
#   'Model_ID': '1423783.3',
#   'Ns': 0,
#   'contigs': 81,
#   'sequences': 81},
#  '1597.46': {'GC': 46.94,
#   'Mb': 2.733811,
#   'Model_ID': '1597.46',
#   'Ns': 0,
#   'contigs': 138,
#   'sequences': 138},
#  '1715100.3': {'GC': 47.17,
#   'Mb': 2.53857,
#   'Model_ID': '1715100.3',
#   'Ns': 11014,
#   'contigs': 61,
#   'sequences': 61},
#  '1423795.4': {'GC': 43.86,
#   'Mb': 2.416882,
#   'Model_ID': '1423795.4',
#   'Ns': 0,
#   'contigs': 105,
#   'sequences': 105},
#  '1423795.5': {'GC': 43.86,
#   'Mb': 2.486149,
#   'Model_ID': '1423795.5',
#   'Ns': 426,
#   'contigs': 87,
#   'sequences': 87},
#  '1624.26': {'GC': 33.32,
#   'Mb': 1.647092,
#   'Model_ID': '1624.26',
#   'Ns': 301,
#   'contigs': 111,
#   'sequences': 111},
#  '1624.27': {'GC': 33.29,
#   'Mb': 1.767645,
#   'Model_ID': '1624.27',
#   'Ns': 0,
#   'contigs': 117,
#   'sequences': 117},
#  '1122147.3': {'GC': 54.09,
#   'Mb': 2.796386,
#   'Model_ID': '1122147.3',
#   'Ns': 0,
#   'contigs': 103,
#   'sequences': 103},
#  '1624.28': {'GC': 33.36,
#   'Mb': 1.746718,
#   'Model_ID': '1624.28',
#   'Ns': 100,
#   'contigs': 56,
#   'sequences': 56},
#  '1423725.3': {'GC': 38.46,
#   'Mb': 2.088322,
#   'Model_ID': '1423725.3',
#   'Ns': 876,
#   'contigs': 36,
#   'sequences': 36},
#  '1122147.4': {'GC': 53.86,
#   'Mb': 2.851052,
#   'Model_ID': '1122147.4',
#   'Ns': 690,
#   'contigs': 164,
#   'sequences': 164},
#  '47770.36': {'GC': 37.25,
#   'Mb': 2.145356,
#   'Model_ID': '47770.36',
#   'Ns': 1500,
#   'contigs': 215,
#   'sequences': 215},
#  '47770.37': {'GC': 37.7,
#   'Mb': 1.882603,
#   'Model_ID': '47770.37',
#   'Ns': 16,
#   'contigs': 7,
#   'sequences': 7},
#  '1597.27': {'GC': 46.88,
#   'Mb': 2.856504,
#   'Model_ID': '1597.27',
#   'Ns': 217,
#   'contigs': 146,
#   'sequences': 146},
#  '1597.26': {'GC': 46.82,
#   'Mb': 2.897144,
#   'Model_ID': '1597.26',
#   'Ns': 401,
#   'contigs': 115,
#   'sequences': 115},
#  '47770.32': {'GC': 37.43,
#   'Mb': 1.917887,
#   'Model_ID': '47770.32',
#   'Ns': 0,
#   'contigs': 247,
#   'sequences': 247},
#  '1597.20': {'GC': 47.09,
#   'Mb': 2.801735,
#   'Model_ID': '1597.20',
#   'Ns': 1,
#   'contigs': 1,
#   'sequences': 1},
#  '47770.30': {'GC': 37.59,
#   'Mb': 2.146851,
#   'Model_ID': '47770.30',
#   'Ns': 0,
#   'contigs': 253,
#   'sequences': 253},
#  '47770.31': {'GC': 37.61,
#   'Mb': 2.069318,
#   'Model_ID': '47770.31',
#   'Ns': 12,
#   'contigs': 259,
#   'sequences': 259},
#  '1597.28': {'GC': 47.32,
#   'Mb': 2.732004,
#   'Model_ID': '1597.28',
#   'Ns': 0,
#   'contigs': 1,
#   'sequences': 1},
#  '1605.14': {'GC': 42.0,
#   'Mb': 1.849081,
#   'Model_ID': '1605.14',
#   'Ns': 0,
#   'contigs': 87,
#   'sequences': 87},
#  '491076.4': {'GC': 37.81,
#   'Mb': 1.795377,
#   'Model_ID': '491076.4',
#   'Ns': 0,
#   'contigs': 86,
#   'sequences': 86},
#  '947827.8': {'GC': 37.24,
#   'Mb': 1.9838,
#   'Model_ID': '947827.8',
#   'Ns': 16,
#   'contigs': 593,
#   'sequences': 593},
#  '1437597.3': {'GC': 60.93,
#   'Mb': 2.092215,
#   'Model_ID': '1437597.3',
#   'Ns': 0,
#   'contigs': 129,
#   'sequences': 129},
#  '47715.67': {'GC': 47.56,
#   'Mb': 2.542072,
#   'Model_ID': '47715.67',
#   'Ns': 0,
#   'contigs': 90,
#   'sequences': 90},
#  '1423721.4': {'GC': 44.63,
#   'Mb': 1.406259,
#   'Model_ID': '1423721.4',
#   'Ns': 87,
#   'contigs': 33,
#   'sequences': 33},
#  '1423721.7': {'GC': 44.66,
#   'Mb': 1.553543,
#   'Model_ID': '1423721.7',
#   'Ns': 0,
#   'contigs': 1,
#   'sequences': 1},
#  '1423721.3': {'GC': 44.8,
#   'Mb': 1.327143,
#   'Model_ID': '1423721.3',
#   'Ns': 0,
#   'contigs': 31,
#   'sequences': 31},
#  '1046599.3': {'GC': 40.27,
#   'Mb': 1.902775,
#   'Model_ID': '1046599.3',
#   'Ns': 0,
#   'contigs': 487,
#   'sequences': 487},
#  '1122149.3': {'GC': 41.83,
#   'Mb': 1.834353,
#   'Model_ID': '1122149.3',
#   'Ns': 21,
#   'contigs': 152,
#   'sequences': 152},
#  '152331.32': {'GC': 44.29,
#   'Mb': 2.29739,
#   'Model_ID': '152331.32',
#   'Ns': 285,
#   'contigs': 65,
#   'sequences': 65},
#  '205913.6': {'GC': 61.19,
#   'Mb': 2.062868,
#   'Model_ID': '205913.6',
#   'Ns': 0,
#   'contigs': 3,
#   'sequences': 3},
#  '2042042.3': {'GC': 41.04,
#   'Mb': 1.754385,
#   'Model_ID': '2042042.3',
#   'Ns': 0,
#   'contigs': 151,
#   'sequences': 151},
#  '1423733.3': {'GC': 47.58,
#   'Mb': 2.87706,
#   'Model_ID': '1423733.3',
#   'Ns': 0,
#   'contigs': 114,
#   'sequences': 114},
#  '1423733.4': {'GC': 47.46,
#   'Mb': 2.999191,
#   'Model_ID': '1423733.4',
#   'Ns': 977,
#   'contigs': 130,
#   'sequences': 130},
#  '1256221.3': {'GC': 47.16,
#   'Mb': 2.361318,
#   'Model_ID': '1256221.3',
#   'Ns': 0,
#   'contigs': 270,
#   'sequences': 270},
#  '1423717.3': {'GC': 35.29,
#   'Mb': 1.76411,
#   'Model_ID': '1423717.3',
#   'Ns': 381,
#   'contigs': 30,
#   'sequences': 30},
#  '1423717.5': {'GC': 35.31,
#   'Mb': 1.775965,
#   'Model_ID': '1423717.5',
#   'Ns': 0,
#   'contigs': 18,
#   'sequences': 18},
#  '1681.107': {'GC': 63.52,
#   'Mb': 1.954586,
#   'Model_ID': '1681.107',
#   'Ns': 0,
#   'contigs': 140,
#   'sequences': 140},
#  '1681.106': {'GC': 63.61,
#   'Mb': 2.001982,
#   'Model_ID': '1681.106',
#   'Ns': 0,
#   'contigs': 157,
#   'sequences': 157},
#  '1681.105': {'GC': 63.51,
#   'Mb': 1.957708,
#   'Model_ID': '1681.105',
#   'Ns': 0,
#   'contigs': 139,
#   'sequences': 139},
#  '1423715.3': {'GC': 52.94,
#   'Mb': 2.538141,
#   'Model_ID': '1423715.3',
#   'Ns': 500,
#   'contigs': 30,
#   'sequences': 30},
#  '1681.103': {'GC': 63.49,
#   'Mb': 1.954175,
#   'Model_ID': '1681.103',
#   'Ns': 0,
#   'contigs': 63,
#   'sequences': 63},
#  '1681.102': {'GC': 63.54,
#   'Mb': 1.955403,
#   'Model_ID': '1681.102',
#   'Ns': 0,
#   'contigs': 160,
#   'sequences': 160},
#  '1599.70': {'GC': 42.06,
#   'Mb': 1.883727,
#   'Model_ID': '1599.70',
#   'Ns': 0,
#   'contigs': 2,
#   'sequences': 2},
#  '1599.71': {'GC': 42.19,
#   'Mb': 1.877682,
#   'Model_ID': '1599.71',
#   'Ns': 0,
#   'contigs': 3,
#   'sequences': 3},
#  '1599.72': {'GC': 41.93,
#   'Mb': 1.912312,
#   'Model_ID': '1599.72',
#   'Ns': 0,
#   'contigs': 4,
#   'sequences': 4},
#  '2042036.3': {'GC': 37.82,
#   'Mb': 1.863891,
#   'Model_ID': '2042036.3',
#   'Ns': 0,
#   'contigs': 103,
#   'sequences': 103},
#  '1423719.4': {'GC': 36.72,
#   'Mb': 1.436212,
#   'Model_ID': '1423719.4',
#   'Ns': 2,
#   'contigs': 28,
#   'sequences': 28},
#  '1590.75': {'GC': 45.5,
#   'Mb': 2.928264,
#   'Model_ID': '1590.75',
#   'Ns': 0,
#   'contigs': 47,
#   'sequences': 47},
#  '1590.74': {'GC': 45.69,
#   'Mb': 2.84302,
#   'Model_ID': '1590.74',
#   'Ns': 0,
#   'contigs': 18,
#   'sequences': 18},
#  '1423822.8': {'GC': 44.06,
#   'Mb': 3.168647,
#   'Model_ID': '1423822.8',
#   'Ns': 0,
#   'contigs': 5,
#   'sequences': 5},
#  '1423822.7': {'GC': 43.96,
#   'Mb': 2.417672,
#   'Model_ID': '1423822.7',
#   'Ns': 812,
#   'contigs': 410,
#   'sequences': 410},
#  '518634.7': {'GC': 59.76,
#   'Mb': 2.000239,
#   'Model_ID': '518634.7',
#   'Ns': 0,
#   'contigs': 117,
#   'sequences': 117},
#  '767456.3': {'GC': 37.84,
#   'Mb': 1.811396,
#   'Model_ID': '767456.3',
#   'Ns': 0,
#   'contigs': 1,
#   'sequences': 1},
#  '649758.4': {'GC': 46.83,
#   'Mb': 2.178583,
#   'Model_ID': '649758.4',
#   'Ns': 3562,
#   'contigs': 11,
#   'sequences': 11},
#  '2042040.3': {'GC': 39.67,
#   'Mb': 1.858189,
#   'Model_ID': '2042040.3',
#   'Ns': 2,
#   'contigs': 156,
#   'sequences': 156},
#  '109790.33': {'GC': 35.29,
#   'Mb': 1.595946,
#   'Model_ID': '109790.33',
#   'Ns': 0,
#   'contigs': 1,
#   'sequences': 1},
#  '109790.30': {'GC': 34.96,
#   'Mb': 1.585579,
#   'Model_ID': '109790.30',
#   'Ns': 0,
#   'contigs': 69,
#   'sequences': 69},
#  '879300.3': {'GC': 33.01,
#   'Mb': 1.169892,
#   'Model_ID': '879300.3',
#   'Ns': 0,
#   'contigs': 27,
#   'sequences': 27},
#  '548485.3': {'GC': 39.59,
#   'Mb': 1.666594,
#   'Model_ID': '548485.3',
#   'Ns': 0,
#   'contigs': 71,
#   'sequences': 71},
#  '1051656.3': {'GC': 47.01,
#   'Mb': 2.658268,
#   'Model_ID': '1051656.3',
#   'Ns': 0,
#   'contigs': 150,
#   'sequences': 150},
#  '2042032.3': {'GC': 37.71,
#   'Mb': 1.857902,
#   'Model_ID': '2042032.3',
#   'Ns': 0,
#   'contigs': 130,
#   'sequences': 130},
#  '1590.240': {'GC': 45.49,
#   'Mb': 2.831035,
#   'Model_ID': '1590.240',
#   'Ns': 0,
#   'contigs': 66,
#   'sequences': 66},
#  '1739365.3': {'GC': 48.58,
#   'Mb': 2.628226,
#   'Model_ID': '1739365.3',
#   'Ns': 14900,
#   'contigs': 139,
#   'sequences': 139},
#  '2042034.3': {'GC': 39.65,
#   'Mb': 1.840278,
#   'Model_ID': '2042034.3',
#   'Ns': 0,
#   'contigs': 240,
#   'sequences': 240},
#  '1051654.3': {'GC': 47.01,
#   'Mb': 2.805968,
#   'Model_ID': '1051654.3',
#   'Ns': 1,
#   'contigs': 57,
#   'sequences': 57},
#  '83684.7': {'GC': 50.99,
#   'Mb': 1.972205,
#   'Model_ID': '83684.7',
#   'Ns': 0,
#   'contigs': 1,
#   'sequences': 1},
#  '1051658.3': {'GC': 46.9,
#   'Mb': 2.636868,
#   'Model_ID': '1051658.3',
#   'Ns': 2,
#   'contigs': 55,
#   'sequences': 55},
#  '2042038.3': {'GC': 33.83,
#   'Mb': 1.982624,
#   'Model_ID': '2042038.3',
#   'Ns': 0,
#   'contigs': 229,
#   'sequences': 229},
#  '220668.9': {'GC': 45.61,
#   'Mb': 2.824535,
#   'Model_ID': '220668.9',
#   'Ns': 0,
#   'contigs': 4,
#   'sequences': 4},
#  '216816.152': {'GC': 66.12,
#   'Mb': 0.002376,
#   'Model_ID': '216816.152',
#   'Ns': 0,
#   'contigs': 1,
#   'sequences': 1},
#  '557436.17': {'GC': 39.49,
#   'Mb': 1.722319,
#   'Model_ID': '557436.17',
#   'Ns': 180,
#   'contigs': 150,
#   'sequences': 150},
#  '1168290.3': {'GC': 61.43,
#   'Mb': 1.713485,
#   'Model_ID': '1168290.3',
#   'Ns': 0,
#   'contigs': 1,
#   'sequences': 1},
#  '1600.4': {'GC': 37.83,
#   'Mb': 1.67679,
#   'Model_ID': '1600.4',
#   'Ns': 0,
#   'contigs': 1,
#   'sequences': 1},
#  '1600.6': {'GC': 37.1,
#   'Mb': 1.373067,
#   'Model_ID': '1600.6',
#   'Ns': 6850,
#   'contigs': 96,
#   'sequences': 96},
#  '47715.142': {'GC': 47.39,
#   'Mb': 2.62681,
#   'Model_ID': '47715.142',
#   'Ns': 0,
#   'contigs': 91,
#   'sequences': 91},
#  '47715.143': {'GC': 47.43,
#   'Mb': 2.598542,
#   'Model_ID': '47715.143',
#   'Ns': 0,
#   'contigs': 57,
#   'sequences': 57},
#  '47715.140': {'GC': 47.32,
#   'Mb': 2.65291,
#   'Model_ID': '47715.140',
#   'Ns': 0,
#   'contigs': 56,
#   'sequences': 56},
#  '47715.141': {'GC': 47.28,
#   'Mb': 2.646974,
#   'Model_ID': '47715.141',
#   'Ns': 0,
#   'contigs': 390,
#   'sequences': 390},
#  '47715.146': {'GC': 47.37,
#   'Mb': 2.582912,
#   'Model_ID': '47715.146',
#   'Ns': 0,
#   'contigs': 93,
#   'sequences': 93},
#  '47715.147': {'GC': 47.44,
#   'Mb': 2.573309,
#   'Model_ID': '47715.147',
#   'Ns': 0,
#   'contigs': 131,
#   'sequences': 131},
#  '47715.144': {'GC': 47.39,
#   'Mb': 2.631016,
#   'Model_ID': '47715.144',
#   'Ns': 0,
#   'contigs': 52,
#   'sequences': 52},
#  '47715.145': {'GC': 47.41,
#   'Mb': 2.588259,
#   'Model_ID': '47715.145',
#   'Ns': 0,
#   'contigs': 59,
#   'sequences': 59},
#  '47715.148': {'GC': 47.42,
#   'Mb': 2.54793,
#   'Model_ID': '47715.148',
#   'Ns': 0,
#   'contigs': 52,
#   'sequences': 52},
#  '47715.149': {'GC': 47.44,
#   'Mb': 2.436233,
#   'Model_ID': '47715.149',
#   'Ns': 0,
#   'contigs': 471,
#   'sequences': 471},
#  '1679.14': {'GC': 60.82,
#   'Mb': 2.211597,
#   'Model_ID': '1679.14',
#   'Ns': 0,
#   'contigs': 77,
#   'sequences': 77},
#  '1679.11': {'GC': 60.77,
#   'Mb': 2.014963,
#   'Model_ID': '1679.11',
#   'Ns': 0,
#   'contigs': 31,
#   'sequences': 31},
#  '1679.10': {'GC': 61.0,
#   'Mb': 2.221927,
#   'Model_ID': '1679.10',
#   'Ns': 0,
#   'contigs': 1,
#   'sequences': 1},
#  '1679.13': {'GC': 60.52,
#   'Mb': 2.090706,
#   'Model_ID': '1679.13',
#   'Ns': 424,
#   'contigs': 29,
#   'sequences': 29},
#  '1679.12': {'GC': 60.77,
#   'Mb': 2.016155,
#   'Model_ID': '1679.12',
#   'Ns': 38,
#   'contigs': 36,
#   'sequences': 36},
#  '240427.19': {'GC': 48.1,
#   'Mb': 2.916283,
#   'Model_ID': '240427.19',
#   'Ns': 0,
#   'contigs': 3,
#   'sequences': 3},
#  '47715.115': {'GC': 47.34,
#   'Mb': 2.639431,
#   'Model_ID': '47715.115',
#   'Ns': 100,
#   'contigs': 319,
#   'sequences': 319},
#  '47715.114': {'GC': 47.37,
#   'Mb': 2.586275,
#   'Model_ID': '47715.114',
#   'Ns': 0,
#   'contigs': 192,
#   'sequences': 192},
#  '1312920.5': {'GC': 46.94,
#   'Mb': 2.852103,
#   'Model_ID': '1312920.5',
#   'Ns': 2401,
#   'contigs': 2,
#   'sequences': 2},
#  '47715.116': {'GC': 47.37,
#   'Mb': 2.662657,
#   'Model_ID': '47715.116',
#   'Ns': 0,
#   'contigs': 167,
#   'sequences': 167},
#  '33961.3': {'GC': 39.72,
#   'Mb': 1.258855,
#   'Model_ID': '33961.3',
#   'Ns': 33,
#   'contigs': 21,
#   'sequences': 21},
#  '1678.111': {'GC': 59.86,
#   'Mb': 2.375816,
#   'Model_ID': '1678.111',
#   'Ns': 0,
#   'contigs': 1,
#   'sequences': 1},
#  ...}

# %%
def species_gc_plot(species_of_interest, species_dict, total_dataset_dict):
    genome_id_int = []
    for key in species_dict.keys():
        if species_dict[key] == species_of_interest:
            genome_id_int.append(key)
    GC_content = []
    for genome_id in set(genome_id_int):
#         if genome_id == '1579.33' or genome_id == '29397.12' or genome_id == '1613.113' or genome_id == '47715.249':
#             continue
        try:
            GC_content.append(total_dataset_dict[genome_id]['GC'])
        except:
            pass
    ref_GC = np.median(GC_content)
#     q75, q25 = np.percentile(GC_content, [90 ,10])
#     iqr = q75 - q25
    
    num_removed = 0
    species_GC_spread = []
    remaining_genomes = []
    with open('../Data/All_meta_data.csv','r') as csvfile:
        line_count = 0
        for line in csvfile:
            if line_count == 0:
                line_count = 1
                continue
            genome_id = str(line.strip()).split(",")[0]
            species_in_question = str(line.strip()).split(",")[3]
            if species_in_question == species_of_interest:
                try:
                    temp_GC = total_dataset_dict[genome_id]['GC']
                    if ref_GC-2 <= temp_GC <= ref_GC+2:
#                     if q25 <= temp_GC <= q75:
                        species_GC_spread.append(temp_GC)
                        remaining_genomes.append(genome_id)
                    else:
                        num_removed = num_removed + 1
                except:
                    pass
    
    plt.hist(species_GC_spread, list(frange(30,65,0.5)), range=(30,65)) #
    plt.title(species_of_interest + " GC spread: Reference = " + str(ref_GC))
    plt.text(30,2,"Removed:"+str(num_removed))
    plt.show()
    
    return(remaining_genomes)

# %%
fasta_file_paths = glob.glob('../nt_fastas/*.faa')
fasta_genome_ids = [x.replace("../nt_fastas/","").replace(".faa","") for x in fasta_file_paths]

Mbs = []
contigs = []
sequences = []
GC_content = []
Ns_all = []
percent_n = []
complete_genomes = []

for genome_id in fasta_genome_ids:
    try:
        mb_temp = total_dataset_dict[genome_id]['Mb']
        Mbs.append(mb_temp)
        sequences.append(total_dataset_dict[genome_id]['sequences'])
        GC_content.append(total_dataset_dict[genome_id]['GC'])
        n_temp = total_dataset_dict[genome_id]['Ns']
        Ns_all.append(n_temp)
        percent_n_temp = round(n_temp/(mb_temp*1000000), 4)
        percent_n.append(percent_n_temp)
#         if total_dataset_dict[genome_id]['sequences'] == 1:
#             complete_genomes.append(genome_id)
    except:
        pass

# Read in Meta
with open('../Data/All_meta_data.csv','r') as csvfile:
    species_dict = {}
    line_count = 0
    for line in csvfile:
        if line_count == 0:
            line_count = 1
            continue
        species_dict[str(line.strip()).split(",")[0]] = str(line.strip()).split(",")[3]

# species_w_refs = []
# for key in species_dict.keys():
#     species_w_refs.append(species_dict[key])
# species_w_refs = set(species_w_refs)

all_species = []
for key in species_dict.keys():
    all_species.append(species_dict[key])
all_species = set(all_species)

genomes_after_gc = []
for species_of_interest in all_species:
    output = species_gc_plot(species_of_interest, species_dict, total_dataset_dict)
    genomes_after_gc = genomes_after_gc+output

# %%
len(species_dict)
# Out:
# 1397

# %%
len(all_species)
# Out:
# 25

# %%
# Genomes After Removing GC Outliers
print(len(genomes_after_gc))
# Out:
# 1334

# %%
# Remove genomes based on N's and contigs
genomes_after_ns = []

for genome_id in genomes_after_gc:
    mb_temp = total_dataset_dict[genome_id]['Mb']
    Mbs.append(mb_temp)
    n_temp = total_dataset_dict[genome_id]['Ns']
    Ns_all.append(n_temp)
    percent_n_temp = round(n_temp/(mb_temp*1000000), 4)
    if percent_n_temp < .002:
        genomes_after_ns = genomes_after_ns+[genome_id]
    else:
        continue
print(len(genomes_after_ns))

# Remove genomes based on contigs
genomes_after_seqs = []

for genome_id in genomes_after_ns:
    if total_dataset_dict[genome_id]['sequences'] <= 300:
        genomes_after_seqs = genomes_after_seqs+[genome_id]
    else:
        continue
print(len(genomes_after_seqs))
# Out:
# 1288
# 1225
